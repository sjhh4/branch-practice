# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import requests
import os
import json

# %%
os.path
# Out:
# <module 'ntpath' from 'C:\\Users\\sjhh4\\.conda\\envs\\ETA3.9\\lib\\ntpath.py'>

# %%
# import json
# with open("Desktop/Python/FastCampus/3주차/metadata/track.json", "r") as json_file:
#     track = json.load(json_file)
# 출처: https://rfriend.tistory.com/474 [R, Python 분석과 프로그래밍의 친구 (by R Friend):티스토리]
# 출처: https://rfriend.tistory.com/474 [R, Python 분석과 프로그래밍의 친구 (by R Friend):티스토리]
# track

# %%
api_key = 'd5q7S0mTkrywR8z9g8PF0lPUV6ToUm33'

# %%
url = 'https://developers.neople.co.kr/contents/apiDocs'

resp = requests.get(url)

resp.text

html = BeautifulSoup(resp.text, 'html.parser')

# %%
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <title>Neople Developers</title>
# <link href="/css/api.css" rel="stylesheet" type="text/css"/>
# <link href="" rel="shortcut icon">
# <script src="/js/jquery.js" type="text/javascript"></script>
# <script src="/js/ui/apinav.js" type="text/javascript"></script>
# <script src="/js/web_common.js" type="text/javascript"></script>
# <script src="/js/ui/local_fix.js" type="text/javascript"></script>
# <script src="/js/ui/stk_slt.js" type="text/javascript"></script>
# <style type="text/css">body{overflow-y:scroll}</style>
# <!--[if lt IE 9]><script type="text/javascript" src="/js/ui/html5.js"></script><![endif]-->
# </link></meta></meta></head>
# <body>
# <div id="wrap">
# <div class="nav">
# ...

# %%
data_nm = []

for i in html.select('li.article a span'):
    data_nm.append(i.text)
data_nm
# Out:
# ['01. 서버 정보',
#  '02. 캐릭터 검색',
#  '03. 캐릭터 `기본 정보` 조회',
#  '04. 캐릭터 `타임라인 정보` 조회',
#  '05.캐릭터 `능력치 정보` 조회',
#  '06. 캐릭터 `장착 장비` 조회',
#  '07. 캐릭터 `장착 아바타` 조회',
#  '08. 캐릭터 `장착 크리쳐` 조회',
#  '09. 캐릭터 `장착 휘장` 조회',
#  '10. 캐릭터 `장착 탈리스만` 조회',
#  '11. 캐릭터 `스킬 스타일` 조회',
#  '12. 캐릭터 `버프 스킬 강화 장착 장비` 조회',
#  '13. 캐릭터 `버프 스킬 강화 장착 아바타` 조회',
#  '14. 캐릭터 `버프 스킬 강화 장착 크리처` 조회',
#  '15. 경매장 등록 아이템 검색',
#  '16. 경매장 등록 아이템 조회',
#  '17. 경매장 시세 검색',
#  '18. 아바타 마켓 상품 검색',
#  '19. 아바타 마켓 상품 조회',
#  '20. 아바타 마켓 상품 시세 검색',
#  '21. 아바타 마켓 상품 시세 조회',
#  '22. 아바타 마켓 해시태그 조회',
#  '23. 아이템 검색',
#  '24. 아이템 상세 정보 조회',
#  '25. 아이템 상점 판매 정보 조회',
#  '26. 다중 아이템 상세 정보 조회',
#  '27. 아이템 해시태그 ',
#  '28. 세트 아이템 검색',
#  '29. 세트 아이템 상세 정보 조회',
#  '30. 다중 세트 아이템 상세 정보 조회',
#  '31. 장비 조합 세트 아이템 활성화 정보 조회',
#  '32. 직업 정보',
#  '33. 직업별 스킬 리스트',
#  '34. 직업별 스킬 상세 정보 조회']

# %%
for i in range(len(data_nm)):
    data_nm[i] = data_nm[i][3:].strip()
    
data_nm
# Out:
# ['서버 정보',
#  '캐릭터 검색',
#  '캐릭터 `기본 정보` 조회',
#  '캐릭터 `타임라인 정보` 조회',
#  '캐릭터 `능력치 정보` 조회',
#  '캐릭터 `장착 장비` 조회',
#  '캐릭터 `장착 아바타` 조회',
#  '캐릭터 `장착 크리쳐` 조회',
#  '캐릭터 `장착 휘장` 조회',
#  '캐릭터 `장착 탈리스만` 조회',
#  '캐릭터 `스킬 스타일` 조회',
#  '캐릭터 `버프 스킬 강화 장착 장비` 조회',
#  '캐릭터 `버프 스킬 강화 장착 아바타` 조회',
#  '캐릭터 `버프 스킬 강화 장착 크리처` 조회',
#  '경매장 등록 아이템 검색',
#  '경매장 등록 아이템 조회',
#  '경매장 시세 검색',
#  '아바타 마켓 상품 검색',
#  '아바타 마켓 상품 조회',
#  '아바타 마켓 상품 시세 검색',
#  '아바타 마켓 상품 시세 조회',
#  '아바타 마켓 해시태그 조회',
#  '아이템 검색',
#  '아이템 상세 정보 조회',
#  '아이템 상점 판매 정보 조회',
#  '다중 아이템 상세 정보 조회',
#  '아이템 해시태그',
#  '세트 아이템 검색',
#  '세트 아이템 상세 정보 조회',
#  '다중 세트 아이템 상세 정보 조회',
#  '장비 조합 세트 아이템 활성화 정보 조회',
#  '직업 정보',
#  '직업별 스킬 리스트',
#  '직업별 스킬 상세 정보 조회']

# %%
# 내가 분석해볼 주제 : 가장 인기 많은 캐릭터는 왜 인기가 많은 것인가? 부제: 캐릭터의 스킬 구성 중심으로.
# 직업 정보, 직업별 스킬 리스트, 직업별 스킬 상세 정보 조회 - 데이터 크롤링 해오고,
# 직업별 인구 분포 데이터를 크롤링 해보자


jobid = ''
skillid = ''

# %%
html.select('#a31 textarea')
# Out:
# [<textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea class="input" style="display:none;">요청변수|유형|설명|필수여부|기본값|최대값
#  -----|----|--------|:------------:|:---------:|:---------:
#  |||||</textarea>]

# %%
url_jobs = 'https://api.neople.co.kr/df/jobs?apikey=d5q7S0mTkrywR8z9g8PF0lPUV6ToUm33'

resp = requests.get(url)

resp.text
# Out:
# '\n\t\n<!DOCTYPE html>\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="description" content="">\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<title>Neople Developers</title>\n<link rel="stylesheet" type="text/css" href="/css/api.css">\n<link rel="shortcut icon" href="" />\n<script type="text/javascript" src="/js/jquery.js"></script>\n<script type="text/javascript" src="/js/ui/apinav.js"></script>\n<script type="text/javascript" src="/js/web_common.js"></script>\n<script type="text/javascript" src="/js/ui/local_fix.js"></script>\n<script type="text/javascript" src="/js/ui/stk_slt.js"></script>\n<style type="text/css">body{overflow-y:scroll}</style>\n<!--[if lt IE 9]><script type="text/javascript" src="/js/ui/html5.js"></script><![endif]-->\n</head>\n<body>\n<div id="wrap">\n\t<div class="nav">\n\t\t<h1><a href="/main"><img src="/img/logo.png" alt="Neople Developers"/></a></h1>\n\t\t<ul>\
# ...

# %%
html = BeautifulSoup(resp.text, 'html.parser')
html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <title>Neople Developers</title>
# <link href="/css/api.css" rel="stylesheet" type="text/css"/>
# <link href="" rel="shortcut icon">
# <script src="/js/jquery.js" type="text/javascript"></script>
# <script src="/js/ui/apinav.js" type="text/javascript"></script>
# <script src="/js/web_common.js" type="text/javascript"></script>
# <script src="/js/ui/local_fix.js" type="text/javascript"></script>
# <script src="/js/ui/stk_slt.js" type="text/javascript"></script>
# <style type="text/css">body{overflow-y:scroll}</style>
# <!--[if lt IE 9]><script type="text/javascript" src="/js/ui/html5.js"></script><![endif]-->
# </link></meta></meta></head>
# <body>
# <div id="wrap">
# <div class="nav">
# ...

# %%
html.select('dd textarea')
# Out:
# [<textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
#  <textarea cols="30" id="" name="requestHeader" rows="10"></textarea>,
#  <textarea cols="30" name="requestBody" rows="10"></textarea>,
# ...

# %%
# 던파는 open API를 사용해야해서 포기!!
# 롤로 변경한다.
# op.gg 사이트의 데이터를 크롤링해보자

url = 'https://www.op.gg/api/statistics/kr/champions/ranked?period=month&tier=all&position='

header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

resp = requests.get(url, headers = header)

html = BeautifulSoup(resp.text, 'html.parser')

# %%
html
# Out:
# {"data":[{"champion_id":81,"play":2354715,"win":1177195,"lose":1177520,"kill":14818470,"death":12308672,"assist":16380854,"cs":409506794,"neutral_cs":26801468,"gold":27597924113,"pick_rate":0.3629,"ban_rate":0.11182255069276738,"ward":3131562},{"champion_id":145,"play":1471276,"win":729144,"lose":742132,"kill":11978605,"death":8216417,"assist":8708327,"cs":270891511,"neutral_cs":22610406,"gold":18958651944,"pick_rate":0.2268,"ban_rate":0.02406387358816002,"ward":2012166},{"champion_id":236,"play":1390190,"win":706335,"lose":683855,"kill":11327400,"death":7970229,"assist":8030624,"cs":254889577,"neutral_cs":20032173,"gold":17300089997,"pick_rate":0.2143,"ban_rate":0.40491030482319357,"ward":2314111},{"champion_id":104,"play":1104690,"win":543973,"lose":560717,"kill":7337448,"death":6052151,"assist":7035585,"cs":83124665,"neutral_cs":127667926,"gold":13661827765,"pick_rate":0.1703,"ban_rate":0.27897578901439263,"ward":3127747},{"champion_id":64,"play":1090727,"win":499817,"lose":590910
# ...

# %%
resp.text
# Out:
# '{"data":[{"champion_id":81,"play":2354715,"win":1177195,"lose":1177520,"kill":14818470,"death":12308672,"assist":16380854,"cs":409506794,"neutral_cs":26801468,"gold":27597924113,"pick_rate":0.3629,"ban_rate":0.11182255069276738,"ward":3131562},{"champion_id":145,"play":1471276,"win":729144,"lose":742132,"kill":11978605,"death":8216417,"assist":8708327,"cs":270891511,"neutral_cs":22610406,"gold":18958651944,"pick_rate":0.2268,"ban_rate":0.02406387358816002,"ward":2012166},{"champion_id":236,"play":1390190,"win":706335,"lose":683855,"kill":11327400,"death":7970229,"assist":8030624,"cs":254889577,"neutral_cs":20032173,"gold":17300089997,"pick_rate":0.2143,"ban_rate":0.40491030482319357,"ward":2314111},{"champion_id":104,"play":1104690,"win":543973,"lose":560717,"kill":7337448,"death":6052151,"assist":7035585,"cs":83124665,"neutral_cs":127667926,"gold":13661827765,"pick_rate":0.1703,"ban_rate":0.27897578901439263,"ward":3127747},{"champion_id":64,"play":1090727,"win":499817,"lose":59091
# ...

# %%
data = json.loads(resp.text)
data = data['data']
data
# Out:
# [{'champion_id': 81,
#   'play': 2354715,
#   'win': 1177195,
#   'lose': 1177520,
#   'kill': 14818470,
#   'death': 12308672,
#   'assist': 16380854,
#   'cs': 409506794,
#   'neutral_cs': 26801468,
#   'gold': 27597924113,
#   'pick_rate': 0.3629,
#   'ban_rate': 0.11182255069276738,
#   'ward': 3131562},
#  {'champion_id': 145,
#   'play': 1471276,
#   'win': 729144,
#   'lose': 742132,
#   'kill': 11978605,
#   'death': 8216417,
#   'assist': 8708327,
#   'cs': 270891511,
#   'neutral_cs': 22610406,
#   'gold': 18958651944,
#   'pick_rate': 0.2268,
#   'ban_rate': 0.02406387358816002,
#   'ward': 2012166},
#  {'champion_id': 236,
#   'play': 1390190,
#   'win': 706335,
#   'lose': 683855,
#   'kill': 11327400,
#   'death': 7970229,
#   'assist': 8030624,
#   'cs': 254889577,
#   'neutral_cs': 20032173,
#   'gold': 17300089997,
#   'pick_rate': 0.2143,
#   'ban_rate': 0.40491030482319357,
#   'ward': 2314111},
#  {'champion_id': 104,
#   'play': 1104690,
#   'win': 543973,
# ...

# %%
data = pd.DataFrame(data)
data
# Out:
#      champion_id     play      win     lose      kill     death    assist  \
# 0             81  2354715  1177195  1177520  14818470  12308672  16380854
# 1            145  1471276   729144   742132  11978605   8216417   8708327
# 2            236  1390190   706335   683855  11327400   7970229   8030624
# 3            104  1104690   543973   560717   7337448   6052151   7035585
# 4             64  1090727   499817   590910   7350763   6215595   8835403
# ..           ...      ...      ...      ...       ...       ...       ...
# 155           77    64638    31594    33044    361113    336146    450001
# 156          526    57686    28542    29144     92678    375049    778379
# 157          427    35467    16711    18756     86421    161434    403734
# 158          136    32252    16247    16005    162488    179365    280760
# 159           72    31139    16005    15134    122230    143666    281705
#
#             cs  neutral_cs         gold  pick_rate  ban_rate     ward
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   champion_id  160 non-null    int64
#  1   play         160 non-null    int64
#  2   win          160 non-null    int64
#  3   lose         160 non-null    int64
#  4   kill         160 non-null    int64
#  5   death        160 non-null    int64
#  6   assist       160 non-null    int64
#  7   cs           160 non-null    int64
#  8   neutral_cs   160 non-null    int64
#  9   gold         160 non-null    int64
#  10  pick_rate    160 non-null    float64
#  11  ban_rate     160 non-null    float64
#  12  ward         160 non-null    int64
# dtypes: float64(2), int64(11)
# memory usage: 16.4 KB

# %%
url2 = 'https://www.op.gg/statistics/champions?region=kr&position=&mode=ranked&tier=all&period=month'

header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'
}

resp2 = requests.get(url2, headers=header)

# %%
resp2.text
# Out:
# '<!DOCTYPE html><html data-web-version="3" lang="en"><head><script>\n            (function(t, l) {\n                try {\n                    let w = window,\n                        d = document,\n                        s = d.createElement("script"),\n                        f = d.getElementsByTagName("script")[0];\n                    w[t] =\n                        w[t] ||\n                        function() {\n                            (w["_rgea"] = w["_rgea"] || [["uts", new Date()]]).push(\n                                Array.prototype.slice.call(arguments)\n                            );\n                            w.RGEA && w.RGEA.p();\n                        };\n                    s.type = "text/javascript";\n                    s.async = true;\n                    s.defer = true;\n                    s.src = l;\n                    f.parentNode.insertBefore(s, f);\n\n                    // 되는 파라미터\n                    rgea("propertyId", "RGEA0002-32de3446-a2a6-4f9a
# ...

# %%
json = '{"1":{"id":1,"key":"Annie","name":"Annie","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Annie.png","enemy_tips":["Annie\'s summoned bear, Tibbers, burns opposing units around himself. Try to keep your distance from him after he\'s been summoned.","Summoner Smite can be used to help take down Tibbers.","Keep an eye out for a white, swirling power around Annie. It means she\'s ready to unleash her stun."],"ally_tips":["Storing a stun for use with her ultimate can turn the tide of a team fight.","Striking killing blows on minions with Disintegrate enables Annie to farm extremely well early in the game.","Molten Shield is a good spell to cast to work up to Annie\'s stun, so sometimes it\'s beneficial to grab at least 1 rank in it early."],"passive":{"name":"Pyromania","description":"After casting 4 spells, Annie\'s next offensive spell will stun the target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Annie_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0001/ability_0001_P1.webm"},"spells":[{"key":"Q","name":"Disintegrate","description":"Annie hurls a Mana infused fireball, dealing damage and refunding the Mana cost if it destroys the target.","max_rank":5,"range_burn":[625],"cooldown_burn":[4],"cost_burn":[60,65,70,75,80],"tooltip":"Annie hurls a fireball, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. If the target dies, Annie refunds the Mana cost and reduces the Cooldown by 50%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AnnieQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0001/ability_0001_Q1.webm"},{"key":"W","name":"Incinerate","description":"Annie casts a blazing cone of fire, dealing damage to all enemies in the area.","max_rank":5,"range_burn":[600],"cooldown_burn":[8],"cost_burn":[90,95,100,105,110],"tooltip":"Annie projects a wave of fire, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AnnieW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0001/ability_0001_W1.webm"},{"key":"E","name":"Molten Shield","description":"Grants Annie or an ally a shield, a burst of Move Speed, and damages enemies who attack her with basic attacks.","max_rank":5,"range_burn":[800],"cooldown_burn":[14,13,12,11,10],"cost_burn":[40],"tooltip":"Annie grants herself or an ally \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds and \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e decaying over ? seconds. While the shield holds, enemies who Attack it take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AnnieE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0001/ability_0001_E1.webm"},{"key":"R","name":"Summon: Tibbers","description":"Annie wills her bear Tibbers to life, dealing damage to units in the area. Tibbers can attack and also burns enemies that stand near him.","max_rank":3,"range_burn":[600],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Annie summons her bear Tibbers, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. For the next ? seconds, Tibbers burns nearby enemies for \\u003cmagicDamage\\u003e? magic damage per second\\u003c/magicDamage\\u003e and his Attacks deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Annie can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this ability to direct Tibbers.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Annie dies, Tibbers becomes enraged, gaining \\u003cattackSpeed\\u003e275% Attack Speed\\u003c/attackSpeed\\u003e and \\u003cspeed\\u003e100% Move Speed\\u003c/speed\\u003e decaying over 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AnnieR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0001/ability_0001_R1.webm"}]},"2":{"id":2,"key":"Olaf","name":"Olaf","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Olaf.png","enemy_tips":["Olaf becomes more dangerous the lower life he is. Save your disables to finish him off.","Preventing Olaf from reaching his axe will minimize the amount of harassment he can cause in the laning phase.","Olaf has reduced defenses from damage during Ragnarok, despite being immune to disables. If you can\'t escape from Olaf during Ragnarok, try focusing your damage on him with your teammates."],"ally_tips":["Olaf can combine Berserker Rage, Vicious Strikes, and Ragnarok at low life to become deceptively strong.","The bonus healing granted by Vicious Strikes amplifies your Life Steal from all sources as well as heals from allies."],"passive":{"name":"Berserker Rage","description":"Olaf gains Attack Speed and Life Steal based on his missing Health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Olaf_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0002/ability_0002_P1.webm"},"spells":[{"key":"Q","name":"Undertow","description":"Olaf throws an axe into the ground at a target location, dealing damage to enemies it passes through and reducing their Armor and Move Speed. If Olaf picks up the axe, the ability\'s cooldown is reset.","max_rank":5,"range_burn":[1000],"cooldown_burn":[9],"cost_burn":[40,45,50,55,60],"tooltip":"Olaf throws an axe, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for up to 2.5 seconds (based on distance travelled). Champions hit lose \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Olaf picks up the axe, this Ability\'s Cooldown is refunded.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OlafAxeThrowCast.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0002/ability_0002_Q1.webm"},{"key":"W","name":"Tough It Out","description":"Olaf\'s Attack Speed is increased, he reduces incoming damage, and he gains a Shield.","max_rank":5,"range_burn":[700],"cooldown_burn":[16,15,14,13,12],"cost_burn":[30],"tooltip":"Olaf gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds, and \\u003cshield\\u003e? plus ?% missing Health Shield (up to a maximum of ? Shield below ?% Health)\\u003c/shield\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OlafFrenziedStrikes.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0002/ability_0002_W1.webm"},{"key":"E","name":"Reckless Swing","description":"Olaf attacks with such force that it deals true damage to his target and himself, refunding the Health cost if he destroys the target.","max_rank":5,"range_burn":[325],"cooldown_burn":[11,10,9,8,7],"cost_burn":[0],"tooltip":"Olaf ferociously swings his axes, dealing \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e. If the enemy dies, the cost is refunded.\\u003cbr /\\u003e\\u003cbr /\\u003eAttacks lower the Cooldown of this Ability by 1 second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OlafRecklessStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0002/ability_0002_E1.webm"},{"key":"R","name":"Ragnarok","description":"Olaf passively gains increased armor and magic resist. He can activate this ability to become immune to disables for as long as he keeps attacking.","max_rank":3,"range_burn":[400],"cooldown_burn":[100,90,80],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Olaf gains \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive: \\u003c/spellActive\\u003eOlaf cleanses all \\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e and \\u003cstatus\\u003eDisabling\\u003c/status\\u003e effects on himself and becomes immune to them for ? seconds. While active, Olaf gains \\u003cscaleAD\\u003e? Attack Damage\\u003c/scaleAD\\u003e. Hitting a champion with an Attack or \\u003cspellName\\u003eReckless Swing\\u003c/spellName\\u003e extends the duration by ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAdditionally, Olaf gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e towards enemy champions for ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OlafRagnarok.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0002/ability_0002_R1.webm"}]},"3":{"id":3,"key":"Galio","name":"Galio","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Galio.png","enemy_tips":["Galio moves slower when he is charging Shield of Durand.","Hero\'s Entrance can be interrupted before Galio jumps into the air.","Galio cannot traverse walls with Justice Punch."],"ally_tips":["You can release Shield of Durand even while crowd controlled.","You can use the minimap ally icons to cast Hero\'s Entrance.","You can use the step back from Justice Punch to dodge enemy spells."],"passive":{"name":"Colossal Smash","description":"Every few seconds, Galio\'s next basic attack deals bonus magic damage in an area.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Galio_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0003/ability_0003_P1.webm"},"spells":[{"key":"Q","name":"Winds of War","description":"Galio fires two windblasts that converge into a large tornado that deals damage over time.","max_rank":5,"range_burn":[825],"cooldown_burn":[12,11,11,10,10],"cost_burn":[70,75,80,85,90],"tooltip":"Galio fires two windblasts that deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each. When the windblasts meet, they combine into a tornado that deals \\u003cmagicDamage\\u003e?% max Health magic damage\\u003c/magicDamage\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GalioQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0003/ability_0003_Q1.webm"},{"key":"W","name":"Shield of Durand","description":"Galio charges a defensive stance, moving slowly. Upon releasing the charge, Galio will taunt and damage nearby enemies.","max_rank":5,"range_burn":[275],"cooldown_burn":[18,17,17,16,16],"cost_burn":[50],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Galio gains a \\u003cshield\\u003e? Magic Shield\\u003c/shield\\u003e after not taking damage for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Galio reduces incoming magic damage by ? and incoming physical damage by ? and \\u003cstatus\\u003eSlows\\u003c/status\\u003e himself by 15%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Galio \\u003cstatus\\u003eTaunts\\u003c/status\\u003e enemy champions for between 0.5 to 1.5 seconds, deals between \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and refreshes the damage reduction for 2 seconds. Taunt duration, damage, and range increase with charge time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GalioW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0003/ability_0003_W1.webm"},{"key":"E","name":"Justice Punch","description":"Galio will briefly step back and charge, knocking up the first enemy champion he encounters.","max_rank":5,"range_burn":[650],"cooldown_burn":[12,11,10,9,8],"cost_burn":[50],"tooltip":"Galio lunges forward with a mighty blow, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first champion hit. Other enemies in the way take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eGalio\'s dash stops on hitting terrain.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GalioE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0003/ability_0003_E1.webm"},{"key":"R","name":"Hero\'s Entrance","description":"Galio designates an ally\'s position as his landing spot, granting all allies in the area a magic shield. After a delay Galio smashes down location, knocking up nearby enemies.","max_rank":3,"range_burn":[4000,4750,5500],"cooldown_burn":[200,180,160],"cost_burn":[100],"tooltip":"Galio designates an allied champion\'s position as his landing spot, granting all allied champions in the area \\u003cspellName\\u003eShield of Durand\'s\\u003c/spellName\\u003e passive \\u003cshield\\u003eShield\\u003c/shield\\u003e for ? seconds. Galio then flies to his landing zone.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen Galio lands, he \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for ? seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GalioR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0003/ability_0003_R1.webm"}]},"4":{"id":4,"key":"TwistedFate","name":"Twisted Fate","image_url":"https://opgg-static.akamaized.net/images/lol/champion/TwistedFate.png","enemy_tips":["Focus on dodging Wild Cards early when your champion doesn\'t have the hit points to afford getting hit.","If you have low Health, use Destiny as an indicator to run to safety. It will give you a head start in escaping any possible ganks."],"ally_tips":["Coordinate with your allies for the best time to use Destiny to ambush enemies.","Stealth characters often escape a battle with very low hit points. Take advantage of Destiny\'s ability to reveal stealthed units to finish them off.","Twisted Fate is viable as an Attack Damage or Ability Power character, letting him fit on many different team compositions."],"passive":{"name":"Loaded Dice","description":"Upon killing a unit, Twisted Fate rolls his \'lucky\' dice receiving 1 to 6 bonus gold.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Cardmaster_SealFate.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0004/ability_0004_P1.webm"},"spells":[{"key":"Q","name":"Wild Cards","description":"Twisted Fate throws three cards, dealing damage to each enemy unit they pass through.","max_rank":5,"range_burn":[10000],"cooldown_burn":[6],"cost_burn":[60,70,80,90,100],"tooltip":"Twisted Fate throws three cards that deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WildCards.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0004/ability_0004_Q1.webm"},{"key":"W","name":"Pick a Card","description":"Twisted Fate chooses a magic card from his deck, and uses that for his next attack, causing bonus effects.","max_rank":5,"range_burn":[200],"cooldown_burn":[8,7,7,6,6],"cost_burn":[40,55,70,85,100],"tooltip":"Twisted Fate begins shuffling his deck, allowing him to \\u003crecast\\u003eRecast\\u003c/recast\\u003e to lock in one of three cards and enhance his next Attack.\\u003cbr /\\u003e\\u003cli\\u003eThe Blue Card deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and restores \\u003cscaleMana\\u003e50/75/100/125/150 Mana\\u003c/scaleMana\\u003e.\\u003cli\\u003eThe Red Card deals \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e to nearby enemies and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 30/35/40/45/50% for 2.5 seconds.\\u003cli\\u003eThe Gold Card deals \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStuns\\u003c/status\\u003e for 1/1.25/1.5/1.75/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PickACard.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0004/ability_0004_W1.webm"},{"key":"E","name":"Stacked Deck","description":"Every 4 attacks, Twisted Fate deals bonus damage. In addition, his Attack Speed is increased.","max_rank":5,"range_burn":[0],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every 4th Attack deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eTwisted Fate also gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CardmasterStack.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0004/ability_0004_E1.webm"},{"key":"R","name":"Destiny","description":"Twisted Fate predicts the fortunes of his foes, revealing all enemy champions and enabling the use of Gate, which teleports Twisted Fate to any target location in 1.5 seconds.","max_rank":3,"range_burn":[5500],"cooldown_burn":[180,150,120],"cost_burn":[100],"tooltip":"Twisted Fate focuses on his cards, granting \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of all enemy champions on the map for 6/8/10 seconds and allowing him to \\u003crecast\\u003eRecast\\u003c/recast\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Twisted Fate teleports up to 5500 units away.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Destiny.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0004/ability_0004_R1.webm"}]},"5":{"id":5,"key":"XinZhao","name":"Xin Zhao","image_url":"https://opgg-static.akamaized.net/images/lol/champion/XinZhao.png","enemy_tips":["Xin Zhao is a powerful initiator with both his charge and ultimate dealing damage to all units around him. Try having your team stay spread out until he\'s used his ultimate.","Xin Zhao relies heavily on his Three Talon Strikes for damage and cooldown resets, so preventing him from finishing his combo will have a dramatic effect."],"ally_tips":["Xin Zhao is a great initiator to combat. Lead the front to start a fight and use your ultimate to do the most damage possible.","Try to position yourself so your ultimate\'s knockback is most effective."],"passive":{"name":"Determination","description":"Every third attack deals bonus damage and heals Xin Zhao.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/XinZhaoP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0005/ability_0005_P1.webm"},"spells":[{"key":"Q","name":"Three Talon Strike","description":"Xin Zhao\'s next 3 standard attacks deal increased damage with the third attack knocking an opponent into the air.","max_rank":5,"range_burn":[375],"cooldown_burn":[7,6,6,5,5],"cost_burn":[30],"tooltip":"Xin Zhao\'s next 3 Attacks deal an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and reduces his other Ability\'s Cooldowns by 1 second. The third Attack also \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for 0.75 seconds.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XinZhaoQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0005/ability_0005_Q1.webm"},{"key":"W","name":"Wind Becomes Lightning","description":"Xin Zhao slashes in front of himself with his spear, then thrusts it forward, slowing affected enemies and marking them as Challenged.","max_rank":5,"range_burn":[1000],"cooldown_burn":[12,11,10,9,8],"cost_burn":[60,55,50,45,40],"tooltip":"Xin Zhao slashes, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e physical damage, then thrusts, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e. Enemies hit by the thrust are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 50% for 1.5 seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eChampions and Large Monsters hit by the thrust are marked as \\u003ckeywordMajor\\u003eChallenged\\u003c/keywordMajor\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XinZhaoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0005/ability_0005_W1.webm"},{"key":"E","name":"Audacious Charge","description":"Xin Zhao charges to an enemy, gaining increased Attack Speed and dealing damage to all enemies in the area, slowing them briefly. Audacious Charge gains increased range against Challenged targets.","max_rank":5,"range_burn":[650],"cooldown_burn":[12],"cost_burn":[50],"tooltip":"Xin Zhao charges an enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for 0.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eXin Zhao also grants himself \\u003cattackSpeed\\u003e40/45/50/55/60% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eAudacious Charge\'s\\u003c/spellName\\u003e range is increased on enemies that are \\u003ckeywordMajor\\u003eChallenged\\u003c/keywordMajor\\u003e. \\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XinZhaoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0005/ability_0005_E1.webm"},{"key":"R","name":"Crescent Guard","description":"Xin Zhao challenges an enemy he damaged recently. Xin Zhao deals damage to nearby enemies based on their current Health and knocks non-challenged targets back, becoming impervious to damage dealt by champions outside of the circle created.","max_rank":3,"range_burn":[500],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"The last champion Xin Zhao damaged with an Attack or \\u003cspellName\\u003eAudacious Charge\\u003c/spellName\\u003e is \\u003ckeywordMajor\\u003eChallenged\\u003c/keywordMajor\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eXin Zhao unleashes a sweep around him that deals \\u003cphysicalDamage\\u003e? plus ?% current Health physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eKnocks Back\\u003c/status\\u003e all \\u003ckeywordMajor\\u003enon-Challenged\\u003c/keywordMajor\\u003e enemies. \\u003cbr /\\u003e  \\u003cbr /\\u003eAfterwards, Xin Zhao becomes immune to damage from enemies outside the sweep range for ? seconds. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XinZhaoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0005/ability_0005_R1.webm"}]},"6":{"id":6,"key":"Urgot","name":"Urgot","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Urgot.png","enemy_tips":["Urgot relies heavily on blasting opponents with his legs, which have their own cooldowns and only detonate when he attacks in the direction they are facing. Avoid getting hit by multiple.","Urgot can deal and absorb tremendous amounts of damage with Purge, but slows himself while firing.","If you are struck by Fear Beyond Death, do your best to avoid falling below the execution threshold (25% of your Maximum Health) until the effect times out."],"ally_tips":["Pay attention to your individual leg\'s cooldowns, as they make for a signficiant portion of your damage","Land Corrosive Charge or Disdain to lock on to target\'s with Purge - a great way to trigger multiple legs in rapid succession.","Save Fear Beyond Death for opponents you know are already too weak to survive. It\'s especially good for picking off fleeing foes."],"passive":{"name":"Echoing Flames","description":"Urgot\'s basic attacks and Purge periodically trigger blasts of flame from his legs, dealing physical damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Urgot_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0006/ability_0006_P1.webm"},"spells":[{"key":"Q","name":"Corrosive Charge","description":"Fires an explosive charge at the target location, dealing physical damage and slowing enemies caught in the explosion.","max_rank":5,"range_burn":[800],"cooldown_burn":[10,9,9,8,8],"cost_burn":[70],"tooltip":"Urgot fires an explosive charge, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UrgotQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0006/ability_0006_Q1.webm"},{"key":"W","name":"Purge","description":"Urgot slows himself while he unloads his weapon on nearby enemies. Prioritizes enemy champions Urgot has recently struck with other abilities and triggers Echoing Flames.","max_rank":5,"range_burn":[490],"cooldown_burn":[12,9,6,3,0],"cost_burn":[40,30,20,10,0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Urgot\'s other Abilities mark the last champion hit for 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Urgot begins firing his chain gun at the closest enemy, prioritizing marked enemies. He Attacks them 3 times a second dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e per shot. Urgot can move while firing and has 40% \\u003cstatus\\u003eSlow\\u003c/status\\u003e resistance, but loses \\u003cspeed\\u003e125 Move Speed\\u003c/speed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eAt max rank, this Ability lasts indefinitely and can be \\u003ctoggle\\u003eToggled\\u003c/toggle\\u003e on and off.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UrgotW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0006/ability_0006_W1.webm"},{"key":"E","name":"Disdain","description":"Urgot charges in a direction, shielding himself and trampling non-champion enemies. If he catches an enemy champion, he will stop and hurl them out of his way.","max_rank":5,"range_burn":[475],"cooldown_burn":[16,15,15,14,14],"cost_burn":[60,70,80,90,100],"tooltip":"Urgot charges forward, gaining \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds. The first champion hit is \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds and thrown behind Urgot. All enemies Urgot collides with take \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UrgotE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0006/ability_0006_E1.webm"},{"key":"R","name":"Fear Beyond Death","description":"Urgot fires a chem-drill that impales the first enemy champion hit. If that champion falls below a health threshold, Urgot judges them weak and can execute them.","max_rank":3,"range_burn":[2500],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Urgot fires a chem-drill, impaling the first champion hit, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e for ? seconds by 1% per 1% missing Health, up to ?%.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the impaled victim falls below ?% Health, Urgot can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability, \\u003cstatus\\u003eSuppressing\\u003c/status\\u003e the victim and dragging them to himself. On reaching Urgot, they are killed and nearby enemies are \\u003cstatus\\u003eFeared\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UrgotR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0006/ability_0006_R1.webm"}]},"7":{"id":7,"key":"Leblanc","name":"LeBlanc","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Leblanc.png","enemy_tips":["LeBlanc\'s ultimate can create fake LeBlancs during her spellcast or, rarely, at a distant position. ","The fake LeBlanc created at a distance will always run at the nearest Champion, cast a harmless spell, then immediately disappear.","Attacking LeBlanc first avoids most of her tricks, especially if she\'s recently used her dash, Distortion.","Stunning or silencing LeBlanc will prevent her from activating the return part of Distortion."],"ally_tips":["Distortion allows you to be aggressive with your other spells while being able to return to safety.","Using Distortion can help your positioning to land Ethereal Chains.","You can chain Sigil of Malice and Ethereal Chains to prevent characters with blink from escaping for up to 4 seconds."],"passive":{"name":"Mirror Image","description":"When LeBlanc drops below 40% Health, she becomes invisible for 1 second and creates a Mirror Image that deals no damage and lasts for up to 8 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/LeBlancP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0007/ability_0007_P1.webm"},"spells":[{"key":"Q","name":"Sigil of Malice","description":"LeBlanc projects a sigil, dealing damage and marking the target for 3.5 seconds. Damaging the marked target with an ability detonates the sigil, dealing additional damage.","max_rank":5,"range_burn":[700],"cooldown_burn":[6],"cost_burn":[50,55,60,65,70],"tooltip":"LeBlanc projects a sigil to an enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and marking them for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eDamaging the marked enemy with an Ability detonates the sigil, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeblancQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0007/ability_0007_Q1.webm"},{"key":"W","name":"Distortion","description":"LeBlanc dashes to a location, dealing damage to enemies near her destination. For the next 4 seconds, activate Distortion again to return LeBlanc to her starting location.","max_rank":5,"range_burn":[600],"cooldown_burn":[18,16,14,12,10],"cost_burn":[60,70,80,90,100],"tooltip":"LeBlanc dashes then deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies. For 4 seconds after dashing, LeBlanc can \\u003crecast\\u003eRecast\\u003c/recast\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e LeBlanc returns to her starting location.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeblancW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0007/ability_0007_W1.webm"},{"key":"E","name":"Ethereal Chains","description":"LeBlanc launches a chain that shackles the first enemy hit. If the target remains shackled for 1.5 seconds, LeBlanc roots them and deals additional damage.","max_rank":5,"range_burn":[925],"cooldown_burn":[14,13,12,11,11],"cost_burn":[50],"tooltip":"LeBlanc launches a chain that shackles the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and granting \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf they remain shackled for 1.5 seconds, LeBlanc \\u003cstatus\\u003eRoots\\u003c/status\\u003e them for 1.5 seconds and deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeblancE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0007/ability_0007_E1.webm"},{"key":"R","name":"Mimic","description":"LeBlanc casts a mimicked version of one of her basic spells.","max_rank":3,"range_burn":[25000],"cooldown_burn":[60,45,30],"cost_burn":[0],"tooltip":"LeBlanc mimics her most recent Ability, using it again. The mimicked Ability deals increased damage.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eMimicked Sigil of Malice\\u003c/spellName\\u003e deals \\u003cmagicDamage\\u003e{{ rq1damage }} magic damage\\u003c/magicDamage\\u003e when applied, and \\u003cmagicDamage\\u003e{{ rq2damage }} magic damage\\u003c/magicDamage\\u003e when consumed.\\u003cbr /\\u003e\\u003cspellName\\u003eMimicked Distortion\\u003c/spellName\\u003e deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cspellName\\u003eMimicked Ethereal Chains\\u003c/spellName\\u003e deals \\u003cmagicDamage\\u003e{{ re1damage }} magic damage\\u003c/magicDamage\\u003e when shackled and \\u003cmagicDamage\\u003e{{ re2damage }} magic damage\\u003c/magicDamage\\u003e when \\u003cstatus\\u003eRooting\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeblancR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0007/ability_0007_R1.webm"}]},"8":{"id":8,"key":"Vladimir","name":"Vladimir","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Vladimir.png","enemy_tips":["Try to take Vladimir down before Hemoplague detonates, as it will heal him for each afflicted enemy Champion.","Making Vladimir use Sanguine Pool at the start of a fight will maximize the Health cost of the ability to him.","Items that counter Health stacking, such as Liandry\'s Torment and Blade of the Ruined King, are very effective against Vladimir."],"ally_tips":["Transfusion instantly deals damage to the enemy before healing Vladimir, making it one of the best last hitting tools in the game.","Cast Hemoplague where it will afflict the most units.","Sanguine Pool pops incoming missiles, so it can be used to dodge disables."],"passive":{"name":"Crimson Pact","description":"Every 30 points of bonus Health gives Vladimir 1 Ability Power and every 1 point of Ability Power gives Vladimir 1.6 bonus Health (does not stack with itself).","image_url":"https://opgg-static.akamaized.net/images/lol/passive/VladimirP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0008/ability_0008_P1.webm"},"spells":[{"key":"Q","name":"Transfusion","description":"Vladimir steals life from the target enemy. When Vladimir\'s resource is full, Transfusion will benefit from massively increased damage and healing for a brief time.","max_rank":5,"range_burn":[600],"cooldown_burn":[9,7,6,5,4],"cost_burn":[0],"tooltip":"Vladimir drains his target\'s lifeforce, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e. After using this Ability twice, Vladimir gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for 0.5 seconds and empowers the next use of this Ability for 2.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThe empowered version of this Ability deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e instead and restores an additional \\u003chealing\\u003e? plus ? missing Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VladimirQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0008/ability_0008_Q1.webm"},{"key":"W","name":"Sanguine Pool","description":"Vladimir sinks into a pool of blood, becoming untargetable for 2 seconds. Additionally, enemies on the pool are slowed and Vladimir siphons life from them.","max_rank":5,"range_burn":[350],"cooldown_burn":[28,25,22,19,16],"cost_burn":[0],"tooltip":"Vladimir sinks into a pool of blood for 2 seconds, gaining \\u003cspeed\\u003e37.5% decaying Move Speed\\u003c/speed\\u003e for 1 second and becoming Untargetable and Ghosted while \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies in the pool by 40%.\\u003cbr /\\u003e\\u003cbr /\\u003eVladimir deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over the duration and restores \\u003chealing\\u003eHealth equal to 15% of the damage dealt\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VladimirSanguinePool.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0008/ability_0008_W1.webm"},{"key":"E","name":"Tides of Blood","description":"Vladimir pays his own health to charge up a reservoir of blood which, when released, deals damage in the area around him but can be blocked by enemy units.","max_rank":5,"range_burn":[600],"cooldown_burn":[13,11,9,7,5],"cost_burn":[0],"tooltip":"\\u003ccharge\\u003eBegin Charging: \\u003c/charge\\u003eVladimir charges up a reservoir of blood, spending up to ? Health. While at full charge, Vladimir is \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 20%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease: \\u003c/release\\u003eVladimir unleashes a torrent of blood missiles at surrounding enemies, dealing between \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e based on charge time. If this Ability was charged for at least 1 second, it also \\u003cstatus\\u003eSlows\\u003c/status\\u003e targets by 40/45/50/55/60% for 0.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VladimirE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0008/ability_0008_E1.webm"},{"key":"R","name":"Hemoplague","description":"Vladimir infects an area with a virulent plague. Affected enemies take increased damage for the duration. After a few seconds, Hemoplague deals magic damage to infected enemies and heals Vladimir for each enemy Champion hit.","max_rank":3,"range_burn":[625],"cooldown_burn":[120],"cost_burn":[0],"tooltip":"Vladimir creates a virulent plague, causing its victims to take 10% increased damage from all sources for 4 seconds. After it expires, Vladimir deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to all infected targets. Vladimir restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e if he hits a champion, and restores an additional \\u003chealing\\u003e? Health\\u003c/healing\\u003e for each champion beyond the first.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VladimirHemoplague.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0008/ability_0008_R1.webm"}]},"9":{"id":9,"key":"Fiddlesticks","name":"Fiddlesticks","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Fiddlesticks.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"A Harmless Scarecrow","description":"Fiddlesticks\' trinket is replaced by scarecrow effigies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/FiddleSticks_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0009/ability_0009_P1.webm"},"spells":[{"key":"Q","name":"Terrify","description":"Fiddlesticks damaging enemies with spells while unseen or targeting an enemy with Terrify\'s activation strikes a target unit with fear, causing it to flee in terror for a duration.","max_rank":5,"range_burn":[575],"cooldown_burn":[15,14,14,13,13],"cost_burn":[65],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While unseen and out of combat or impersonating an \\u003ckeywordMajor\\u003eEffigy\\u003c/keywordMajor\\u003e, damaging an enemy with an ability \\u003cstatus\\u003eFears\\u003c/status\\u003e them for ? second(s).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e \\u003cstatus\\u003eFear\\u003c/status\\u003e an enemy for ? second(s) and deal \\u003cmagicDamage\\u003e? current Health magic damage\\u003c/magicDamage\\u003e. If the target has recently been \\u003cstatus\\u003eFeared\\u003c/status\\u003e by Fiddlesticks, instead deal \\u003cmagicDamage\\u003e? current Health magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FiddleSticksQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0009/ability_0009_Q1.webm"},{"key":"W","name":"Bountiful Harvest","description":"Fiddlesticks drains health from nearby enemies, dealing bonus execute damage at the end of the duration.","max_rank":5,"range_burn":[650],"cooldown_burn":[10,9,9,8,8],"cost_burn":[60,65,70,75,80],"tooltip":"Fiddlesticks channels and drains the souls of nearby enemies, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second for 2 seconds, plus \\u003cmagicDamage\\u003e?% missing Health magic damage\\u003c/magicDamage\\u003e at the end. Fiddlesticks restores \\u003chealing\\u003e?% of damage as Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Fiddlesticks ends the channel without interruption, the remaining Cooldown is reduced by 60%.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FiddleSticksW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0009/ability_0009_W1.webm"},{"key":"E","name":"Reap","description":"Fiddlesticks slashes an area with its scythe, slowing all enemies hit and silencing enemies hit in the center of the slash.","max_rank":5,"range_burn":[850],"cooldown_burn":[10,9,8,7,6],"cost_burn":[40,45,50,55,60],"tooltip":"Fiddlesticks unleashes dark magic, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds. Enemies in the center are also \\u003cstatus\\u003eSilenced\\u003c/status\\u003e for the duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FiddleSticksE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0009/ability_0009_E1.webm"},{"key":"R","name":"Crowstorm","description":"A murder of crows flock wildly around Fiddlesticks, dealing damage per second to all enemy units in the area.","max_rank":3,"range_burn":[800],"cooldown_burn":[140,110,80],"cost_burn":[100],"tooltip":"Fiddlesticks channels for ? seconds, then teleports and unleashes a murder of crows, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FiddleSticksR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0009/ability_0009_R1.webm"}]},"10":{"id":10,"key":"Kayle","name":"Kayle","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kayle.png","enemy_tips":["Divine Judgment only grants Kayle or her allies immunity to damage. Slows and stuns can still be applied, so trap them if they\'re being overzealous.","Kayle is usually a fragile target. If you see her ultimate cast on an ally, switch to attacking her.","Kayle starts the game as a weaker melee champion. Try to put her behind before she ascends to her ranged form."],"ally_tips":["Using Divine Judgment on a high-DPS ally can turn the tides of battle by giving your ally free reign to attack. ","Kayle\'s attacks become incredibly powerful once she gains attack range from Divine Ascent. Play safe until then. ","Kayle benefits greatly from Attack Damage and Ability Power, making hybrid items like Nashor\'s Tooth and Hextech Gunblade very effective on her."],"passive":{"name":"Divine Ascent","description":"Kayle\'s attacks are empowered by the heavens as she levels up and spends skill points. Her wings are lit aflame as she progressively gains Attack Speed, Move Speed, Attack Range, and waves of fire on her attacks.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kayle_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0010/ability_0010_P1.webm"},"spells":[{"key":"Q","name":"Radiant Blast","description":"Kayle conjures a portal, summoning a celestial sword that pierces through enemies, slowing, damaging, and reducing the resistances of all hit.","max_rank":5,"range_burn":[900],"cooldown_burn":[12,11,10,9,8],"cost_burn":[70,75,80,85,90],"tooltip":"Kayle fires a celestial sword that stops on the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds, and removing \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e for ? seconds from the target and enemies behind them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KayleQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0010/ability_0010_Q1.webm"},{"key":"W","name":"Celestial Blessing","description":"Blessed by the divine, Kayle heals and grants Move Speed to herself and the nearest ally.","max_rank":5,"range_burn":[900],"cooldown_burn":[15],"cost_burn":[90,100,110,120,130],"tooltip":"Kayle infuses herself and an allied champion with light, restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e and granting \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KayleW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0010/ability_0010_W1.webm"},{"key":"E","name":"Starfire Spellblade","description":"Passive: Kayle\'s celestial sword, Virtue, deals bonus magic damage to enemies she attacks.\\u003cbr\\u003e\\u003cbr\\u003eActive: Kayle\'s next attack smites her target with celestial fire, dealing bonus damage proportionate to their missing health.","max_rank":5,"range_burn":[550],"cooldown_burn":[8,7,7,6,6],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Kayle\'s Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kayle\'s next Attack becomes ranged and deals an additional \\u003cmagicDamage\\u003e? missing Health magic damage\\u003c/magicDamage\\u003e. When Kayle reaches level ?, this Attack explodes on hitting the target, dealing damage to surrounding enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KayleE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0010/ability_0010_E1.webm"},{"key":"R","name":"Divine Judgment","description":"Kayle makes an ally invulnerable and calls upon former Aspects of Justice to purify the area around her target with a holy rain of swords.","max_rank":3,"range_burn":[900],"cooldown_burn":[160,120,80],"cost_burn":[100,50,0],"tooltip":"Kayle makes an allied champion Invulnerable for ? seconds. She then purifies the area around them dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KayleR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0010/ability_0010_R1.webm"}]},"11":{"id":11,"key":"MasterYi","name":"Master Yi","image_url":"https://opgg-static.akamaized.net/images/lol/champion/MasterYi.png","enemy_tips":["Meditate is an effective method of healing damage over time, but Master Yi is susceptible to coordinated team ganks early in the game.","If Master Yi tries to farm with Alpha Strike, hit him a few times so he has to use mana with Meditate to heal.","Although Master Yi cannot be slowed while using Highlander, other disables can stop him in his tracks."],"ally_tips":["If you\'re in a lane against ranged players, leveling up Meditate can allow you to stay in the lane longer and gain levels faster than they will.","Wuju Style is very strong early for last hitting minions.","Try using Alpha Strike on a minion in front of an enemy champion so you are placed at a safe distance at the end of the spell."],"passive":{"name":"Double Strike","description":"Every few consecutive basic attack, Master Yi strikes twice.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/MasterYi_Passive1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0011/ability_0011_P1.webm"},"spells":[{"key":"Q","name":"Alpha Strike","description":"Master Yi teleports across the battlefield with blinding speed, dealing physical damage to multiple units in his path, while simultaneously becoming untargetable. Alpha Strike can critically strike and deals bonus physical damage to monsters. Basic attacks reduce Alpha Strike\'s cooldown.","max_rank":5,"range_burn":[600],"cooldown_burn":[18,17,17,16,16],"cost_burn":[50,55,60,65,70],"tooltip":"Master Yi becomes Untargetable and teleports to rapidly strike enemies near his target, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to all enemies hit after ? hits. \\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability can strike the same enemy repeatedly if there are no other targets, dealing ?% damage for subsequent hits (\\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e), for a maximum single target total of \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AlphaStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0011/ability_0011_Q1.webm"},{"key":"W","name":"Meditate","description":"Master Yi rejuvenates his body by focus of mind, restoring Health and taking reduced damage for a short time. In addition, Master Yi will gain stacks of Double Strike and pause the remaining duration on Wuju Style and Highlander for each second he channels.","max_rank":5,"range_burn":[20],"cooldown_burn":[28],"cost_burn":[50],"tooltip":"Master Yi channels, reducing incoming damage by ?% and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e over ? seconds. This healing is increased by up to ?% based on Master Yi\'s missing Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Meditate.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0011/ability_0011_W1.webm"},{"key":"E","name":"Wuju Style","description":"Grants bonus true damage on basic attacks.","max_rank":5,"range_burn":[20],"cooldown_burn":[18,17,16,15,14],"cost_burn":[0],"tooltip":"Master Yi\'s Attacks deal an additional \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WujuStyle.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0011/ability_0011_E1.webm"},{"key":"R","name":"Highlander","description":"Master Yi moves with unparalleled agility, temporarily increasing his Move Speed and Attack Speed as well as making him immune to all slowing effects. While active, Champion kills or assists extend Highlander\'s duration. Passively reduces cooldown for his other abilities on a kill or assist.","max_rank":3,"range_burn":[1],"cooldown_burn":[85],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Champion takedowns reduce the remaining Cooldown of Master Yi\'s basic Abilities by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Master Yi enters a trance, gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e, \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e, and immunity to \\u003cstatus\\u003eSlows\\u003c/status\\u003e for ? seconds. Champion takedowns extend the duration of this Ability by ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Highlander.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0011/ability_0011_R1.webm"}]},"12":{"id":12,"key":"Alistar","name":"Alistar","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Alistar.png","enemy_tips":["Alistar is very disruptive but very tough - try to target more fragile damage dealers.","Watch out for the Pulverize-Headbutt combo when around turrets.","When Alistar uses his ultimate, it\'s often better to move back and wait until the effect wears off before attacking him."],"ally_tips":["Using Pulverize can allow you to establish better positioning for Headbutt.","Move Speed is very important on Alistar. Consider which boots to buy carefully.","Using Flash can allow you catch your target off guard to knock them back into your allies with Pulverize and Headbutt."],"passive":{"name":"Triumphant Roar","description":"Alistar charges his roar by stunning or displacing enemy champions or when nearby enemies die. When fully charged he heals himself all nearby allied champions.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Alistar_E.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0012/ability_0012_P1.webm"},"spells":[{"key":"Q","name":"Pulverize","description":"Alistar smashes the ground, dealing damage to nearby enemies and tossing them into the air.","max_rank":5,"range_burn":[365],"cooldown_burn":[15,14,13,12,11],"cost_burn":[65,70,75,80,85],"tooltip":"Alistar smashes the ground, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e enemies for 1 second and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Pulverize.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0012/ability_0012_Q1.webm"},{"key":"W","name":"Headbutt","description":"Alistar rams a target with his head, dealing damage and knocking the target back.","max_rank":5,"range_burn":[650],"cooldown_burn":[14,13,12,11,10],"cost_burn":[65,70,75,80,85],"tooltip":"Alistar rams into an enemy, \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Headbutt.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0012/ability_0012_W1.webm"},{"key":"E","name":"Trample","description":"Alistar tramples nearby enemy units, ignoring unit collision and gaining stacks if he damages an enemy champion. At full stacks Alistar\'s next basic attack against an enemy champion deals additional magic damage and stuns them.","max_rank":5,"range_burn":[350],"cooldown_burn":[12,11,11,10,10],"cost_burn":[50,60,70,80,90],"tooltip":"Alistar begins trampling the ground, becoming Ghosted and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 5 seconds to nearby enemies. Each pulse that damages a champion grants a stack.\\u003cbr /\\u003e\\u003cbr /\\u003eAt 5 stacks, Alistar\'s next Attack \\u003cstatus\\u003eStuns\\u003c/status\\u003e for 1 second and deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AlistarE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0012/ability_0012_E1.webm"},{"key":"R","name":"Unbreakable Will","description":"Alistar lets out a wild roar, removing all crowd control effects on himself, and reducing incoming physical and magical damage for the duration.","max_rank":3,"range_burn":[1],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Alistar immediately cleanses all \\u003cstatus\\u003eDisabling\\u003c/status\\u003e effects and takes ?% reduced damage for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FerociousHowl.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0012/ability_0012_R1.webm"}]},"13":{"id":13,"key":"Ryze","name":"Ryze","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ryze.png","enemy_tips":["Ryze is especially dangerous to opponents that are marked with Flux.","Use Realm Warp\'s windup time to figure out how to deal with what may be coming out of the portal.","Crowd controlling Ryze during Realm Warp\'s windup will cancel the portal."],"ally_tips":["Use Overload\'s passive to optimize for maximum damage or maximum speed.","Spell Flux\'s short cooldown allows it to be used to spread Flux to many enemies.","Ryze can move and cast other spells while Realm Warp is charging without cancelling the portal."],"passive":{"name":"Arcane Mastery","description":"\\u003cmainText\\u003eRyze\'s spells deal extra damage based on his Bonus Mana, and he gains a percentage increase to his maximum Mana based on his Ability Power.\\u003c/mainText\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Ryze_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0013/ability_0013_P1.webm"},"spells":[{"key":"Q","name":"Overload","description":"Passively, Ryze\'s other basic abilities reset the cooldown of Overload and charge a rune. When Ryze casts Overload with 2 runes charged, he gains a brief burst of Move Speed.\\u003cbr\\u003e\\u003cbr\\u003eOn cast, Ryze throws a charge of pure energy in a line, dealing damage to the first enemy struck. If the target has Flux on it, Overload deals extra damage and bounces to nearby enemies with Flux.","max_rank":5,"range_burn":[1000],"cooldown_burn":[5],"cost_burn":[40,38,36,34,32],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e \\u003cspellName\\u003eRune Prison\\u003c/spellName\\u003e and \\u003cspellName\\u003eSpell Flux\\u003c/spellName\\u003e refresh this Ability\'s Cooldown and charge a rune for ? seconds (max ? runes).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Ryze unleashes a blast, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit. If the target has \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e on it, it is consumed, causing this Ability to deal ?% increased damage and bounces to nearby enemies with \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eRyze also discharges all runes, granting Ryze \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? seconds if ? runes were charged.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RyzeQWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0013/ability_0013_Q1.webm"},{"key":"W","name":"Rune Prison","description":"Ryze traps a target in a cage of runes, damaging them and slowing their movement. If the target has Flux on it, they are instead rooted.","max_rank":5,"range_burn":[615],"cooldown_burn":[13,12,11,10,9],"cost_burn":[40,55,70,85,100],"tooltip":"Ryze deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds. If the target has \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e, it is consumed and this Ability \\u003cstatus\\u003eRoots\\u003c/status\\u003e instead of \\u003cstatus\\u003eSlowing\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RyzeW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0013/ability_0013_W1.webm"},{"key":"E","name":"Spell Flux","description":"Ryze releases an orb of pure magical power that damages an enemy and debuffs all nearby enemies. Ryze\'s spells have additional effects against the debuffed enemy.","max_rank":5,"range_burn":[615],"cooldown_burn":[3,3,3,2,2],"cost_burn":[35,45,55,65,75],"tooltip":"Ryze fires an orb, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and applies \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e for ? seconds to the target and nearby enemies. Enemies already afflicted with \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e will cause it to spread further.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RyzeE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0013/ability_0013_E1.webm"},{"key":"R","name":"Realm Warp","description":"Passively, Overload deals even more damage against targets with Flux.\\u003cbr\\u003e\\u003cbr\\u003eOn cast, Ryze creates a portal to a nearby location. After a few seconds, allies standing near the portal are teleported to the target location.","max_rank":3,"range_burn":[3000],"cooldown_burn":[210,180,150],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e \\u003cspellName\\u003eOverload\\u003c/spellName\\u003e damage bonus against targets with \\u003ckeywordMajor\\u003eFlux\\u003c/keywordMajor\\u003e increased to ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Ryze opens a portal to another location. After ? seconds, all allies near the portal are teleported to that location.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RyzeR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0013/ability_0013_R1.webm"}]},"14":{"id":14,"key":"Sion","name":"Sion","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sion.png","enemy_tips":["Even if Sion still hits a Decimating Smash, making him release the charge earlier reduces its impact.","Use the time after Sion has died to reposition and prepare for his return."],"ally_tips":["You only have very slight turning ability during Unstoppable Onslaught, so make sure to use it in straight paths.","Roar of the Slayer is a great setup ability to land a very powerful Decimating Smash.","The Soul Furnace buff displays how much shield strength is remaining, use this information to time its explosion perfectly."],"passive":{"name":"Glory in Death","description":"After being killed, Sion will temporarily reanimate with rapidly decaying Health. His attacks become very rapid, heal him, and deal bonus damage based on his target\'s maximum Health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Sion_Passive1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0014/ability_0014_P1.webm"},"spells":[{"key":"Q","name":"Decimating Smash","description":"Sion charges a powerful swing in an area in front of himself that will deal damage to enemies when released. If he charges for enough time, enemies hit by the swing will also be knocked up and stunned.","max_rank":5,"range_burn":[10000],"cooldown_burn":[10,9,8,7,6],"cost_burn":[45],"tooltip":"\\u003ccharge\\u003eBegin Charging\\u003c/charge\\u003e: Sion charges a heavy blow for up to 2 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease\\u003c/release\\u003e: Sion slams his axe down, briefly \\u003cstatus\\u003eSlowing\\u003c/status\\u003e and dealing between \\u003cphysicalDamage\\u003e? and ? physical damage\\u003c/physicalDamage\\u003e based on charge time. If Sion charged for at least 1 second, enemies are \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e and \\u003cstatus\\u003eStunned\\u003c/status\\u003e for between 1.25 to 2.25 seconds based on charge time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SionQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0014/ability_0014_Q1.webm"},{"key":"W","name":"Soul Furnace","description":"Sion shields himself and can reactivate after 3 seconds to deal Magic Damage to enemies nearby. When Sion kills enemies, he passively gains maximum Health.","max_rank":5,"range_burn":[500],"cooldown_burn":[15,14,13,12,11],"cost_burn":[65,70,75,80,85],"tooltip":"\\u003cspellPassive\\u003ePassive\\u003c/spellPassive\\u003e: Sion gains 4 max Health when he kills a unit, or 15 for champion takedowns, large minions and large monsters.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive\\u003c/spellActive\\u003e: Sion gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 6 seconds. After 3 seconds if the shield still holds, Sion can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to detonate the shield to deal \\u003cmagicDamage\\u003e? plus 10/11/12/13/14% max Health magic damage\\u003c/magicDamage\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SionW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0014/ability_0014_W1.webm"},{"key":"E","name":"Roar of the Slayer","description":"Sion fires a short range shockwave that damages and slows and reduces the Armor of the first enemy hit. If the shockwave hits a minion or monster, it will be knocked back, damaging, slowing, and reducing the Armor of all enemies that it passes through.","max_rank":5,"range_burn":[800],"cooldown_burn":[12,11,10,9,8],"cost_burn":[35,40,45,50,55],"tooltip":"Sion fires a shockwave, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds and removing \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e for ? seconds. Non-champions hit are \\u003cstatus\\u003eKnocked Back\\u003c/status\\u003e. Enemies hit by a \\u003cstatus\\u003eKnocked Back\\u003c/status\\u003e unit take the same damage and effects.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SionE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0014/ability_0014_E1.webm"},{"key":"R","name":"Unstoppable Onslaught","description":"Sion charges in a direction, ramping up speed over time. He can steer his charge slightly with the mouse cursor location. When he collides with an enemy he deals damage and knocks them up based on the distance he has charged.","max_rank":3,"range_burn":[7500],"cooldown_burn":[140,100,60],"cost_burn":[100],"tooltip":"Sion charges Unstoppably in a direction for 8 seconds, turning towards the mouse cursor. Sion stops on colliding with an enemy champion or wall or on \\u003crecast\\u003eRecasting\\u003c/recast\\u003e this Ability.  \\u003cbr /\\u003e\\u003cbr /\\u003eAt the end of the charge, Sion deals between \\u003cphysicalDamage\\u003e? and ? physical damage\\u003c/physicalDamage\\u003e based on distance travelled. Enemies close to Sion are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for between ? and ? seconds based on distance travelled. Enemies in a larger area are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for 3 seconds","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SionR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0014/ability_0014_R1.webm"}]},"15":{"id":15,"key":"Sivir","name":"Sivir","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sivir.png","enemy_tips":["Boomerang Blade costs a lot of mana to cast, so dodging it sets Sivir back. If it hits you on the way out, avoid its path on the way back.","Sivir is a powerful pushing champion, so leaving her unattended in a lane for too long will often result in your turrets being destroyed.","When laning against Sivir, it is possible to throw off the timing of her Spell Shield by faking an advance, then backing off."],"ally_tips":["Sivir\'s Boomerang Blade returns to her after reaching the max range, so you can shift position to hit enemies who would otherwise have evaded it.","Ricochet resets Sivir\'s basic attack timer on activation, so activating this immediately after landing a normal basic attack will maximize damage output.","Try saving Spell Shield for enemy abilities that can disable you such as stuns and roots."],"passive":{"name":"Fleet of Foot","description":"Sivir gains a short burst of Move Speed when she attacks an enemy champion.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Sivir_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0015/ability_0015_P1.webm"},"spells":[{"key":"Q","name":"Boomerang Blade","description":"Sivir hurls her crossblade like a boomerang, dealing damage each way.","max_rank":5,"range_burn":[1200],"cooldown_burn":[7],"cost_burn":[70,80,90,100,110],"tooltip":"Sivir hurls her crossblade, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to all enemies it cuts through before returning, dealing damage a second time. This Ability deals ?% less damage per non-champion hit, down to a minimum of ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SivirQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0015/ability_0015_Q1.webm"},{"key":"W","name":"Ricochet","description":"Sivir\'s next few basic attacks will bounce to nearby targets, dealing reduced damage to secondary targets.","max_rank":5,"range_burn":[20],"cooldown_burn":[12,10,9,7,6],"cost_burn":[75],"tooltip":"Sivir\'s next ? Attacks bounce to nearby enemies, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the initial target and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to each subsequent target.\\u003cbr /\\u003e\\u003cbr /\\u003eIf a given Attack critically strikes its first target, all subsequent bounces from that Attack will also critically strike.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SivirW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0015/ability_0015_W1.webm"},{"key":"E","name":"Spell Shield","description":"Creates a magical barrier that blocks a single enemy ability cast on Sivir. She receives Mana back if a spell is blocked.","max_rank":5,"range_burn":[20],"cooldown_burn":[22,19,16,13,10],"cost_burn":[0],"tooltip":"Sivir creates a magical barrier for 1.5 seconds that blocks the next incoming enemy Ability. If an Ability is blocked by the shield, Sivir regains \\u003cscaleMana\\u003e110/120/130/140/150 Mana\\u003c/scaleMana\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SivirE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0015/ability_0015_E1.webm"},{"key":"R","name":"On The Hunt","description":"Sivir leads her allies in battle, granting them a surge Move Speed for a period of time. Additionally passively grants Sivir bonus Attack Speed while Ricochet is active.","max_rank":3,"range_burn":[1000],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eSivir gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e while \\u003cspellName\\u003eRicochet\\u003c/spellName\\u003e is active.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive: \\u003c/spellPassive\\u003eSivir rallies her allies for ? seconds, granting all nearby allies \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SivirR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0015/ability_0015_R1.webm"}]},"16":{"id":16,"key":"Soraka","name":"Soraka","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Soraka.png","enemy_tips":["Focus on attacking Soraka when she ever ventures to the frontline to heal her allies.","Take advantage of Soraka\'s long cooldown on Equinox if she uses it to harass.","It\'s easier to focus Soraka than the ally she is healing."],"ally_tips":["Soraka is a powerful ally in battle, using her strong healing to keep the party moving forward.","You can use Wish on your allies from across the map to save them from otherwise fatal events.","Equinox can be used as a powerful zoning tool to keep enemies at bay."],"passive":{"name":"Salvation","description":"Soraka runs faster towards nearby low health allies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Soraka_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0016/ability_0016_P1.webm"},"spells":[{"key":"Q","name":"Starcall","description":"A star falls from the sky at the target location dealing magic damage and slowing enemies. If an enemy champion is hit by Starcall, Soraka recovers Health.","max_rank":5,"range_burn":[810],"cooldown_burn":[8,7,6,5,4],"cost_burn":[45,50,55,60,65],"tooltip":"Soraka calls down a star, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eHitting an enemy champion grants Soraka \\u003ckeywordMajor\\u003eRejuvenation\\u003c/keywordMajor\\u003e, which restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e over ? seconds and grants \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over the same duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SorakaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0016/ability_0016_Q1.webm"},{"key":"W","name":"Astral Infusion","description":"Soraka sacrifices a portion of her own health to heal another friendly champion.","max_rank":5,"range_burn":[550],"cooldown_burn":[6,5,4,3,2],"cost_burn":[40,45,50,55,60],"tooltip":"Soraka restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to another allied champion.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Soraka is affected by \\u003ckeywordMajor\\u003eRejuvenation\\u003c/keywordMajor\\u003e, the Health cost will be reduced by ?%, and the target will gain \\u003ckeywordMajor\\u003eRejuvenation\\u003c/keywordMajor\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SorakaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0016/ability_0016_W1.webm"},{"key":"E","name":"Equinox","description":"Creates a zone at a location that silences all enemies inside. When the zone expires, all enemies still inside are rooted.","max_rank":5,"range_burn":[925],"cooldown_burn":[20,19,18,17,16],"cost_burn":[70,75,80,85,90],"tooltip":"Soraka creates a starfield that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to champions. The field lingers for ? seconds, \\u003cstatus\\u003eSilencing\\u003c/status\\u003e enemies inside. When the zone disappears, champions inside the zone are \\u003cstatus\\u003eRooted\\u003c/status\\u003e for ? second(s) and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SorakaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0016/ability_0016_E1.webm"},{"key":"R","name":"Wish","description":"Soraka fills her allies with hope, instantly restoring health to herself and all friendly champions.","max_rank":3,"range_burn":[25000],"cooldown_burn":[160,145,130],"cost_burn":[100],"tooltip":"Soraka calls upon divine powers, restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e to them, regardless of distance. Healing is increased to \\u003chealing\\u003e?\\u003c/healing\\u003e on targets below 40% Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SorakaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0016/ability_0016_R1.webm"}]},"17":{"id":17,"key":"Teemo","name":"Teemo","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Teemo.png","enemy_tips":["Teemo\'s Toxic Shot punishes players who get hit and back out, so stay at a safe range until you\'re ready to commit.","It can be valuable to use Oracle\'s Lens(Trinket) to destroy mushrooms around key locations."],"ally_tips":["Teemo\'s mushrooms can be used to farm creep waves very effectively.","Place your mushrooms at key locations on the map, such as by the Dragon or Baron Nashor, to reveal when your enemies might be attempting to kill them."],"passive":{"name":"Guerrilla Warfare","description":"If Teemo stands still and takes no actions for a short duration, he becomes Invisible indefinitely. If he\'s in brush, Teemo can enter and maintain his Invisibility while moving. After leaving Invisibility, Teemo gains the Element of Surprise, increasing his Attack Speed for a few seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Teemo_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0017/ability_0017_P1.webm"},"spells":[{"key":"Q","name":"Blinding Dart","description":"Obscures an enemy\'s vision with a powerful venom, dealing damage to the target unit and blinding it for the duration.","max_rank":5,"range_burn":[680],"cooldown_burn":[7],"cost_burn":[70,75,80,85,90],"tooltip":"Teemo fires a dart, \\u003cstatus\\u003eBlinding\\u003c/status\\u003e the target for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BlindingDart.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0017/ability_0017_Q1.webm"},{"key":"W","name":"Move Quick","description":"Teemo scampers around, passively increasing his Move Speed until he is struck by an enemy champion or turret. Teemo can sprint to gain bonus Move Speed that isn\'t stopped by being struck for a short time.","max_rank":5,"range_burn":[20],"cooldown_burn":[14],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Teemo gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e while he hasn\'t been damaged by a champion or turret in the last 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Teemo sprints, gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e that is not lost when struck for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MoveQuick.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0017/ability_0017_W1.webm"},{"key":"E","name":"Toxic Shot","description":"Each of Teemo\'s attacks will poison the target, dealing damage on impact and each second after for 4 seconds.","max_rank":5,"range_burn":[680],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Teemo\'s Attacks apply poison, dealing an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ToxicShot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0017/ability_0017_E1.webm"},{"key":"R","name":"Noxious Trap","description":"Teemo throws an explosive poisonous trap using one of the mushrooms stored in his pack. If an enemy steps on the trap, it will release a poisonous cloud, slowing enemies and damaging them over time. If Teemo throws a mushroom onto another mushroom it will bounce, gaining additional range.","max_rank":3,"range_burn":[400,650,900],"cooldown_burn":[0],"cost_burn":[75],"tooltip":"Teemo tosses a mushroom trap that detonates when stepped on. The traps \\u003cstatus\\u003eSlow\\u003c/status\\u003e by ?% and deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds. Enemies are revealed for the same duration.\\u003cbr /\\u003e\\u003cbr /\\u003eTraps last ? minutes and are stealthed. A mushroom tossed onto another mushroom bounces before landing at its position. This Ability has ? charges (? second refresh).\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TeemoRCast.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0017/ability_0017_R1.webm"}]},"18":{"id":18,"key":"Tristana","name":"Tristana","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Tristana.png","enemy_tips":["If you see Tristana activate Rapid Fire in a fight, stun her and try to back off until the spell dissipates.","Stand away from your creeps in a lane to take less collateral damage from Explosive Charge."],"ally_tips":["Her massive gun allows Tristana to fire on targets at a great distance. Utilize this to prevent your enemies from ever laying a hand on you.","Use Rocket Jump after you have stacked up your Explosive Charge on an enemy to finish them off with a burst of damage.","Use Rapid Fire to help stack up your Explosive Charge on enemy champions."],"passive":{"name":"Draw a Bead","description":"Increases Tristana\'s Attack Range as she levels.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Tristana_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0018/ability_0018_P1.webm"},"spells":[{"key":"Q","name":"Rapid Fire","description":"Tristana fires her weapon rapidly, increasing her Attack Speed for a short time.","max_rank":5,"range_burn":[20],"cooldown_burn":[20,19,18,17,16],"cost_burn":[0],"tooltip":"Tristana goes full-auto, gaining \\u003cattackSpeed\\u003e50/65/80/95/110% Attack Speed\\u003c/attackSpeed\\u003e for 7 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TristanaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0018/ability_0018_Q1.webm"},{"key":"W","name":"Rocket Jump","description":"Tristana fires at the ground to propel her to a distant location, dealing damage and slowing surrounding units for a brief period where she lands.","max_rank":5,"range_burn":[900],"cooldown_burn":[22,20,18,16,14],"cost_burn":[60],"tooltip":"Tristana launches herself, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 60% for 1/1.5/2/2.5/3 seconds upon landing.\\u003cbr /\\u003e\\u003cbr /\\u003eChampion takedowns and max stack \\u003cspellName\\u003eExplosive Charge\\u003c/spellName\\u003e detonations on champions refresh this Ability\'s Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TristanaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0018/ability_0018_W1.webm"},{"key":"E","name":"Explosive Charge","description":"When Tristana kills a unit, her cannonballs burst into shrapnel, dealing damage to surrounding enemies. Can be activated to place a bomb on a target enemy that explodes after a short duration dealing damage to surrounding units.","max_rank":5,"range_burn":[550],"cooldown_burn":[16,15,15,14,14],"cost_burn":[50,55,60,65,70],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eTristana\'s Attacks that kill enemies deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding enemies.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Tristana attaches a bomb to an enemy or turret that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to surrounding enemies after ? seconds. The damage is increased by ?% Critical Strike Chance and by ?% each time Tristana hits an Attack or Ability (max 4 stacks).\\u003cbr /\\u003e\\u003cbr /\\u003eAt ? stacks, the bomb explodes immediately (max \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TristanaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0018/ability_0018_E1.webm"},{"key":"R","name":"Buster Shot","description":"Tristana loads a massive cannonball into her weapon and fires it at an enemy unit. This deals Magic Damage and knocks the target back. If the target is carrying the Explosive Charge bomb, the bomb detonation radius is doubled.","max_rank":3,"range_burn":[550],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Tristana fires a massive cannonball, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the target and \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e along with surrounding enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TristanaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0018/ability_0018_R1.webm"}]},"19":{"id":19,"key":"Warwick","name":"Warwick","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Warwick.png","enemy_tips":["Warwick\'s attacks heal him at low health. Save your disables to finish him off.","Warwick is empowered versus low health enemies. Manage your health to keep him at bay.","Warwick\'s ultimate cast range scales with his Move Speed."],"ally_tips":["Follow your Blood Hunt trails to low health enemy champions.","Infinite Duress (R)\'s distance scales with any Move Speed you gain, even from ally buffs and summoner spells.","Jaws of the Beast (Q) will follow enemies who run, dash or teleport if you keep the button held down."],"passive":{"name":"Eternal Hunger","description":"Warwick\'s basic attacks deal bonus magic damage. If Warwick is below 50% health, he heals the same amount. If Warwick is below 25% health, this healing triples.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/WarwickP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0019/ability_0019_P1.webm"},"spells":[{"key":"Q","name":"Jaws of the Beast","description":"Warwick lunges forward and bites his target, dealing damage based on their maximum health and healing for damage dealt.","max_rank":5,"range_burn":[350],"cooldown_burn":[6],"cost_burn":[50,60,70,80,90],"tooltip":"\\u003ctap\\u003eTap:\\u003c/tap\\u003e Warwick lunges forward and bites, dealing \\u003cmagicDamage\\u003e? plus 6/7/8/9/10% max Health magic damage\\u003c/magicDamage\\u003e and restoring \\u003chealing\\u003e25/37.5/50/62.5/75% of damage dealt as Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003chold\\u003eHold:\\u003c/hold\\u003e Warwick lunges and clamps his jaws on the target, leaping behind them. While clamped, Warwick follows all movement of the target. After releasing his hold, he does the same damage and healing.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WarwickQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0019/ability_0019_Q1.webm"},{"key":"W","name":"Blood Hunt","description":"Warwick senses enemies below 50% health, gaining Move Speed toward and attack speed against them. When they fall below 20% health, he frenzies and these bonuses triple.","max_rank":5,"range_burn":[4000],"cooldown_burn":[120,105,90,75,60],"cost_burn":[70],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Warwick can sense champions below 50% Health, gaining \\u003cspeed\\u003e35/40/45/50/55% Move Speed\\u003c/speed\\u003e towards them and gaining \\u003cattackSpeed\\u003e70/80/90/100/110% Attack Speed\\u003c/attackSpeed\\u003e against them. These bonuses are tripled against enemies below 20% Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Warwick can briefly sense all enemies, and gains this Ability\'s passive effect against the closest champion for 8 seconds, regardless of Health. Warwick cannot use this Ability while in combat with champions.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WarwickW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0019/ability_0019_W1.webm"},{"key":"E","name":"Primal Howl","description":"Warwick gains damage reduction for 2.5 seconds. At the end, or if re-activated, he howls, causing nearby enemies to flee for 1 second.","max_rank":5,"range_burn":[375],"cooldown_burn":[15,14,13,12,11],"cost_burn":[40],"tooltip":"Warwick gains 35/40/45/50/55% damage reduction for 2.5 seconds. After it ends, Warwick howls, \\u003cstatus\\u003eFearing\\u003c/status\\u003e nearby enemies for 1 second. Warwick can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to end the Ability early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WarwickE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0019/ability_0019_E1.webm"},{"key":"R","name":"Infinite Duress","description":"Warwick leaps in a direction (scaling with his bonus Move Speed), suppressing the first champion he collides with for 1.5 seconds.","max_rank":3,"range_burn":[25000],"cooldown_burn":[110,90,70],"cost_burn":[100],"tooltip":"Warwick leaps a huge distance that scales with his \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e, \\u003cstatus\\u003eSuppressing\\u003c/status\\u003e the first champion he collides with while he channels for ? seconds. He attacks that champion 3 times over the duration, applying %i:OnHit% \\u003cOnHit\\u003eOn-Hit\\u003c/OnHit\\u003e effects and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Warwick restores \\u003chealing\\u003e100% of all damage dealt\\u003c/healing\\u003e during the channel as Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/WarwickR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0019/ability_0019_R1.webm"}]},"20":{"id":20,"key":"Nunu","name":"Nunu \\u0026 Willump","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nunu.png","enemy_tips":["Interrupting the charge up on Absolute Zero will lower the amount of damage your team takes.","Using Summoner Flash is a surefire way to escape Absolute Zero.","Biggest Snowball Ever moves very fast but cannot turn as quickly, so don\'t try to escape it by running away in a straight line.  Instead, make sudden, sharp turns."],"ally_tips":["Consume allows Nunu to stay in a lane against ranged opponents.","You can choose to interrupt Absolute Zero early for partial damage if an opponent is about to run out of range.","It\'s often beneficial to delay the casting of Absolute Zero until the initial round of disables are used. Try to hang back before rushing into a team fight."],"passive":{"name":"Call of the Freljord","description":"Nunu increases the attack speed and Move Speed of Willump and a nearby ally, and causes Willump\'s basic attacks to damage enemies around the target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/NunuPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0020/ability_0020_P1.webm"},"spells":[{"key":"Q","name":"Consume","description":"Willump takes a bite out of a minion, monster, or enemy champion, dealing damage and healing himself.","max_rank":5,"range_burn":[125],"cooldown_burn":[12,11,10,9,8],"cost_burn":[60],"tooltip":"Nunu asks Willump to take a bite of an enemy, dealing \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e when used against a minion or jungle monster. Against a champion, it instead deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThe \\u003chealing\\u003ehealing\\u003c/healing\\u003e is increased by ?% when Nunu and Willump are below ?% Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NunuQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0020/ability_0020_Q1.webm"},{"key":"W","name":"Biggest Snowball Ever!","description":"Willump creates a snowball that grows in size and speed as he rolls it.  The snowball damages and knocks up enemies.","max_rank":5,"range_burn":[7500],"cooldown_burn":[14],"cost_burn":[50,55,60,65,70],"tooltip":"Nunu and Willump create a snowball that grows in size and speed as they roll it. They turn slower while rolling it, but can increase turning speed by holding the turn.\\u003cbr /\\u003e\\u003cbr /\\u003eThe snowball does between \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for between ? and ? seconds when it collides with a champion, large monster or wall. These values scale up with distance rolled.\\u003cbr /\\u003e\\u003cbr /\\u003eNunu and Willump can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to let the snowball go early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NunuW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0020/ability_0020_W1.webm"},{"key":"E","name":"Snowball Barrage","description":"Nunu throws multiple snowballs that damage enemies.  When he\'s finished, Willump roots any champions or large monsters that were hit by a snowball.","max_rank":5,"range_burn":[625],"cooldown_burn":[14,13,12,11,10],"cost_burn":[50,55,60,65,70],"tooltip":"Nunu throws three snowballs, dealing a total of \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per snowball and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies hit by all three by ?% for ? seconds. Nunu can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this up to twice more.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter ? seconds, Nunu \\u003cstatus\\u003eRoots\\u003c/status\\u003e all nearby enemies that had been \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by the snowballs for ? seconds and deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NunuE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0020/ability_0020_E1.webm"},{"key":"R","name":"Absolute Zero","description":"Nunu \\u0026 Willump create a powerful blizzard in an area that slows enemies and deals massive damage at the end.","max_rank":3,"range_burn":[650],"cooldown_burn":[110,100,90],"cost_burn":[100],"tooltip":"Nunu and Willump channel a powerful blizzard for up to ? seconds. Enemies inside are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?%, increasing to ?% over the duration. Nunu and Willump also gain \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for the duration before decaying over ? seconds afterwards.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen the blizzard ends, it detonates, dealing between \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e based on channel time. Nunu and Willump can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to end the blizzard early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NunuR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0020/ability_0020_R1.webm"}]},"21":{"id":21,"key":"MissFortune","name":"Miss Fortune","image_url":"https://opgg-static.akamaized.net/images/lol/champion/MissFortune.png","enemy_tips":["Miss Fortune\'s speed boost is removed if she is damaged by an enemy.","Miss Fortune is easy to kill if you can reach her; target her first in team fights."],"ally_tips":["Miss Fortune ramps up speed if she hasn\'t recently taken damage. Avoid getting hit to move very fast.","Use Double Up on the furthest enemy minion if enemy champions are hiding in back; it will bounce to them for lots of damage.","Make sure to utilize Love Tap while Strut is on cooldown to maximize the active\'s availability."],"passive":{"name":"Love Tap","description":"Miss Fortune deals bonus physical damage whenever she basic attacks a new target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/MissFortune_W.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0021/ability_0021_P1.webm"},"spells":[{"key":"Q","name":"Double Up","description":"Miss Fortune fires a bullet at an enemy, damaging them and a target behind them. Both strikes can also apply Love Tap.","max_rank":5,"range_burn":[650],"cooldown_burn":[7,6,5,4,3],"cost_burn":[43,46,49,52,55],"tooltip":"Miss Fortune fires a bouncing shot, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to an enemy and to another one behind them. \\u003cbr /\\u003e\\u003cbr /\\u003eThe second shot can critically strike. It always critically strikes if the first shot kills its target. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MissFortuneRicochetShot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0021/ability_0021_Q1.webm"},{"key":"W","name":"Strut","description":"Miss Fortune passively gains Move Speed when not attacked. This ability can be activated to grant bonus Attack Speed for a short duration. While it\'s on cooldown, Love Taps reduce the remaining cooldown of Strut.","max_rank":5,"range_burn":[600],"cooldown_burn":[12],"cost_burn":[45],"tooltip":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e After ? seconds of not taking damage, Miss Fortune gains \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e. After another ? seconds, this increases to \\u003cspeed\\u003e?\\u003c/speed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Gain the passive effect\'s full \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e bonus and \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eLove Taps\\u003c/spellName\\u003e reduce the Cooldown of this Ability by ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MissFortuneViciousStrikes.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0021/ability_0021_W1.webm"},{"key":"E","name":"Make It Rain","description":"Miss Fortune reveals an area with a flurry of bullets, dealing waves of damage to opponents and slowing them.","max_rank":5,"range_burn":[1000],"cooldown_burn":[18,16,14,12,10],"cost_burn":[80],"tooltip":"Miss Fortune rains bullets, revealing an area, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ? and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second for ? seconds (total \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MissFortuneScattershot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0021/ability_0021_E1.webm"},{"key":"R","name":"Bullet Time","description":"Miss Fortune channels a barrage of bullets into a cone in front of her, dealing large amounts of damage to enemies. Each wave of Bullet Time can critically strike","max_rank":3,"range_burn":[25000],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Miss Fortune channels a barrage of bullets, firing ? waves over ? seconds, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e per wave (total \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e).\\u003cbr /\\u003e\\u003cbr /\\u003eEach wave can critically strike for %i:scaleCrit% \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e (total %i:scaleCrit% \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MissFortuneBulletTime.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0021/ability_0021_R1.webm"}]},"22":{"id":22,"key":"Ashe","name":"Ashe","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ashe.png","enemy_tips":["Ashe has very few defensive options, and she\'s a good target to gank.","Be wary of moving around the map alone if Ashe has not recently cast her Enchanted Crystal Arrow."],"ally_tips":["Try to fire Enchanted Crystal Arrow in the same direction enemies are moving, so it is more likely to hit.","Volley arrows are blocked by the first enemy they hit, so keep your distance to avoid having them all absorbed by enemy frontliners.","Hawkshot reveals units in brush. If a team fight is occuring in the jungle it can give you a significant advantage."],"passive":{"name":"Frost Shot","description":"Ashe\'s attacks slow their target, causing her to deal increased damage to these targets.\\u003cbr\\u003e\\u003cbr\\u003eAshe\'s critical strikes deal no bonus damage but apply an empowered slow to the target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Ashe_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0022/ability_0022_P1.webm"},"spells":[{"key":"Q","name":"Ranger\'s Focus","description":"Ashe builds up Focus by attacking. At maximum Focus, Ashe can cast Ranger\'s Focus to consume all stacks of Focus, temporarily increasing her Attack Speed and transforming her basic attack into a powerful flurry attack for the duration.","max_rank":5,"range_burn":[400],"cooldown_burn":[0],"cost_burn":[50],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eAshe\'s Attacks grant a stack for 4 seconds. At 4 stacks, she may activate this ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive:\\u003c/spellPassive\\u003e Ashe gains \\u003cattackSpeed\\u003e20/25/30/35/40% Attack Speed\\u003c/attackSpeed\\u003e and her Attacks deal \\u003cphysicalDamage\\u003e? damage\\u003c/physicalDamage\\u003e instead for 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AsheQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0022/ability_0022_Q1.webm"},{"key":"W","name":"Volley","description":"Ashe fires arrows in a cone for increased damage. Also applies Frost Shot.","max_rank":5,"range_burn":[1200],"cooldown_burn":[18,14,11,7,4],"cost_burn":[75,70,65,60,55],"tooltip":"Ashe fires a volley of ? arrows, each dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Enemies can be hit by multiple arrows, but only take damage from the first.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Volley.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0022/ability_0022_W1.webm"},{"key":"E","name":"Hawkshot","description":"Ashe sends her Hawk Spirit on a scouting mission anywhere on the map.","max_rank":5,"range_burn":[25000],"cooldown_burn":[5],"cost_burn":[0],"tooltip":"Ashe sends forth a hawk to grant vision for 5 seconds anywhere on the map. It also reveals the area around it as it flies.\\u003cbr /\\u003e\\u003cbr /\\u003eThis ability has 2 charges (? second recharge).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AsheSpiritOfTheHawk.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0022/ability_0022_E1.webm"},{"key":"R","name":"Enchanted Crystal Arrow","description":"Ashe fires a missile of ice in a straight line. If the arrow collides with an enemy Champion, it deals damage and stuns the Champion, stunning for longer the farther arrow has traveled. In addition, surrounding enemy units take damage and are slowed.","max_rank":3,"range_burn":[25000],"cooldown_burn":[80,70,60],"cost_burn":[100],"tooltip":"Ashe launches a crystal arrow of ice that \\u003cstatus\\u003eStuns\\u003c/status\\u003e the first champion hit and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The \\u003cstatus\\u003eStun\\u003c/status\\u003e duration increases with distance travelled, up to ? seconds. Surrounding enemies take half damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EnchantedCrystalArrow.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0022/ability_0022_R1.webm"}]},"23":{"id":23,"key":"Tryndamere","name":"Tryndamere","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Tryndamere.png","enemy_tips":["Try harassing Tryndamere early so he can\'t kill minions and heal with Bloodlust.","Remember, Tryndamere can only slow you if you are facing away from him.","Most of Tryndamere\'s damage is physical. If he\'s getting too strong, consider buying a Thornmail."],"ally_tips":["Delaying the activation of Undying Rage is a very effective way to make an enemy champion over-commit to trying to kill you.","Bloodlust is an excellent way to heal Tryndamere. Try not to let it fade off before you activate it.","If the enemy is stacking Armor, try building items like Last Whisper or Youmuu\'s Ghostblade."],"passive":{"name":"Battle Fury","description":"Tryndamere gains Fury for each attack, critical strike, and killing blow he makes. Fury passively increases his Critical Strike Chance and can be consumed with his Bloodlust spell.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Tryndamere_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0023/ability_0023_P1.webm"},"spells":[{"key":"Q","name":"Bloodlust","description":"Tryndamere thrives on the thrills of combat, increasing his Attack Damage as he is more and more wounded. He can cast Bloodlust to consume his Fury and heal himself.","max_rank":5,"range_burn":[400],"cooldown_burn":[12],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Tryndamere thirsts for blood, gaining \\u003cscaleAD\\u003e10/15/20/25/30 Attack Damage\\u003c/scaleAD\\u003e plus \\u003cscaleAD\\u003e0.15/0.25/0.35/0.45/0.55\\u003c/scaleAD\\u003e per 1% missing Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Tryndamere consumes his \\u003ckeywordMajor\\u003eFury\\u003c/keywordMajor\\u003e, restoring \\u003chealing\\u003e? plus 0.5/0.95/1.4/1.85/2.3 Health per Fury\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TryndamereQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0023/ability_0023_Q1.webm"},{"key":"W","name":"Mocking Shout","description":"Tryndamere lets out an insulting cry, decreasing surrounding champions\' Attack Damage. Enemies with their backs turned to Tryndamere also have their Move Speed reduced.","max_rank":5,"range_burn":[850],"cooldown_burn":[14],"cost_burn":[0],"tooltip":"Tryndamere hurls insults, reducing champions\' Attack Damage by 20/35/50/65/80 for 4 seconds. Enemies with their backs towards Tryndamere are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 30/37.5/45/52.5/60% for the same duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TryndamereW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0023/ability_0023_W1.webm"},{"key":"E","name":"Spinning Slash","description":"Tryndamere slices toward a target unit, dealing damage to enemies in his path.","max_rank":5,"range_burn":[650],"cooldown_burn":[12,11,10,9,8],"cost_burn":[0],"tooltip":"Tryndamere spins through his enemies, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and generating \\u003ckeywordMajor\\u003e? Fury\\u003c/keywordMajor\\u003e per enemy hit.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability\'s Cooldown is reduced by 0.75 second when Tryndamere critically strikes, and reduced by 1.5 seconds when critically striking a champion.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TryndamereE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0023/ability_0023_E1.webm"},{"key":"R","name":"Undying Rage","description":"Tryndamere\'s lust for battle becomes so strong that he is unable to die, no matter how wounded he becomes.","max_rank":3,"range_burn":[400],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Tryndamere becomes completely immune to death for 5 seconds, refusing to be reduced below 30/50/70 Health, and instantly gains \\u003ckeywordMajor\\u003e50/75/100 Fury\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UndyingRage.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0023/ability_0023_R1.webm"}]},"24":{"id":24,"key":"Jax","name":"Jax","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Jax.png","enemy_tips":["Try to engage him in short bursts instead of going toe-to-toe with him. Preventing him from attacking consecutively drastically lowers his damage output.","Jax can dodge all incoming attacks for a very short amount of time and stuns enemies in melee range when it ends. Wait to strike him until after his dodge is finished."],"ally_tips":["Jax can Leap Strike to friendly units, including wards. You can use them to plan your escape.","Jax benefits greatly from items that have both Ability Power and Attack Damage such as Guinsoo\'s Rageblade and Hextech Gunblade."],"passive":{"name":"Relentless Assault","description":"Jax\'s consecutive basic attacks continuously increase his Attack Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Armsmaster_MasterOfArms.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0024/ability_0024_P1.webm"},"spells":[{"key":"Q","name":"Leap Strike","description":"Jax leaps toward a unit. If they are an enemy, he strikes them with his weapon.","max_rank":5,"range_burn":[700],"cooldown_burn":[8,7,7,6,6],"cost_burn":[65],"tooltip":"Jax leaps to a friendly or enemy unit or ward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e if it is an enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JaxLeapStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0024/ability_0024_Q1.webm"},{"key":"W","name":"Empower","description":"Jax charges his weapon with energy, causing his next attack to deal additional damage.","max_rank":5,"range_burn":[300],"cooldown_burn":[7,6,5,4,3],"cost_burn":[30],"tooltip":"Jax charges his weapon with energy, causing his next Attack or \\u003cspellName\\u003eLeap Strike\\u003c/spellName\\u003e to deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JaxEmpowerTwo.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0024/ability_0024_W1.webm"},{"key":"E","name":"Counter Strike","description":"Jax\'s combat prowess allows him to dodge all incoming attacks for a short duration and then quickly counterattack, stunning all surrounding enemies.","max_rank":5,"range_burn":[300],"cooldown_burn":[14,12,11,9,8],"cost_burn":[50,60,70,80,90],"tooltip":"Jax enters a defensive stance for up to 2 seconds, dodging incoming Attacks and taking 25% less damage from area of effect Abilities.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter 2 seconds or \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, Jax deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eStuns\\u003c/status\\u003e nearby enemies for 1 second. Deals 20% increased damage for each Attack Jax dodged (max: 100%).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JaxCounterStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0024/ability_0024_E1.webm"},{"key":"R","name":"Grandmaster\'s Might","description":"Every third consecutive attack deals additional Magic Damage. Additionally, Jax can activate this ability to strengthen his resolve, increasing his Armor and Magic Resist for a short duration.","max_rank":3,"range_burn":[100],"cooldown_burn":[80],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every third Attack deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Jax strengthens his resolve, granting him \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JaxRelentlessAssault.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0024/ability_0024_R1.webm"}]},"25":{"id":25,"key":"Morgana","name":"Morgana","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Morgana.png","enemy_tips":["Tormented Shadow deals tons of damage to units missing large amounts of Health. When low on Health, be wary of Morgana\'s attempts to trap you within its reach.","Morgana often needs to land Dark Binding to setup her other attacks. Use your minions as shields against Dark Binding.","Black Shield makes Morgana immune to disabling effects, but can be broken with magic damage."],"ally_tips":["Shrewd use of Black Shield can determine the outcome of team fights.","Items that provide survivability allow Morgana to become extremely difficult to kill in conjunction with Black Shield and Soul Shackles.","Tormented Shadow is an excellent farming tool if you\'re by yourself in a lane."],"passive":{"name":"Soul Siphon","description":"Morgana drains spirit from her enemies, healing as she deals damage to champions, large minions, and medium and larger jungler monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/FallenAngel_Empathize.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0025/ability_0025_P1.webm"},"spells":[{"key":"Q","name":"Dark Binding","description":"Morgana binds an enemy in place with dark magic, forcing them to feel the pain they\'ve caused and dealing magic damage. ","max_rank":5,"range_burn":[1250],"cooldown_burn":[10],"cost_burn":[50,55,60,65,70],"tooltip":"Morgana hurls a blast of starfire that \\u003cstatus\\u003eRoots\\u003c/status\\u003e the first enemy hit for ? seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MorganaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0025/ability_0025_Q1.webm"},{"key":"W","name":"Tormented Shadow","description":"Morgana casts a cursed shadow on an area, damaging enemies who dare stand in her dark circle. They receive magic damage over time, which increases the lower health they are.","max_rank":5,"range_burn":[900],"cooldown_burn":[12],"cost_burn":[70,85,100,115,130],"tooltip":"Morgana ignites the ground for ? seconds, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second, increased by up to ?% based on the targets\' percentage missing health.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability\'s Cooldown is reduced by ?% every time Morgana is healed by \\u003cspellName\\u003eSoul Siphon\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MorganaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0025/ability_0025_W1.webm"},{"key":"E","name":"Black Shield","description":"Morgana anoints an ally with a protective barrier of starfire, which absorbs magical damage and disabling effects until it is broken.","max_rank":5,"range_burn":[800],"cooldown_burn":[24,22,20,18,16],"cost_burn":[80],"tooltip":"Morgana grants an ally champion \\u003cshield\\u003e? Magic Shield\\u003c/shield\\u003e for ? seconds. The shield prevents \\u003cstatus\\u003eDisabling\\u003c/status\\u003e and \\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e effects until it breaks.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MorganaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0025/ability_0025_E1.webm"},{"key":"R","name":"Soul Shackles","description":"Morgana unleashes the full force of her Celestial power as she unbinds her wings and hovers above the ground. She lashes chains of dark pain onto nearby enemy champions, gaining Move Speed towards them. The chains slow and deal initial damage and, after a delay, stun those who are unable to break them.","max_rank":3,"range_burn":[625],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Morgana chains herself to nearby enemy Champions, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?%. After ? seconds, enemies unable to break the chains take an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile casting this Ability, Morgana gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e towards enemies she has chained.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MorganaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0025/ability_0025_R1.webm"}]},"26":{"id":26,"key":"Zilean","name":"Zilean","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zilean.png","enemy_tips":["If you\'re able to match Zilean\'s speed, it can sometimes be beneficial to wait until his ultimate has faded before landing the killing blow.","Zilean is fragile if a team focuses on him, but otherwise he\'s very difficult to kill. Commit to killing him as a team."],"ally_tips":["You can combine the use of Time Bomb and Rewind to place two Time Bombs on a target quickly. Placing the second bomb will detonate the first and stun all nearby enemies.","Time Warp is an effective way to enable allies to finish off enemies, or escape from a losing battle.","Chronoshift is a powerful deterrent to attacking your carries, but casting Chronoshift too early in a fight can cause the enemy to switch targets too soon, making it less effective."],"passive":{"name":"Time In A Bottle","description":"Zilean stores time as Experience and can grant it to his allies. When he has enough Experience to finish an ally\'s level up, he can right-click them to impart it. Zilean receives as much Experience as he gives.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Zilean_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0026/ability_0026_P1.webm"},"spells":[{"key":"Q","name":"Time Bomb","description":"Tosses a bomb to target area that sticks to units that come near it (prioritizes Champions). It detonates after 3 seconds, dealing area of effect damage. If a Time Bomb is detonated early by another Time Bomb, it also stuns enemies.","max_rank":5,"range_burn":[900],"cooldown_burn":[10,9,9,8,8],"cost_burn":[60,65,70,75,80],"tooltip":"Zilean tosses a time-delayed bomb that sticks to the first unit which comes within a small area around it. After 3 seconds it detonates, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003ePlacing a second bomb on a unit that already has one detonates the first bomb immediately and \\u003cstatus\\u003eStuns\\u003c/status\\u003e enemies in the blast for 1.1/1.2/1.3/1.4/1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZileanQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0026/ability_0026_Q1.webm"},{"key":"W","name":"Rewind","description":"Zilean can prepare himself for future confrontations, reducing the cooldowns of his other basic abilities.","max_rank":5,"range_burn":[600],"cooldown_burn":[14,12,10,8,6],"cost_burn":[35],"tooltip":"Zilean turns time, reducing his other basic Ability Cooldowns by 10 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZileanW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0026/ability_0026_W1.webm"},{"key":"E","name":"Time Warp","description":"Zilean bends time around any unit, decreasing an enemy\'s Move Speed or increasing an ally\'s Move Speed for a short time.","max_rank":5,"range_burn":[550],"cooldown_burn":[15],"cost_burn":[50],"tooltip":"Zilean \\u003cstatus\\u003eSlows\\u003c/status\\u003e an enemy champion by 40/55/70/85/99% or grants an allied champion \\u003cspeed\\u003e40/55/70/85/99% Move Speed\\u003c/speed\\u003e for 2.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TimeWarp.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0026/ability_0026_E1.webm"},{"key":"R","name":"Chronoshift","description":"Zilean places a protective time rune on an allied champion, teleporting the champion back in time if they take lethal damage.","max_rank":3,"range_burn":[900],"cooldown_burn":[120,90,60],"cost_burn":[125,150,175],"tooltip":"Zilean grants a protective time rune to an allied champion for ? seconds. If the target would die, the rune rewinds their timeline, putting them into Stasis for ? seconds, then reviving them and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ChronoShift.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0026/ability_0026_R1.webm"}]},"27":{"id":27,"key":"Singed","name":"Singed","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Singed.png","enemy_tips":["Keep your distance to avoid being Flung back into Singed\'s allies.","Singed needs to run close to your team to be effective. Try to take advantage of this by using crowd control effects on him while attacking his allies.","Be careful when chasing Singed. He\'s very difficult to bring down, and can leave his Poison Trail to damage you in your pursuit."],"ally_tips":["Poison Trail is very effective at farming and harassing, allowing Singed to dominate the flow of whatever lane he\'s in.","Use Insanity Potion to trick your opponents into chasing you through your Poison Trail.","Flinging enemies into your tower can deal heavy amounts of damage to them."],"passive":{"name":"Noxious Slipstream","description":"Singed drafts off nearby champions, gaining a burst of Move Speed when passing them.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Singed_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0027/ability_0027_P1.webm"},"spells":[{"key":"Q","name":"Poison Trail","description":"Leaves a trail of poison behind Singed, dealing damage to enemies caught in the path.","max_rank":5,"range_burn":[20],"cooldown_burn":[0],"cost_burn":[13],"tooltip":"\\u003ctoggle\\u003eToggle:\\u003c/toggle\\u003e Singed lays a poisonous trail that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PoisonTrail.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0027/ability_0027_Q1.webm"},{"key":"W","name":"Mega Adhesive","description":"Throws a vial of mega adhesive on the ground, slowing and grounding enemies who walk on it.","max_rank":5,"range_burn":[1000],"cooldown_burn":[17,16,15,14,13],"cost_burn":[60,70,80,90,100],"tooltip":"Singed hurls a cask of sticky liquid, \\u003cstatus\\u003eGrounding\\u003c/status\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies in the area by 50/55/60/65/70% for 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MegaAdhesive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0027/ability_0027_W1.webm"},{"key":"E","name":"Fling","description":"Damages target enemy unit and flings them into the air behind Singed. If the target Singed flings lands in his Mega Adhesive, they are also rooted.","max_rank":5,"range_burn":[125],"cooldown_burn":[10,9,9,8,8],"cost_burn":[60,70,80,90,100],"tooltip":"Singed flings an enemy over his shoulder, dealing \\u003cmagicDamage\\u003e? plus 6/6.5/7/7.5/8% max Health magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Singed flings a target into his \\u003cspellName\\u003eMega Adhesive\\u003c/spellName\\u003e, they are \\u003cstatus\\u003eRooted\\u003c/status\\u003e for 1/1.25/1.5/1.75/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Fling.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0027/ability_0027_E1.webm"},{"key":"R","name":"Insanity Potion","description":"Singed drinks a potent brew of chemicals, granting him increased combat stats, and making his Poison Trail apply Grievous Wounds.","max_rank":3,"range_burn":[20],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Singed drinks a potent brew of chemicals, granting him ? \\u003cscaleAP\\u003eAbility Power\\u003c/scaleAP\\u003e, \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e, \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e, \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e, \\u003chealing\\u003eHealth Regen\\u003c/healing\\u003e, and \\u003cscaleMana\\u003eMana Regen\\u003c/scaleMana\\u003e for ? seconds. During this effect, Singed\'s Poison Trail also applies ?% Grievous Wounds for ? second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/InsanityPotion.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0027/ability_0027_R1.webm"}]},"28":{"id":28,"key":"Evelynn","name":"Evelynn","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Evelynn.png","enemy_tips":["Purchasing Vision Wards can help you detect Evelynn\'s location in order to prepare for her ambushes.","A large share of Evelynn\'s threat is in her charm, \'Allure.\' Protect allies marked with \'Allure\' or, if you are marked, make sure allies are between you and where Evelynn may attack from.","If you suspect Evelynn is about to ambush one of your teammates, let them know by pinging the minimap and typing in chat."],"ally_tips":["Allure\'s arm time might seem long, but the Charm and magic resist shred put Evelynn at an exteme advantage so are worth the wait.","While stealthed, pay attention to when you are (near) being detected by enemy champions. This is identified by the glowing yellow and red eyes over nearby enemy champions.","If at low health, you can take advantage of Demon Shade\'s healing and Camouflage to return to the fight and surprise opponents."],"passive":{"name":"Demon Shade","description":"When out of combat, Evelynn enters Demon Shade. Demon Shade heals Evelynn when she is low on health and grants Camouflage after level 6.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Evelynn_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0028/ability_0028_P1.webm"},"spells":[{"key":"Q","name":"Hate Spike","description":"Evelynn strikes out with her Lasher, dealing damage to the first unit hit. Then, Evelynn can shoot a line of spikes at nearby foes up to 3 times.","max_rank":5,"range_burn":[800],"cooldown_burn":[4],"cost_burn":[40,45,50,55,60],"tooltip":"Evelynn strikes with her Lasher, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit and causing Evelynn\'s next 3 Attacks or Abilities on that unit to deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Evelynn can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability up to 3 times.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Evelynn fires spikes through the nearest enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to all enemies hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EvelynnQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0028/ability_0028_Q1.webm"},{"key":"W","name":"Allure","description":"Evelynn curses her target, causing her next attack or spell after a delay to charm her target and reduce their magic resist.","max_rank":5,"range_burn":[1200,1300,1400,1500,1600],"cooldown_burn":[15,14,13,12,11],"cost_burn":[60,70,80,90,100],"tooltip":"Evelynn marks a champion or jungle monster for 5 seconds. If Evelynn hits the target with an Attack or Ability, she will expunge the mark, refund its cost, and \\u003cstatus\\u003eSlow\\u003c/status\\u003e the target by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the mark lasts at least 2.5 seconds, expunging it has extra effects:\\u003cli\\u003eAgainst champions: \\u003cstatus\\u003eCharms\\u003c/status\\u003e them for ? second(s) and removes \\u003cscaleMR\\u003e?% Magic Resist\\u003c/scaleMR\\u003e for ? seconds.\\u003cli\\u003eAgainst jungle monsters: \\u003cstatus\\u003eCharms\\u003c/status\\u003e them for ? seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EvelynnW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0028/ability_0028_W1.webm"},{"key":"E","name":"Whiplash","description":"Evelynn whips her target with her Lasher, dealing damage. She then gains Move Speed for a short duration.","max_rank":5,"range_burn":[210],"cooldown_burn":[8],"cost_burn":[40,45,50,55,60],"tooltip":"Evelynn whips an enemy, dealing \\u003cmagicDamage\\u003e? plus ? max Health magic damage\\u003c/magicDamage\\u003e. Evelynn gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eEntering \\u003ckeywordMajor\\u003eDemon Shade\\u003c/keywordMajor\\u003e refreshes this Ability\'s cooldown and empowers it. When this Ability is empowered, Evelynn dashes to the target and deals \\u003cmagicDamage\\u003e? plus ? max Health magic damage\\u003c/magicDamage\\u003e to her target and everyone she passes through instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EvelynnE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0028/ability_0028_E1.webm"},{"key":"R","name":"Last Caress","description":"Evelynn briefly goes untargetable and decimates the area in front of her before warping backwards a long distance.","max_rank":3,"range_burn":[25000],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Evelynn unleashes her demonic energy, dealing heavy damage, becoming Untargetable and teleporting backwards. She deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, increased to \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e against enemies below \\u003chealing\\u003e30% Health\\u003c/healing\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EvelynnR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0028/ability_0028_R1.webm"}]},"29":{"id":29,"key":"Twitch","name":"Twitch","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Twitch.png","enemy_tips":["Twitch is fragile. Work with teammates to focus on him when you\'re able to catch him out of Camouflage.","Spell Shields won\'t block the damage from Deadly Venom, but they will block the effects Twitch can trigger with it.","If you suspect Twitch has left the lane, let your teammates know that Twitch is \'\'MIA.\'\'"],"ally_tips":["Twitch\'s Attack Speed is among the highest in the game; try purchasing items with on-hit effects such as Black Cleaver or Wit\'s End.","Contaminate has a large range; apply as many stacks of Deadly Venom as possible before using it.","You can catch up to an enemy out of attack range with Venom Cask."],"passive":{"name":"Deadly Venom","description":"Twitch\'s basic attacks infect the target, dealing true damage each second.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Twitch_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0029/ability_0029_P1.webm"},"spells":[{"key":"Q","name":"Ambush","description":"Twitch becomes Camouflaged for a short duration and gains Move Speed. When leaving Camouflage, Twitch gains Attack Speed for a short duration.\\u003cbr\\u003e\\u003cbr\\u003eWhen an enemy champion with Deadly Venom dies, Ambush\'s cooldown is reset.","max_rank":5,"range_burn":[20],"cooldown_burn":[16],"cost_burn":[40],"tooltip":"Twitch \\u003ckeywordStealth\\u003eCamouflages\\u003c/keywordStealth\\u003e and gains \\u003cspeed\\u003e30% Move Speed\\u003c/speed\\u003e for 10/11/12/13/14 seconds. The Move Speed increases to 30% while near an enemy champion that can\'t see him. After exiting \\u003ckeywordStealth\\u003eCamouflage\\u003c/keywordStealth\\u003e, Twitch gains \\u003cattackSpeed\\u003e40/45/50/55/60% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen an enemy champion dies while afflicted with \\u003ckeywordMajor\\u003eVenom\\u003c/keywordMajor\\u003e, this Ability\'s Cooldown is refreshed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TwitchHideInShadows.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0029/ability_0029_Q1.webm"},{"key":"W","name":"Venom Cask","description":"Twitch hurls a cask of venom that explodes in an area, slowing targets and applying deadly venom to the target.","max_rank":5,"range_burn":[950],"cooldown_burn":[13,12,11,10,9],"cost_burn":[70],"tooltip":"Twitch hurls a cask that adds a stack of \\u003cspellName\\u003eDeadly Venom\\u003c/spellName\\u003e to all enemies struck and leaves behind a toxic cloud that persists for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies that remain within the cloud are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% and receive an additional stack of \\u003cspellName\\u003eDeadly Venom\\u003c/spellName\\u003e each second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TwitchVenomCask.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0029/ability_0029_W1.webm"},{"key":"E","name":"Contaminate","description":"Twitch wreaks further havoc on poisoned enemies with a blast of his vile diseases.","max_rank":5,"range_burn":[1200],"cooldown_burn":[12,11,10,9,8],"cost_burn":[50,60,70,80,90],"tooltip":"Deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to all nearby enemies affected by \\u003cspellName\\u003eDeadly Venom\\u003c/spellName\\u003e, plus an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? magical damage\\u003c/magicDamage\\u003e per stack of \\u003cspellName\\u003eDeadly Venom\\u003c/spellName\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eMax Stack Damage: \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? magical damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TwitchExpunge.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0029/ability_0029_E1.webm"},{"key":"R","name":"Spray and Pray","description":"Twitch unleashes the full power of his crossbow, shooting bolts over a great distance that pierce all enemies caught in their path.","max_rank":3,"range_burn":[1200],"cooldown_burn":[90],"cost_burn":[100],"tooltip":"Twitch unleashes his crossbow, gaining ? Attack Range and \\u003cscaleAD\\u003e? Attack Damage\\u003c/scaleAD\\u003e, and causing his Attacks to become piercing bolts for ? seconds. These bolts hit all enemies they pass through, but deal ?% less damage to subsequent targets, down to a minimum of ?% damage.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TwitchFullAutomatic.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0029/ability_0029_R1.webm"}]},"30":{"id":30,"key":"Karthus","name":"Karthus","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Karthus.png","enemy_tips":["Karthus can cast spells for a short duration after he is killed. Move away from his corpse to be safe.","Make sure you always have enough health to survive Requiem, even if you have to go back to the base more frequently to heal."],"ally_tips":["Ask your allies to help point out when you should use Requiem to get kills in different lanes.","Lay Waste is very strong at farming minions and harassing enemy champions."],"passive":{"name":"Death Defied","description":"Upon dying, Karthus enters a spirit form that allows him to continue casting spells.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Karthus_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0030/ability_0030_P1.webm"},"spells":[{"key":"Q","name":"Lay Waste","description":"Karthus unleashes a delayed blast at a location, dealing damage to nearby enemies. Deals increased damage to isolated enemies. ","max_rank":5,"range_burn":[875],"cooldown_burn":[0],"cost_burn":[20,25,30,35,40],"tooltip":"Karthus creates a blast of magic, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. If the blast hits only one enemy, it instead deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarthusLayWasteA1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0030/ability_0030_Q1.webm"},{"key":"W","name":"Wall of Pain","description":"Karthus creates a passable screen of leeching energy. Any enemy units that walk through the screen have their Move Speed and Magic Resist reduced for a period.","max_rank":5,"range_burn":[1000],"cooldown_burn":[15],"cost_burn":[70],"tooltip":"Karthus creates a wall that lasts for 5 seconds. Enemies that pass through lose \\u003cscaleMR\\u003e15% Magic Resist\\u003c/scaleMR\\u003e for 5 seconds and are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 40/50/60/70/80% decaying over the duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarthusWallOfPain.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0030/ability_0030_W1.webm"},{"key":"E","name":"Defile","description":"Karthus passively steals energy from his victims, gaining Mana on each kill. Alternatively, Karthus can surround himself in the souls of his prey, dealing damage to nearby enemies, but quickly draining his own Mana.","max_rank":5,"range_burn":[550],"cooldown_burn":[0],"cost_burn":[30,42,54,66,78],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eWhen Karthus kills a unit, he restores \\u003cscaleMana\\u003e15/25/35/45/55 Mana\\u003c/scaleMana\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ctoggle\\u003eToggle: \\u003c/toggle\\u003eKarthus creates a necrotic aura, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarthusDefile.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0030/ability_0030_E1.webm"},{"key":"R","name":"Requiem","description":"After channeling for 3 seconds, Karthus deals damage to all enemy champions.","max_rank":3,"range_burn":[10000],"cooldown_burn":[200,180,160],"cost_burn":[100],"tooltip":"Karthus channels for 3 seconds, then deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemy champions, regardless of distance.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarthusFallenOne.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0030/ability_0030_R1.webm"}]},"31":{"id":31,"key":"Chogath","name":"Cho\'Gath","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Chogath.png","enemy_tips":["Purchasing a few HP items decreases the chances of Cho\'Gath killing you quickly.","Focus on preventing Cho\'Gath from reaching his max size.","Rupture has a smoke cloud indicating the area it will strike. Try to watch out for it to prevent Cho\'Gath from being able to combo his abilities."],"ally_tips":["Try to line up your attacks with Vorpal Spikes so that they kill minions and harass enemy champions at the same time.","If you\'re having difficulty feasting upon champions, try eating minions until you\'re larger.","Using Rupture on creeps in combination with Carnivore is a good way to gain Health and Mana."],"passive":{"name":"Carnivore","description":"Whenever Cho\'Gath kills a unit, he recovers Health and Mana. The values restored increase with Cho\'Gath\'s level.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/GreenTerror_TailSpike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0031/ability_0031_P1.webm"},"spells":[{"key":"Q","name":"Rupture","description":"Ruptures the ground at target location, popping enemy units into the air, dealing damage and slowing them.","max_rank":5,"range_burn":[950],"cooldown_burn":[6],"cost_burn":[60],"tooltip":"Cho\'Gath ruptures the ground, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e enemies for 1 second, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 60% for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Rupture.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0031/ability_0031_Q1.webm"},{"key":"W","name":"Feral Scream","description":"Cho\'Gath unleashes a terrible scream at enemies in a cone, dealing magic damage and Silencing enemies for a few seconds.","max_rank":5,"range_burn":[300],"cooldown_burn":[13,12,11,10,9],"cost_burn":[70,80,90,100,110],"tooltip":"Cho\'Gath roars, \\u003cstatus\\u003eSilencing\\u003c/status\\u003e enemies for 1.6/1.7/1.8/1.9/2 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FeralScream.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0031/ability_0031_W1.webm"},{"key":"E","name":"Vorpal Spikes","description":"Cho\'Gath\'s attacks release deadly spikes, dealing damage and slowing all enemy units in front of him.","max_rank":5,"range_burn":[40],"cooldown_burn":[8,7,6,5,4],"cost_burn":[30],"tooltip":"Cho\'Gath\'s next 3 Attacks launch spikes that deal \\u003cmagicDamage\\u003e? plus ? of the target\'s max Health magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlow\\u003c/status\\u003e by 30/35/40/45/50%, decaying over 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VorpalSpikes.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0031/ability_0031_E1.webm"},{"key":"R","name":"Feast","description":"Devours an enemy unit, dealing a high amount of true damage. If the target is killed, Cho\'Gath grows, gaining maximum Health.","max_rank":3,"range_burn":[175],"cooldown_burn":[80],"cost_burn":[100],"tooltip":"Cho\'Gath ravenously feeds on an enemy, dealing \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e to champions or \\u003ctrueDamage\\u003e?\\u003c/trueDamage\\u003e to minions or jungle monsters. If this kills the target, Cho\'Gath gains a stack, which causes him to grow in size and gain \\u003chealing\\u003e? max Health\\u003c/healing\\u003e. Only ? stacks can be gained from minions and non-epic jungle monsters. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Feast.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0031/ability_0031_R1.webm"}]},"32":{"id":32,"key":"Amumu","name":"Amumu","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Amumu.png","enemy_tips":["Avoid bunching up with other allies when Amumu has his ultimate available.","Erratic movement, or hiding behind creep waves can make it difficult for Amumu to instigate a fight with Bandage Toss.","Amumu\'s Despair makes purchasing primarily Health items a risky proposition."],"ally_tips":["Amumu is highly dependent on teammates, so try laning with your friends for maximum effectiveness.","Cooldown Reduction on Amumu is very strong, but it\'s often difficult to itemize for it. Grab the Golem buff whenever possible to gain Cooldown Reduction without sacrificing stats.","Despair is very effective against other tanks, so make sure you\'re in range of opponents with the highest Health."],"passive":{"name":"Cursed Touch","description":"Amumu\'s basic attacks \\u003cfont color=\'#9b0f5f\'\\u003eCurse\\u003c/font\\u003e his enemies, causing them to take bonus true damage from incoming magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Amumu_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0032/ability_0032_P1.webm"},"spells":[{"key":"Q","name":"Bandage Toss","description":"Amumu tosses a sticky bandage at a target, stunning and damaging the target while he pulls himself to them.","max_rank":5,"range_burn":[1100],"cooldown_burn":[3],"cost_burn":[30,35,40,45,50],"tooltip":"Amumu launches a bandage, pulling himself to the first enemy hit, \\u003cstatus\\u003eStunning\\u003c/status\\u003e them for 1 second, and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 2 charges.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BandageToss.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0032/ability_0032_Q1.webm"},{"key":"W","name":"Despair","description":"Overcome by anguish, nearby enemies lose a percentage of their maximum Health each second and have their \\u003cfont color=\'#9b0f5f\'\\u003eCurses\\u003c/font\\u003e refreshed.","max_rank":5,"range_burn":[300],"cooldown_burn":[1],"cost_burn":[8],"tooltip":"\\u003ctoggle\\u003eToggle:\\u003c/toggle\\u003e Amumu begins crying, dealing \\u003cmagicDamage\\u003e12/16/20/24/28 plus ? max Health magic damage\\u003c/magicDamage\\u003e to nearby enemies every second and refreshing \\u003ckeywordMajor\\u003eCurse\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AuraofDespair.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0032/ability_0032_W1.webm"},{"key":"E","name":"Tantrum","description":"Permanently reduces the physical damage Amumu would take. Amumu can unleash his rage, dealing damage to surrounding enemies. Each time Amumu is hit, the cooldown on Tantrum is reduced by 0.5 seconds.","max_rank":5,"range_burn":[350],"cooldown_burn":[9,8,7,6,5],"cost_burn":[35],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Amumu takes ? reduced physical damage. Additionally, when Amumu is hit by an Attack, this Ability\'s Cooldown is reduced by 0.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Amumu throws a tantrum, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Tantrum.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0032/ability_0032_E1.webm"},{"key":"R","name":"Curse of the Sad Mummy","description":"Amumu entangles surrounding enemy units in bandages, applying his \\u003ckeywordMajor\\u003eCurse\\u003c/keywordMajor\\u003e, damaging and stunning them.","max_rank":3,"range_burn":[550],"cooldown_burn":[150,125,100],"cost_burn":[100,150,200],"tooltip":"Amumu flares out his bandages, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for ? seconds, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and applying \\u003ckeywordMajor\\u003eCurse\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CurseoftheSadMummy.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0032/ability_0032_R1.webm"}]},"33":{"id":33,"key":"Rammus","name":"Rammus","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Rammus.png","enemy_tips":["Pay particular attention to when his Defensive Ball Curl is off. Rammus has much lower stats than a normal tank when he\'s out of the stance.","Rammus often stacks high Armor, leaving him especially vulnerable to caster damage while not in Defensive Ball Curl."],"ally_tips":["Powerball can be used as an effective escape mechanism.","Using taunt on a champion by your tower can cause the tower to attack your enemy.","Tremors and Defensive Ball Curl can be used late in the game to obliterate towers. If you\'re bogged down in a team fight, it is often valuable to break off and attack the buildings."],"passive":{"name":"Spiked Shell","description":"Rammus\' basic attacks deal bonus magic damage, scaling with his Armor.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Armordillo_ScavengeArmor.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0033/ability_0033_P1.webm"},"spells":[{"key":"Q","name":"Powerball","description":"Rammus accelerates in a ball towards his enemies, dealing damage and slowing targets affected by the impact.","max_rank":5,"range_burn":[300],"cooldown_burn":[16,13,11,8,6],"cost_burn":[60],"tooltip":"Rammus curls into a ball, gaining \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, accelerating up to \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e over 6 seconds. Rammus stops after colliding with an enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e nearby enemies by 40/50/60/70/80% for 1 second.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Rammus ends this Ability early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PowerBall.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0033/ability_0033_Q1.webm"},{"key":"W","name":"Defensive Ball Curl","description":"Rammus goes into a defensive formation, vastly increasing his Armor and Magic Resistance, amplifying Spiked Shells\' damage, and returning damage to enemies that basic attack him, but he is also slowed during this time.","max_rank":5,"range_burn":[300],"cooldown_burn":[6],"cost_burn":[40],"tooltip":"Rammus enters a defensive formation, gaining \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e, \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e himself by 30% for 6 seconds. While active, \\u003cspellName\\u003eSpiked Shell\'s\\u003c/spellName\\u003e damage is increased by ?% and also damages enemies that Attack Rammus.\\u003cbr /\\u003e\\u003cbr /\\u003eRammus\'s Attacks increase the duration by ? seconds (max: ?).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Rammus ends this Ability early.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DefensiveBallCurl.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0033/ability_0033_W1.webm"},{"key":"E","name":"Frenzying Taunt","description":"Rammus taunts an enemy champion or monster into a reckless assault against him. Additionally, he gains increased Attack Speed for a short time, but this bonus is extended by having any of his other spells active.","max_rank":5,"range_burn":[325],"cooldown_burn":[12],"cost_burn":[50],"tooltip":"Rammus \\u003cstatus\\u003eTaunts\\u003c/status\\u003e an enemy champion or jungle monster for 1.2/1.4/1.6/1.8/2 seconds and gains \\u003cattackSpeed\\u003e20/25/30/35/40% Attack Speed\\u003c/attackSpeed\\u003e for 1.2/1.4/1.6/1.8/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PuncturingTaunt.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0033/ability_0033_E1.webm"},{"key":"R","name":"Soaring Slam","description":"Rammus hops into the air and slams down at a target area, dealing magic damage and slowing enemies. If cast while Rammus is in Powerball, Rammus knocks up enemies near the center as well.","max_rank":3,"range_burn":[25000],"cooldown_burn":[110,95,80],"cost_burn":[100],"tooltip":"Rammus hops into the air and slams down in an area, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds. Enemies in the center take additional damage based on how far Rammus hopped (max: \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e). If used during \\u003cspellName\\u003ePowerball\\u003c/spellName\\u003e, enemies in the center are also \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eRammus then creates ? aftershocks in the area over ? seconds, each dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and stacking the \\u003cstatus\\u003eSlow\\u003c/status\\u003e (max: ?%).\\u003cbr /\\u003e\\u003cbr /\\u003eThe range of this Ability is increased by Rammus\'s \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Tremors2.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0033/ability_0033_R1.webm"}]},"34":{"id":34,"key":"Anivia","name":"Anivia","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Anivia.png","enemy_tips":["Try to gank Anivia when she\'s laning. With multiple people, it is easier to ensure that her egg dies.","If you\'re playing a ranged champion, stay far enough away from Anivia so you can dodge Flash Frost more easily.","Try to fight Anivia in the lanes. In the jungle she can block pathways with lower ranks of Crystallize."],"ally_tips":["Timing Flash Frost with Frostbite can lead to devastating combinations.","Anivia is extremely reliant on Mana for Glacial Storm. Try getting items with Mana or going for a Crest of the Ancient Golem buff on Summoner\'s Rift.","It can be very difficult for enemy champions to kill her egg early in game. Seize the advantage by playing aggressively."],"passive":{"name":"Rebirth","description":"Upon taking fatal damage, Anivia reverts to an egg and is reborn with full health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Anivia_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0034/ability_0034_P1.webm"},"spells":[{"key":"Q","name":"Flash Frost","description":"Anivia brings her wings together and summons a sphere of ice that flies towards her opponents, chilling and damaging anyone in its path. When the sphere explodes it does moderate damage in a radius, stunning anyone in the area.","max_rank":5,"range_burn":[1075],"cooldown_burn":[12,11,10,9,8],"cost_burn":[80,85,90,95,100],"tooltip":"Anivia fires a massive chunk of ice, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003ckeywordMajor\\u003eChilling\\u003c/keywordMajor\\u003e enemies for ? seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?%. At the end of its range, the ice detonates, \\u003cstatus\\u003eStunning\\u003c/status\\u003e enemies for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eAnivia can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this ability while the ice flies to detonate it early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FlashFrost.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0034/ability_0034_Q1.webm"},{"key":"W","name":"Crystallize","description":"Anivia condenses the moisture in the air into an impassable wall of ice to block all movement. The wall only lasts a short duration before it melts.","max_rank":5,"range_burn":[1000],"cooldown_burn":[17],"cost_burn":[70],"tooltip":"Anivia summons a wall of ice 400/500/600/700/800 units wide. The wall lasts for 5 seconds before it melts.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Crystallize.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0034/ability_0034_W1.webm"},{"key":"E","name":"Frostbite","description":"With a flap of her wings, Anivia blasts a freezing gust of wind at her target, dealing damage. If the target was recently hit by Flash Frost or damaged by a fully formed Glacial Storm, the damage they take is doubled.","max_rank":5,"range_burn":[650],"cooldown_burn":[4],"cost_burn":[50],"tooltip":"Anivia blasts an enemy with a freezing wind, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Against \\u003ckeywordMajor\\u003eChilled\\u003c/keywordMajor\\u003e enemies, Anivia deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Frostbite.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0034/ability_0034_E1.webm"},{"key":"R","name":"Glacial Storm","description":"Anivia summons a driving rain of ice and hail to damage her enemies and slow their advance.","max_rank":3,"range_burn":[750],"cooldown_burn":[4,3,2],"cost_burn":[60],"tooltip":"\\u003ctoggle\\u003eToggle:\\u003c/toggle\\u003e Anivia calls forth a driving rain of ice and hail that \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies by ?% and deals \\u003cmagicDamage\\u003e? magic damage per second\\u003c/magicDamage\\u003e. The storm increases in size over ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen the storm is fully formed, it \\u003ckeywordMajor\\u003eChills\\u003c/keywordMajor\\u003e, \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?%, and does \\u003cmagicDamage\\u003e? magic damage per second\\u003c/magicDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GlacialStorm.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0034/ability_0034_R1.webm"}]},"35":{"id":35,"key":"Shaco","name":"Shaco","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Shaco.png","enemy_tips":["If Shaco is doing well early-game, it is worth the investment to place Stealth Wards near his Jungle camps.","If Shaco uses Deceive to enter a fight he won\'t be able to quickly use it again to get away. Work with your team to quickly focus him down."],"ally_tips":["Using Deceive over terrain can help you make a clean escape.","Try getting items with on-hit effects. These will also benefit your Hallucination clone.","Backstab\'s damage can be increased with increased Critical Damage effects like Infinity Edge."],"passive":{"name":"Backstab","description":"Shaco\'s basic attacks and Two-Shiv Poison deal additional damage when striking from behind.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Jester_CarefulStrikes.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0035/ability_0035_P1.webm"},"spells":[{"key":"Q","name":"Deceive","description":"Shaco becomes Invisible and teleports to target location.\\u003cbr\\u003e\\u003cbr\\u003eHis first attack while Invisible is empowered, dealing bonus damage and critically striking if he attacks from behind.","max_rank":5,"range_burn":[400],"cooldown_burn":[12,11,11,10,10],"cost_burn":[60],"tooltip":"Shaco teleports and becomes \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e for ? seconds. Using \\u003cspellName\\u003eJack In The Box\\u003c/spellName\\u003e or \\u003cspellName\\u003eHallucinate\\u003c/spellName\\u003e does not break \\u003ckeywordStealth\\u003eInvisibility\\u003c/keywordStealth\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eShaco\'s next Attack while \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If striking from behind, this Attack critically strikes for ? damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Deceive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0035/ability_0035_Q1.webm"},{"key":"W","name":"Jack In The Box","description":"Shaco creates a hidden animated Jack-in-the-Box. When triggered, it will fear and attack nearby enemies.","max_rank":5,"range_burn":[500],"cooldown_burn":[16],"cost_burn":[50,55,60,65,70],"tooltip":"Shaco creates a trap that stealths itself after 2 seconds and lasts for ? seconds. It activates when an enemy comes near or when revealed, \\u003cstatus\\u003eFearing\\u003c/status\\u003e nearby enemy Champions for 0.5/0.75/1/1.25/1.5 seconds, or ? seconds for minions and jungle monsters.\\u003cbr /\\u003e\\u003cbr /\\u003eOnce activated, the trap fires at all nearby enemies for 5 seconds, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, or \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e if focused on a single target.\\u003cbr /\\u003e\\u003cbr /\\u003eJack in the Box\'s attacks deal an additional \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e damage to monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JackInTheBox.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0035/ability_0035_W1.webm"},{"key":"E","name":"Two-Shiv Poison","description":"Shaco\'s Shivs passively poison targets on hit, slowing their Move Speed. He can throw his Shivs to deal damage and poison the target. The thrown Shiv deals bonus damage if the target is below 30% health.","max_rank":5,"range_burn":[625],"cooldown_burn":[8],"cost_burn":[65],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While this Ability is off Cooldown, Shaco\'s Attacks \\u003cstatus\\u003eSlow\\u003c/status\\u003e the target by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Shaco throws a shiv, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds. If the target has less than ?% Health, the shiv deals \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TwoShivPoison.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0035/ability_0035_E1.webm"},{"key":"R","name":"Hallucinate","description":"Shaco creates an illusion of himself near him, which can attack nearby enemies (Deals reduced damage to turrets).  Upon death, it explodes, spawning three mini Jack in the Boxes and dealing damage to nearby enemies.","max_rank":3,"range_burn":[200],"cooldown_burn":[100,90,80],"cost_burn":[100],"tooltip":"Shaco briefly disappears, then reappears with a clone that lasts ? seconds and detonates when it dies, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and spawning three mini \\u003cspellName\\u003eJack in the Boxes\\u003c/spellName\\u003e that trigger immediately. The clone deals ?% of Shaco\'s damage and receives ?% increased damage.\\u003cbr /\\u003e\\u003cbr /\\u003eMini \\u003cspellName\\u003eJack in the Boxes\\u003c/spellName\\u003e deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, or \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e if firing at only one enemy, and \\u003cstatus\\u003eFear\\u003c/status\\u003e for ? second(s).\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HallucinateFull.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0035/ability_0035_R1.webm"}]},"36":{"id":36,"key":"DrMundo","name":"Dr. Mundo","image_url":"https://opgg-static.akamaized.net/images/lol/champion/DrMundo.png","enemy_tips":["Try to coordinate high-damage abilities with your allies right after Dr. Mundo uses his ultimate, but if you\'re unable to kill him quickly with burst he will heal through the damage.","Try casting Ignite when Dr. Mundo uses Sadism to negate a large portion of its healing."],"ally_tips":["A well-timed Sadism can bait enemy champions into attacking you even when they lack the damage to finish you.","Spirit Visage will increase the healing done by your ultimate and lower cooldowns on all of your abilities.","Cleavers are a powerful tool for killing neutral monsters. Instead of returning to base, farm neutral monsters until your ultimate can heal you."],"passive":{"name":"Goes Where He Pleases","description":"Dr. Mundo resists the first Immobilizing effect that hits him, instead losing Health and dropping a chemical cannister nearby. Dr. Mundo can pick it up by walking over it, restoring Health and reducing this Ability\'s Cooldown.\\u003cbr\\u003e\\u003cbr\\u003eDr. Mundo also has significantly increased Health regeneration.\\u003cbr\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/passive/DrMundo_P.Dr_Mundo_VGU.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0036/ability_0036_P1.webm"},"spells":[{"key":"Q","name":"Infected Bonesaw","description":"Dr. Mundo throws an infected bonesaw, dealing damage to the first enemy hit based on their current health and slowing them.","max_rank":5,"range_burn":[975],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"Dr. Mundo hurls his bonesaw, dealing \\u003cmagicDamage\\u003e?% current Health magic damage\\u003c/magicDamage\\u003e to the first enemy hit and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the bonesaw hits a champion or monster, Dr. Mundo restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e. If it hits a non-champion or non-monster, Dr. Mundo instead restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DrMundoQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0036/ability_0036_Q1.webm"},{"key":"W","name":"Heart Zapper","description":"Dr. Mundo electrocutes himself, dealing persistent damage to nearby enemies and storing a portion of damage he takes. At the end of the duration or on Recast, Dr. Mundo deals a burst of damage to nearby enemies. If the burst hit an enemy, he heals a percentage of the stored damage.","max_rank":5,"range_burn":[325],"cooldown_burn":[17,16,16,15,15],"cost_burn":[0],"tooltip":"Dr. Mundo charges up a defibrilator, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each second for up to ? seconds to nearby enemies. While active he stores ?% of damage taken as gray health and can \\u003crecast\\u003eRecast\\u003c/recast\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Detonate the defibrilator, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies. If this hits at least one champion, Dr. Mundo restores \\u003chealing\\u003e?% of gray health\\u003c/healing\\u003e. If only non-champions were hit, Dr. Mundo instead restores \\u003chealing\\u003e?% of gray health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DrMundoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0036/ability_0036_W1.webm"},{"key":"E","name":"Blunt Force Trauma","description":"Passive - Dr. Mundo gains bonus Attack Damage, increasing based on his missing Health.\\u003cbr\\u003e\\u003cbr\\u003eActive - Dr. Mundo slams his “medical” bag into an enemy, dealing additional damage based on his missing Health. If the enemy dies they are swatted away, dealing damage to enemies they pass through.","max_rank":5,"range_burn":[0],"cooldown_burn":[8,7,7,6,6],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Dr Mundo gains \\u003cphysicalDamage\\u003e? Attack Damage\\u003c/physicalDamage\\u003e, plus up to \\u003cphysicalDamage\\u003e? Attack Damage\\u003c/physicalDamage\\u003e based on his missing Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Mundo violently swings his \\"medical\\" bag, causing his next Attack to deal an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, increased by up to ? based on his missing Health. If the enemy is killed, Mundo swats them away, dealing the minimum damage to all enemies they pass through. Small monsters are swatted immediately.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DrMundoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0036/ability_0036_E1.webm"},{"key":"R","name":"Maximum Dosage","description":"Dr. Mundo pumps himself with chemicals, instantly healing a percent of his missing Health. He then gains bonus Attack Damage and Move Speed, and regenerates a portion of his maximum Health over a long duration.","max_rank":3,"range_burn":[20],"cooldown_burn":[110],"cost_burn":[0],"tooltip":"Dr. Mundo pumps himself with chemicals, temporarily gaining \\u003chealing\\u003e?% of his missing Health as max Health\\u003c/healing\\u003e then gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e, \\u003cphysicalDamage\\u003e? Attack Damage\\u003c/physicalDamage\\u003e, and regenerating \\u003chealing\\u003e?% max Health\\u003c/healing\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DrMundoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0036/ability_0036_R1.webm"}]},"37":{"id":37,"key":"Sona","name":"Sona","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sona.png","enemy_tips":["Spread out when you see Sona so she can\'t make your entire team dance.","Kill Sona first, as she will heal up her team if left alone for too long."],"ally_tips":["Make sure to tag your allies while Sona\'s auras are active, but avoid getting caught out by enemies.","Save Crescendo for the game-altering moment.","Well-timed uses of Aria of Perseverance will grant you maximum survivability."],"passive":{"name":"Power Chord","description":"\\u003cpassive\\u003eAccelerando\\u003c/passive\\u003e: Sona gains non-Ultimate ability haste permanently for her basic abilities as she uses her abilities well, up to a cap. Beyond that cap, further successful uses reduce her ultimate\'s remaining cooldown instead.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cpassive\\u003ePower Chord\\u003c/passive\\u003e: Every few spell casts, Sona\'s next attack will deal bonus magic damage in addition to an additional effect based on what basic Ability Sona last activated.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Sona_Passive_Charged.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0037/ability_0037_P1.webm"},"spells":[{"key":"Q","name":"Hymn of Valor","description":"Sona plays the Hymn of Valor, sends out bolts of sound, dealing magic damage to two nearby enemies, prioritizing champions and monsters. Sona gains a temporary aura that grants allies tagged by the zone bonus damage on their next attack against enemies.","max_rank":5,"range_burn":[825],"cooldown_burn":[8],"cost_burn":[50,55,60,65,70],"tooltip":"Sona deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the nearest two enemies, prioritizing champions. She then begins a new \\u003ckeywordMajor\\u003eMelody\\u003c/keywordMajor\\u003e. Gain a stack of \\u003ckeywordMajor\\u003eAccelerando\\u003c/keywordMajor\\u003e for every champion you damage with this.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMelody:\\u003c/keywordMajor\\u003e Sona gains an aura for ? seconds, granting allied champions an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e %i:OnHit% on their next Attack within ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003ePower Chord - Staccato:\\u003c/keywordMajor\\u003e Power Chord bonus damage (\\u003cmagicDamage\\u003e? total magic damage\\u003c/magicDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SonaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0037/ability_0037_Q1.webm"},{"key":"W","name":"Aria of Perseverance","description":"Sona plays the Aria of Perseverance, sending out protective melodies, healing Sona and a nearby wounded ally. Sona gains a temporary aura that grants allies tagged by the zone a temporary shield.","max_rank":5,"range_burn":[1000],"cooldown_burn":[10],"cost_burn":[80,85,90,95,100],"tooltip":"\\u003cspellPassive\\u003eActive:\\u003c/spellPassive\\u003e Sona restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to herself and a nearby allied champion, prioritizing the most wounded. She then begins a new \\u003ckeywordMajor\\u003eMelody\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMelody:\\u003c/keywordMajor\\u003e Sona gains an aura for ? seconds, granting allied champions \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eGain a stack of \\u003ckeywordMajor\\u003eAccelerando\\u003c/keywordMajor\\u003e whenever you heal another injured ally and every time you protect another ally from at least ? damage with this shield.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003ePower Chord - Diminuendo:\\u003c/keywordMajor\\u003e Power Chord also reduces physical and magic damage dealt by the target by ? for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SonaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0037/ability_0037_W1.webm"},{"key":"E","name":"Song of Celerity","description":"Sona plays the Song of Celerity, granting nearby allies bonus Move Speed. Sona gains a temporary aura that grants allied champions tagged by the zone bonus Move Speed.","max_rank":5,"range_burn":[430],"cooldown_burn":[14],"cost_burn":[65],"tooltip":"\\u003cspellPassive\\u003eActive:\\u003c/spellPassive\\u003e She begins a new \\u003ckeywordMajor\\u003eMelody\\u003c/keywordMajor\\u003e and grants herself \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e for ? seconds, extended to up to ? seconds if she doesn\'t take damage. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMelody:\\u003c/keywordMajor\\u003e Sona gains an aura for ? seconds that grants allied champions \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003ePower Chord - Tempo:\\u003c/keywordMajor\\u003e Power Chord also \\u003cstatus\\u003eSlows\\u003c/status\\u003e the target by ? for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SonaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0037/ability_0037_E1.webm"},{"key":"R","name":"Crescendo","description":"Sona plays her ultimate chord, stunning enemy champions and forcing them to dance and dealing magic damage to them. Each rank reduces the base cooldown of Sona\'s basic abilities.","max_rank":3,"range_burn":[900],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Sona strikes an irresistible chord, \\u003cstatus\\u003eStunning\\u003c/status\\u003e enemy for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SonaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0037/ability_0037_R1.webm"}]},"38":{"id":38,"key":"Kassadin","name":"Kassadin","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kassadin.png","enemy_tips":["Kassadin deals mostly magic damage. If he\'s doing well consider buying magic resist items like Mercury\'s Treads and Banshee\'s Veil.","Each time Kassadin consecutively uses Riftwalk, he pays more and more mana. Keep this in mind as you chase him.","It takes 6 spell casts for Kassadin\'s slow, Force Pulse, to become castable. If he levels up that ability, judiciously use your own skills while laning against him."],"ally_tips":["Kassadin has multiple item paths; he can go caster via Mana and Ability Power or anti-caster with Cooldown Reduction and Magic Resist.","Kassadin\'s ultimate has many uses and is on a shorter cooldown than most, use it often.","Try to get the Ancient Golem buff to counteract Riftwalk\'s increasing Mana cost."],"passive":{"name":"Void Stone","description":"Kassadin takes reduced magic damage and ignores unit collision.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kassadin_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0038/ability_0038_P1.webm"},"spells":[{"key":"Q","name":"Null Sphere","description":"Kassadin fires an orb of void energy at a target, dealing damage and interrupting channels. The excess energy forms around himself, granting a temporary shield that absorbs magic damage.","max_rank":5,"range_burn":[650],"cooldown_burn":[11,10,10,9,9],"cost_burn":[70,75,80,85,90],"tooltip":"Kassadin fires an orb of void energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and interrupting channels. Kassadin also gains \\u003cshield\\u003e? Magic Shield\\u003c/shield\\u003e for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NullLance.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0038/ability_0038_Q1.webm"},{"key":"W","name":"Nether Blade","description":"Passive: Kassadin\'s basic attacks deal bonus magic damage. Active: Kassadin\'s next basic attack deals significant bonus magic damage and restores Mana.","max_rank":5,"range_burn":[1],"cooldown_burn":[7],"cost_burn":[1],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Kassadin\'s Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kassadin charges his blade, causing his next Attack to deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and restore \\u003cscaleMana\\u003e4/4.5/5/5.5/6% missing Mana\\u003c/scaleMana\\u003e, increased to \\u003cscaleMana\\u003e20/22.5/25/27.5/30%\\u003c/scaleMana\\u003e against champions.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NetherBlade.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0038/ability_0038_W1.webm"},{"key":"E","name":"Force Pulse","description":"Kassadin draws energy from spells cast in his vicinity. Upon charging up, Kassadin can use Force Pulse to damage and slow enemies in a cone in front of him.","max_rank":5,"range_burn":[400],"cooldown_burn":[5],"cost_burn":[60,65,70,75,80],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Kassadin gains a charge whenever any Ability is used near him. At 6 charges, Kassadin can activate this Ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kassadin unleashes a void pulse, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 50/60/70/80/90% for 1 second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ForcePulse.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0038/ability_0038_E1.webm"},{"key":"R","name":"Riftwalk","description":"Kassadin teleports to a nearby location dealing damage to nearby enemy units. Multiple Riftwalks in a short period of time cost additional Mana but also deal additional damage.","max_rank":3,"range_burn":[500],"cooldown_burn":[5,3,2],"cost_burn":[40],"tooltip":"Kassadin teleports to a nearby location, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEach subsequent use of this Ability within the next ? seconds doubles the Mana cost and deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The cost and damage increases can stack up to ? times.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RiftWalk.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0038/ability_0038_R1.webm"}]},"39":{"id":39,"key":"Irelia","name":"Irelia","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Irelia.png","enemy_tips":["Pay attention to Ionian Fervor stacks and try to engage Irelia when it is down.","Minion waves greatly enhance Irelia\'s mobility, beware fighting her inside one.","Beware of wasting your high impact spells on Defiant Dance."],"ally_tips":["Use Bladesurge to cover great distances by targeting low life minions on your way to champion targets.","Defiant Dance is not interrupted by crowd control, try timing it for incoming disables.","Flawless Duet does not have a maximum travel distance, try using it in creative ways."],"passive":{"name":"Ionian Fervor","description":"When Irelia strikes enemies with spells she gains stacking bonus Attack Speed. At maximum stacks she also gains bonus damage on hit.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Irelia_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0039/ability_0039_P1.webm"},"spells":[{"key":"Q","name":"Bladesurge","description":"Irelia dashes forward to strike her target, healing herself. If the target is Marked or dies to Bladesurge, its cooldown refreshes.","max_rank":5,"range_burn":[600],"cooldown_burn":[11,10,9,8,7],"cost_burn":[20],"tooltip":"Irelia dashes to an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e to herself. If the enemy dies or was \\u003ckeywordMajor\\u003eUnsteady\\u003c/keywordMajor\\u003e, the Cooldown is refreshed.\\u003cbr /\\u003e\\u003cbr /\\u003eDeals ? damage to minions.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IreliaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0039/ability_0039_Q1.webm"},{"key":"W","name":"Defiant Dance","description":"Irelia charges a strike that deals more damage as she charges. She takes reduced physical damage during the charge.","max_rank":5,"range_burn":[825],"cooldown_burn":[20,18,16,14,12],"cost_burn":[70,75,80,85,90],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Irelia enters a defensive stance for up to ? seconds, becoming unable to act but reducing physical damage taken by ?% and magic damage taken by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Irelia lashes out with her blades, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e increased up to \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e based on charge time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IreliaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0039/ability_0039_W1.webm"},{"key":"E","name":"Flawless Duet","description":"Irelia sends out two blades which converge on each other. Enemies caught in between are damaged, stunned and Marked.","max_rank":5,"range_burn":[850],"cooldown_burn":[16,15,14,13,12],"cost_burn":[50],"tooltip":"Irelia throws a blade into the ground and can \\u003crecast\\u003eRecast\\u003c/recast\\u003e for up to ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Irelia throws a second blade, then they fly towards each other \\u003cstatus\\u003eStunning\\u003c/status\\u003e for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Champions and large jungle monsters become \\u003ckeywordMajor\\u003eUnsteady\\u003c/keywordMajor\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IreliaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0039/ability_0039_E1.webm"},{"key":"R","name":"Vanguard\'s Edge","description":"Irelia fires a massive number of blades that explode outward upon hitting an enemy champion. Enemies hit by the blades are damaged and Marked. Afterwards the blades form a wall that will damage and slow enemies that walk through it.","max_rank":3,"range_burn":[950],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Irelia launches a barrage of blades, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and making champions and large jungle monsters \\u003ckeywordMajor\\u003eUnsteady\\u003c/keywordMajor\\u003e for ? seconds. The barrage explodes into a cage around the first champion hit for ? seconds. The cage deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cpassive\\u003eBladesurge\'s base cooldown is reduced by ? seconds.\\u003c/passive\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IreliaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0039/ability_0039_R1.webm"}]},"40":{"id":40,"key":"Janna","name":"Janna","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Janna.png","enemy_tips":["Save an interrupt ability for when Janna uses her ultimate.","Listen for the charge up sound on Howling Gale in case Janna is trying to hit you with it from off screen or from brush.","Janna\'s at her strongest when buffing another ally. If you can harass her ally, it will weaken her ability to fight you."],"ally_tips":["Eye of the Storm can be used on allied turrets.","Quickly firing a Howling Gale without the charge up can be used to heavily disable the other team.","Timing Janna\'s ultimate can push enemies away from a wounded ally or even separate enemies."],"passive":{"name":"Tailwind","description":"Janna gains bonus Move Speed moving towards allied champions and nearby allied champions gain this bonus when moving toward her.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Janna_Tailwind.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0040/ability_0040_P1.webm"},"spells":[{"key":"Q","name":"Howling Gale","description":"By creating a localized change in pressure and temperature, Janna is able to create a small storm that grows in size with time. She can activate the spell again to release the storm. On release this storm will fly towards the direction it was cast in, dealing damage and knocking away any enemies in its path.","max_rank":5,"range_burn":[1700],"cooldown_burn":[12],"cost_burn":[60,70,80,90,100],"tooltip":"Janna summons a tornado that grows stronger over 3 seconds then blows along its path. It deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for 0.5 seconds. The distance, damage, and \\u003cstatus\\u003eKnock Up\\u003c/status\\u003e duration increase based on how much the tornado grew. Janna can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to send the tornado early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HowlingGale.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0040/ability_0040_Q1.webm"},{"key":"W","name":"Zephyr","description":"Janna summons an air elemental that passively increases her Move Speed and enables her to pass through units. She may also activate this ability to deal damage and slow an enemy\'s Move Speed. The passive is lost while this ability is on cooldown.","max_rank":5,"range_burn":[650],"cooldown_burn":[12],"cost_burn":[50,60,70,80,90],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While this Ability is available, Janna gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e and is Ghosted.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Janna\'s elemental strikes an enemy, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for 3 seconds, and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SowTheWind.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0040/ability_0040_W1.webm"},{"key":"E","name":"Eye Of The Storm","description":"Janna conjures a defensive gale that shields an ally champion or turret from incoming damage and increases their Attack Damage.","max_rank":5,"range_burn":[800],"cooldown_burn":[15,13,12,10,9],"cost_burn":[70,80,90,100,110],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Janna gains ?% Heal and Shield Power for ? seconds whenever she impairs an enemy champion\'s movement.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Janna grants an ally champion or turret \\u003cshield\\u003e? Shield\\u003c/shield\\u003e decaying over 5 seconds. While shielded, they gain \\u003cscaleAD\\u003e? Attack Damage\\u003c/scaleAD\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EyeOfTheStorm.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0040/ability_0040_E1.webm"},{"key":"R","name":"Monsoon","description":"Janna surrounds herself in a magical storm, throwing enemies back. After the storm has settled, soothing winds heal nearby allies while the ability is active.","max_rank":3,"range_burn":[725],"cooldown_burn":[150,135,120],"cost_burn":[100],"tooltip":"Janna summons a magical monsoon, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e nearby enemies then healing nearby allies for \\u003chealing\\u003e? Health\\u003c/healing\\u003e over 3 seconds. Moving or using an Ability ends the monsoon early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ReapTheWhirlwind.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0040/ability_0040_R1.webm"}]},"41":{"id":41,"key":"Gangplank","name":"Gangplank","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Gangplank.png","enemy_tips":["Parrrley deals a high amount of physical damage. Items that grant Armor can help if an enemy Gangplank is doing well.","Once Gangplank reaches level 6, watch out for his global-range ultimate, Cannon Barrage!"],"ally_tips":["Parrrley applies On Hit effects like Frozen Mallet or Black Cleaver.","Paying attention to low-health enemies on the map can land you a surprise kill with Cannon Barrage.","Try placing Cannon Barrage on the path of escape to cut off fleeing enemies."],"passive":{"name":"Trial by Fire","description":"Every few seconds, Gangplank\'s melee strike will set his opponent on fire.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Gangplank_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0041/ability_0041_P1.webm"},"spells":[{"key":"Q","name":"Parrrley","description":"Shoots target, plundering Gold for each enemy unit killed.","max_rank":5,"range_burn":[625],"cooldown_burn":[4],"cost_burn":[55,50,45,40,35],"tooltip":"Gangplank fires a bullet dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If this kills the target, Gangplank gains an additional 3/4/5/6/7 Gold and 4/5/6/7/8 Silver Serpents. \\u003cbr /\\u003e\\u003cbr /\\u003eGangplank can spend Silver Serpents in the shop to upgrade \\u003cspellName\\u003eCannon Barrage\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GangplankQWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0041/ability_0041_Q1.webm"},{"key":"W","name":"Remove Scurvy","description":"Eats citrus to cure crowd control effects and restore Health.","max_rank":5,"range_burn":[400],"cooldown_burn":[22,20,18,16,14],"cost_burn":[60,70,80,90,100],"tooltip":"Gangplank consumes a large amount of citrus fruit, removing all \\u003cstatus\\u003eDisabling\\u003c/status\\u003e effects and restoring \\u003chealing\\u003e? plus 13% missing Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GangplankW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0041/ability_0041_W1.webm"},{"key":"E","name":"Powder Keg","description":"Gangplank uncovers a powder keg at target location. If he attacks it, it explodes, spreading the attack\'s damage to enemies in the area, slowing them.","max_rank":5,"range_burn":[1000],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Gangplank places a powder keg that can be attacked by Gangplank and enemy champions for 25 seconds. When an enemy destroys it, the keg is defused. When Gangplank destroys it, it explodes, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 40/50/60/70/80% for 2 seconds and dealing the \\u003cphysicalDamage\\u003eAttack\'s damage\\u003c/physicalDamage\\u003e, ignoring ?% Armor. Champions take an additional \\u003cphysicalDamage\\u003e80/105/130/155/180 physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eKeg health decays every ? seconds. Keg explosions detonate other kegs with overlapping blast zones, but don\'t deal damage to the same target more than once. Keg explosions triggered by \\u003cspellName\\u003eParrrley\\u003c/spellName\\u003e will grant the bonus gold for targets killed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GangplankE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0041/ability_0041_E1.webm"},{"key":"R","name":"Cannon Barrage","description":"Gangplank signals his ship to bombard an area, slowing and damaging enemies.","max_rank":3,"range_burn":[30000],"cooldown_burn":[180,160,140],"cost_burn":[100],"tooltip":"Gangplank signals his ship to fire ? waves of cannonballs anywhere on the map over 8 seconds. Each wave \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 30% for 0.5 seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability can be upgraded in the shop via \\u003cspellName\\u003eParrrley\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GangplankR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0041/ability_0041_R1.webm"}]},"42":{"id":42,"key":"Corki","name":"Corki","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Corki.png","enemy_tips":["Watch out for Corki\'s Missile Barrage. They deal splash damage, so you can get hit even when hiding behind minions.","Corki is vulnerable after he uses his Valkyrie or Special Delivery, so try switching focus to him if he uses them to enter a fight."],"ally_tips":["Phosphorus Bomb can be used to reveal enemy units that might be hiding in a nearby patch of brush.","Valkyrie can be used defensively as well, so try using it for a quick escape.","Corki can continue to attack while using Gatling Gun. Maximizing Gatling Gun is key to mastering Corki."],"passive":{"name":"Hextech Munitions","description":"A percentage of Corki\'s basic attack damage is converted into \\u003cmagicDamage\\u003emagic damage\\u003c/magicDamage\\u003e.\\u003cbr\\u003e\\u003cbr\\u003eCorki can occasionally retrieve The Package inside his base, granting him Move Speed and an empowered cast of Valkyrie.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Corki_RapidReload.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0042/ability_0042_P1.webm"},"spells":[{"key":"Q","name":"Phosphorus Bomb","description":"Corki fires a flash bomb at a target location, dealing magic damage to enemies in the area. This attack additionally reveals units in the area for a duration.","max_rank":5,"range_burn":[825],"cooldown_burn":[8],"cost_burn":[60,70,80,90,100],"tooltip":"Corki lobs a bomb, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The area and champions hit are revealed for 6 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PhosphorusBomb.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0042/ability_0042_Q1.webm"},{"key":"W","name":"Valkyrie","description":"Corki flies a short distance, dropping bombs that create a trail of fire that damages opponents who remain in it.","max_rank":5,"range_burn":[600],"cooldown_burn":[20,19,18,17,16],"cost_burn":[100],"tooltip":"Corki flies over and scorches a path, burning it for ? seconds. Enemies in the fire take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Corki has \\u003ckeywordMajor\\u003eThe Package\\u003c/keywordMajor\\u003e, he instead consumes it to fly a much greater distance, refresh this Ability\'s Cooldown, \\u003cstatus\\u003eKnock Aside\\u003c/status\\u003e enemies hit, and burn the path for ? seconds. Enemies hit and in the path are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CarpetBomb.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0042/ability_0042_W1.webm"},{"key":"E","name":"Gatling Gun","description":"Corki\'s gatling gun rapidly fires in a cone in front of him, dealing damage and reducing enemy Armor and Magic Resist.","max_rank":5,"range_burn":[600],"cooldown_burn":[16],"cost_burn":[50],"tooltip":"Corki fires a gatling gun in front of him, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second and shredding up to \\u003cscaleArmor\\u003e8/11/14/17/20 Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e over 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eTotal Damage Per Second: ?","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GGun.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0042/ability_0042_E1.webm"},{"key":"R","name":"Missile Barrage","description":"Corki fires a missile toward his target location that explodes on impact, dealing damage to enemies in an area. Corki stores missiles over time, up to a maximum. Every 3rd missile fired will be a Big One, dealing extra damage.","max_rank":3,"range_burn":[1225],"cooldown_burn":[2],"cost_burn":[20],"tooltip":"Corki fires a missile that explodes on the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding enemies. Every third missile instead deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 7 charges.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MissileBarrage.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0042/ability_0042_R1.webm"}]},"43":{"id":43,"key":"Karma","name":"Karma","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Karma.png","enemy_tips":["Karma\'s passive lowers her Mantra cooldown when she hits enemy champions with abilities and basic attacks. Deny her from getting free hits on you.","Karma\'s Soulflare erupts for bonus damage in the area in which it\'s placed. React quickly and escape the circle to avoid taking heavy damage.","Focused Resolve is a strong disengage tool. Create distance to avoid being rooted and seek to engage afterwards."],"ally_tips":["Gathering Fire rewards aggressive play. Look to land abilities and basic attacks on your opponent to lower Mantra\'s cooldown and stay on the offensive.","When using Focused Resolve, slow your opponents with Inner Flame or speed yourself up with Inspire if you\'re having trouble sticking to a target. ","Don\'t be too conservative with Mantra. Gathering Fire is strongest in teamfights, making it easy to recharge Mantra multiple times."],"passive":{"name":"Gathering Fire","description":"Karma\'s damaging abilities will reduce the cooldown of Mantra.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Karma_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0043/ability_0043_P1.webm"},"spells":[{"key":"Q","name":"Inner Flame","description":"Karma sends forth a ball of spirit energy that explodes and deals damage upon hitting an enemy unit.\\u003cbr\\u003e\\u003cbr\\u003eMantra Bonus: In addition to the explosion, Mantra increases the destructive power of her Inner Flame, creating a cataclysm which deals damage after a short delay.","max_rank":5,"range_burn":[950],"cooldown_burn":[9,8,7,6,5],"cost_burn":[45],"tooltip":"Karma fires a blast of energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first target hit and surrounding enemies, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 35% for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarmaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0043/ability_0043_Q1.webm"},{"key":"W","name":"Focused Resolve","description":"Karma creates a tether between herself and a targeted enemy, dealing damage and revealing them. If the tether is not broken, the enemy will be rooted and damaged again.\\u003cbr\\u003e\\u003cbr\\u003eMantra Bonus: Karma strengthens the link, healing herself and extending the root duration.","max_rank":5,"range_burn":[675],"cooldown_burn":[12],"cost_burn":[50,55,60,65,70],"tooltip":"Karma tethers herself to a champion or jungle monster, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and revealing them for 2 seconds. If the tether remains unbroken, the target takes \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e again and is \\u003cstatus\\u003eRooted\\u003c/status\\u003e for 1.4/1.55/1.7/1.85/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarmaSpiritBind.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0043/ability_0043_W1.webm"},{"key":"E","name":"Inspire","description":"Karma summons a protective shield that absorbs incoming damage and increases the Move Speed of the protected ally.\\u003cbr\\u003e\\u003cbr\\u003eMantra Bonus: Energy radiates out from her target, strengthening the initial shield and applying Inspire to nearby allied champions.","max_rank":5,"range_burn":[800],"cooldown_burn":[10,9,9,8,8],"cost_burn":[50,55,60,65,70],"tooltip":"Karma grants an allied champion \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 2.5 seconds and \\u003cspeed\\u003e40% Move Speed\\u003c/speed\\u003e for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarmaSolKimShield.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0043/ability_0043_E1.webm"},{"key":"R","name":"Mantra","description":"Karma empowers her next ability to do an additional effect. Mantra is available at level 1 and does not require a skill point.","max_rank":4,"range_burn":[1100],"cooldown_burn":[40,38,36,34],"cost_burn":[0],"tooltip":"Karma empowers her next Ability used within 8 seconds.\\u003cbr /\\u003e\\u003cli\\u003e\\u003cspellName\\u003eInner Flame\\u003c/spellName\\u003e: Deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and leaves behind a circle of flame, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies and dealing an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cli\\u003e\\u003cspellName\\u003eFocused Resolve\\u003c/spellName\\u003e: Karma will restore \\u003chealing\\u003e? Health\\u003c/healing\\u003e at the beginning and end of the tether, and \\u003cstatus\\u003eRoot\\u003c/status\\u003e for ? second(s) longer.\\u003cli\\u003e\\u003cspellName\\u003eInspire\\u003c/spellName\\u003e: Karma shields her target for \\u003cshield\\u003e? more Shield\\u003c/shield\\u003e, and also shields allies near her target, granting 30% of the total \\u003cshield\\u003eShield\\u003c/shield\\u003e and \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e value.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KarmaMantra.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0043/ability_0043_R1.webm"}]},"44":{"id":44,"key":"Taric","name":"Taric","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Taric.png","enemy_tips":["Taric\'s ultimate, Cosmic Radiance, has a long delay before its effect. Try to quickly assess whether to disengage the fight or attempt to kill his allies before it goes off.","Taric reduces his spell cooldowns by basic attacking enemies with Bravado. Try to kite him in teamfights and punish him for approaching the minion wave in lane."],"ally_tips":["The cooldown reducing component of Bravado makes Cooldown Reduction items like Frozen Heart, Iceborn Gauntlet, and Spirit Visage exceptionally powerful on Taric.","Using Starlight\'s Touch at lower charges makes its healing less Mana efficient, but can greatly increase Taric\'s sustained damage via Bravado.","Rather than saving Cosmic Radiance for the last moment and risking someone dying during the delay, it can be more beneficial to cast it as soon as you know a teamfight is guaranteed to start."],"passive":{"name":"Bravado","description":"Spellcasts empower Taric\'s next 2 basic attacks to deal bonus magic damage, reduce his spell cooldowns, and attack in quick succession.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Taric_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0044/ability_0044_P1.webm"},"spells":[{"key":"Q","name":"Starlight\'s Touch","description":"Heals nearby allied champions based on charges stored. Bravado-empowered attacks grant a charge of Starlight\'s Touch.","max_rank":5,"range_burn":[325],"cooldown_burn":[3],"cost_burn":[60],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Gain a stack (max 1/2/3/4/5) every ? seconds and when hitting a \\u003cspellName\\u003eBravado\\u003c/spellName\\u003e Attack.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Consume all stacks to restore \\u003chealing\\u003e? Health\\u003c/healing\\u003e per stack to nearby ally champions (\\u003chealing\\u003e?\\u003c/healing\\u003e at 1/2/3/4/5 stacks).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaricQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0044/ability_0044_Q1.webm"},{"key":"W","name":"Bastion","description":"Passively increase the Armor of Taric and any allied champion with Bastion.\\u003cbr\\u003e\\u003cbr\\u003eActively shields an ally and grants them Bastion for as long as they remain near Taric. Taric\'s spells also cast off the ally with Bastion.","max_rank":5,"range_burn":[800],"cooldown_burn":[15],"cost_burn":[60],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eTaric gains \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and forms a tether between him and the ally bound by this Ability. As long as they are near each other, the ally gains \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and Taric casts all his Abilities from both himself and his linked ally.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive: \\u003c/spellPassive\\u003eTaric binds to an ally champion, granting a \\u003cshield\\u003e7/8/9/10/11% max Health Shield\\u003c/shield\\u003e for 2.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaricW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0044/ability_0044_W1.webm"},{"key":"E","name":"Dazzle","description":"Taric readies a beam of starlight that, after a brief delay, deals magic damage and stuns enemies.","max_rank":5,"range_burn":[610],"cooldown_burn":[15,14,13,12,11],"cost_burn":[40],"tooltip":"Taric projects a beam of starlight, bursting after 1 second to deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStun\\u003c/status\\u003e enemies for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaricE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0044/ability_0044_E1.webm"},{"key":"R","name":"Cosmic Radiance","description":"Pulses cosmic energy onto nearby allied champions after a delay, making them invulnerable for a short duration.","max_rank":3,"range_burn":[400],"cooldown_burn":[180,150,120],"cost_burn":[100],"tooltip":"Taric calls down protection from the heavens. After ? seconds, nearby ally champions become invulnerable for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaricR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0044/ability_0044_R1.webm"}]},"45":{"id":45,"key":"Veigar","name":"Veigar","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Veigar.png","enemy_tips":["Dark Matter deals very high damage, but it can be avoided. Pay attention to the sound and visual indicator to be aware of when and where the spell will land.","Event Horizon only stuns units on the edge. If you\'re inside the spell, you can still move and attack.","Veigar\'s ultimate deals increased damage based on your missing health."],"ally_tips":["Use Event Horizon to increase your chances of landing Dark Matter.","Veigar is extremely Mana and Cooldown Reduction dependent. Try buying items with these stats in order to increase the effectiveness of your passive and Baleful Strike.","Veigar is very fragile. It is valuable to select at least one summoner spell that can be used defensively."],"passive":{"name":"Phenomenal Evil Power","description":"Veigar is the greatest Evil to ever strike at the hearts of Runeterra - and he\'s only getting bigger! Striking an enemy Champion with a spell or scoring a takedown grants Veigar permanently increased Ability Power.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/VeigarEntropy.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0045/ability_0045_P1.webm"},"spells":[{"key":"Q","name":"Baleful Strike","description":"Veigar unleashes a bolt of dark energy that deals magic damage to the first two enemies hit. Units killed by this bolt grant Veigar some ability power permanently.","max_rank":5,"range_burn":[900],"cooldown_burn":[6,5,5,4,4],"cost_burn":[30,35,40,45,50],"tooltip":"Veigar unleashes a bolt of dark energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first two enemies hit.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Veigar kills an enemy with this Ability, he gains a stack of \\u003ckeywordMajor\\u003ePhenomenal Evil\\u003c/keywordMajor\\u003e. Large minions and large jungle monsters grant 2 additional stacks.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VeigarBalefulStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0045/ability_0045_Q1.webm"},{"key":"W","name":"Dark Matter","description":"Veigar calls a great mass of dark matter to fall from the sky to the target location, dealing magic damage when it lands. Stacks of Phenomenal Evil reduce Dark Matter\'s cooldown.","max_rank":5,"range_burn":[900],"cooldown_burn":[0],"cost_burn":[60,65,70,75,80],"tooltip":"Veigar summons dark matter from the sky, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEvery 50 stacks of \\u003ckeywordMajor\\u003ePhenomenal Evil\\u003c/keywordMajor\\u003e reduce this Ability\'s Cooldown by 10%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VeigarDarkMatter.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0045/ability_0045_W1.webm"},{"key":"E","name":"Event Horizon","description":"Veigar twists the edges of space, creating a cage that Stuns enemies that pass through.","max_rank":5,"range_burn":[725],"cooldown_burn":[20,18,17,15,14],"cost_burn":[70,75,80,85,90],"tooltip":"Veigar twists the edges of space, creating a cage that \\u003cstatus\\u003eStuns\\u003c/status\\u003e enemies that pass through for 1.5/1.75/2/2.25/2.5 seconds. The cage lasts for 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VeigarEventHorizon.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0045/ability_0045_E1.webm"},{"key":"R","name":"Primordial Burst","description":"Blasts target enemy champion, dealing a large amount of magic damage, increasing based on the target\'s missing health.","max_rank":3,"range_burn":[650],"cooldown_burn":[120,90,60],"cost_burn":[100],"tooltip":"Veigar blasts an enemy champion with primal magic to deal between \\u003cmagicDamage\\u003e? and ? magic damage\\u003c/magicDamage\\u003e, increasing with the target\'s missing Health. Damage is maximized against enemies below 33% Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VeigarR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0045/ability_0045_R1.webm"}]},"48":{"id":48,"key":"Trundle","name":"Trundle","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Trundle.png","enemy_tips":["Trundle is very powerful at location-based combat. Try to draw him off of his Frozen Domain.","Make sure to get out of his Pillar of Ice as quickly as possible, as it significantly slows you down."],"ally_tips":["Trundle excels at fighting within his Frozen Domain. Try to draw enemies onto it.","Use Subjugate to soften a powerful enemy tank or to create a target for your team to focus fire.","Chomp is good for lowering the physical damage of enemies; try to focus it on enemy physical damage dealers."],"passive":{"name":"King\'s Tribute","description":"When an enemy unit dies near Trundle, he heals for a percent of its maximum Health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Trundle_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0048/ability_0048_P1.webm"},"spells":[{"key":"Q","name":"Chomp","description":"Trundle bites his opponent, dealing damage, briefly slowing and sapping some of their Attack Damage.","max_rank":5,"range_burn":[300],"cooldown_burn":[3],"cost_burn":[30],"tooltip":"Trundle\'s next Attack deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and briefly \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 75%, then Trundle gains \\u003cphysicalDamage\\u003e20/25/30/35/40 Attack Damage\\u003c/physicalDamage\\u003e for 5 seconds and the enemy loses \\u003cphysicalDamage\\u003e{{ effect3amount*0.5 }} Attack Damage\\u003c/physicalDamage\\u003e for the same duration.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TrundleTrollSmash.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0048/ability_0048_Q1.webm"},{"key":"W","name":"Frozen Domain","description":"Trundle turns target location into his domain, gaining Attack Speed, Move Speed, and increased healing from all sources while on it.","max_rank":5,"range_burn":[750],"cooldown_burn":[15,14,13,12,11],"cost_burn":[40],"tooltip":"Trundle freezes an area for 8 seconds. While inside he gains \\u003cspeed\\u003e20/28/36/44/52% Move Speed\\u003c/speed\\u003e, \\u003cattackSpeed\\u003e30/50/70/90/110% Attack Speed\\u003c/attackSpeed\\u003e, and 25% increased healing.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/trundledesecrate.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0048/ability_0048_W1.webm"},{"key":"E","name":"Pillar of Ice","description":"Trundle creates an ice pillar at target location, becoming impassable terrain and slowing all nearby enemy units.","max_rank":5,"range_burn":[1000],"cooldown_burn":[24,22,20,18,16],"cost_burn":[75],"tooltip":"Trundle creates an icy pillar for 6 seconds, briefly \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e enemies directly over it and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e nearby enemies by 30/34/38/42/46%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TrundleCircle.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0048/ability_0048_E1.webm"},{"key":"R","name":"Subjugate","description":"Trundle immediately steals a percent of his target\'s Health, Armor and Magic Resistance. Over the next 4 seconds the amount of Health, Armor, and Magic Resistance stolen is doubled.","max_rank":3,"range_burn":[650],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Trundle drains the lifeforce of an enemy champion, dealing \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e and stealing \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TrundlePain.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0048/ability_0048_R1.webm"}]},"50":{"id":50,"key":"Swain","name":"Swain","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Swain.png","enemy_tips":["Swain\'s passive is very potent if you are immobilized. Make sure to be extra careful around enemies who have immobilizing effects.","High mobility counters all of Swain\'s basic abilities: Death\'s Hand does more damage the closer he is, Vision of Empire has a very long delay and Nevermove must start returning back to him to be dangerous.","Buying an item with Grievous Wounds will make Swain much easier to kill during his Demonic Ascension."],"ally_tips":["If you\'re having trouble rooting an enemy with Nevermove, try throwing it at opponents when they are near their minions so the explosion surprises them.","While laning, try to use Death\'s Hand\'s piercing damage to damage opponents from a safe distance.","Vision of Empire is quite difficult to land on its own, look for skirmishes around the map where enemies may be distracted or crowd controlled so you can land it more easily.","Demonic Ascension may make Swain very hard to kill but he\'s pretty easy to get away from. Try building items that can slow opponents to keep them in range if their mobility is overwhelming."],"passive":{"name":"Ravenous Flock","description":"Swain\'s ravens collect \\u003ci\\u003eSoul Fragments\\u003c/i\\u003e that heal him and permanently increase his maximum health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Swain_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0050/ability_0050_P1.webm"},"spells":[{"key":"Q","name":"Death\'s Hand","description":"Swain unleashes several bolts of eldritch power that pierce through enemies. Enemies hit take more damage for each bolt they are struck by.","max_rank":5,"range_burn":[750],"cooldown_burn":[7,6,5,4,3],"cost_burn":[45,50,55,60,65],"tooltip":"Swain unleashes eldritch bolts, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per bolt past the first (max \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SwainQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0050/ability_0050_Q1.webm"},{"key":"W","name":"Vision of Empire","description":"Swain opens a demon eye that deals damage and slows enemies. Champions hit are revealed and also grant Swain a Soul Fragment.","max_rank":5,"range_burn":[5500,6000,6500,7000,7500],"cooldown_burn":[22,21,20,19,18],"cost_burn":[60,65,70,75,80],"tooltip":"Swain opens a demon eye, revealing a location for 1.5 seconds, then deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 25/35/45/55/65% for 2.5 seconds. Champions hit grant Swain a \\u003cspan class=\\"size18 colorFF3F3F\\"\\u003eSoul Fragment\\u003c/span\\u003e and are revealed for 4/5/6/7/8 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SwainW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0050/ability_0050_W1.webm"},{"key":"E","name":"Nevermove","description":"Swain launches a wave of demonic power forward. It then returns to Swain and roots enemies it hits. Swain can then choose to pull all rooted champions closer. This ability has a shorter cooldown during Demonic Ascension.","max_rank":5,"range_burn":[850],"cooldown_burn":[10],"cost_burn":[50],"tooltip":"Swain launches a wave of demonic power, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The wave then returns, detonating on the first enemy hit dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eRooting\\u003c/status\\u003e enemies in an area for 1.5 seconds. During \\u003cspellName\\u003eDemonic Ascension\\u003c/spellName\\u003e, this ability\'s cooldown is reduced by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003eHitting a champion with Nevermove allows Swain to reactivate this ability to pull all champions hit by Nevermove, gaining a \\u003cspan class=\\"size18 colorFF3F3F\\"\\u003eSoul Fragment\\u003c/span\\u003e for each.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SwainE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0050/ability_0050_E1.webm"},{"key":"R","name":"Demonic Ascension","description":"Swain transforms into a demon and drains health from nearby enemy champions, minions, and neutral monsters. Swain can cast Demonflare to decimate and slow nearby enemies with a nova of soulfire. This form is indefinite as long as Swain drains enemy champions.","max_rank":3,"range_burn":[650],"cooldown_burn":[100,80,60],"cost_burn":[100],"tooltip":"Swain frees the demon, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each second and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e per target damaged. His Demonic Energy depletes over time, and can be recharged indefinitely by draining enemy Champions and is fully restored on Champion takedowns.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter ? seconds, Swain can cast \\u003cspellName\\u003eDemonflare\\u003c/spellName\\u003e which deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies by ?% for ?s.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eHealing is reduced to \\u003chealing\\u003e?\\u003c/healing\\u003e against non-champions.\\u003cbr /\\u003eAfter ? seconds, Swain\'s Demonic Energy depletes faster.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SwainR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0050/ability_0050_R1.webm"}]},"51":{"id":51,"key":"Caitlyn","name":"Caitlyn","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Caitlyn.png","enemy_tips":["Keep behind allied minions if Caitlyn is harassing you with Piltover Peacemaker (it deals less damage with each subsequent target).","You can intercept Ace in the Hole\'s missile from hitting an ally if you stand in its path."],"ally_tips":["Make use of her Yordle Snap Traps by placing them pre-emptively to ensure that you\'ll have one off of cooldown during combat.","Avoid using Ace in the Hole in large team melees as it might be blocked by the wrong target.","Fire 90 Caliber Net away from the opponent to close the gap or hop over walls."],"passive":{"name":"Headshot","description":"Every few basic attacks, or against a target she has trapped or netted, Caitlyn will fire a headshot dealing bonus damage that scales with her critical strike chance. On trapped or netted targets, Caitlyn\'s Headshot attack range is doubled.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Caitlyn_Headshot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0051/ability_0051_P1.webm"},"spells":[{"key":"Q","name":"Piltover Peacemaker","description":"Caitlyn revs up her rifle for 1 second to unleash a penetrating shot that deals physical damage (deals less damage to subsequent targets).","max_rank":5,"range_burn":[1250],"cooldown_burn":[10,9,8,7,6],"cost_burn":[55,60,65,70,75],"tooltip":"Caitlyn revs her rifle to fire a piercing shot dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. After the bolt strikes the first target, it opens into a wider shot that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies revealed by \\u003cspellName\\u003eYordle Snap Trap\\u003c/spellName\\u003e always take full damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CaitlynQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0051/ability_0051_Q1.webm"},{"key":"W","name":"Yordle Snap Trap","description":"Caitlyn sets a trap to find sneaky yordles. When sprung, the trap reveals and immobilizes the enemy champion for 1.5 seconds, granting Caitlyn an empowered Headshot.","max_rank":5,"range_burn":[800],"cooldown_burn":[0],"cost_burn":[20],"tooltip":"Caitlyn sets a trap that \\u003cstatus\\u003eRoots\\u003c/status\\u003e the first champion that steps on it for 1.5 seconds and granting \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of them for 3 seconds. Traps last for 30/35/40/45/50 seconds, and 3/3/4/4/5 traps may be active at once. This Ability has 3/3/4/4/5 charges (? second refresh).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CaitlynW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0051/ability_0051_W1.webm"},{"key":"E","name":"90 Caliber Net","description":"Caitlyn fires a heavy net to slow her target. The recoil knocks Caitlyn back.","max_rank":5,"range_burn":[750],"cooldown_burn":[16,14,12,10,8],"cost_burn":[75],"tooltip":"Caitlyn fires a net, pushing her backwards. The net \\u003cstatus\\u003eSlows\\u003c/status\\u003e the first target hit by 50% for 1 seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CaitlynE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0051/ability_0051_E1.webm"},{"key":"R","name":"Ace in the Hole","description":"Caitlyn takes time to line up the perfect shot, dealing massive damage to a single target at a huge range. Enemy champions can intercept the bullet for their ally.","max_rank":3,"range_burn":[3500],"cooldown_burn":[90,75,60],"cost_burn":[100],"tooltip":"Caitlyn takes a moment to channel and line up the perfect shot, then she fires, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, but other enemy champions can intercept it. This Ability grants \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of the target during the channel.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CaitlynR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0051/ability_0051_R1.webm"}]},"53":{"id":53,"key":"Blitzcrank","name":"Blitzcrank","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Blitzcrank.png","enemy_tips":["Blitzcrank\'s passive Mana Barrier grants him a shield when he is low on health.","Staying behind creeps can prevent you from being Rocket Grabbed. Blitzcrank\'s Rocket Grab only pulls the first enemy target it encounters."],"ally_tips":["The 1-2-3 combo of Rocket Grab, Power Fist, and Static Field can devastate an individual opponent.","Using Blitzcrank\'s grab to pull an enemy into your tower range followed by a Power Fist will allow the tower to get several hits on them."],"passive":{"name":"Mana Barrier","description":"Blitzcrank gains a shield based on his mana when dropping to low health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Blitzcrank_ManaBarrier.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0053/ability_0053_P1.webm"},"spells":[{"key":"Q","name":"Rocket Grab","description":"Blitzcrank fires his right hand to grab an opponent on its path, dealing damage and dragging it back to him.","max_rank":5,"range_burn":[1079],"cooldown_burn":[20,19,18,17,16],"cost_burn":[100],"tooltip":"Blitzcrank fires his right hand, \\u003cstatus\\u003ePulling\\u003c/status\\u003e the first enemy hit towards him and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RocketGrab.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0053/ability_0053_Q1.webm"},{"key":"W","name":"Overdrive","description":"Blitzcrank super charges himself to get dramatically increased Move and Attack Speed. He is temporarily slowed after the effect ends.","max_rank":5,"range_burn":[1],"cooldown_burn":[15],"cost_burn":[75],"tooltip":"Blitzcrank supercharges himself, gaining \\u003cspeed\\u003e?% decaying Move Speed\\u003c/speed\\u003e and \\u003cattackSpeed\\u003e30/38/46/54/62% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds. Afterwards, Blitzcrank is \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 30% for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Overdrive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0053/ability_0053_W1.webm"},{"key":"E","name":"Power Fist","description":"Blitzcrank charges up his fist to make his next attack deal double damage and pop his target up in the air.","max_rank":5,"range_burn":[300],"cooldown_burn":[9,8,7,6,5],"cost_burn":[25],"tooltip":"Blitzcrank charges up his fist, causing his next Attack to \\u003cstatus\\u003eKnock Up\\u003c/status\\u003e and deal \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PowerFist.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0053/ability_0053_E1.webm"},{"key":"R","name":"Static Field","description":"Enemies attacked by Blitzcrank are marked and take lightning damage after 1 second. Additionally, Blitzcrank can activate this ability to remove nearby enemies\' shields, damage them, and silence them briefly.","max_rank":3,"range_burn":[600],"cooldown_burn":[60,40,20],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eWhile this ability is available, lightning charges Blitzcrank\'s fists, marking those he Attacks. After 1 second, they are shocked for \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive: \\u003c/spellActive\\u003eBlitzcrank overcharges, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSilencing\\u003c/status\\u003e nearby enemies for 0.75 seconds. Their shields are also destroyed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/StaticField.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0053/ability_0053_R1.webm"}]},"54":{"id":54,"key":"Malphite","name":"Malphite","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Malphite.png","enemy_tips":["If you\'re a physical damage character stay behind your allies when fighting Malphite. Ground Slam can significantly reduce your damage output.","Malphite is one of a couple tanks who are capable of jungling. Watch out if he gets Smite."],"ally_tips":["Armor naturally reduces the rate that attacks go through Granite Shield, so Brutal Strikes will strengthen the shield against physical damage.","Despite his abilities scaling on Armor, some games require Malphite to get Magic Resist. When those games occur, try getting Aegis of the Legion, Mercury\'s Treads, and Guardian Angel."],"passive":{"name":"Granite Shield","description":"Malphite is shielded by a layer of rock which absorbs damage up to 10% of his maximum Health. If Malphite has not been hit for a few seconds, this effect recharges.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Malphite_GraniteShield.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0054/ability_0054_P1.webm"},"spells":[{"key":"Q","name":"Seismic Shard","description":"Malphite sends a shard of the earth through the ground at his foe, dealing damage upon impact and stealing Move Speed for 3 seconds.","max_rank":5,"range_burn":[625],"cooldown_burn":[8],"cost_burn":[70,75,80,85,90],"tooltip":"Malphite launches a shard of earth at an enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 20/25/30/35/40% for ? seconds. Malphite also steals the amount \\u003cstatus\\u003eSlowed\\u003c/status\\u003e, gaining it as \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SeismicShard.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0054/ability_0054_Q1.webm"},{"key":"W","name":"Thunderclap","description":"Malphite attacks with such force that it creates a sonic boom. For the next few seconds, his attacks create aftershocks in front of him.","max_rank":5,"range_burn":[400],"cooldown_burn":[12],"cost_burn":[30,35,40,45,50],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eMalphite gains \\u003cscaleArmor\\u003e?% Armor (%i:scaleArmor%?)\\u003c/scaleArmor\\u003e. This effect is increased to \\u003cscaleArmor\\u003e?% (%i:scaleArmor%?)\\u003c/scaleArmor\\u003e while \\u003cspellName\\u003eGranite Shield\\u003c/spellName\\u003e is active.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive: \\u003c/spellPassive\\u003eMalphite\'s next Attack deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and creates an aftershock which deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e in their direction. His Attacks continue to create aftershocks for the next ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Obduracy.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0054/ability_0054_W1.webm"},{"key":"E","name":"Ground Slam","description":"Malphite slams the ground, sending out a shockwave that deals magic damage based on his Armor and reduces the Attack Speed of enemies for a short duration.","max_rank":5,"range_burn":[400],"cooldown_burn":[7],"cost_burn":[50,55,60,65,70],"tooltip":"Malphite slams the ground, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and reducing \\u003cattackSpeed\\u003eAttack Speed by ?%\\u003c/attackSpeed\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Landslide.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0054/ability_0054_E1.webm"},{"key":"R","name":"Unstoppable Force","description":"Malphite launches himself to a location at high speed, damaging enemies and knocking them into the air.","max_rank":3,"range_burn":[1000],"cooldown_burn":[130,105,80],"cost_burn":[100],"tooltip":"Malphite charges with the force of a landslide, dashing Unstoppably. At the end of the dash, Malphite \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for ? seconds and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UFSlash.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0054/ability_0054_R1.webm"}]},"55":{"id":55,"key":"Katarina","name":"Katarina","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Katarina.png","enemy_tips":["Katarina\'s abilities deal magic damage, so even if she\'s building Attack Damage items, get magic resistance to counter her.","Try to save a disable for when Katarina uses her Death Lotus."],"ally_tips":["Picking up Daggers will significantly reduce Shunpo\'s cooldown.","Try waiting until the other team is distracted with fighting your team, and use Shunpo to teleport into the fray and unleash a devastating Death Lotus.","Using Shunpo on an allied Champion, Dagger, or minion can be a great escape tactic."],"passive":{"name":"Voracity","description":"Whenever an enemy champion dies that Katarina has damaged recently, her remaining ability cooldowns are dramatically reduced.\\u003cbr\\u003e\\u003cbr\\u003eIf Katarina picks up a \\u003cfont color=\'#FFF673\'\\u003eDagger\\u003c/font\\u003e, she uses it to slash through all nearby enemies, dealing magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Katarina_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0055/ability_0055_P1.webm"},"spells":[{"key":"Q","name":"Bouncing Blade","description":"Katarina throws a \\u003cfont color=\'#FFF673\'\\u003eDagger\\u003c/font\\u003e at the target that then bounces to nearby enemies before ricocheting onto the ground.","max_rank":5,"range_burn":[625],"cooldown_burn":[11,10,9,8,7],"cost_burn":[0],"tooltip":"Katarina throws a \\u003ckeywordMajor\\u003eDagger\\u003c/keywordMajor\\u003e, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the target and 2 nearby enemies. The \\u003ckeywordMajor\\u003eDagger\\u003c/keywordMajor\\u003e then ricochets onto the ground behind the primary target.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KatarinaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0055/ability_0055_Q1.webm"},{"key":"W","name":"Preparation","description":"Katarina gains a burst of Move Speed, tossing a \\u003cfont color=\'#FFF673\'\\u003eDagger\\u003c/font\\u003e into the air directly above herself.","max_rank":5,"range_burn":[25000],"cooldown_burn":[15,14,13,12,11],"cost_burn":[0],"tooltip":"Katarina tosses a \\u003ckeywordMajor\\u003eDagger\\u003c/keywordMajor\\u003e into the air and gains \\u003cspeed\\u003e50/60/70/80/90% Move Speed\\u003c/speed\\u003e decaying over 1.25 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KatarinaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0055/ability_0055_W1.webm"},{"key":"E","name":"Shunpo","description":"Katarina blinks to the target, striking it if its an enemy, or striking the nearest enemy otherwise.","max_rank":5,"range_burn":[725],"cooldown_burn":[14,12,11,9,8],"cost_burn":[0],"tooltip":"Katarina dashes in the blink of an eye to the target ally, enemy, or \\u003ckeywordMajor\\u003eDagger\\u003c/keywordMajor\\u003e. If it is an enemy, Katarina strikes for \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e - otherwise she strikes the nearest enemy in range.\\u003cbr /\\u003e\\u003cbr /\\u003ePicking up a \\u003ckeywordMajor\\u003eDagger\\u003c/keywordMajor\\u003e will reduce this Ability\'s Cooldown by \\u003cscaleLevel\\u003e?\\u003c/scaleLevel\\u003e seconds (\\u003cscaleLevel\\u003e?%\\u003c/scaleLevel\\u003e).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eKatarina can blink to any location near the target.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KatarinaEWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0055/ability_0055_E1.webm"},{"key":"R","name":"Death Lotus","description":"Katarina becomes a flurry of blades, dealing massive magic damage while she channels to the 3 nearest enemy champions.","max_rank":3,"range_burn":[550],"cooldown_burn":[90,60,45],"cost_burn":[0],"tooltip":"Katarina becomes a flurry of blades, rapidly attacking the three nearest enemy champions with a flurry of knives. Each knife deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, and applies ?% Grievous Wound for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eTotal over ? seconds to each enemy: \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KatarinaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0055/ability_0055_R1.webm"}]},"56":{"id":56,"key":"Nocturne","name":"Nocturne","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nocturne.png","enemy_tips":["Stay close to your allies when Paranoia is cast - there is strength in numbers!","Nocturne\'s Unspeakable Horror is broken with range, so try to save your movement abilities for when he casts it."],"ally_tips":["Using Paranoia at a critical moment is well worth it even if you cannot use the dash.","Duskbringer isn\'t only an offensive ability. It can be used to close distance out of combat or escape from certain death.","Use Shroud of Darkness in tandem with Paranoia\'s dash. Your opponents may panic and waste a critical disable on your spell shield."],"passive":{"name":"Umbra Blades","description":"Every few seconds, Nocturne\'s next attack strikes surrounding enemies for bonus physical damage and heals himself. \\u003cbr\\u003e\\u003cbr\\u003eNocturne\'s basic attacks reduce this cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Nocturne_UmbraBlades.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0056/ability_0056_P1.webm"},"spells":[{"key":"Q","name":"Duskbringer","description":"Nocturne throws a shadow blade that deals damage, leaves a Dusk Trail, and causes champions to leave a Dusk Trail. While on the trail, Nocturne can move through units and has increased Move Speed and Attack Damage.","max_rank":5,"range_burn":[1125],"cooldown_burn":[8],"cost_burn":[60,65,70,75,80],"tooltip":"Nocturne throws a shadow blade, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and leaving a dusk trail for 5 seconds. Enemy champions hit also leave a trail. \\u003cbr /\\u003e\\u003cbr /\\u003eWhile on the trail, Nocturne is Ghosted and gains \\u003cspeed\\u003e15/20/25/30/35% Move Speed\\u003c/speed\\u003e and \\u003cphysicalDamage\\u003e20/30/40/50/60 Attack Damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NocturneDuskbringer.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0056/ability_0056_Q1.webm"},{"key":"W","name":"Shroud of Darkness","description":"Nocturne empowers his blades, passively gaining Attack Speed. Activating Shroud of Darkness allows Nocturne to fade into the shadows, creating a magical barrier which blocks a single enemy ability and doubles his passive Attack Speed if successful.","max_rank":5,"range_burn":[20],"cooldown_burn":[20,18,16,14,12],"cost_burn":[50],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Nocturne gains \\u003cattackSpeed\\u003e60/70/80/90/100% Attack Speed\\u003c/attackSpeed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Nocturne creates a shadow barrier for 1.5 seconds that blocks the next enemy Ability. If an Ability is blocked, this Ability\'s passive effect is increased to \\u003cattackSpeed\\u003e60/70/80/90/100% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NocturneShroudofDarkness.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0056/ability_0056_W1.webm"},{"key":"E","name":"Unspeakable Horror","description":"Nocturne plants a nightmare into his target\'s mind, dealing damage each second and applying fear to the target if they do not get out of range by the end of the duration.","max_rank":5,"range_burn":[425],"cooldown_burn":[15,14,13,12,11],"cost_burn":[60,65,70,75,80],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Nocturne gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e toward \\u003cstatus\\u003eFeared\\u003c/status\\u003e enemies.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Nocturne plants a nightmare tether into his target, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 2 seconds. If the tether remains unbroken, the target is \\u003cstatus\\u003eFeared\\u003c/status\\u003e for 1.25/1.5/1.75/2/2.25 second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NocturneUnspeakableHorror.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0056/ability_0056_E1.webm"},{"key":"R","name":"Paranoia","description":"Nocturne reduces the sight radius of all enemy champions and removes their ally vision in the process. He can then launch himself at a nearby enemy champion.","max_rank":3,"range_burn":[2500,3250,4000],"cooldown_burn":[140,115,90],"cost_burn":[100],"tooltip":"Nocturne darkens the map, reducing the sight radius and removing ally vision of enemy champions for ? seconds. Nocturne can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability during the duration to launch himself at an enemy champion dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NocturneParanoia.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0056/ability_0056_R1.webm"}]},"57":{"id":57,"key":"Maokai","name":"Maokai","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Maokai.png","enemy_tips":["Saplings will chase the first enemy that gets too close, but detonate after a few seconds or if they collide with other enemies. Be especially careful around brush sapling, as they are much more dangerous.","The cooldown on Maokai\'s self healing is heavily gated on how many time you hit him with spells. Careful about wasting abilities on him.","Maokai will avoid taking damage while he\'s using Twisted Advance, so don\'t waste your spells."],"ally_tips":["Saplings can be tossed into brush for empowered effect - but don\'t stack well.","Try looking for flanks or other situations where Nature\'s Grasp is unavoidable or takes enemies by surprise.","Maokai\'s passive makes him extremely durable against focus fire from spells - so long as he can still basic attack something."],"passive":{"name":"Sap Magic","description":"Maokai\'s basic attack also heals him on a moderate cooldown. Each time Maokai casts a spell or is struck by an enemy\'s spell, this cooldown is reduced.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Maokai_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0057/ability_0057_P1.webm"},"spells":[{"key":"Q","name":"Bramble Smash","description":"Maokai knocks back nearby enemies with a shockwave, dealing magic damage and slowing them.","max_rank":5,"range_burn":[600],"cooldown_burn":[8,7,6,5,5],"cost_burn":[60],"tooltip":"Maokai smashes his fist into the ground, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies briefly. Nearby enemies are \\u003cstatus\\u003eKnocked Back\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MaokaiQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0057/ability_0057_Q1.webm"},{"key":"W","name":"Twisted Advance","description":"Maokai contorts into a mass of moving roots, becoming untargetable and dashing to the target. Upon arrival, he roots the target.","max_rank":5,"range_burn":[525],"cooldown_burn":[13,12,11,10,9],"cost_burn":[60],"tooltip":"Maokai transforms into a moving mass of roots, becoming Untargetable and dashing to an enemy. Upon arrival, he \\u003cstatus\\u003eRoots\\u003c/status\\u003e the target for 1/1.1/1.2/1.3/1.4 second(s) and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MaokaiW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0057/ability_0057_W1.webm"},{"key":"E","name":"Sapling Toss","description":"Maokai flings a sapling to the target area to stand guard. More effective in brush.","max_rank":5,"range_burn":[1100],"cooldown_burn":[10],"cost_burn":[60,70,80,90,100],"tooltip":"Maokai flings a sapling, which stands watch for ? seconds. Saplings will chase nearby enemies, detonating on proximity, dealing \\u003cmagicDamage\\u003e? plus ? max Health magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e surrounding enemies by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf placed in a brush, Saplings last for ? seconds and cause a larger explosion, dealing \\u003cmagicDamage\\u003e? plus ? max Health magic damage\\u003c/magicDamage\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MaokaiE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0057/ability_0057_E1.webm"},{"key":"R","name":"Nature\'s Grasp","description":"Maokai summons a colossal wall of brambles and thorns that slowly advances forwards, damaging and rooting any enemies in the path.","max_rank":3,"range_burn":[3000],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Maokai summons a colossal wave of brambles and thorns, \\u003cstatus\\u003eRooting\\u003c/status\\u003e enemies for between ? and ? seconds, increasing with distance travelled, and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MaokaiR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0057/ability_0057_R1.webm"}]},"58":{"id":58,"key":"Renekton","name":"Renekton","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Renekton.png","enemy_tips":["Pay close attention to Renekton\'s Fury gauge as that will usually signify when he is about to attack.","Keeping Renekton from being able to fight and gain Fury by continually harassing him will severely reduce the effectiveness of his abilities."],"ally_tips":["Slice and Dice excels at harassing maneuvers. Slice in, follow up with another skill and then Dice back out to safety.","Cull the Meek drains an enormous amount of life when used in the middle of the fray. You can use this to bait opponents into thinking you are weaker than you really are.","Cooldown reduction is especially good for Renekton, allowing him to both quickly build up and use his Fury."],"passive":{"name":"Reign of Anger","description":"Renekton\'s attacks generate Fury, increased when he is low on life. This Fury can empower his abilities with bonus effects.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Renekton_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0058/ability_0058_P1.webm"},"spells":[{"key":"Q","name":"Cull the Meek","description":"Renekton swings his blade, dealing moderate physical damage to all targets around him, and heals for a small portion of the damage dealt. If he has more than 50 Fury, his damage and heal are increased.","max_rank":5,"range_burn":[325],"cooldown_burn":[7],"cost_burn":[0],"tooltip":"Renekton swings his blade, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and restoring \\u003chealing\\u003e? Health\\u003c/healing\\u003e per non-champion and \\u003chealing\\u003e?\\u003c/healing\\u003e per champion hit (max \\u003chealing\\u003e50/75/100/125/150 Health\\u003c/healing\\u003e). He also generates \\u003ckeywordMajor\\u003e2.5 Fury\\u003c/keywordMajor\\u003e per non-champion and \\u003ckeywordMajor\\u003e10 Fury\\u003c/keywordMajor\\u003e per champion (max \\u003ckeywordMajor\\u003e30 Fury\\u003c/keywordMajor\\u003e).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eFury Bonus\\u003c/keywordMajor\\u003e: Damage is increased to \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and healing is increased to \\u003chealing\\u003e? Health\\u003c/healing\\u003e against non-champions and \\u003chealing\\u003e? Health\\u003c/healing\\u003e against champions (max \\u003chealing\\u003e200/300/400/500/600 Health\\u003c/healing\\u003e). Does not generate any \\u003ckeywordMajor\\u003eFury\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenektonCleave.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0058/ability_0058_Q1.webm"},{"key":"W","name":"Ruthless Predator","description":"Renekton slashes his target twice, dealing moderate physical damage and stuns them for 0.75 seconds. If Renekton has more than 50 Fury, he slashes his target three times, destroying damage shields on the target, dealing high physical damage, and stunning them for 1.5 seconds.","max_rank":5,"range_burn":[300],"cooldown_burn":[16,14,12,10,8],"cost_burn":[0],"tooltip":"Renekton\'s next Attack strikes twice, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for 0.75 seconds and dealing a total of \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Hitting a champion generates an additonal \\u003ckeywordMajor\\u003e10 Fury\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eFury Bonus\\u003c/keywordMajor\\u003e: Renekton Attacks 3 times instead, destroying \\u003cshield\\u003eShields\\u003c/shield\\u003e before dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e for 1.5 seconds. Does not generate additional \\u003ckeywordMajor\\u003eFury\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenektonPreExecute.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0058/ability_0058_W1.webm"},{"key":"E","name":"Slice and Dice","description":"Renekton dashes, dealing damage to units along the way. Empowered, Renekton deals bonus damage and reduces the Armor of units hit.","max_rank":5,"range_burn":[450],"cooldown_burn":[18,17,16,15,14],"cost_burn":[0],"tooltip":"Renekton dashes, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. He generates \\u003ckeywordMajor\\u003e2 Fury\\u003c/keywordMajor\\u003e per non-champion and \\u003ckeywordMajor\\u003e10 Fury\\u003c/keywordMajor\\u003e per champion hit. Hitting at least one enemy allows Renekton to \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability once for 4 seconds. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eFury Bonus\\u003c/keywordMajor\\u003e: The \\u003crecast\\u003eRecast\\u003c/recast\\u003e dash deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e instead and removes \\u003cscaleArmor\\u003e25/27.5/30/32.5/35% Armor\\u003c/scaleArmor\\u003e for 4 seconds. Does not generate \\u003ckeywordMajor\\u003eFury\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenektonSliceAndDice.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0058/ability_0058_E1.webm"},{"key":"R","name":"Dominus","description":"Renekton transforms into the Tyrant form, gaining bonus Health and dealing damage to enemies around him. While in this form, Renekton gains Fury periodically.","max_rank":3,"range_burn":[20],"cooldown_burn":[120],"cost_burn":[0],"tooltip":"Renekton surrounds himself with dark energies for ? seconds, gaining \\u003chealing\\u003e? max Health\\u003c/healing\\u003e and \\u003ckeywordMajor\\u003e? Fury\\u003c/keywordMajor\\u003e. While active, he deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and gains \\u003ckeywordMajor\\u003e? Fury\\u003c/keywordMajor\\u003e per second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenektonReignOfTheTyrant.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0058/ability_0058_R1.webm"}]},"59":{"id":59,"key":"JarvanIV","name":"Jarvan IV","image_url":"https://opgg-static.akamaized.net/images/lol/champion/JarvanIV.png","enemy_tips":["Keep out of the path between Jarvan IV and his Demacian Standard to avoid being knocked up in the air.","Cataclysm\'s terrain is a frightening force to fight against, but movement abilities can go through it."],"ally_tips":["You can use the Dragon Strike / Demacian Standard combo to get out of your own Cataclysm arenas.","Split your basic attacks on different champions at the beginning of fights to maximize damage.","Use Demacian Standard as a scouting tool when worried about incoming enemies."],"passive":{"name":"Martial Cadence","description":"Jarvan\'s first basic attack on an enemy deals bonus physical damage based on their current Health. This effect cannot occur again on the same enemy for a few seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/JarvanIV_MartialCadence.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0059/ability_0059_P1.webm"},"spells":[{"key":"Q","name":"Dragon Strike","description":"Jarvan IV extends his lance, dealing physical damage and lowering the Armor of enemies in its path. Additionally, this will pull Jarvan to his Demacian Standard, knocking up enemies in his path.","max_rank":5,"range_burn":[770],"cooldown_burn":[10,9,8,7,6],"cost_burn":[45,50,55,60,65],"tooltip":"Jarvan extends his lance, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and removing \\u003cscaleArmor\\u003e10/14/18/22/26% Armor\\u003c/scaleArmor\\u003e for 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the lance connects with \\u003cspellName\\u003eDemacian Standard\\u003c/spellName\\u003e, Jarvan will pull himself to it, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e those in his path for 0.75 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JarvanIVDragonStrike.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0059/ability_0059_Q1.webm"},{"key":"W","name":"Golden Aegis","description":"Jarvan IV calls upon the ancient kings of Demacia to shield him from harm and slow surrounding enemies.","max_rank":5,"range_burn":[625],"cooldown_burn":[9],"cost_burn":[30],"tooltip":"Jarvan summons an aegis, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e nearby enemies by 15/20/25/30/35% for 2 seconds and granting him \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for each enemy champion hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JarvanIVGoldenAegis.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0059/ability_0059_W1.webm"},{"key":"E","name":"Demacian Standard","description":"Jarvan IV carries the pride of Demacia, passively granting him bonus Attack Speed. Activating Demacian Standard allows Jarvan IV to place a Demacian flag that deals magic damage on impact and grants Attack Speed to nearby allied champions.","max_rank":5,"range_burn":[860],"cooldown_burn":[12],"cost_burn":[55],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Jarvan gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Jarvan throws a standard into the ground, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and granting allies near the standard \\u003cattackSpeed\\u003e20/22.5/25/27.5/30% Attack Speed\\u003c/attackSpeed\\u003e for 8 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JarvanIVDemacianStandard.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0059/ability_0059_E1.webm"},{"key":"R","name":"Cataclysm","description":"Jarvan IV heroically leaps into battle at a target with such force that he terraforms the surrounding area to create an arena around them. Nearby enemies are damaged at the moment of impact.","max_rank":3,"range_burn":[650],"cooldown_burn":[120,105,90],"cost_burn":[100],"tooltip":"Jarvan heroically leaps to an enemy Champion, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to them and surrounding enemies and creating an arena of impassable terrain around them for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eJarvan can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to collapse the terrain.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JarvanIVCataclysm.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0059/ability_0059_R1.webm"}]},"60":{"id":60,"key":"Elise","name":"Elise","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Elise.png","enemy_tips":["Elise\'s Spider Form is more dangerous when you are at low health, and her Human Form more potent when you are at high health.","Rappel will only move Elise straight up and down unless she can descend upon an enemy unit.","Rappel has a long cooldown. Elise is vulnerable after she has used it."],"ally_tips":["Spider Form is most effective at finishing off enemies with low health; Human Form\'s Neurotoxin does more damage to healthy foes. ","When in Spider Form, Spiderlings will attack the target that Elise uses Venomous Bite on. ","Elise\'s Spider Form and Spider Form abilities do not cost mana and can be prioritized when you are trying to conserve mana."],"passive":{"name":"Spider Queen","description":"Human Form: When Elise\'s abilities hit an enemy, she gains a dormant Spiderling.\\u003cbr\\u003e\\u003cbr\\u003eSpider Form: Basic attacks deal bonus magic damage and restore health to Elise.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ElisePassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0060/ability_0060_P1.webm"},"spells":[{"key":"Q","name":"Neurotoxin / Venomous Bite","description":"Human Form: Deals damage based upon how high the target\'s Health is.\\u003cbr\\u003e\\u003cbr\\u003eSpider Form: Lunges at an enemy and deals damage based upon how low their Health is.","max_rank":5,"range_burn":[625],"cooldown_burn":[6],"cost_burn":[80,85,90,95,100],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e: Elise injects neurotoxin, dealing \\u003cmagicDamage\\u003e40/70/100/130/160 plus ? current Health magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EliseHumanQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0060/ability_0060_Q1.webm"},{"key":"W","name":"Volatile Spiderling / Skittering Frenzy","description":"Human Form: Releases a venom-gorged Spiderling that explodes when it nears a target.\\u003cbr\\u003e\\u003cbr\\u003eSpider Form: Elise and her Spiderlings gain Attack Speed.","max_rank":5,"range_burn":[950],"cooldown_burn":[12],"cost_burn":[60,70,80,90,100],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e: Elise summons an explosive spider that moves to a location and explodes when it nears an enemy or after 3 seconds. The spider deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EliseHumanW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0060/ability_0060_W1.webm"},{"key":"E","name":"Cocoon / Rappel","description":"Human Form: Stuns the first enemy unit hit and reveals them if they are not stealthed.\\u003cbr\\u003e\\u003cbr\\u003eSpider Form: Elise and her Spiderlings ascend into the air and then descend upon target enemy. After descending on an enemy target, Elise\'s bonus damage and healing from Spider Queen is increased.","max_rank":5,"range_burn":[1075],"cooldown_burn":[12,11,11,10,10],"cost_burn":[50],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e: Elise fires a cocoon, \\u003cstatus\\u003eStunning\\u003c/status\\u003e and revealing the first enemy hit for 1.6/1.7/1.8/1.9/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EliseHumanE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0060/ability_0060_E1.webm"},{"key":"R","name":"Spider Form","description":"Transforms into a menacing spider, reducing her attack range in exchange for Move Speed, new abilities, and a Spiderling swarm that will attack her foes.","max_rank":4,"range_burn":[20],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e: Elise transforms into a menacing spider, becoming melee ranged, and gaining \\u003cspeed\\u003e25 Move Speed\\u003c/speed\\u003e and access to \\u003ckeywordMajor\\u003eSpider Form\\u003c/keywordMajor\\u003e Abilities. She also summons all dormant \\u003ckeywordMajor\\u003eSpiderlings\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EliseR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0060/ability_0060_R1.webm"}]},"61":{"id":61,"key":"Orianna","name":"Orianna","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Orianna.png","enemy_tips":["Orianna can only affect the area the Ball is around. Use this to your advantage.","Watch out for Orianna\'s Ball returning to her due to leashing. This may cause some unexpected situations."],"ally_tips":["Command: Protect can be used on yourself to return the Ball back to you quickly. Combine this with Command: Attack for a quick harassment.","Command: Dissonance is a very powerful escape tool if Orianna has the Ball. The combination of speed and leaving a slowing obstacle can be quite powerful.","Command: Shockwave can be used to drag enemies towards you or away from you if you position the Ball properly."],"passive":{"name":"Clockwork Windup","description":"Orianna\'s Attacks deal additional magic damage. This damage increases the more Orianna Attacks the same target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/OriannaPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0061/ability_0061_P1.webm"},"spells":[{"key":"Q","name":"Command: Attack","description":"Orianna commands her Ball to fire toward a target location, dealing magic damage to targets along the way (deals less damage to subsequent targets). Her Ball remains at the target location after.","max_rank":5,"range_burn":[815],"cooldown_burn":[6,5,4,3,3],"cost_burn":[30,35,40,45,50],"tooltip":"Orianna commands her \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e to move to an area, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding enemies and to enemies it passes through. Deals 10% less damage per enemy hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrianaIzunaCommand.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0061/ability_0061_Q1.webm"},{"key":"W","name":"Command: Dissonance","description":"Orianna commands her Ball to release a pulse of energy, dealing magic damage around it. This leaves a field behind that speeds up allies and slows enemies.","max_rank":5,"range_burn":[255],"cooldown_burn":[7],"cost_burn":[70,80,90,100,110],"tooltip":"Orianna commands her \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e to release an electric pulse, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding enemies.\\u003cbr /\\u003e\\u003cbr /\\u003eThe pulse leaves behind an energy field for ? seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies by ?% and granting allies \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e, decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrianaDissonanceCommand.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0061/ability_0061_W1.webm"},{"key":"E","name":"Command: Protect","description":"Orianna commands her Ball to attach to an allied champion, Shielding them and dealing magic damage to any enemies it passes through on the way. Additionally, the Ball grants additional Armor and Magic Resist to the champion it is attached to.","max_rank":5,"range_burn":[1095],"cooldown_burn":[9],"cost_burn":[60],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eThe \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e adds \\u003cscaleArmor\\u003e6/12/18/24/30 Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e6/12/18/24/30 Magic Resist\\u003c/scaleMR\\u003e to the allied champion it is attached to.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive: \\u003c/spellActive\\u003eOrianna commands her \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e to attach to an allied champion, granting them \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 2.5 seconds. Enemies the \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e passes through take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrianaRedactCommand.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0061/ability_0061_E1.webm"},{"key":"R","name":"Command: Shockwave","description":"Orianna commands her Ball to unleash a shockwave, dealing magic damage and launching nearby enemies towards the Ball after a short delay.","max_rank":3,"range_burn":[410],"cooldown_burn":[110,95,80],"cost_burn":[100],"tooltip":"Orianna commands her \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e to unleash a shockwave, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies and \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them in the direction of the \\u003ckeywordMajor\\u003eBall\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrianaDetonateCommand.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0061/ability_0061_R1.webm"}]},"62":{"id":62,"key":"MonkeyKing","name":"Wukong","image_url":"https://opgg-static.akamaized.net/images/lol/champion/MonkeyKing.png","enemy_tips":["Wukong will often use Decoy after Nimbus Strike. Try delaying your abilities by a short amount of time to ensure that you\'re hitting the real Wukong.","Wukong becomes tougher to kill when surrounded by his enemies. Try to isolate him to gain an advantage."],"ally_tips":["Decoy and Nimbus Strike work well together to quickly strike your enemy and get out before they can retaliate.","Try using Decoy near brush to make an enemy overreact to your movement."],"passive":{"name":"Stone Skin","description":"Wukong gains stacking armor and max health regeneration while fighting champions and monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/MonkeyKingStoneSkin.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0062/ability_0062_P1.webm"},"spells":[{"key":"Q","name":"Crushing Blow","description":"Wukong\'s next attack gains attack range, deals bonus damage, and reduces the target\'s armor for a few seconds.","max_rank":5,"range_burn":[250,275,300,325,350],"cooldown_burn":[8,7,7,6,6],"cost_burn":[40],"tooltip":"Wukong and his \\u003ckeywordMajor\\u003eClone\'s\\u003c/keywordMajor\\u003e next Attack gains ? range, deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, and removes \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability\'s cooldown is reduced by ? seconds every time Wukong or his \\u003ckeywordMajor\\u003eClone\\u003c/keywordMajor\\u003e hit an enemy with an Attack or Ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MonkeyKingDoubleAttack.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0062/ability_0062_Q1.webm"},{"key":"W","name":"Warrior Trickster","description":"Wukong becomes \\u003cfont color=\'#91d7ee\'\\u003eInvisible\\u003c/font\\u003e and dashes in a direction, leaving behind a clone that will attack nearby enemies.","max_rank":5,"range_burn":[275],"cooldown_burn":[22,19,17,14,12],"cost_burn":[80,70,60,50,40],"tooltip":"Wukong dashes and becomes \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e for ? second, leaving behind a stationary \\u003ckeywordMajor\\u003eClone\\u003c/keywordMajor\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThe \\u003ckeywordMajor\\u003eClone\\u003c/keywordMajor\\u003e Attacks nearby enemies Wukong has recently damaged and will mimic his ultimate, each dealing ?% of normal damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MonkeyKingDecoy.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0062/ability_0062_W1.webm"},{"key":"E","name":"Nimbus Strike","description":"Wukong dashes to a targeted enemy and sends out images to attack enemies near his target, dealing damage to each enemy struck.","max_rank":5,"range_burn":[650],"cooldown_burn":[10,9,9,8,8],"cost_burn":[30,35,40,45,50],"tooltip":"Wukong dashes to an enemy, sending out \\u003ckeywordMajor\\u003eClones\\u003c/keywordMajor\\u003e that mimic the dash to up to ? additional enemies nearby. Each enemy struck takes \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. He and his \\u003ckeywordMajor\\u003eClone\\u003c/keywordMajor\\u003e gain \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003e\\u003cspan class=\\"color8c8c8c\\"\\u003eDeals ? damage to monsters.\\u003c/span\\u003e\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MonkeyKingNimbus.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0062/ability_0062_E1.webm"},{"key":"R","name":"Cyclone","description":"Wukong\'s extends his staff and spins it around repeatedly, gaining Move Speed.\\u003cbr\\u003e\\u003cbr\\u003eEnemies struck take damage and are knocked up.","max_rank":3,"range_burn":[315],"cooldown_burn":[120,105,90],"cost_burn":[100],"tooltip":"Wukong gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e and spins his staff, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e nearby enemies for ? seconds and take \\u003cphysicalDamage\\u003e? plus ? max Health physical damage\\u003c/physicalDamage\\u003e over ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability can be cast a second time within ? seconds before going on cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MonkeyKingSpinToWin.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0062/ability_0062_R1.webm"}]},"63":{"id":63,"key":"Brand","name":"Brand","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Brand.png","enemy_tips":["Brand must land an ability before his combo is able to get started. Dodging his Sear or Pillar of Flame will disrupt his rhythm.","Try to move away from allies when you see Pyroclasm being cast. The initial missile speed is slow, which should give your team time to react.","Brand\'s passive allows him to excel against teams that cluster together. Be sure to split up against him."],"ally_tips":["You can deter enemies from standing near their minions by setting them ablaze, due to Conflagration.","You can use Brand\'s abilities in a variety of combinations to maximize his damage in different situations.","Pyroclasm bounces randomly between enemies, so try to cast it on a small group of enemies if you want to hit the same target multiple times."],"passive":{"name":"Blaze","description":"Brand\'s spells light his targets ablaze, dealing damage over 4 seconds, stacking up to 3 times. If Brand kills an enemy while it is ablaze he regains mana. When Blaze reaches max stacks on a Champion or large monster, it becomes unstable. It detonates in 2 seconds, applying spell effects and dealing massive damage in an area around the victim.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/BrandP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0063/ability_0063_P1.webm"},"spells":[{"key":"Q","name":"Sear","description":"Brand launches a ball of fire forward that deals magic damage. If the target is ablaze, Sear will stun the target for 1.5 seconds.","max_rank":5,"range_burn":[1050],"cooldown_burn":[8,7,7,6,6],"cost_burn":[50],"tooltip":"Brand launches a fireball that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the target is \\u003ckeywordMajor\\u003eAblaze\\u003c/keywordMajor\\u003e, they will be \\u003cstatus\\u003eStunned\\u003c/status\\u003e for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BrandQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0063/ability_0063_Q1.webm"},{"key":"W","name":"Pillar of Flame","description":"After a short delay, Brand creates a Pillar of Flame at a target area, dealing magic damage to enemy units within the area. Units that are ablaze take an additional 25% damage.","max_rank":5,"range_burn":[900],"cooldown_burn":[10,9,9,8,8],"cost_burn":[60,70,80,90,100],"tooltip":"Brand creates a pillar of pure fire, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eUnits that are \\u003ckeywordMajor\\u003eAblaze\\u003c/keywordMajor\\u003e take \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BrandW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0063/ability_0063_W1.webm"},{"key":"E","name":"Conflagration","description":"Brand conjures a powerful blast at his target that spreads to nearby enemies, dealing magic damage. If the target is ablaze, Conflagration\'s spread is doubled.","max_rank":5,"range_burn":[625],"cooldown_burn":[12,11,10,9,8],"cost_burn":[70,75,80,85,90],"tooltip":"Brand conjures a powerful blast at his target, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding units.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the target is \\u003ckeywordMajor\\u003eAblaze\\u003c/keywordMajor\\u003e, the spread range is doubled.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BrandE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0063/ability_0063_E1.webm"},{"key":"R","name":"Pyroclasm","description":"Brand unleashes a devastating torrent of fire that bounces up to 5 times off of Brand and nearby enemies, dealing magic damage to enemies each time bounce. Bounces prioritize stacking Blaze to max on Champions. If a target is ablaze, Pyroclasm will briefly slow them.","max_rank":3,"range_burn":[750],"cooldown_burn":[105,90,75],"cost_burn":[100],"tooltip":"Brand unleashes a devastating torrent of fire that can bounce to Brand or another enemy up to 5 times, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies each bounce. Bounces prioritize stacking \\u003ckeywordMajor\\u003eBlaze\\u003c/keywordMajor\\u003e to max on champions.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the target is \\u003ckeywordMajor\\u003eAblaze\\u003c/keywordMajor\\u003e, they are briefly \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BrandR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0063/ability_0063_R1.webm"}]},"64":{"id":64,"key":"LeeSin","name":"Lee Sin","image_url":"https://opgg-static.akamaized.net/images/lol/champion/LeeSin.png","enemy_tips":["Stay spread out to minimize the impact of Lee Sin\'s ultimate, Dragon\'s Rage.","Lee Sin has powerful tools to combat physical damage in Iron Will and Cripple but he is still vulnerable to magic damage.","Lee Sin relies heavily on following up with his abilities. Use disables to prevent him from chaining together his abilities and attacks."],"ally_tips":["Use Sonic Wave before Dragon\'s Rage so you can chase the target with Resonating Strike.","Take advantage of Flurry by weaving in basic attacks between spell casts - this maximizes damage output and minimizes Energy loss.","Self-casting Safeguard and using Iron Will are powerful tools for killing neutral monsters (in the jungle)."],"passive":{"name":"Flurry","description":"After Lee Sin uses an ability, his next 2 basic attacks gain Attack Speed and return Energy.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/LeeSinPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0064/ability_0064_P1.webm"},"spells":[{"key":"Q","name":"Sonic Wave / Resonating Strike","description":"Sonic Wave: Lee Sin projects a discordant wave of sound to locate his enemies, dealing physical damage to the first enemy it encounters. If Sonic Wave hits, Lee Sin can cast Resonating Strike for the next 3 seconds.\\u003cbr\\u003eResonating Strike: Lee Sin dashes to the enemy hit by Sonic Wave, dealing physical damage based on the target\'s missing Health.","max_rank":5,"range_burn":[1100],"cooldown_burn":[10,9,8,7,6],"cost_burn":[50],"tooltip":"Lee Sin projects a discordant wave of sound, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit, granting True Sight of them, and allows Lee Sin to \\u003crecast\\u003eRecast\\u003c/recast\\u003e for the next 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Lee Sin dashes to the enemy hit by the sound wave, dealing between \\u003cphysicalDamage\\u003e? to ? physical damage\\u003c/physicalDamage\\u003e scaling with the target\'s missing Health. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BlindMonkQOne.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0064/ability_0064_Q1.webm"},{"key":"W","name":"Safeguard / Iron Will","description":"Safeguard: Lee Sin rushes to target ally, shielding himself from damage. If the ally is a champion, they are also shielded. After using Safeguard, Lee Sin can cast Iron Will for the next 3 seconds.\\u003cbr\\u003eIron Will: Lee Sin\'s intense training allows him to thrive in battle. For 4 seconds, Lee Sin gains Life Steal and Spell Vamp.","max_rank":5,"range_burn":[700],"cooldown_burn":[12],"cost_burn":[50],"tooltip":"Lee Sin dashes to an ally or ward. If the target is a champion, Lee Sin grants them and himself \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 2 seconds and reduces this Ability\'s Cooldown by 50%. Lee Sin may \\u003crecast\\u003eRecast\\u003c/recast\\u003e for the next 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Lee Sin gains 5/9.5/14/18.5/23% Life Steal and Spell Vamp for 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BlindMonkWOne.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0064/ability_0064_W1.webm"},{"key":"E","name":"Tempest / Cripple","description":"Tempest: Lee Sin smashes the ground, sending out a shockwave that deals magic damage and reveals enemy units hit. If Tempest hits an enemy, Lee Sin can cast cripple for the next 3 seconds.\\u003cbr\\u003eCripple: Lee Sin cripples nearby enemies damaged by Tempest, reducing their Move Speed for 4 seconds. Move Speed recovers gradually over the duration.","max_rank":5,"range_burn":[425],"cooldown_burn":[9],"cost_burn":[50],"tooltip":"Lee Sin smashes the ground, sending out a shockwave that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and reveals them for 4 seconds. If this hits an enemy, Lee Sin can \\u003crecast\\u003eRecast\\u003c/recast\\u003e for the next 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Lee Sin \\u003cstatus\\u003eSlows\\u003c/status\\u003e nearby enemies struck by the shockwave by 20/30/40/50/60% decaying over 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BlindMonkEOne.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0064/ability_0064_E1.webm"},{"key":"R","name":"Dragon\'s Rage","description":"Lee Sin performs a powerful roundhouse kick launching his target back, dealing physical damage to the target and any enemies they collide with. Enemies the target collides with are knocked into the air for a short duration. This technique was taught to him by Jesse Perring, although Lee Sin does not kick players off the map.","max_rank":3,"range_burn":[375],"cooldown_burn":[110,85,60],"cost_burn":[0],"tooltip":"Lee Sin performs a powerful roundhouse kick \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e an enemy champion and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies the target collides with are briefly \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e and take \\u003cphysicalDamage\\u003e? plus ?% of the kicked enemy\'s bonus Health as physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BlindMonkRKick.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0064/ability_0064_R1.webm"}]},"67":{"id":67,"key":"Vayne","name":"Vayne","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Vayne.png","enemy_tips":["Vayne is fragile - turn the pressure up on her and she will be forced to play cautiously.","Deny Vayne the opportunity to pin you against walls."],"ally_tips":["Tumble has many uses, but it cannot pass over walls.","Condemn can be used to both pin targets to walls to ensure a kill, or to escape a pursuer.","Don\'t go in first to a large teamfight. Wait for your teammates to initiate."],"passive":{"name":"Night Hunter","description":"Vayne ruthlessly hunts evil-doers, gaining \\u003cspeed\\u003e30 Move Speed\\u003c/speed\\u003e when moving toward nearby enemy champions.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Vayne_NightHunter.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0067/ability_0067_P1.webm"},"spells":[{"key":"Q","name":"Tumble","description":"Vayne tumbles, maneuvering to carefully place her next shot. Her next attack deals bonus damage.","max_rank":5,"range_burn":[300],"cooldown_burn":[4,3,3,2,2],"cost_burn":[30],"tooltip":"Vayne rolls a short distance, and deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e on her next Attack.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VayneTumble.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0067/ability_0067_Q1.webm"},{"key":"W","name":"Silver Bolts","description":"Vayne tips her bolts with a rare metal, toxic to evil things. The third consecutive attack or ability against the same target deals a percentage of the target\'s max health as bonus true damage.","max_rank":5,"range_burn":[750],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive\\u003c/spellPassive\\u003e: Every third consecutive Attack or Ability against an enemy deals an additional \\u003ctrueDamage\\u003e?% max Health true damage\\u003c/trueDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VayneSilveredBolts.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0067/ability_0067_W1.webm"},{"key":"E","name":"Condemn","description":"Vayne draws a heavy crossbow from her back, and fires a huge bolt at her target, knocking them back and dealing damage. If they collide with terrain, they are impaled, dealing bonus damage and stunning them.","max_rank":5,"range_burn":[550],"cooldown_burn":[20,18,16,14,12],"cost_burn":[90],"tooltip":"Vayne fires a bolt that \\u003cstatus\\u003eKnocks Back\\u003c/status\\u003e and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If the target collides with terrain, they take \\u003cphysicalDamage\\u003e? bonus physical damage\\u003c/physicalDamage\\u003e and become \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VayneCondemn.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0067/ability_0067_E1.webm"},{"key":"R","name":"Final Hour","description":"Readying herself for an epic confrontation, Vayne gains increased Attack Damage, Invisibility during Tumble, reduced Tumble cooldown, and more bonus Move Speed from Night Hunter","max_rank":3,"range_burn":[1],"cooldown_burn":[100,85,70],"cost_burn":[80],"tooltip":"Vayne gains \\u003cphysicalDamage\\u003e? Attack Damage\\u003c/physicalDamage\\u003e for ? seconds, extended by ? seconds whenever a champion damaged by Vayne dies within ? seconds. Additionally, during the duration:\\u003cli\\u003e\\u003cspellName\\u003eNight Hunter\\u003c/spellName\\u003e instead grants \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e.\\u003cli\\u003eThe Cooldown of \\u003cspellName\\u003eTumble\\u003c/spellName\\u003e is reduced by ?%, and grants \\u003ckeywordStealth\\u003eInvisibility\\u003c/keywordStealth\\u003e for ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VayneInquisition.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0067/ability_0067_R1.webm"}]},"68":{"id":68,"key":"Rumble","name":"Rumble","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Rumble.png","enemy_tips":["Watch Rumble\'s Heat bar carefully. If you see him Overheat, go in for the kill while his skills are disabled.","Rumble\'s ultimate can deal a lot of damage if you stay inside the area of effect. When you see the missiles falling, move out of the way as quickly as possible.","Rumble deals almost entirely magic damage. Build some Magic Resistance to reduce his damage."],"ally_tips":["Try and pace yourself to stay in the Danger Zone to maximize your effectiveness. It is easy to overheat if you rapidly use your abilities.","Try and keep targets in the range of your Flamespitter. It can deal a lot of damage overtime.","If you are winning a fight you can use your ultimate to wall off an escape path."],"passive":{"name":"Junkyard Titan","description":"Every spell Rumble casts gives him Heat. When he reaches 50% Heat he reaches Danger Zone, granting all his basic abilities bonus effects. When he reaches 100% Heat, he starts Overheating, gaining bonus Attack Speed and granting his basic attacks bonus damage, but making him unable to cast spells for a few seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Rumble_JunkyardTitan1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0068/ability_0068_P1.webm"},"spells":[{"key":"Q","name":"Flamespitter","description":"Rumble torches opponents in front of him, dealing magic damage in a cone for 3 seconds. While in Danger Zone this damage is increased.","max_rank":5,"range_burn":[600],"cooldown_burn":[10,9,8,7,6],"cost_burn":[0],"tooltip":"Rumble ignites his flamethrower, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 3 seconds, reduced to \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e against minions.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDanger Zone:\\u003c/keywordMajor\\u003e Damage is increased to \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RumbleFlameThrower.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0068/ability_0068_Q1.webm"},{"key":"W","name":"Scrap Shield","description":"Rumble pulls up a shield, protecting him from damage and granting him a quick burst of speed. While in Danger Zone, the shield strength and speed bonus is increased.","max_rank":5,"range_burn":[20],"cooldown_burn":[6],"cost_burn":[0],"tooltip":"Rumble tosses up a barrier, gaining \\u003cshield\\u003e? Shield\\u003c/shield\\u003e and \\u003cspeed\\u003e10/15/20/25/30% Move Speed\\u003c/speed\\u003e for 1 second.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDanger Zone:\\u003c/keywordMajor\\u003e The barrier grants \\u003cshield\\u003e? Shield\\u003c/shield\\u003e and \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RumbleShield.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0068/ability_0068_W1.webm"},{"key":"E","name":"Electro Harpoon","description":"Rumble launches a harpoon, electrocuting his target with magic damage, slowing their Move Speed, and reducing their Magic Resist. Rumble can carry 2 harpoons at a time. While in Danger Zone the damage and slow percentage is increased.","max_rank":5,"range_burn":[850],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Rumble launches an electrified harpoon, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds, and reducing the enemy\'s Magic Resist by ?% for ? seconds. Hitting an enemy who\'s already \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by this Ability increases the \\u003cstatus\\u003eSlow\\u003c/status\\u003e to ?% and reduces the enemy\'s Magic Resist by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 2 charges (? second refresh).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDanger Zone:\\u003c/keywordMajor\\u003e The harpoon deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e instead and the \\u003cstatus\\u003eSlow\\u003c/status\\u003e and reduced Magic Resist are increased by 50%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RumbleGrenade.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0068/ability_0068_E1.webm"},{"key":"R","name":"The Equalizer","description":"Rumble fires off a group of rockets, creating a wall of flames that damages and slows enemies.","max_rank":3,"range_burn":[1750],"cooldown_burn":[100,85,70],"cost_burn":[0],"tooltip":"Rumble launches a line of rockets, creating a burning trail that \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eRumble can control the direction of the trail by clicking and dragging while casting this Ability.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RumbleCarpetBomb.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0068/ability_0068_R1.webm"}]},"69":{"id":69,"key":"Cassiopeia","name":"Cassiopeia","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Cassiopeia.png","enemy_tips":["Be wary of Cassiopeia\'s damage potential with Twin Fang when she has you poisoned.","Turn away from Cassiopeia when she is casting Petrifying Gaze to get slowed instead of stunned."],"ally_tips":["Use Twin Fang on poisoned stationary targets like monsters and units stunned by her Petrifying Gaze for maximum damage.","Lead your enemy when targeting with Noxious Blast to ensure the hit."],"passive":{"name":"Serpentine Grace","description":"Cassiopeia gains Move Speed per level, but she cannot purchase Boots items.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Cassiopeia_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0069/ability_0069_P1.webm"},"spells":[{"key":"Q","name":"Noxious Blast","description":"Cassiopeia blasts an area with Poison after a brief delay, granting her increased Move Speed if she hits an enemy champion.","max_rank":5,"range_burn":[850],"cooldown_burn":[3],"cost_burn":[50,60,70,80,90],"tooltip":"Cassiopeia blasts noxious gas, \\u003ckeywordMajor\\u003ePoisoning\\u003c/keywordMajor\\u003e enemies and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 3 seconds. Hitting a champion grants Cassiopeia \\u003cspeed\\u003e30/35/40/45/50% Move Speed\\u003c/speed\\u003e decaying over 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CassiopeiaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0069/ability_0069_Q1.webm"},{"key":"W","name":"Miasma","description":"Cassiopeia releases several clouds of poison, slowing, grounding, and lightly damaging enemies that pass through them. Grounded enemies cannot use Movement abilities.","max_rank":5,"range_burn":[700],"cooldown_burn":[24,22,20,18,16],"cost_burn":[70,80,90,100,110],"tooltip":"Cassiopeia spews venom, leaving toxic clouds for 5 seconds. Enemies in the clouds take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second, are \\u003ckeywordMajor\\u003ePoisoned\\u003c/keywordMajor\\u003e, \\u003cstatus\\u003eGrounded\\u003c/status\\u003e, and \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 40/50/60/70/80%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CassiopeiaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0069/ability_0069_W1.webm"},{"key":"E","name":"Twin Fang","description":"Cassiopeia lets loose an attack that deals increased damage to Poisoned targets and heals her for a percentage of the damage dealt. If the target dies from this attack, Cassiopeia regains Mana.","max_rank":5,"range_burn":[700],"cooldown_burn":[0],"cost_burn":[50,48,46,44,42],"tooltip":"Cassiopeia launches deadly fangs, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. If the enemy is \\u003ckeywordMajor\\u003ePoisoned\\u003c/keywordMajor\\u003e, they take an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and Cassiopeia restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this kills the target, Cassiopeia restores \\u003cscaleMana\\u003e50/48/46/44/42 Mana\\u003c/scaleMana\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CassiopeiaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0069/ability_0069_E1.webm"},{"key":"R","name":"Petrifying Gaze","description":"Cassiopeia releases a swirl of magical energy from her eyes, stunning any enemies in front of her that are facing her and slowing any others with their back turned.","max_rank":3,"range_burn":[825],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Cassiopeia unleashes a petrifying gaze, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e enemies facing her for ? seconds. Enemies facing away are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% decaying over the same duration instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CassiopeiaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0069/ability_0069_R1.webm"}]},"72":{"id":72,"key":"Skarner","name":"Skarner","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Skarner.png","enemy_tips":["Skarner can\'t harm you very much outside of short range, so stay away from him!","Skarner\'s Move Speed is increased as long as his shield, Crystalline Exoskeleton, persists. Attack him to lower his speed.","Skarner is especially dangerous when inside Crystal Spire zones his team controls. Try to capture them ahead of time if a fight may break out around them."],"ally_tips":["Basic attacks reduce the cooldown of Crystal Slash. Use them as often as possible for maximum damage.","Capturing Crystal Spires before attempting neutral objectives or team fights around them improves Skarner\'s performance in said fights dramatically.","Impale is extremely powerful when you use it to position an enemy so your allies can attack them."],"passive":{"name":"Crystal Spires","description":"Skarner\'s presence causes crystals to spawn in set locations around the map. Crystals can be captured by either team by standing close to them. When near crystals his team owns, Skarner gains Move Speed, attack speed, and increased mana regeneration.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Skarner_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0072/ability_0072_P1.webm"},"spells":[{"key":"Q","name":"Crystal Slash","description":"Skarner lashes out with his claws, dealing physical damage to all nearby enemies and charging himself with Crystal Energy for several seconds if a unit is struck. If he casts Crystal Slash again while powered by Crystal Energy, he deals bonus magic damage.","max_rank":5,"range_burn":[350],"cooldown_burn":[3,3,3,2,2],"cost_burn":[10],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Attacks against champions reduce this Ability\'s Cooldown by ? second(s). Attacks against minions reduce it by ? second(s).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Skarner slashes wildly, dealing \\u003cphysicalDamage\\u003e? plus ?% max Health physical damage\\u003c/physicalDamage\\u003e to nearby enemies. If at least one enemy was hit, Skarner becomes charged for 5 seconds. While charged, this Ability deals an additional \\u003cmagicDamage\\u003e? plus ?% max Health magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SkarnerVirulentSlash.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0072/ability_0072_Q1.webm"},{"key":"W","name":"Crystalline Exoskeleton","description":"Skarner gains a shield and has increased Move Speed while the shield persists.","max_rank":5,"range_burn":[1],"cooldown_burn":[13,12,12,11,11],"cost_burn":[60],"tooltip":"Skarner gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 6 seconds. While active, Skarner gains \\u003cspeed\\u003e8/10/12/14/16% Move Speed\\u003c/speed\\u003e, increasing up to \\u003cspeed\\u003e16/20/24/28/32% Move Speed\\u003c/speed\\u003e over 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SkarnerExoskeleton.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0072/ability_0072_W1.webm"},{"key":"E","name":"Fracture","description":"Skarner summons a blast of crystalline energy which deals damage to enemies struck and slows them. Basic attacking these enemies within a short window will stun them.","max_rank":5,"range_burn":[980],"cooldown_burn":[14,13,13,12,12],"cost_burn":[55],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Consuming this Ability\'s mark or using \\u003cspellName\\u003eImpale\\u003c/spellName\\u003e reduces this Abilty\'s Cooldown by the duration of the crowd control.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Skarner blasts crystalline energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 30/35/40/45/50% for 2.5 seconds, and marking for 5 seconds. Skarner\'s next Attack against a marked enemy consumes it to deal an additional \\u003cphysicalDamage\\u003e30/50/70/90/110 physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eStun\\u003c/status\\u003e for 1.25 second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SkarnerFracture.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0072/ability_0072_E1.webm"},{"key":"R","name":"Impale","description":"Skarner suppresses an enemy champion and deals damage to it. During this time, Skarner can move freely and will drag his helpless victim around with him. When the effect ends, the target will be dealt additional damage.","max_rank":3,"range_burn":[350],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Skarner impales an enemy champion, \\u003cstatus\\u003eSuppressing\\u003c/status\\u003e them for ? seconds, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e at the beginning and end of the duration. While \\u003cstatus\\u003eSuppressing\\u003c/status\\u003e, Skarner can move and will drag his helpless victim around with him.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SkarnerImpale.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0072/ability_0072_R1.webm"}]},"74":{"id":74,"key":"Heimerdinger","name":"Heimerdinger","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Heimerdinger.png","enemy_tips":["It\'s better to destroy all of Heimerdinger\'s turrets at once with the help of creeps than to fight them one at a time.","Be wary of Heimerdinger\'s Upgrade!!!, as he can use it to find an answer to most trouble he gets into. Once his ultimate is down, go in for the kill!"],"ally_tips":["Turret placement can be a deciding factor in a battle. Against most enemies turrets are best when they can support each other, but if the enemy has a lot of area of effect damage your turrets can be destroyed quickly. Placing turrets in brush can lead to a surprise attack in your favor.","The success of Electron Storm Grenade is very important to Heimerdinger\'s survival. The slow and stun both are capable of keeping enemies in place long enough to punish them, but it is also the first line of defense against a surprise attack.","Spreading out Hextech Micro-Rockets leads to more reliable damage and more efficiency against multiple targets, but focusing it creates the biggest impact."],"passive":{"name":"Hextech Affinity","description":"Gain Move Speed while near allied towers and turrets deployed by Heimerdinger.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Heimerdinger_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0074/ability_0074_P1.webm"},"spells":[{"key":"Q","name":"H-28 G Evolution Turret","description":"Heimerdinger lays down a rapid-fire cannon turret equipped with a secondary pass-through beam attack (turrets deal half damage to towers).","max_rank":5,"range_burn":[350],"cooldown_burn":[1],"cost_burn":[20],"tooltip":"Heimerdinger constructs a \\u003ckeywordMajor\\u003eTurret\\u003c/keywordMajor\\u003e that attacks nearby enemies. Heimerdinger can have ? turrets active at once. \\u003ckeywordMajor\\u003eTurrets\\u003c/keywordMajor\\u003e slowly build up charge. At max charge, they fire a stronger attack.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Heimerdinger gets too far away, his \\u003ckeywordMajor\\u003eTurrets\\u003c/keywordMajor\\u003e will deactivate after 8 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has ? charges.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HeimerdingerQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0074/ability_0074_Q1.webm"},{"key":"W","name":"Hextech Micro-Rockets","description":"Heimerdinger fires long-range rockets that converge on his cursor.","max_rank":5,"range_burn":[1325],"cooldown_burn":[11,10,9,8,7],"cost_burn":[50,60,70,80,90],"tooltip":"Heimerdinger unleashes a barrage of ? rockets that deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit. Additional rocket hits deal reduced damage.\\u003cbr /\\u003e\\u003cbr /\\u003eMax Damage: \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eNearby \\u003ckeywordMajor\\u003eTurrets\\u003c/keywordMajor\\u003e gain 20% charge per rocket that hits a champion.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HeimerdingerW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0074/ability_0074_W1.webm"},{"key":"E","name":"CH-2 Electron Storm Grenade","description":"Heimerdinger lobs a grenade at a location, dealing damage to enemy units, as well as stunning anyone directly hit and slowing surrounding units.","max_rank":5,"range_burn":[970],"cooldown_burn":[11],"cost_burn":[85],"tooltip":"Heimerdinger hurls a grenade that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e in an area and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds. Enemies in the center are also \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eHitting a champion fully charges nearby \\u003ckeywordMajor\\u003eTurrets\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HeimerdingerE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0074/ability_0074_E1.webm"},{"key":"R","name":"UPGRADE!!!","description":"Heimerdinger invents an upgrade, causing his next spell to have increased effects. ","max_rank":3,"range_burn":[1],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Heimerdinger upgrades his next non-ultimate Ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eH-28Q Apex Turret:\\u003c/spellName\\u003e Place an upgraded \\u003ckeywordMajor\\u003eTurret\\u003c/keywordMajor\\u003e for 8 seconds that doesn\'t count towards Heimerdinger\'s max turrets, deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per shot and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per charged shot. Its attacks deal damage in an area, \\u003cstatus\\u003eSlow\\u003c/status\\u003e by 25% for 2 seconds, and it is immune to crowd control.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eHextech Rocket Swarm:\\u003c/spellName\\u003e Fires 4 waves of rockets that each deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Champions and jungle monsters hit by additional rockets take reduced damage, and minions take increased damage. Max Damage: \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellName\\u003eCH-3X Lightning Grenade:\\u003c/spellName\\u003e Throws a bouncing grenade that discharges three times, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The \\u003cstatus\\u003eStun\\u003c/status\\u003e and \\u003cstatus\\u003eSlow\\u003c/status\\u003e areas are larger.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Cancel this Ability.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HeimerdingerR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0074/ability_0074_R1.webm"}]},"75":{"id":75,"key":"Nasus","name":"Nasus","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nasus.png","enemy_tips":["While transformed by his ultimate, Nasus is stronger than most champions in the League. Engage him only if you have a clear advantage.","Max rank Wither is a very effective counter to Attack Damage characters, so try to avoid getting caught alone by it.","Nasus is prone to being kited. Try not to engage him at full Health."],"ally_tips":["Paying attention to last hitting with Siphoning Strike will have a large impact at the end of a game.","If you\'re solo, Spirit Fire is a great way to farm a lane. It can be bad if you\'re in a lane with 2 and you push too far. Find the right balance between Siphoning Strike last hits and AoE farming.","If you have low defenses, people will focus you down even during your ultimate. Try buying some survivability items even in your DPS builds."],"passive":{"name":"Soul Eater","description":"Nasus drains his foe\'s spiritual energy, giving him bonus Life Steal.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Nasus_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0075/ability_0075_P1.webm"},"spells":[{"key":"Q","name":"Siphoning Strike","description":"Nasus strikes his foe, dealing damage and increasing the power of his future Siphoning Strikes if he slays his target.","max_rank":5,"range_burn":[300],"cooldown_burn":[7,6,5,4,3],"cost_burn":[20],"tooltip":"Nasus\' next Attack deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Killing an enemy with this Attack permanently increases its damage by 3, increased to 12 against champions, large minions and large jungle monsters.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NasusQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0075/ability_0075_Q1.webm"},{"key":"W","name":"Wither","description":"Nasus ages an enemy champion, decelerating their Move Speed and Attack Speed over time.","max_rank":5,"range_burn":[700],"cooldown_burn":[15,14,13,12,11],"cost_burn":[80],"tooltip":"Nasus ages a champion, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 35%, increasing to 47/59/71/83/95% over 5 seconds. Their Attack Speed is also reduced by 50% of the \\u003cstatus\\u003eSlow\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NasusW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0075/ability_0075_W1.webm"},{"key":"E","name":"Spirit Fire","description":"Nasus unleashes a spirit flame at a location, dealing damage and reducing the Armor of enemies who stand on it.","max_rank":5,"range_burn":[650],"cooldown_burn":[12],"cost_burn":[70,85,100,115,130],"tooltip":"Nasus ignites a spirit flame, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Enemies in the area lose \\u003cscaleArmor\\u003e25/30/35/40/45% Armor\\u003c/scaleArmor\\u003e and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NasusE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0075/ability_0075_E1.webm"},{"key":"R","name":"Fury of the Sands","description":"Nasus unleashes a mighty sandstorm that batters nearby enemies. While the storm rages, he gains increased Health, Attack Range, damages nearby enemies, has a reduced cooldown on Siphoning Strike, and gains bonus Armor and Magic Resistance.","max_rank":3,"range_burn":[20],"cooldown_burn":[120],"cost_burn":[100],"tooltip":"Nasus becomes empowered in the sandstorm for 15 seconds, increasing his \\u003chealing\\u003emaximum Health by ?\\u003c/healing\\u003e and \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resistance\\u003c/scaleMR\\u003e by ?.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile the storm rages, nearby enemies take \\u003cmagicDamage\\u003e? of their maximum Health as magic damage\\u003c/magicDamage\\u003e each second and \\u003cspellName\\u003eSiphoning Strike\\u003c/spellName\\u003e has a ?% reduced Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NasusR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0075/ability_0075_R1.webm"}]},"76":{"id":76,"key":"Nidalee","name":"Nidalee","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nidalee.png","enemy_tips":["Nidalee\'s Hunt debuff is only applied with Javelin Toss and Bushwhack. Avoiding being hit by these abilities will impair her ability to deal follow-up damage.","Nidalee\'s Javelin Toss deals more damage the farther she is. If she is far away, it\'s imperative to dodge it.","Nidalee\'s Takedown deals extreme damage to Hunted targets, but she has to get close to use it. Save your crowd control or defensive abilities for when she goes in for the kill."],"ally_tips":["Use brush to your advantage! Moving in and out of brush can heavily alter your effectiveness in battle.","Start team fights by harassing with your Javelin Toss, and then switch to cougar form to chase down Hunted targets.","Bushwhack traps deal damage based on their victim\'s current Health. Set them up in your team\'s backline before fights break out during sieges to help your team deal damage to the enemy frontline."],"passive":{"name":"Prowl","description":"Moving through brush increases Nidalee\'s Move Speed by 10% for 2 seconds, increased to 30% toward visible enemy champions within 1400 range.\\u003cbr\\u003e\\u003cbr\\u003eHitting champions or monsters with Javelin Toss or Bushwhack triggers a \\u003cfont color=\'#FFF673\'\\u003eHunt\\u003c/font\\u003e, granting \\u003cfont color=\'#ee91d7\'\\u003eTrue Sight\\u003c/font\\u003e of them for 4 seconds. During this time, Nidalee gains 10% Move Speed (increased to 30% toward the \\u003cfont color=\'#FFF673\'\\u003eHunted\\u003c/font\\u003e target) and her Takedown and Pounce are enhanced against them.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Nidalee_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0076/ability_0076_P1.webm"},"spells":[{"key":"Q","name":"Javelin Toss / Takedown","description":"In human form, Nidalee throws a spiked javelin at her target that gains damage as it flies.  As a cougar, her next attack will attempt to fatally wound her target, dealing more damage the less life they have.","max_rank":5,"range_burn":[1500],"cooldown_burn":[6],"cost_burn":[50,55,60,65,70],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form:\\u003c/keywordMajor\\u003e Nidalee throws her javelin, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, increased up to \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e based on distance flown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JavelinToss.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0076/ability_0076_Q1.webm"},{"key":"W","name":"Bushwhack / Pounce","description":"In human form, Nidalee lays a trap for unwary opponents that, when sprung, damages and reveals its target. As a cougar, she jumps in a direction, dealing damage in an area where she lands.","max_rank":5,"range_burn":[900],"cooldown_burn":[13,12,11,10,9],"cost_burn":[30,35,40,45,50],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form:\\u003c/keywordMajor\\u003e Nidalee places an invisible trap for 2 minutes. When an enemy walks over it, they are dealt \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second for 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e? traps may be active at once.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/Bushwhack.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0076/ability_0076_W1.webm"},{"key":"E","name":"Primal Surge / Swipe","description":"In human form, Nidalee channels the spirit of the cougar to heal her allies and imbue them with Attack Speed for a short duration. As a cougar, she claws in a direction, dealing damage to enemies in front of her.","max_rank":5,"range_burn":[900],"cooldown_burn":[12],"cost_burn":[50,55,60,65,70],"tooltip":"\\u003ckeywordMajor\\u003eHuman Form:\\u003c/keywordMajor\\u003e Nidalee restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e increased up to \\u003chealing\\u003e?\\u003c/healing\\u003e based on missing Health and grants them \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PrimalSurge.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0076/ability_0076_E1.webm"},{"key":"R","name":"Aspect Of The Cougar","description":"Nidalee transforms into a cougar, gaining new abilities.","max_rank":4,"range_burn":[20],"cooldown_burn":[3],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While in \\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e, applying \\u003ckeywordMajor\\u003eHunted\\u003c/keywordMajor\\u003e refreshes this Ability\'s Cooldown.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eHuman Form:\\u003c/keywordMajor\\u003e Nidalee transforms into \\u003ckeywordMajor\\u003eCougar Form\\u003c/keywordMajor\\u003e, gaining melee Attacks and replacing her Active Abilities.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eCougar Form:\\u003c/keywordMajor\\u003e Nidalee transforms into \\u003ckeywordMajor\\u003eHuman Form\\u003c/keywordMajor\\u003e, gaining ranged Attacks and replacing her Active Abilities.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AspectOfTheCougar.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0076/ability_0076_R1.webm"}]},"77":{"id":77,"key":"Udyr","name":"Udyr","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Udyr.png","enemy_tips":["Udyr players will often start in the jungle and only appear to gank in lanes. Try warding key locations to keep track of his movement.","Once the initial shield effect has faded, Turtle Stance is weak against other champions. Press the attack to force him to switch stances and prevent him from regenerating health.","Some Udyr players buy tank items to become very durable. If they do, focus their weaker teammates instead."],"ally_tips":["Damage is applied to turtle shield post-mitigation. Therefore, buying defensive items can drastically increase your survivability.","Udyr is one of the best junglers in the game. Taking advantage of this can give your team a large XP advantage and map control."],"passive":{"name":"Monkey\'s Agility","description":"Udyr gains stacking Move Speed and Attack Speed after using an Ability. Udyr has four basic Abilities that he may use to swap between Stances. Changing Stances immediately ends both the passive and the on-hit portion of the previous Stance.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Udyr_MonkeysAgility.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0077/ability_0077_P1.webm"},"spells":[{"key":"Q","name":"Tiger Stance","description":"Tiger Stance: Activation - Udyr\'s Attack Speed is increased for a few seconds. Persistent Effect - Udyr\'s first attack and every third attack after will deal a high amount of damage over 2 seconds.","max_rank":6,"range_burn":[600],"cooldown_burn":[6],"cost_burn":[45],"tooltip":"\\u003ckeywordMajor\\u003eStance:\\u003c/keywordMajor\\u003e Udyr\'s next Attack and every third Attack after is a Tiger Strike, dealing an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e over 2 seconds. Subsequent Tiger Strikes on that target refresh this effect and deal any remaining damage instantly.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Udyr gains \\u003cattackSpeed\\u003e30/40/50/60/70/80% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UdyrTigerStance.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0077/ability_0077_Q1.webm"},{"key":"W","name":"Turtle Stance","description":"Turtle Stance: Activation - Udyr gains a temporary shield that absorbs damage. Persistent Effect - Udyr\'s first attack and every third attack after heals him for 2.5% of his maximum health.","max_rank":6,"range_burn":[600],"cooldown_burn":[6],"cost_burn":[45],"tooltip":"\\u003ckeywordMajor\\u003eStance:\\u003c/keywordMajor\\u003e Udyr\'s first Attack and every third Attack after restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e, increased up to \\u003chealing\\u003e?\\u003c/healing\\u003e based on Udyr\'s missing health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive:\\u003c/spellPassive\\u003e Udyr gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UdyrTurtleStance.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0077/ability_0077_W1.webm"},{"key":"E","name":"Bear Stance","description":"Bear Stance: Activation - Udyr increases Move Speed for a short duration. Persistent Effect - Udyr\'s basic attacks stun his target for 1 second. This effect cannot occur on the same target for several seconds.","max_rank":6,"range_burn":[600],"cooldown_burn":[6],"cost_burn":[45],"tooltip":"\\u003ckeywordMajor\\u003eStance:\\u003c/keywordMajor\\u003e Udyr\'s Attacks \\u003cstatus\\u003eStun\\u003c/status\\u003e for 1 second. This effect cannot occur on the same target again for 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Udyr gains \\u003cspeed\\u003e15/20/25/30/35/40% Move Speed\\u003c/speed\\u003e and ignores unit collision for 2/2.25/2.5/2.75/3/3.25 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UdyrBearStance.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0077/ability_0077_E1.webm"},{"key":"R","name":"Phoenix Stance","description":"Phoenix Stance: Activation - Udyr unleashes pulsing waves of fire, dealing damage to nearby enemies. Persistent Effect - Udyr\'s first attack and every third attack after engulfs enemies in front of him with flames.","max_rank":6,"range_burn":[325],"cooldown_burn":[6],"cost_burn":[45],"tooltip":"\\u003ckeywordMajor\\u003eStance:\\u003c/keywordMajor\\u003e Udyr\'s first Attack and every third Attack after unleashes a blast of fire towards his target, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Udyr unleashes pulsing waves of fire, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/UdyrPhoenixStance.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0077/ability_0077_R1.webm"}]},"78":{"id":78,"key":"Poppy","name":"Poppy","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Poppy.png","enemy_tips":["Poppy can stop nearby enemies from dashing with Steadfast Presence.","When Poppy starts to spin her hammer, she is charging Keeper\'s Verdict.","You can step on Poppy\'s shield to deny it from her."],"ally_tips":["Iron Ambassador tends to land near walls, try to take advantage of this with Heroic Charge.","Keeper\'s Verdict can be released immediately to send the enemy straight up, take advantage of this in duels."],"passive":{"name":"Iron Ambassador","description":"Poppy throws her buckler that bounces off the target. Poppy can pick it up to gain a temporary shield.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Poppy_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0078/ability_0078_P1.webm"},"spells":[{"key":"Q","name":"Hammer Shock","description":"Poppy swings her hammer, dealing damage and creating a zone that will slow enemies and explode after a delay.","max_rank":5,"range_burn":[430],"cooldown_burn":[8,7,6,5,4],"cost_burn":[35,40,45,50,55],"tooltip":"Poppy smashes the ground, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e8% max Health physical damage\\u003c/physicalDamage\\u003e and making the ground unstable. \\u003cbr /\\u003e\\u003cbr /\\u003eThe unstable area \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies by 20/25/30/35/40% and erupts after 1 second, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e8% max Health physical damage\\u003c/physicalDamage\\u003e again.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PoppyQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0078/ability_0078_Q1.webm"},{"key":"W","name":"Steadfast Presence","description":"Poppy passively gains Armor and Magic Resist. This bonus increases when she is low on Health. Poppy can activate Steadfast Presence to gain Move Speed and stop enemy dashes around her. If a dash is stopped, the enemy is slowed and grounded.","max_rank":5,"range_burn":[400],"cooldown_burn":[20,18,16,14,12],"cost_burn":[50],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Poppy gains \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e. This bonus is doubled if Poppy is below ?% Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Poppy gains \\u003cspeed\\u003e40% Move Speed\\u003c/speed\\u003e and projects a field around her for 2 seconds that stops enemy dashes. Enemies who are stopped by the field are \\u003cstatus\\u003eGrounded\\u003c/status\\u003e and \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for ? seconds and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PoppyW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0078/ability_0078_W1.webm"},{"key":"E","name":"Heroic Charge","description":"Poppy dashes to the target and pushes it back. If the target is pushed into a wall, it is stunned.","max_rank":5,"range_burn":[475],"cooldown_burn":[14,13,12,11,10],"cost_burn":[70],"tooltip":"Poppy tackles an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and carrying them forward. If Poppy tackles them into terrain, the enemy is \\u003cstatus\\u003eStunned\\u003c/status\\u003e for 1.6/1.7/1.8/1.9/2 seconds and take an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PoppyE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0078/ability_0078_E1.webm"},{"key":"R","name":"Keeper\'s Verdict","description":"Poppy channels a hammer strike that knocks enemies very far away.","max_rank":3,"range_burn":[500],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"\\u003ccharge\\u003eBegin Casting:\\u003c/charge\\u003e Poppy begins charging her hammer for up to ? seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e herself by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Poppy smashes the ground, creating a shockwave that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first champion hit and surrounding enemies, \\u003cstatus\\u003eKnocks\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e towards their Nexus, and makes them Untargetable while they fly. The range and \\u003cstatus\\u003eKnock Back\\u003c/status\\u003e distance increase with charge duration.\\u003cbr /\\u003e\\u003cbr /\\u003eAn uncharged swing deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PoppyR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0078/ability_0078_R1.webm"}]},"79":{"id":79,"key":"Gragas","name":"Gragas","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Gragas.png","enemy_tips":["Gragas can knock everybody away with his ultimate. Be careful that you don\'t get knocked into him or, worse, an enemy tower.","Body Slam is on a very low cooldown, making it difficult to pursue Gragas. Don\'t overextend yourself chasing him."],"ally_tips":["The damage reduction from Drunken Rage is applied when you start drinking, try to use it when you see damage coming your way.","Try to knock enemies back into your towers with Explosive Cask.","Try to combo Body Slam with Explosive Cask to set up kills for your team."],"passive":{"name":"Happy Hour","description":"Gragas periodically heals upon using a skill.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/GragasPassiveHeal.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0079/ability_0079_P1.webm"},"spells":[{"key":"Q","name":"Barrel Roll","description":"Gragas rolls his cask to a location, which can be activated to explode or will explode on its own after 4 seconds. The potency of the explosion increases over time. Enemies struck by the blast have their Move Speed slowed.","max_rank":5,"range_burn":[850],"cooldown_burn":[10,9,8,7,6],"cost_burn":[80],"tooltip":"Gragas rolls a cask that explodes after 4 seconds, dealing between \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e for between 40/45/50/55/60 and {{ effect2amount*1.5 }}% for 2 seconds. The damage and \\u003cstatus\\u003eSlow\\u003c/status\\u003e increase with time the cask spent before exploding. \\u003cbr /\\u003e\\u003cbr /\\u003eGragas can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to detonate the cask early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GragasQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0079/ability_0079_Q1.webm"},{"key":"W","name":"Drunken Rage","description":"Gragas guzzles down brew from his cask for 1 second. After finishing, he becomes drunkenly empowered, dealing magic damage to all nearby enemies on his next basic attack and reducing damage received.","max_rank":5,"range_burn":[20],"cooldown_burn":[5],"cost_burn":[30],"tooltip":"Gragas guzzles his brew, reducing incoming damage by ? for 2.5 seconds. After finishing his drink, his next Attack deals an additional \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e7% max Health magic damage\\u003c/magicDamage\\u003e to the target and surrounding enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GragasW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0079/ability_0079_W1.webm"},{"key":"E","name":"Body Slam","description":"Gragas charges to a location and collides with the first enemy unit he comes across, dealing damage to all nearby enemy units and stunning them.","max_rank":5,"range_burn":[600],"cooldown_burn":[14,13,13,12,12],"cost_burn":[50],"tooltip":"Gragas charges forward, colliding with the first enemy, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e nearby enemies for 1 second and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to them.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability\'s Cooldown is reduced by ? seconds if Gragas collides with an enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GragasE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0079/ability_0079_E1.webm"},{"key":"R","name":"Explosive Cask","description":"Gragas hurls his cask to a location, dealing damage and knocking back enemies caught in the blast radius.","max_rank":3,"range_burn":[1000],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Gragas hurls his cask, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eKnocking Away\\u003c/status\\u003e enemies from the impact zone.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GragasR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0079/ability_0079_R1.webm"}]},"80":{"id":80,"key":"Pantheon","name":"Pantheon","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Pantheon.png","enemy_tips":["Pantheon\'s Aegis Assault makes him invulnerable from the front. Get behind him or wait it out.","Be careful near Pantheon if your health is low - a thrown Comet Spear executes low health enemies.","Grand Starfall gives several seconds of warning before Pantheon arrives. Use this time to get out of the way or to form a plan to deal with him."],"ally_tips":["Mortal Will activates after 5 spells or basic attacks - plan your way through fights to allow you to activate it more than once.","Whittle the enemy down with Comet Spears before you jump in.","If an enemy is going to get out of range of your Aegis Assault, you can recast the spell to immediately fire the shield slam."],"passive":{"name":"Mortal Will","description":"Every few spells or attacks, Pantheon\'s next spell is empowered.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Pantheon_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0080/ability_0080_P1.webm"},"spells":[{"key":"Q","name":"Comet Spear","description":"Pantheon either thrusts his spear or throws his spear in the chosen direction.","max_rank":5,"range_burn":[575],"cooldown_burn":[13,11,10,9,8],"cost_burn":[30],"tooltip":"\\u003cspan class=\\"colorFF8C00\\"\\u003eTap:\\u003c/span\\u003e Pantheon thrusts his spear, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies hit. Refunds ?% of this Ability\'s Cooldown.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspan class=\\"colorFF8C00\\"\\u003eHold:\\u003c/span\\u003e Pantheon hurls his spear, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit and ?% less to further targets. \\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability critically strikes enemies below ?% health for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e instead.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspan class=\\"colorEDDA74\\"\\u003eMortal Will Bonus:\\u003c/span\\u003e Deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PantheonQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0080/ability_0080_Q1.webm"},{"key":"W","name":"Shield Vault","description":"Pantheon dashes to a target, damaging and stunning them.","max_rank":5,"range_burn":[600],"cooldown_burn":[13,12,11,10,9],"cost_burn":[55],"tooltip":"Pantheon leaps on his target, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for ? second and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMortal Will Bonus:\\u003c/keywordMajor\\u003e Pantheon\'s next Attack strikes ? times, dealing a total of \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PantheonW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0080/ability_0080_W1.webm"},{"key":"E","name":"Aegis Assault","description":"Pantheon sets his shield, becoming invulnerable to damage from the front and striking repeatedly with his spear.","max_rank":5,"range_burn":[400],"cooldown_burn":[22,20,19,17,16],"cost_burn":[80],"tooltip":"Pantheon braces his shield and engages enemies in a chosen direction for ? seconds, becoming immune to non-tower damage from that direction and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e over the duration. After channeling Pantheon slams with his shield, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspan class=\\"colorEDDA74\\"\\u003eMortal Will Bonus:\\u003c/span\\u003e When Pantheon slams his shield he gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? seconds. \\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PantheonE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0080/ability_0080_E1.webm"},{"key":"R","name":"Grand Starfall","description":"Pantheon composes himself and then leaps into the air, landing at a chosen location as a comet.","max_rank":3,"range_burn":[5500],"cooldown_burn":[180,165,150],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Pantheon gains ?% Armor Penetration.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Pantheon gathers his strength to leap high into the air. He throws his spear from above which in a small area deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003ePantheon then crashes down as a meteor at the target area. Deals up to \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies in a line (decreased by up to ?% at the edges of the area).\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability instantly readies \\u003cspan class=\\"colorEDDA74\\"\\u003eMortal Will\\u003c/span\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PantheonR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0080/ability_0080_R1.webm"}]},"81":{"id":81,"key":"Ezreal","name":"Ezreal","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ezreal.png","enemy_tips":["Ezreal is a very fragile champion so take the fight to him.","Ezreal is completely skill shot based, so make sure to keep minions in between you.","Mystic Shot applies on-hit effects including the Crest of Cinders."],"ally_tips":["Use Arcane Shift to help line up your other skill shots.","You can play Ezreal either as a Attack Damage carry or Ability Power carry depending on how you build him.","You can line up Trueshot Barrage to hit multiple minion waves or even Monsters."],"passive":{"name":"Rising Spell Force","description":"Ezreal gains increasing Attack Speed each time he successfully hits a spell, stacking up to 5 times.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Ezreal_RisingSpellForce.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0081/ability_0081_P1.webm"},"spells":[{"key":"Q","name":"Mystic Shot","description":"Ezreal fires a damaging bolt of energy which reduces all of his cooldowns slightly if it strikes an enemy unit.","max_rank":5,"range_burn":[1150],"cooldown_burn":[5,5,5,4,4],"cost_burn":[28,31,34,37,40],"tooltip":"Ezreal fires a bolt of energy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit and reducing his Ability Cooldowns by ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EzrealQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0081/ability_0081_Q1.webm"},{"key":"W","name":"Essence Flux","description":"Ezreal fires an orb that sticks to the first champion or objective hit. If Ezreal hits an enemy with the orb, it detonates and deals damage.","max_rank":5,"range_burn":[1150],"cooldown_burn":[12],"cost_burn":[50],"tooltip":"Ezreal fires a magical orb that sticks to the first champion, structure, or epic jungle monster hit for ? seconds. If Ezreal hits that target with an Attack or Ability, it detonates, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Detonating with an Ability refunds the Mana cost of that Ability plus \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EzrealW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0081/ability_0081_W1.webm"},{"key":"E","name":"Arcane Shift","description":"Ezreal teleports to a target nearby location and fires a homing bolt which strikes the nearest enemy unit. Prioritizes enemies stuck with Essence Flux.","max_rank":5,"range_burn":[475],"cooldown_burn":[28,25,22,19,16],"cost_burn":[90],"tooltip":"Ezreal teleports then fires a bolt at the nearest enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The bolt prioritizes enemies affected by \\u003cspellName\\u003eEssence Flux\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EzrealE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0081/ability_0081_E1.webm"},{"key":"R","name":"Trueshot Barrage","description":"Ezreal winds up before firing a powerful barrage of energy that deals massive damage to each unit it passes through (damage is reduced for minions and non-epic monsters).","max_rank":3,"range_burn":[25000],"cooldown_burn":[120,105,90],"cost_burn":[100],"tooltip":"Ezreal fires a massive energy arc that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The arc deals ?% damage to minions and non-epic jungle monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EzrealR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0081/ability_0081_R1.webm"}]},"82":{"id":82,"key":"Mordekaiser","name":"Mordekaiser","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Mordekaiser.png","enemy_tips":["Mordekaiser builds up a powerful damage aura when fighting champions, so keep your distance.","Damage he deals can be converted into a large shield, and consumed for health","Realm of Death will cut you off from your teammates completely. Try to save mobility spells to escape Mordekaiser once inside"],"ally_tips":["Offense is your defense. Keep fighting to build up larger Indestructible shields.","Hitting multiple champions with the same ability can help quickly activate Darkness Rise.","Use Realm of Death on a low health enemy to guarantee the kill and keep their stats for the rest of a teamfight."],"passive":{"name":"Darkness Rise","description":"Mordekaiser gains a powerful damage aura and Move Speed after landing 3 attacks or spells against champions or monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/MordekaiserPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0082/ability_0082_P1.webm"},"spells":[{"key":"Q","name":"Obliterate","description":"Mordekaiser smashes the ground with his mace dealing damage to each enemy struck. Damage is increased when hitting a single enemy.","max_rank":5,"range_burn":[675],"cooldown_burn":[9,7,6,5,4],"cost_burn":[0],"tooltip":"Mordekaiser smashes the ground with Nightfall dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, increased to \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e if it hits only a single enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MordekaiserQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0082/ability_0082_Q1.webm"},{"key":"W","name":"Indestructible","description":"Mordekaiser stores damage he deals and takes to create a shield. He may consume the shield to heal.","max_rank":5,"range_burn":[25000],"cooldown_burn":[12,11,10,9,8],"cost_burn":[0],"tooltip":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e Mordekaiser stores ?% of the damage he deals and ?% of the damage he takes.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Mordekaiser gains the stored damage as \\u003cshield\\u003eShield\\u003c/shield\\u003e. He may \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability to restore \\u003chealing\\u003e?% of the remaining Shield as Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eMinimum Shield: \\u003cshield\\u003e?\\u003c/shield\\u003e\\u003cbr /\\u003eMaximum Shield: \\u003cshield\\u003e?\\u003c/shield\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MordekaiserW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0082/ability_0082_W1.webm"},{"key":"E","name":"Death\'s Grasp","description":"Mordekaiser pulls all enemies in an area.","max_rank":5,"range_burn":[700],"cooldown_burn":[18,16,14,12,10],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Mordekaiser gains ?% Magic Penetration.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Mordekaiser pulls enemies in his direction, dealing \\u003cmagicDamage\\u003e? magic damage.\\u003c/magicDamage\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MordekaiserE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0082/ability_0082_E1.webm"},{"key":"R","name":"Realm of Death","description":"Mordekaiser drags his victim to a different dimension with him and steals a portion of their stats. If he kills them, he keeps the stats until the victim respawns.","max_rank":3,"range_burn":[650],"cooldown_burn":[140,120,100],"cost_burn":[0],"tooltip":"Mordekaiser banishes a champion to the Death Realm with him for ?s, stealing ?% of their core stats for the duration.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Mordekaiser kills that enemy in the Death Realm he consumes their soul, keeping the stats he stole until the target respawns.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MordekaiserR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0082/ability_0082_R1.webm"}]},"83":{"id":83,"key":"Yorick","name":"Yorick","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Yorick.png","enemy_tips":["You can cast Smite on Mist Walkers and the Maiden of the Mist to damage or kill them.","Try to thin out Yorick\'s minions before you engage him, Mist Walkers will die from a basic attack or a single target spell.","You can attack Dark Procession to break the wall down."],"ally_tips":["You do not need to cast Awakening to regain the ability to cast Last Rites.","The Maiden will attempt to assist you in a fight, so choose your targets well.","You can send the Maiden down a lane alone, be careful though, as she represents a large portion of your combat power."],"passive":{"name":"Shepherd of Souls","description":"\\u003cfont color=\'#FF9900\'\\u003eThe Cursed Horde:\\u003c/font\\u003e Yorick can summon Mist Walkers to swarm and attack nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Yorick_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0083/ability_0083_P1.webm"},"spells":[{"key":"Q","name":"Last Rites","description":"Yorick deals bonus damage on his next attack and heals himself. If the target dies a grave will be dug.","max_rank":5,"range_burn":[0],"cooldown_burn":[7,6,5,4,4],"cost_burn":[25],"tooltip":"Yorick\'s next Attack deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e, or \\u003chealing\\u003e? Health\\u003c/healing\\u003e if Yorick is below 50% Health. If this Attack kills the target, it leaves a grave.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen there are 3 or more graves nearby and this Ability has already been used, Yorick can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to raise \\u003ckeywordMajor\\u003eMist Walkers\\u003c/keywordMajor\\u003e from all nearby graves.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YorickQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0083/ability_0083_Q1.webm"},{"key":"W","name":"Dark Procession","description":"Yorick summons a destructible wall at target location that will block enemy movement.","max_rank":5,"range_burn":[600],"cooldown_burn":[20,18,16,14,12],"cost_burn":[70],"tooltip":"Yorick summons a wall of spirits blocking enemies\' path, but not allies\'. The wall can be Attacked, and disappears after 2/2/3/3/4 hits.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YorickW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0083/ability_0083_W1.webm"},{"key":"E","name":"Mourning Mist","description":"Yorick throws a globule of Black Mist that damages, slows and marks enemies.","max_rank":5,"range_burn":[700],"cooldown_burn":[12,11,10,9,8],"cost_burn":[50,55,60,65,70],"tooltip":"Yorick throws a globule of Black Mist that deals \\u003cmagicDamage\\u003e15% current Health magic damage (min: ?)\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 30% for 2 seconds, and marks champions and monsters for 4 seconds. Marked enemies continuously \\u003cspellName\\u003eAwaken\\u003c/spellName\\u003e nearby graves (but not exceeding the maximum of ?), and take ?% increased damage from up to ? attacks by \\u003ckeywordMajor\\u003eMist Walkers\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eYorick and his summoned units gain \\u003cspeed\\u003e20% Move Speed\\u003c/speed\\u003e toward the mark. \\u003ckeywordMajor\\u003eMist Walkers\\u003c/keywordMajor\\u003e will leap once at marked enemies that get away from them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YorickE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0083/ability_0083_E1.webm"},{"key":"R","name":"Eulogy of the Isles","description":"Yorick summons the Maiden of the Mist that causes Yorick\'s attacks against the Maiden\'s target to deal bonus damage. The Maiden will also automatically raise Walkers from dead enemies.","max_rank":3,"range_burn":[600],"cooldown_burn":[160,130,100],"cost_burn":[100],"tooltip":"Yorick summons the Maiden of the Mist and ? \\u003ckeywordMajor\\u003eMist Walkers\\u003c/keywordMajor\\u003e. The Maiden has \\u003chealing\\u003e? Health\\u003c/healing\\u003e, deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and raises \\u003ckeywordMajor\\u003eMist Walkers\\u003c/keywordMajor\\u003e from nearby enemy deaths.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen Yorick damages the Maiden\'s target, he will deal \\u003cmagicDamage\\u003e?% max Health magic damage\\u003c/magicDamage\\u003e. This effect has a ? second Cooldown.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter 10 seconds, Yorick can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability to free the Maiden, sending her down the nearest lane.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YorickR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0083/ability_0083_R1.webm"}]},"84":{"id":84,"key":"Akali","name":"Akali","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Akali.png","enemy_tips":["Akali can still be hit by area effect spells while obscured inside Twilight Shroud. Doing so will briefly reveal her position.","Akali\'s Five Point Strike is powerful when used at maximum range and energy. Engage on her when she has low energy to maximize your chance of winning trades.","Return to base if your Health is low and Akali has her ultimate available."],"ally_tips":["Akali excels at killing fragile champions. Let your team initiate and then strike at the people in the back.","Twilight Shroud offers safety in even the most dangerous situations. Use that time to save up energy for a quick strike later."],"passive":{"name":"Assassin\'s Mark","description":"Dealing spell damage to a champion creates a ring of energy around them. Exiting that ring empowers Akali\'s next autoattack with bonus range and damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Akali_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0084/ability_0084_P1.webm"},"spells":[{"key":"Q","name":"Five Point Strike","description":"Akali throws out five kunai, dealing damage based on her bonus Attack Damage and Ability Power and slowing.","max_rank":5,"range_burn":[550],"cooldown_burn":[1],"cost_burn":[130,115,100,85,70],"tooltip":"Akali slings kunai in an arc, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies at the tip by ?% for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkaliQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0084/ability_0084_Q1.webm"},{"key":"W","name":"Twilight Shroud","description":"Akali drops a cover of smoke and briefly gains Move Speed. While inside the shroud, Akali becomes invisible and unable to be selected by enemy spells and attacks. Attacking or using abilities will briefly reveal her.  ","max_rank":5,"range_burn":[350],"cooldown_burn":[20],"cost_burn":[0],"tooltip":"Akali drops a smoke bomb, unleashing a spreading cover of smoke lasting ? seconds and granting herself \\u003cspeed\\u003e30/35/40/45/50% Move Speed\\u003c/speed\\u003e decaying over ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAkali increases her energy by ? while the shroud is active. \\u003cbr /\\u003e\\u003cbr /\\u003eWhile inside the smoke, Akali is \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkaliW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0084/ability_0084_W1.webm"},{"key":"E","name":"Shuriken Flip","description":"Flip backward and fire a shuriken forward, dealing magic damage. The first enemy or smoke cloud hit is marked. Re-cast to dash to the marked target, dealing additional damage.","max_rank":5,"range_burn":[825],"cooldown_burn":[16,14,13,11,10],"cost_burn":[30],"tooltip":"Akali flips backwards as she throws a shuriken, dealing \\u003cmagicDamage\\u003e{{ e1damage }} magic damage\\u003c/magicDamage\\u003e and marking the first enemy or smoke cloud hit. Akali can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this once to dash to the marked target, dealing \\u003cmagicDamage\\u003e{{ e2damagecalc }} magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkaliE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0084/ability_0084_E1.webm"},{"key":"R","name":"Perfect Execution","description":"Akali leaps in a direction, damaging enemies she strikes. Re-cast: Akali dashes in a direction, executing all enemies she strikes.","max_rank":3,"range_burn":[675],"cooldown_burn":[100,80,60],"cost_burn":[0],"tooltip":"Akali vaults over an enemy champion, dealing \\u003cmagicDamage\\u003e{{ cast1damage }} magic damage\\u003c/magicDamage\\u003e to all enemies in her path. \\u003cbr /\\u003e\\u003cbr /\\u003eAkali can \\u003crecast\\u003eRecast\\u003c/recast\\u003e after ? seconds to execute a piercing thrust, dashing and dealing \\u003cmagicDamage\\u003e{{ cast2damagemin }}\\u003c/magicDamage\\u003e to \\u003cmagicDamage\\u003e{{ cast2damagemax }} magic damage\\u003c/magicDamage\\u003e based on missing health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkaliR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0084/ability_0084_R1.webm"}]},"85":{"id":85,"key":"Kennen","name":"Kennen","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kennen.png","enemy_tips":["Consider playing a bit more cautiously around Kennen when you have a Mark of the Storm debuff. If he hits you with 3 Marks of the Storm, you will get stunned.","Kennen is flimsy by nature - turn and attack him if he gets careless with Lightning Rush."],"ally_tips":["You can stun your opponents by inflicting 3 Marks of the Storm upon them.","Lightning Rush can be used to initiate fights with its Energy return component, allowing him to use other abilities afterward.","You can land an initial Mark of the Storm debuff on an opponent with Thundering Shuriken, and then add to it with Electrical Surge."],"passive":{"name":"Mark of the Storm","description":"Kennen stuns enemies he hits 3 times with his abilities.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kennen_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0085/ability_0085_P1.webm"},"spells":[{"key":"Q","name":"Thundering Shuriken","description":"Kennen throws a fast moving shuriken towards a location, causing damage and adding a Mark of the Storm to any opponent that it hits.","max_rank":5,"range_burn":[950],"cooldown_burn":[8,7,6,5,4],"cost_burn":[60,55,50,45,40],"tooltip":"Kennen throws a shuriken, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KennenShurikenHurlMissile1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0085/ability_0085_Q1.webm"},{"key":"W","name":"Electrical Surge","description":"Kennen passively deals extra damage and adds a Mark of the Storm to his target every few attacks, and he can activate this ability to damage and add another Mark of the Storm to targets who are already marked.","max_rank":5,"range_burn":[725],"cooldown_burn":[14,12,10,8,6],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every 5th Attack deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kennen sends out a blast of electricity, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies affected by \\u003cspellName\\u003eMark of the Storm\\u003c/spellName\\u003e.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KennenBringTheLight.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0085/ability_0085_W1.webm"},{"key":"E","name":"Lightning Rush","description":"Kennen morphs into a lightning form, enabling him to pass through units and apply a Mark of the Storm. Kennen gains Move Speed when entering this form, and attack speed when leaving it.","max_rank":5,"range_burn":[200],"cooldown_burn":[10,9,8,7,6],"cost_burn":[100,95,90,85,80],"tooltip":"Kennen turns into a ball of lightning, gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies he passes through, and becoming Ghosted for ? seconds. If Kennen damages at least one enemy, he gains ? Energy. \\u003cbr /\\u003e\\u003cbr /\\u003eAfter this ability ends, Kennen gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds. Kennen can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to end this Ability early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KennenLightningRush.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0085/ability_0085_E1.webm"},{"key":"R","name":"Slicing Maelstrom","description":"Kennen summons a storm that strikes at nearby enemy champions for magical damage.","max_rank":3,"range_burn":[550],"cooldown_burn":[120],"cost_burn":[0],"tooltip":"Kennen unleashes a magical storm, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to all nearby enemies every ? seconds, and gaining \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e for ? seconds. Successive hits deal ?% increased damage for each hit the enemy has already suffered.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KennenShurikenStorm.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0085/ability_0085_R1.webm"}]},"86":{"id":86,"key":"Garen","name":"Garen","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Garen.png","enemy_tips":["Stack armor items to lower the large amount of physical damage that Garen deals out.","Try to run away from Garen as your health gets lower, as he can execute you quickly with Demacian Justice.","Be careful about attacking Garen in brush. It often will lead to taking full damage from Judgment.","Judgment deals maximum damage when only hitting a single target. If getting out of its radius isn\'t possible, move through allied minions to reduce damage taken."],"ally_tips":["Garen\'s regeneration greatly increases if he can avoid receiving damage for several seconds.","Judgment deals maximum damage when only hitting a single target. For effective trading, try to position such that only the enemy champion is hit.","Garen is only constrained by cooldowns, making items such as Black Cleaver very effective for him."],"passive":{"name":"Perseverance","description":"If Garen has not recently been struck by damage or enemy abilities, he regenerates a percentage of his total health each second.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Garen_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0086/ability_0086_P1.webm"},"spells":[{"key":"Q","name":"Decisive Strike","description":"Garen gains a burst of Move Speed, breaking free of all slows affecting him. His next attack strikes a vital area of his foe, dealing bonus damage and silencing them.","max_rank":5,"range_burn":[300],"cooldown_burn":[8],"cost_burn":[0],"tooltip":"Garen removes all \\u003cstatus\\u003eSlowing\\u003c/status\\u003e effects on him and gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? second(s).\\u003cbr /\\u003e\\u003cbr /\\u003eHis next Attack \\u003cstatus\\u003eSilences\\u003c/status\\u003e for ? seconds and does \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GarenQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0086/ability_0086_Q1.webm"},{"key":"W","name":"Courage","description":"Garen passively increases his armor and magic resist by killing enemies. He may also activate this ability to give him a shield and tenacity for a brief moment followed by a lesser amount of damage reduction for a longer duration.","max_rank":5,"range_burn":[0],"cooldown_burn":[23,21,19,17,15],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Killing units permanently grants \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e, up to a max of ?. At max stacks, Garen gains \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Garen steels his courage for ? seconds, reducing incoming damage by ?%. He also gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e and ?% Tenacity for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GarenW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0086/ability_0086_W1.webm"},{"key":"E","name":"Judgment","description":"Garen rapidly spins his sword around his body, dealing physical damage to nearby enemies.","max_rank":5,"range_burn":[325],"cooldown_burn":[9],"cost_burn":[0],"tooltip":"Garen rapidly spins his sword for ? seconds, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e ? times over the duration. The nearest enemy takes \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e per strike instead.\\u003cbr /\\u003e\\u003cbr /\\u003eChampions hit by ? strikes lose \\u003cscaleArmor\\u003e?% Armor\\u003c/scaleArmor\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GarenE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0086/ability_0086_E1.webm"},{"key":"R","name":"Demacian Justice","description":"Garen calls upon the might of Demacia to attempt to execute an enemy champion.","max_rank":3,"range_burn":[400],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Garen calls upon the might of Demacia to slay his enemy, dealing \\u003ctrueDamage\\u003e? plus ?% missing Health true damage\\u003c/trueDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GarenR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0086/ability_0086_R1.webm"}]},"89":{"id":89,"key":"Leona","name":"Leona","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Leona.png","enemy_tips":["When Leona activates Eclipse, you have three seconds to get away from her before she deals damage.","Only foes in the center of Solar Flare get stunned, so you can often avoid this if you\'re quick."],"ally_tips":["Lead the charge and mark your foes with Sunlight before your allies deal damage.","Shield of Daybreak and Zenith Blade form a powerful offensive combo.","You can absorb a huge amount of damage using Eclipse, but you must stay near enemies to gain the bonus duration."],"passive":{"name":"Sunlight","description":"Damaging spells afflict enemies with Sunlight for 1.5 seconds. When allied Champions deal damage to those targets, they consume the Sunlight to deal additional magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/LeonaSunlight.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0089/ability_0089_P1.webm"},"spells":[{"key":"Q","name":"Shield of Daybreak","description":"Leona uses her shield to perform her next basic attack, dealing bonus magic damage and stunning the target.","max_rank":5,"range_burn":[100],"cooldown_burn":[5],"cost_burn":[45,50,55,60,65],"tooltip":"Leona\'s next Attack \\u003cstatus\\u003eStuns\\u003c/status\\u003e for 1 seconds and deals an additional \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeonaShieldOfDaybreak.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0089/ability_0089_Q1.webm"},{"key":"W","name":"Eclipse","description":"Leona raises her shield to gain Damage Reduction, Armor, and Magic Resist. When the duration first ends, if there are nearby enemies, she will deal magic damage to them and prolong the duration of the effect.","max_rank":5,"range_burn":[450],"cooldown_burn":[14,13,12,11,10],"cost_burn":[60],"tooltip":"Leona raises her shield, reducing incoming damage by ? and gaining \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e  and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e for 3 seconds. Afterwards, her shield detonates, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies. If she hits at least one, she retains the \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e bonuses for an additional 3 seconds.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeonaSolarBarrier.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0089/ability_0089_W1.webm"},{"key":"E","name":"Zenith Blade","description":"Leona projects a solar image of her sword, dealing magic damage to all enemies in a line. When the image fades, the last enemy champion struck will be briefly immobilized and Leona will dash to them.","max_rank":5,"range_burn":[875],"cooldown_burn":[12,10,9,7,6],"cost_burn":[60],"tooltip":"Leona thrusts with a sword of light, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The last champion struck will be \\u003cstatus\\u003eRooted\\u003c/status\\u003e for 0.5 seconds and Leona will dash to them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeonaZenithBlade.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0089/ability_0089_E1.webm"},{"key":"R","name":"Solar Flare","description":"Leona calls down a beam of solar energy, dealing damage to enemies in an area. Enemies in the center of the area are stunned, while enemies on the outside are slowed.","max_rank":3,"range_burn":[1200],"cooldown_burn":[90,75,60],"cost_burn":[100],"tooltip":"Leona calls down a radiant beam of solar energy dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds. Enemies in the center of the flare are \\u003cstatus\\u003eStunned\\u003c/status\\u003e instead of \\u003cstatus\\u003eSlowed\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LeonaSolarFlare.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0089/ability_0089_R1.webm"}]},"90":{"id":90,"key":"Malzahar","name":"Malzahar","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Malzahar.png","enemy_tips":["When Malzahar hits a spell on enemies affected by Malefic Visions, the Visions are refreshed.","Avoid minion waves that have been affected by Malefic Visions. You never know when they may die and pass the Visions onto you.","Malzahar is especially dangerous when he has built up his Void Swarm."],"ally_tips":["Wait to cast Void Swarm until there are nearby enemies for the Voidling to attack or kill.","Use Call of the Void and Nether Grasp to renew the duration of Malefic Visions on enemies.","Avoiding damage in lane maximizes the uptime on Void Shift, increasing Malzahar\'s safety dramatically."],"passive":{"name":"Void Shift","description":"When he hasn\'t recently taken damage or been crowd controlled, Malzahar gains massive damage reduction and crowd control immunity, lingering for a short period after taking damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Malzahar_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0090/ability_0090_P1.webm"},"spells":[{"key":"Q","name":"Call of the Void","description":"Malzahar opens up two portals to the Void. After a short delay, they fire projectiles that deal Magic Damage and silence enemy champions.","max_rank":5,"range_burn":[900],"cooldown_burn":[6],"cost_burn":[80],"tooltip":"Malzahar opens two portals to the Void that fire projectiles inward, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSilencing\\u003c/status\\u003e for 1/1.25/1.5/1.75/2 second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MalzaharQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0090/ability_0090_Q1.webm"},{"key":"W","name":"Void Swarm","description":"Malzahar summons Voidlings to attack nearby enemies.","max_rank":5,"range_burn":[150],"cooldown_burn":[8],"cost_burn":[40,45,50,55,60],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Malzahar\'s other Abilities give him a stack when cast (max ?).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Malzahar summons a Voidling plus an additional Voidling per stack. Voidlings last ? seconds and deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MalzaharW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0090/ability_0090_W1.webm"},{"key":"E","name":"Malefic Visions","description":"Malzahar infects his target\'s mind with cruel visions of their demise, dealing damage over time. Using Malzahar\'s other spells on the target will refresh the visions.\\u003cbr\\u003e\\u003cbr\\u003eIf the target dies while afflicted by the visions, they pass on to a nearby enemy unit and Malzahar gains Mana. Malzahar\'s Voidlings are attracted to affected units.","max_rank":5,"range_burn":[650],"cooldown_burn":[15,13,11,9,7],"cost_burn":[60,70,80,90,100],"tooltip":"Malzahar inflicts terrible visions, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 4 seconds. Applying \\u003cspellName\\u003eCall of the Void\\u003c/spellName\\u003e or \\u003cspellName\\u003eNether Grasp\\u003c/spellName\\u003e to the victim during this time refreshes the visions.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the victim dies, Malzahar gains \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e and the visions spread to the nearest enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MalzaharE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0090/ability_0090_E1.webm"},{"key":"R","name":"Nether Grasp","description":"Malzahar channels the essence of the Void to suppress an enemy champion over a zone of damaging negative energy.","max_rank":3,"range_burn":[700],"cooldown_burn":[140,110,80],"cost_burn":[100],"tooltip":"Malzahar \\u003cstatus\\u003eSuppresses\\u003c/status\\u003e an enemy champion and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 2.5 seconds. A zone of negative energy is created around his target dealing \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e over 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/MalzaharR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0090/ability_0090_R1.webm"}]},"91":{"id":91,"key":"Talon","name":"Talon","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Talon.png","enemy_tips":["Talon\'s attacks are all physical damage. Build armor early to counter his burst damage.","Talon is heavily reliant on Shadow Assault to escape a fight. When it is down he\'s significantly more vulnerable.","Talon has unrivaled roaming ability. Make sure to keep track of his position or force him to stay in lane by pushing aggressively."],"ally_tips":["You can use Assassin\'s Path to get behind the enemy and set up for Noxian Diplomacy\'s melee attack.","Shadow Assault is a powerful escape tool, but can also be offensively used to assault a group.","Remember to pick your target before the fight. Focusing all of Talon\'s abilities on one target can be very rewarding, but splitting them up between many may leave you helpless."],"passive":{"name":"Blade\'s End","description":"Talon\'s spells Wound champions and large monsters, stacking up to 3 times. When Talon attacks a champion with 3 stacks of Wound, they bleed for heavy damage over time.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/TalonP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0091/ability_0091_P1.webm"},"spells":[{"key":"Q","name":"Noxian Diplomacy","description":"Talon stabs the target unit. If they are within melee range, this attack deals critical damage. If they are outside melee range, Talon will leap at his target before stabbing them. Talon refunds some health and cooldown if this ability kills the target.","max_rank":5,"range_burn":[575],"cooldown_burn":[8,7,7,6,6],"cost_burn":[40],"tooltip":"Talon leaps to a target and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If used in melee range, this Ability instead critically strikes for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability kills the target, Talon restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e and refunds 50% of its Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TalonQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0091/ability_0091_Q1.webm"},{"key":"W","name":"Rake","description":"Talon sends out a volley of daggers that then return back to him, dealing physical damage every time it passes through an enemy. The returning blades deal bonus damage and slow units hit.","max_rank":5,"range_burn":[650],"cooldown_burn":[9,8,8,7,7],"cost_burn":[55,60,65,70,75],"tooltip":"Talon tosses a volley of blades, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. The blades then return to him, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TalonW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0091/ability_0091_W1.webm"},{"key":"E","name":"Assassin\'s Path","description":"Talon vaults over any terrain or structure, up to a max distance. This ability has a low cooldown, but puts the used terrain on a long cooldown.","max_rank":5,"range_burn":[725],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Talon vaults over the nearest terrain or structure. Talon cannot dash over the same terrain more than once every 160/135/110/85/60 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TalonE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0091/ability_0091_E1.webm"},{"key":"R","name":"Shadow Assault","description":"Talon disperses a ring of blades and becomes Invisible while gaining additional Move Speed. When Talon emerges from Invisibility, the blades converge on his location. Each time the blades move, Shadow Assault deals physical damage to enemies hit by at least one blade.","max_rank":3,"range_burn":[550],"cooldown_burn":[100,80,60],"cost_burn":[100],"tooltip":"Talon disperses a ring of blades that deal \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e, and becomes \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e for ? seconds. When the \\u003ckeywordStealth\\u003eInvisibility\\u003c/keywordStealth\\u003e ends, the blades return to Talon, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e again.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Talon cancels the \\u003ckeywordStealth\\u003eInvisibility\\u003c/keywordStealth\\u003e with an Attack or with \\u003cspellName\\u003eNoxian Diplomacy\\u003c/spellName\\u003e, the blades return to the target instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TalonR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0091/ability_0091_R1.webm"}]},"92":{"id":92,"key":"Riven","name":"Riven","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Riven.png","enemy_tips":["Riven has a great deal of mobility but she cannot move very far with any one skill. Rooting or silencing her during her combo will greatly reduce her effectiveness.","All of Riven\'s damage is physical, prioritize high Armor if an opposing Riven gets out of control.","Riven excels at dueling multiple melee attackers at once, as she will be on an almost equal footing damage-wise. If pairing up against Riven, don\'t go in as double melee until she has expended her full combo."],"ally_tips":["Riven\'s Broken Wings locks onto the champion your cursor is over at the time of cast. If you want to move past your opponent, make sure that your cursor is past your opponent as well.","Riven lacks a source of healing or strong defense and must compensate with burst combos. Lead into fights with Broken Wings and Ki Burst, while using Valor to escape and absorb counter-harass."],"passive":{"name":"Runic Blade","description":"Riven\'s abilities charge her blade, and her basic attacks expend charges to deal an additional damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/RivenRunicBlades.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0092/ability_0092_P1.webm"},"spells":[{"key":"Q","name":"Broken Wings","description":"Riven lashes out in a series of strikes. This ability can be reactivated three times in a short time frame with the third hit knocking back nearby enemies.","max_rank":5,"range_burn":[275],"cooldown_burn":[13],"cost_burn":[0],"tooltip":"Riven dashes forward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. She can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability twice. The first \\u003crecast\\u003eRecast\\u003c/recast\\u003e is the same as the original, but the second has a different effect:\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Riven leaps forward and slams, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e nearby enemies for 0.75 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RivenTriCleave.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0092/ability_0092_Q1.webm"},{"key":"W","name":"Ki Burst","description":"Riven emits a Ki Burst, damaging and stunning nearby enemies.","max_rank":5,"range_burn":[260],"cooldown_burn":[11,10,9,8,7],"cost_burn":[0],"tooltip":"Riven\'s sword emits a burst of runic energy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e for 0.75 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RivenMartyr.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0092/ability_0092_W1.webm"},{"key":"E","name":"Valor","description":"Riven steps forward a short distance and blocks incoming damage.","max_rank":5,"range_burn":[250],"cooldown_burn":[10,9,8,7,6],"cost_burn":[0],"tooltip":"Riven quickly dashes and gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RivenFeint.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0092/ability_0092_E1.webm"},{"key":"R","name":"Blade of the Exile","description":"Riven empowers her keepsake weapon with energy, and gains Attack Damage and Range. During this time, she also gains the ability to use Wind Slash, a powerful ranged attack, once.","max_rank":3,"range_burn":[200],"cooldown_burn":[120,90,60],"cost_burn":[0],"tooltip":"Riven\'s weapon surges with spiritual energy, granting her \\u003cphysicalDamage\\u003e? Attack Damage\\u003c/physicalDamage\\u003e and increased range on damaging Abilities and Attacks for ? seconds. While active, she can \\u003crecast\\u003eRecast.\\u003c/recast\\u003e\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Riven fires a wind slash that deals between \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, based on their missing Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RivenFengShuiEngine.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0092/ability_0092_R1.webm"}]},"96":{"id":96,"key":"KogMaw","name":"Kog\'Maw","image_url":"https://opgg-static.akamaized.net/images/lol/champion/KogMaw.png","enemy_tips":["Kog\'Maw doesn\'t have a good escape ability, so he is especially prone to ganks.","Run away from Kog\'Maw after he dies!!!!","The range on Living Artillery increases each rank.","Bio-Arcane Barrage allows Kog\'Maw to kill Baron Nashor extremely early. It can be valuable to ward Nashor when Kog\'Maw completes his Blade of the Ruined King."],"ally_tips":["Kog\'Maw can outrange most champions with his Bio-Arcane Barrage ability.","Use Void Ooze to set up a perfect Living Artillery.","Make the most out of your Icathian Surprise."],"passive":{"name":"Icathian Surprise","description":"4 seconds after dying, Kogmaw explodes, dealing true damage to surrounding enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/KogMaw_IcathianSurprise.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0096/ability_0096_P1.webm"},"spells":[{"key":"Q","name":"Caustic Spittle","description":"Kog\'Maw launches a corrosive projectile which deals magic damage and corrodes the target\'s armor and magic resist for a short time. Kog\'Maw also gains additional attack speed.","max_rank":5,"range_burn":[1175],"cooldown_burn":[8],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Kog\'Maw gains \\u003cattackSpeed\\u003e10/15/20/25/30% Attack Speed\\u003c/attackSpeed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kog\'Maw vomits a corrosive projectile that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit and shreds \\u003cscaleArmor\\u003e23/25/27/29/31% Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e for 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KogMawQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0096/ability_0096_Q1.webm"},{"key":"W","name":"Bio-Arcane Barrage","description":"Kog\'Maw\'s attacks gain range and deal a percent of the target\'s maximum health as magic damage.","max_rank":5,"range_burn":[530],"cooldown_burn":[17],"cost_burn":[40],"tooltip":"Kog\'Maw gains 130/150/170/190/210 Attack Range and his Attacks deal an additional \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e for 8 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KogMawBioArcaneBarrage.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0096/ability_0096_W1.webm"},{"key":"E","name":"Void Ooze","description":"Kog\'Maw launches a peculiar ooze which damages all enemies it passes through and leaves a trail which slows enemies who stand on it.","max_rank":5,"range_burn":[1200],"cooldown_burn":[12],"cost_burn":[60,70,80,90,100],"tooltip":"Kog\'Maw spits bile, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and leaving a trail of ooze for 4 seconds. Enemies in the ooze are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 20/28/36/44/52%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KogMawVoidOoze.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0096/ability_0096_E1.webm"},{"key":"R","name":"Living Artillery","description":"Kog\'Maw fires an artillery shell at a great distance dealing magic damage (increased significantly on low health enemies) and revealing non-stealthed targets. Additionally, multiple Living Artilleries in a short period of time cause them to cost additional Mana.","max_rank":3,"range_burn":[1300,1550,1800],"cooldown_burn":[2,1,1],"cost_burn":[40],"tooltip":"Kog\'Maw shoots acid at an area, dealing \\u003cmagicDamage\\u003e? plus ?% per 1% missing Health magic damage\\u003c/magicDamage\\u003e and revealing enemies hit for 2 seconds. Enemies below \\u003chealing\\u003e40% Health\\u003c/healing\\u003e instead take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eSubsequent shots within ? seconds cost an additional \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e (max: \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KogMawLivingArtillery.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0096/ability_0096_R1.webm"}]},"98":{"id":98,"key":"Shen","name":"Shen","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Shen.png","enemy_tips":["Be ready to dodge Shen\'s taunt and punish him if he misses.","Once Shen reaches level 6, watch out for his global-range ultimate, which can turn fights quickly."],"ally_tips":["Keep an eye on allies and be ready to save them with your teleport.","Leverage your Energy to get a long-term advantage over Mana users."],"passive":{"name":"Ki Barrier","description":"After casting a spell, Shen gets a shield. Affecting other champions reduces the cooldown of this effect.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Shen_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0098/ability_0098_P1.webm"},"spells":[{"key":"Q","name":"Twilight Assault","description":"Shen recalls his spirit blade to attack with it, dealing damage based on the target\'s max health. The attacks are greatly empowered if it collides with an enemy champion, and all collided enemies are slowed while running away from Shen.","max_rank":5,"range_burn":[400],"cooldown_burn":[8,7,6,5,5],"cost_burn":[140,130,120,110,100],"tooltip":"Shen recalls his \\u003ckeywordMajor\\u003eSpirit Blade\\u003c/keywordMajor\\u003e. Enemies hit by the pull are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 15/20/25/30/35% while moving away from Shen for the next 2 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAdditionally, Shen\'s next 3 Attacks deal an additional \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e. If Shen hit an enemy champion with the \\u003ckeywordMajor\\u003eSpirit Blade\\u003c/keywordMajor\\u003e, the damage is increased to \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e and he gains \\u003cattackSpeed\\u003e50% Attack Speed\\u003c/attackSpeed\\u003e for those Attacks.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShenQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0098/ability_0098_Q1.webm"},{"key":"W","name":"Spirit\'s Refuge","description":"Attacks that would hit Shen or his allies near his spirit blade are blocked.","max_rank":5,"range_burn":[400],"cooldown_burn":[18,16,15,13,12],"cost_burn":[40],"tooltip":"Shen creates a defensive zone at his \\u003ckeywordMajor\\u003eSpirit Blade\\u003c/keywordMajor\\u003e for 1.75 seconds. Attacks against allied champions in the zone are blocked. \\u003cbr /\\u003e\\u003cbr /\\u003eIf there are no champions to protect in the zone when it starts, it will wait for up to 2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShenW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0098/ability_0098_W1.webm"},{"key":"E","name":"Shadow Dash","description":"Shen dashes in a direction, taunting enemies in his path.","max_rank":5,"range_burn":[600],"cooldown_burn":[18,16,14,12,10],"cost_burn":[150],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Dealing damage with \\u003cspellName\\u003eTwilight Assault\\u003c/spellName\\u003e or this Ability recovers \\u003ckeywordMajor\\u003e? Energy\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Shen dashes, \\u003cstatus\\u003eTaunting\\u003c/status\\u003e champions and jungle monsters for ? seconds and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShenE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0098/ability_0098_E1.webm"},{"key":"R","name":"Stand United","description":"Shen shields target allied champion from incoming damage, and soon after teleports to their location.","max_rank":3,"range_burn":[35000],"cooldown_burn":[200,180,160],"cost_burn":[0],"tooltip":"Shen grants an allied champion anywhere on the map between \\u003cshield\\u003e?\\u003c/shield\\u003e and \\u003cshield\\u003e? Shield\\u003c/shield\\u003e based on their missing Health for ? seconds (max Shield at 60% missing Health). After channeling for ? seconds, Shen teleports to his ally\'s location with his \\u003ckeywordMajor\\u003eSpirit Blade\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShenR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0098/ability_0098_R1.webm"}]},"99":{"id":99,"key":"Lux","name":"Lux","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Lux.png","enemy_tips":["Lux has powerful zone control abilities. Try to spread out and attack from different directions so she cannot lock down a specific area.","When retreating with low health, be prepared to dodge Lux\'s Final Spark, a red targeting beam fires prior to the main beam, so try to move to the side if possible."],"ally_tips":["Lux has great zone control abilities. Try to set up Lucent Singularity to prevent an enemy\'s advance or escape.","If you have trouble landing Prismatic Barrier, remember that it returns to you after it reaches max range. Try positioning yourself to hit your allies with its return trip.","Lucent Singularity is a great scouting tool. Try throwing it into brush before walking into it to check for ambushes."],"passive":{"name":"Illumination","description":"Lux\'s damaging spells charge the target with energy for a few seconds. Lux\'s next attack ignites the energy, dealing bonus magic damage (depending on Lux\'s level) to the target.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/LuxIlluminatingFraulein.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0099/ability_0099_P1.webm"},"spells":[{"key":"Q","name":"Light Binding","description":"Lux releases a sphere of light that binds and deals damage to up to two enemy units.","max_rank":5,"range_burn":[1175],"cooldown_burn":[11],"cost_burn":[50],"tooltip":"Lux fires a ball of light, \\u003cstatus\\u003eRooting\\u003c/status\\u003e the first two enemies for 2 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to each.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuxLightBinding.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0099/ability_0099_Q1.webm"},{"key":"W","name":"Prismatic Barrier","description":"Lux throws her wand and bends the light around any friendly target it touches, protecting them from enemy damage.","max_rank":5,"range_burn":[1150],"cooldown_burn":[14,13,12,11,10],"cost_burn":[60,65,70,75,80],"tooltip":"Lux throws her wand, granting \\u003cshield\\u003e? Shield\\u003c/shield\\u003e to allies it passes through. Then it returns, granting the same \\u003cshield\\u003eShield\\u003c/shield\\u003e on its return.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuxPrismaticWave.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0099/ability_0099_W1.webm"},{"key":"E","name":"Lucent Singularity","description":"Fires an anomaly of twisted light to an area, which slows nearby enemies. Lux can detonate it to damage enemies in the area of effect.","max_rank":5,"range_burn":[1100],"cooldown_burn":[10,9,9,8,8],"cost_burn":[70,80,90,100,110],"tooltip":"Lux creates a light zone that \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 25/30/35/40/45% and reveals the area. After 5 seconds or on \\u003crecast\\u003eRecasting\\u003c/recast\\u003e this Ability, it detonates, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e for an additional ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuxLightStrikeKugel.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0099/ability_0099_E1.webm"},{"key":"R","name":"Final Spark","description":"After gathering energy, Lux fires a beam of light that deals damage to all targets in the area. In addition, triggers Lux\'s passive ability and refreshes the Illumination debuff duration.","max_rank":3,"range_burn":[3340],"cooldown_burn":[60,50,40],"cost_burn":[100],"tooltip":"Lux fires a dazzling ray of light, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to all enemies in a line.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuxR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0099/ability_0099_R1.webm"}]},"101":{"id":101,"key":"Xerath","name":"Xerath","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Xerath.png","enemy_tips":["Xerath\'s range can be intimidating, but most champions who close distance with him can trade favorably.","Xerath takes a long time to engage Rite of the Arcane. Watch for his spellcast animation and start dodging.","Banshee\'s Veil will make it much harder for Xerath to land Shocking Orb on you."],"ally_tips":["It\'s easier to land Arcanopulse on an enemy when they\'re moving toward or away from you, rather than side to side.","Eye of Destruction will make landing Arcanopulse easier as the target will be slowed.","If you stun an enemy with Shocking Orb, follow up with a guaranteed center hit on Eye of Destruction."],"passive":{"name":"Mana Surge","description":"Xerath\'s basic attacks periodically restore Mana.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Xerath_Passive1.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0101/ability_0101_P1.webm"},"spells":[{"key":"Q","name":"Arcanopulse","description":"Fires a long-range beam of energy, dealing magic damage to all targets hit.","max_rank":5,"range_burn":[750],"cooldown_burn":[9,8,7,6,5],"cost_burn":[80,90,100,110,120],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Xerath begins charging an arcane beam, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e himself gradually up to 50%. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Xerath fires the beam, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The range increases with time charged.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XerathArcanopulseChargeUp.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0101/ability_0101_Q1.webm"},{"key":"W","name":"Eye of Destruction","description":"Calls down a barrage of arcane energy, slowing and dealing magic damage to all enemies in an area. Targets in the middle receive additional damage and a stronger slow.","max_rank":5,"range_burn":[1000],"cooldown_burn":[14,13,12,11,10],"cost_burn":[70,80,90,100,110],"tooltip":"Xerath calls down a blast of arcane energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. Enemies in the center take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e instead and are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?%, decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XerathArcaneBarrage2.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0101/ability_0101_W1.webm"},{"key":"E","name":"Shocking Orb","description":"Deals magic damage to an enemy and stuns them.","max_rank":5,"range_burn":[1050],"cooldown_burn":[13,12,12,11,11],"cost_burn":[60,65,70,75,80],"tooltip":"Xerath fires an orb of raw magic, \\u003cstatus\\u003eStunning\\u003c/status\\u003e the first enemy hit for up to 2.25 seconds based on distance travelled, and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XerathMageSpear.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0101/ability_0101_E1.webm"},{"key":"R","name":"Rite of the Arcane","description":"Xerath immobilizes himself and gains numerous long-range barrages.","max_rank":3,"range_burn":[5000],"cooldown_burn":[130,115,100],"cost_burn":[100],"tooltip":"Xerath ascends to his true form and channels for 10 seconds. During this time he may \\u003crecast\\u003eRecast\\u003c/recast\\u003e up to 3/4/5 times.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Xerath launches a magical artillery, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XerathLocusOfPower2.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0101/ability_0101_R1.webm"}]},"102":{"id":102,"key":"Shyvana","name":"Shyvana","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Shyvana.png","enemy_tips":["A significant portion of Shyvana\'s power is generated through aggression, making her weak against opponents who are able to keep their distance.","All of Shyvana\'s basic abilities hit multiple enemies in dragon form. It\'s important for opposing champions to not cluster while fighting her.","Shyvana\'s Fury Bar indicate her ultimate can be activated. Harassing her when she\'s low on Fury can be very effective."],"ally_tips":["Shyvana\'s abilities all benefit from attacking units. As a result, Attack Speed items are more valuable on her than most champions.","Flame Breath is great to level-up against difficult lane opponents.","Burnout is an ideal choice for jungling. Monsters will be hit by the full duration, and the speed boost improves her ganking potential.","It can be valuable to purchase one of the items that can slow enemies: Frozen Mallet, Dead Man\'s Plate, or Entropy."],"passive":{"name":"Fury of the Dragonborn","description":"Shyvana deals bonus damage to dragons and gains Armor and Magic Resistance. As Shyvana and her allies slay more dragons, she gains more bonus Armor and Magic Resistance.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ShyvanaReinforcedScales.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0102/ability_0102_P1.webm"},"spells":[{"key":"Q","name":"Twin Bite","description":"Shyvana strikes twice on her next attack. Basic attacks reduce the cooldown of Twin Bite by 0.5 seconds.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF3300\'\\u003eDragon Form: \\u003c/font\\u003eTwin Bite cleaves all units in front of Shyvana.","max_rank":5,"range_burn":[650],"cooldown_burn":[7,6,6,5,5],"cost_burn":[0],"tooltip":"Shyvana\'s next Attack strikes twice, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e then \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eAttacks reduce this Ability\'s Cooldown by ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDragon Form:\\u003c/keywordMajor\\u003e The empowered Attacks hit all units in front of Shyvana.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShyvanaDoubleAttack.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0102/ability_0102_Q1.webm"},{"key":"W","name":"Burnout","description":"Shyvana surrounds herself in fire, dealing magic damage per second to nearby enemies and moving faster for 3 seconds, part of this damage is applied again when Shyvana basic attacks an enemy with Burnout active. The Move Speed reduces over the duration of the spell. Basic attacks extend the duration of Burnout. \\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF3300\'\\u003eDragon Form: \\u003c/font\\u003eBurnout grows in size.","max_rank":5,"range_burn":[325],"cooldown_burn":[12],"cost_burn":[0],"tooltip":"Shyvana summons a flame storm around her, gaining \\u003cspeed\\u003e? decaying Move Speed\\u003c/speed\\u003e and dealing \\u003cmagicDamage\\u003e? magic damage per second\\u003c/magicDamage\\u003e for ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eThe flame storm also causes Shyvana\'s Attacks to deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to surrounding enemies and extend this Ability\'s duration by ? second.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDragon Form:\\u003c/keywordMajor\\u003e The size of the flame storm is increased.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShyvanaImmolationAura.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0102/ability_0102_W1.webm"},{"key":"E","name":"Flame Breath","description":"Shyvana unleashes a fireball that deals damage to all enemies it encounters and leaves cinders on the target, marking them for 5 seconds. Shyvana\'s basic attacks on marked targets deal a percentage of their maximum Health as damage on-hit.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF3300\'\\u003eDragon Form: \\u003c/font\\u003eFlame Breath explodes on impact or at target location, dealing bonus damage and scorching the earth for a short duration.","max_rank":5,"range_burn":[925],"cooldown_burn":[12,11,10,9,8],"cost_burn":[0],"tooltip":"Shyvana unleashes a fireball that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and marks for ? seconds. The fireball stops on the first champion hit.\\u003cbr /\\u003e\\u003cbr /\\u003eShyvana\'s Attacks against marked targets deal an additional \\u003cmagicDamage\\u003e?% max Health magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDragon Form:\\u003c/keywordMajor\\u003e The fireball explodes once it ends, dealing an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and scorching the earth, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShyvanaFireball.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0102/ability_0102_E1.webm"},{"key":"R","name":"Dragon\'s Descent","description":"Shyvana transforms into a dragon and takes flight to a target location. Enemies along her path take damage and are knocked toward her target location.\\u003cbr\\u003e\\u003cbr\\u003eShyvana passively gains Fury per second and gains 2 Fury on basic attack.","max_rank":3,"range_burn":[850],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eShyvana generates \\u003ckeywordMajor\\u003e? Fury\\u003c/keywordMajor\\u003e every second, and Attacks generate an extra \\u003ckeywordMajor\\u003e? Fury\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive: \\u003c/spellActive\\u003eShyvana transforms into \\u003ckeywordMajor\\u003eDragon Form\\u003c/keywordMajor\\u003e, gaining \\u003chealing\\u003e? max Health\\u003c/healing\\u003e and flying forward, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eKnocking\\u003c/status\\u003e enemies toward her target location.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ShyvanaTransformCast.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0102/ability_0102_R1.webm"}]},"103":{"id":103,"key":"Ahri","name":"Ahri","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ahri.png","enemy_tips":["Ahri\'s survivability is dramatically reduced when her Ultimate, Spirit Rush, is down.","Stay behind minions to make Charm difficult to land, this will reduce Ahri\'s damage potential significantly."],"ally_tips":["Use Charm to set up your combos, it will make landing Orb of Deception and Fox-Fire dramatically easier.","Initiate team fights using Charm, and chase down stragglers with Spirit Rush.","Spirit Rush enables Ahri\'s abilities, it opens up paths for Charm, helps double hitting with Orb of Deception, and closes to make use of Fox-Fire."],"passive":{"name":"Essence Theft","description":"When Ahri strikes 9 enemies with her abilities, her next ability also heals her for each enemy hit.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Ahri_SoulEater2.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0103/ability_0103_P1.webm"},"spells":[{"key":"Q","name":"Orb of Deception","description":"Ahri sends out and pulls back her orb, dealing magic damage on the way out and true damage on the way back. ","max_rank":5,"range_burn":[970],"cooldown_burn":[7],"cost_burn":[60,70,80,90,100],"tooltip":"Ahri throws then pulls back her orb, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e on the way out and \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e on the way back.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AhriOrbofDeception.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0103/ability_0103_Q1.webm"},{"key":"W","name":"Fox-Fire","description":"Ahri gains a brief burst of Move Speed and releases three fox-fires, that lock onto and attack nearby enemies.","max_rank":5,"range_burn":[700],"cooldown_burn":[9,8,7,6,5],"cost_burn":[30],"tooltip":"Ahri releases 3 fox-fires that seek nearby enemies and deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, reduced to \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e beyond the first. She also gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AhriFoxFire.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0103/ability_0103_W1.webm"},{"key":"E","name":"Charm","description":"Ahri blows a kiss that damages and charms an enemy it encounters, instantly stopping movement abilities and causing them to walk harmlessly towards her.","max_rank":5,"range_burn":[975],"cooldown_burn":[14],"cost_burn":[60],"tooltip":"Ahri blows a kiss that \\u003cstatus\\u003eCharms\\u003c/status\\u003e the first enemy hit for ? second(s) and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AhriSeduce.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0103/ability_0103_E1.webm"},{"key":"R","name":"Spirit Rush","description":"Ahri dashes forward and fires essence bolts, damaging nearby enemies. Spirit Rush can be cast up to three times before going on cooldown, and gains additional recasts when taking down enemy champions.","max_rank":3,"range_burn":[450],"cooldown_burn":[140,115,90],"cost_burn":[100],"tooltip":"Ahri nimbly dashes, firing ? essence bolts at nearby enemies, prioritizing champions. These bolts deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each. Spirit Rush can be recast up to 2 more times within ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eConsuming a champion\'s Essence with Essence Theft during this period extends the recast window by up to ? seconds and grants an additional recast of Spirit Rush (up to ? stored).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AhriTumble.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0103/ability_0103_R1.webm"}]},"104":{"id":104,"key":"Graves","name":"Graves","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Graves.png","enemy_tips":["Graves deals mostly physical damage so Armor is an effective counter.","Leaving the Smoke Screen\'s area of effect removes the harmful effect immediately."],"ally_tips":["Smoke Screen can be used both to escape and to set up a kill.","Using Quickdraw to get into range and delivering a point blank Buckshot can do lots of damage."],"passive":{"name":"New Destiny","description":"Graves\' shotgun has some unique properties. He must reload when he runs out of ammo. Attacks fire 4 bullets, which cannot pass through units. Non-champions struck by multiple bullets are knocked back.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/GravesTrueGrit.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0104/ability_0104_P1.webm"},"spells":[{"key":"Q","name":"End of the Line","description":"Graves fires an explosive shell that detonates after 2 seconds, or 0.2 seconds if it strikes terrain.","max_rank":5,"range_burn":[925],"cooldown_burn":[12,11,10,9,8],"cost_burn":[80],"tooltip":"Graves fires a powder round dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. After 1 second or after colliding with terrain, it detonates, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e along the travel path again and to enemies near the blast.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GravesQLineSpell.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0104/ability_0104_Q1.webm"},{"key":"W","name":"Smoke Screen","description":"Graves fires a smoke canister at the target area creating a cloud of smoke that reduces sight range. Enemies caught in the initial impact are dealt magic damage and have their Move Speed reduced briefly.","max_rank":5,"range_burn":[950],"cooldown_burn":[26,24,22,20,18],"cost_burn":[70,75,80,85,90],"tooltip":"Graves creates a cloud of black smoke for 4 seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies inside by 50% and blocking their vision outside the area. The initial impact deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GravesSmokeGrenade.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0104/ability_0104_W1.webm"},{"key":"E","name":"Quickdraw","description":"Graves dashes forward gaining an Armor boost for several seconds. If Graves dashes towards an enemy champion, gain two stacks of True Grit instead. Hitting enemies with basic attacks lowers the cooldown of this skill and refreshes the resistance boost.","max_rank":5,"range_burn":[425],"cooldown_burn":[16,15,14,13,12],"cost_burn":[40],"tooltip":"Graves dashes and reloads one \\u003ckeywordMajor\\u003eShell\\u003c/keywordMajor\\u003e into his shotgun. He also gains a stack for 4 seconds (max ? stacks) or two stacks if he dashes towards an enemy champion. Stacks grant him \\u003cscaleArmor\\u003e4/7/10/13/16 Armor\\u003c/scaleArmor\\u003e. Stacks are refreshed when damaging a non-minion.\\u003cbr /\\u003e\\u003cbr /\\u003eEach bullet hit from Graves\' Attacks reduces this Ability\'s Cooldown by 0.5 seconds.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GravesMove.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0104/ability_0104_E1.webm"},{"key":"R","name":"Collateral Damage","description":"Graves fires an explosive shell dealing heavy damage to the first champion it hits. After hitting a champion or reaching the end of its range, the shell explodes dealing damage in a cone.","max_rank":3,"range_burn":[1000],"cooldown_burn":[120,90,60],"cost_burn":[100],"tooltip":"Graves fires an explosive cartridge, blasting himself backwards. The cartridge deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit. After hitting an enemy champion or reaching the end of its range, the cartridge explodes outward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GravesChargeShot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0104/ability_0104_R1.webm"}]},"105":{"id":105,"key":"Fizz","name":"Fizz","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Fizz.png","enemy_tips":["Fizz\'s attacks becomes more deadly for a few seconds after he uses his empowered attack - keep him away while his trident is glowing!","Fizz is a slippery target when his abilities are not on cooldown - bait him into using them early and follow up with crowd control or hard-hitting attacks!"],"ally_tips":["Since Fizz can move through units, find opportunities in lane to walk through minions and apply Seastone Trident\'s passive - following it up with the ability\'s active attack after a few seconds.","Fizz\'s ultimate ability, Chum the Waters, can be aimed at an enemy or towards the area where you think they\'ll be going.","Fizz\'s spells scale off Ability Power - consider getting items like Zhonya\'s Hourglass or Banshee\'s Veil against teams that have high burst threat - and items like Lich Bane or Rabadon\'s Deathcap if you think you can survive without the Health."],"passive":{"name":"Nimble Fighter","description":"Fizz can move through units and takes a flat amount of reduced damage from all sources","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Fizz_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0105/ability_0105_P1.webm"},"spells":[{"key":"Q","name":"Urchin Strike","description":"Fizz dashes through his target, dealing magic damage and applying on hit effects.","max_rank":5,"range_burn":[550],"cooldown_burn":[8,7,7,6,6],"cost_burn":[50],"tooltip":"Fizz dashes through an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e plus \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FizzQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0105/ability_0105_Q1.webm"},{"key":"W","name":"Seastone Trident","description":"Fizz\'s attacks bleed his enemies, dealing magic damage over several seconds. Fizz can empower his next attack to deal bonus damage and empower his further attacks for a short time.","max_rank":5,"range_burn":[600],"cooldown_burn":[7,6,6,5,5],"cost_burn":[30,40,50,60,70],"tooltip":"\\u003cspellPassive\\u003ePassive\\u003c/spellPassive\\u003e: Fizz\'s Attacks cause his enemies to bleed, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive\\u003c/spellActive\\u003e: Fizz\'s next Attack deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. If this Attack kills its target, Fizz refunds \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e and reduces the cooldown of this Ability to ? second. If it does not kill, Fizz\'s Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FizzW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0105/ability_0105_W1.webm"},{"key":"E","name":"Playful / Trickster","description":"Fizz hops into the air, landing gracefully upon his spear and becoming untargetable. From this position, Fizz can either slam the ground or choose to jump again before smashing back down.","max_rank":5,"range_burn":[400],"cooldown_burn":[16,14,12,10,8],"cost_burn":[90,95,100,105,110],"tooltip":"Fizz hops onto his trident, becoming Untargetable for 0.75 seconds, after which he deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies and \\u003cstatus\\u003eSlows\\u003c/status\\u003e them by 40/45/50/55/60% for 2 seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eFizz can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability while Untargetable to dash again, which ends the effect early, deals damage in a smaller area, and doesn\'t \\u003cstatus\\u003eSlow\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FizzE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0105/ability_0105_E1.webm"},{"key":"R","name":"Chum the Waters","description":"Fizz tosses a fish in a direction that attaches to any champion that touches it, slowing the target. After a short delay, a shark erupts from the ground, knocking up the target and knocking any nearby enemies aside. All enemies hit are dealt magic damage and slowed.","max_rank":3,"range_burn":[1300],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Fizz launches a fish that attaches to the first champion hit. The victim is afflicted with \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e and \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by between 40% to 80% based on how far the fish travelled before attaching. \\u003cbr /\\u003e\\u003cbr /\\u003eAfter ? seconds a shark erupts on the target, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e the target with the fish for 1 second, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e everything else, and dealing between \\u003cmagicDamage\\u003e? to ? magic damage\\u003c/magicDamage\\u003e based on how far the fish travelled before attaching.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FizzR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0105/ability_0105_R1.webm"}]},"106":{"id":106,"key":"Volibear","name":"Volibear","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Volibear.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"The Relentless Storm","description":"Volibear\'s Attacks and abilities grant Attack Speed, and eventually cause his Attacks to deal bonus magic damage to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Volibear_Icon_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0106/ability_0106_P1.webm"},"spells":[{"key":"Q","name":"Thundering Smash","description":"Volibear gains speed towards enemies, \\u003cstatus\\u003eStunning\\u003c/status\\u003e and damaging the first one he Attacks.","max_rank":5,"range_burn":[300],"cooldown_burn":[14,13,12,11,10],"cost_burn":[50],"tooltip":"Volibear gains \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, doubled to \\u003cspeed\\u003e?\\u003c/speed\\u003e towards enemy champions for the next ? seconds. While active, Volibear\'s next Attack deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eStuns\\u003c/status\\u003e the target for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eVolibear becomes enraged if an enemy \\u003cstatus\\u003eImmobilizes\\u003c/status\\u003e him before he \\u003cstatus\\u003eStuns\\u003c/status\\u003e a target, ending the Ability early but refreshing its Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VolibearQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0106/ability_0106_Q1.webm"},{"key":"W","name":"Frenzied Maul","description":"Volibear damages an enemy, applying on-hit effects and marking them.  Casting this ability again on the same target deals bonus damage and Heals Volibear.","max_rank":5,"range_burn":[325],"cooldown_burn":[5],"cost_burn":[30,35,40,45,50],"tooltip":"Volibear mauls an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and marking them for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability is used on a marked target, its damage is increased to \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e and Volibear restores \\u003chealing\\u003e? plus ? missing Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VolibearW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0106/ability_0106_W1.webm"},{"key":"E","name":"Sky Splitter","description":"Volibear summons a lightning bolt at a location, dealing damage and Slowing enemies while granting Volibear a Shield if he\'s inside the blast radius.","max_rank":5,"range_burn":[1200],"cooldown_burn":[13],"cost_burn":[60],"tooltip":"Volibear summons a thundercloud that fires a lightning bolt, dealing \\u003cmagicDamage\\u003e? plus ?% max Health magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Volibear is inside the blast zone, he gains a \\u003cshield\\u003e? plus ?% max Health Shield\\u003c/shield\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VolibearE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0106/ability_0106_E1.webm"},{"key":"R","name":"Stormbringer","description":"Volibear leaps to a target location, Slowing and damaging enemies beneath him while gaining bonus Health.  Enemy towers near his landing location become temporarily disabled.","max_rank":3,"range_burn":[550],"cooldown_burn":[160,140,120],"cost_burn":[100],"tooltip":"Volibear transforms and leaps, gaining \\u003chealing\\u003e? Health\\u003c/healing\\u003e and ? Attack Range for the next ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eUpon landing, Volibear cracks the earth, \\u003cstatus\\u003eDisabling\\u003c/status\\u003e nearby towers for ? seconds and dealing \\u003cphysicalDamage\\u003e? physical damage to them\\u003c/physicalDamage\\u003e. Nearby enemies are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?%, decaying over 1 second. Enemies directly underneath Volibear suffer \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VolibearR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0106/ability_0106_R1.webm"}]},"107":{"id":107,"key":"Rengar","name":"Rengar","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Rengar.png","enemy_tips":["Rengar gains an empowered ability when his resource bar is full. Try to confront him when it\'s low.","Rengar\'s passive enables him to leap out of brush, so avoid fighting him when near bushes.","Rengar puts an indicator over the nearest enemy champion when he is camouflaged during his ultimate."],"ally_tips":["Use Rengar\'s ultimate to find and assassinate high priority targets in team fights and skirmishes.","A lot of Rengar\'s power comes from empowered abilities he uses at the right moment - choose wisely!","Make sure to take paths through brush when chasing opponents to take advantage of Rengar\'s passive."],"passive":{"name":"Unseen Predator","description":"While in brush, Rengar leaps at his target with his basic attack. Leaping while at no Ferocity generates Ferocity.\\u003cbr\\u003e\\u003cbr\\u003eAt Max Ferocity, his next ability is empowered. Casting an empowered ability increases Rengar\'s Move Speed for a few seconds.\\u003cbr\\u003e\\u003cbr\\u003eKilling enemy champions awards trophies on Rengar\'s \\u003cfont color=\'#BBFFFF\'\\u003eBonetooth Necklace\\u003c/font\\u003e, granting bonus attack damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Rengar_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0107/ability_0107_P1.webm"},"spells":[{"key":"Q","name":"Savagery","description":"Rengar\'s next attack brutally stabs his target for bonus damage.\\u003cbr\\u003e\\u003cbr\\u003eFerocity effect: deals increased damage and grants Attack Speed.","max_rank":5,"range_burn":[450],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Rengar\'s next 2 Attacks gain \\u003cattackSpeed\\u003e40% Attack Speed\\u003c/attackSpeed\\u003e. The first Attack critically strikes for \\u003cphysicalDamage\\u003e? (%i:scaleAD%%i:scaleCrit%) physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMax Ferocity:\\u003c/keywordMajor\\u003e The first Attack critically strikes for \\u003cphysicalDamage\\u003e? (%i:scaleLevel%%i:scaleAD%%i:scaleCrit%) physical damage\\u003c/physicalDamage\\u003e and grants Rengar \\u003cattackSpeed\\u003e? Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RengarQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0107/ability_0107_Q1.webm"},{"key":"W","name":"Battle Roar","description":"Rengar lets out a battle roar, damaging enemies and healing for some of the recent damage he has taken.\\u003cbr\\u003e\\u003cbr\\u003eFerocity effect: additionally breaks crowd control effects.","max_rank":5,"range_burn":[450],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Rengar roars, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies and restoring \\u003chealing\\u003e50%\\u003c/healing\\u003e of the damage taken in the last 1.5 seconds as Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMax Ferocity:\\u003c/keywordMajor\\u003e Deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and additionally cleanses Rengar of crowd control.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RengarW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0107/ability_0107_W1.webm"},{"key":"E","name":"Bola Strike","description":"Rengar throws a bola, slowing the first target hit for a short duration.\\u003cbr\\u003e\\u003cbr\\u003eFerocity effect: roots the target.","max_rank":5,"range_burn":[1000],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Rengar throws a bola, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit, Revealing and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 30/45/60/75/90% for 1.75 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMax Ferocity:\\u003c/keywordMajor\\u003e Deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eRoots\\u003c/status\\u003e for 1.75 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RengarE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0107/ability_0107_E1.webm"},{"key":"R","name":"Thrill of the Hunt","description":"Rengar\'s predatory instincts take over, \\u003cfont color=\'#cd90ee\'\\u003eCamouflaging\\u003c/font\\u003e him and revealing the nearest enemy champion in a large radius around him. During Thrill of the Hunt, Rengar gains Move Speed and he can leap to the tracked enemy without being in brush, reducing their armor.","max_rank":3,"range_burn":[2500,3000,3500],"cooldown_burn":[110,100,90],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Rengar will also leap attack when \\u003ckeywordStealth\\u003eCamouflaged\\u003c/keywordStealth\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Rengar gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e and \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e in a small area around the nearest enemy champion for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter ? seconds, Rengar becomes \\u003ckeywordStealth\\u003eCamouflaged\\u003c/keywordStealth\\u003e and can leap without being in Brush. Leaping to the nearest champion deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, shreds \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e for ? seconds, and ends this Ability.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RengarR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0107/ability_0107_R1.webm"}]},"110":{"id":110,"key":"Varus","name":"Varus","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Varus.png","enemy_tips":["If you are affected by Blight, Varus\' abilities will deal extra damage to you.","When he gets a kill or assist, Varus temporarily gains Attack Speed and is much more dangerous.","You\'ll get bound in place if a tendril from Varus\' ultimate, Chain of Corruption, reaches you. You can cause the tendril to die however by running far enough away from it."],"ally_tips":["An early point in Blighted Quiver helps harass enemy champions and get killing blows on minions.","During short range fights it\'s sometimes best to fire Piercing Arrow quickly, rather than charging it to full power.","Try to take advantage of Piercing Arrow\'s very long range to snipe at enemy champions before a fight or as they\'re trying to flee."],"passive":{"name":"Living Vengeance","description":"On kill or assist, Varus temporarily gains Attack Speed. This bonus is larger if the enemy is a champion.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/VarusPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0110/ability_0110_P1.webm"},"spells":[{"key":"Q","name":"Piercing Arrow","description":"Varus readies and then fires a powerful shot that gains extra range and damage the longer he spends preparing to fire.","max_rank":5,"range_burn":[925],"cooldown_burn":[16,15,14,13,12],"cost_burn":[65,70,75,80,85],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Varus draws back his next shot, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e himself by 20%. After 4 seconds, if not fired, Varus will cancel the Ability and refund 50% of its Mana cost.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Varus releases the arrow, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, reduced by 15% per enemy hit (minimum 33%). Damage and \\u003ckeywordMajor\\u003eBlight\\u003c/keywordMajor\\u003e detonation effects are increased by up to ?% based on charge time (maximum \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e) .","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VarusQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0110/ability_0110_Q1.webm"},{"key":"W","name":"Blighted Quiver","description":"Passive: Varus\' basic attacks deal bonus magic damage and apply Blight. Varus\' other abilities detonate Blight, dealing magic damage based on the target\'s maximum Health. Active: Varus empowers his next Piercing Arrow.","max_rank":5,"range_burn":[750],"cooldown_burn":[40],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eVarus\' Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and apply a \\u003ckeywordMajor\\u003eBlight\\u003c/keywordMajor\\u003e stack for 6 seconds (max 3 stacks).\\u003cbr /\\u003e\\u003cbr /\\u003eVarus\' other Abilities detonate \\u003ckeywordMajor\\u003eBlight\\u003c/keywordMajor\\u003e stacks dealing \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e per stack (max \\u003cmagicDamage\\u003e? max Health damage\\u003c/magicDamage\\u003e). Detonating \\u003ckeywordMajor\\u003eBlight\\u003c/keywordMajor\\u003e on champions and epic monsters also reduces his basic Abilities\' Cooldowns by ?% of their Maximum per stack.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Varus\' next \\u003cspellName\\u003ePiercing Arrow\\u003c/spellName\\u003e deals an additonal \\u003cmagicDamage\\u003e? missing Health magic damage\\u003c/magicDamage\\u003e, increased up to \\u003cmagicDamage\\u003e? missing Health damage\\u003c/magicDamage\\u003e based on charge time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VarusW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0110/ability_0110_W1.webm"},{"key":"E","name":"Hail of Arrows","description":"Varus fires a hail of arrows that deal physical damage and desecrate the ground. Desecrated ground slows enemies\' Move Speed and reduces their self healing and regeneration.","max_rank":5,"range_burn":[925],"cooldown_burn":[18,16,14,12,10],"cost_burn":[80],"tooltip":"Varus fires a hail of arrows that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and desecrates the ground for 4 seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies by 25/30/35/40/45% and applying ?% Grievous Wounds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VarusE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0110/ability_0110_E1.webm"},{"key":"R","name":"Chain of Corruption","description":"Varus flings out a damaging tendril of corruption that immobilizes the first enemy champion hit and then spreads towards nearby uninfected champions, immobilizing them too on contact.","max_rank":3,"range_burn":[1300],"cooldown_burn":[100,80,60],"cost_burn":[100],"tooltip":"Varus flings out a tendril of corruption, \\u003cstatus\\u003eRooting\\u003c/status\\u003e the first champion hit for 2 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. \\u003cstatus\\u003eRooted\\u003c/status\\u003e enemies gain 3 \\u003ckeywordMajor\\u003eBlight\\u003c/keywordMajor\\u003e stacks over the duration.\\u003cbr /\\u003e\\u003cbr /\\u003eThe corruption spreads from its target to uninfected enemy champions. If it reaches them, they take the same damage and \\u003cstatus\\u003eRoot\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VarusR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0110/ability_0110_R1.webm"}]},"111":{"id":111,"key":"Nautilus","name":"Nautilus","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nautilus.png","enemy_tips":["If Nautilus uses Riptide right next to you, hold in place until the ripple effect finishes before running. Running early will run straight into the secondary explosions, causing you to take additional damage and slow.","While Nautilus is shielded, he is capable of dealing large amounts of area of effect damage with his basic attacks - consider taking down the shield if you have time."],"ally_tips":["While ganking, consider aiming Dredge Line at nearby terrain and following it up with Riptide for a higher hit rate.","Riptide has a delayed blast timing on activation - you can use this while running away or when enemies are incoming to serve as a deterrent."],"passive":{"name":"Staggering Blow","description":"Nautilus\' first Attack against a target deals increased physical damage and roots them briefly.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Nautilus_StaggeringBlow.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0111/ability_0111_P1.webm"},"spells":[{"key":"Q","name":"Dredge Line","description":"Nautilus hurls his anchor forward.  Colliding with an enemy pulls them and Nautilus together, dealing magic damage.  Colliding with terrain pulls Nautilus towards it.","max_rank":5,"range_burn":[1150],"cooldown_burn":[14,13,12,11,10],"cost_burn":[60],"tooltip":"Nautilus hurls his anchor forward. If it hits an enemy, Nautilus drags himself and the target together, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e them briefly. If the anchor hits terrain, Nautilus will drag himself towards it.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NautilusAnchorDrag.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0111/ability_0111_Q1.webm"},{"key":"W","name":"Titan\'s Wrath","description":"Nautilus gains a temporary Shield.  While it persists, his Attacks deal damage over time to his target and surrounding enemies.","max_rank":5,"range_burn":[350],"cooldown_burn":[12],"cost_burn":[80],"tooltip":"Nautilus gains a \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds. While the \\u003cshield\\u003eShield\\u003c/shield\\u003e persists, Nautilus\' Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 2 seconds to his target and all surrounding enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NautilusPiercingGaze.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0111/ability_0111_W1.webm"},{"key":"E","name":"Riptide","description":"Nautilus creates three exploding waves around himself. Each explosion damages and slows enemies.","max_rank":5,"range_burn":[600],"cooldown_burn":[7,6,6,5,5],"cost_burn":[50,60,70,80,90],"tooltip":"Nautilus creates three exploding waves around himself, each dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies in the area and \\u003cstatus\\u003eSlows\\u003c/status\\u003e them by ?% decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NautilusSplashZone.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0111/ability_0111_E1.webm"},{"key":"R","name":"Depth Charge","description":"Nautilus fires a shockwave into the earth that chases an opponent. This shockwave rips up the earth above it, knocking enemies into the air. When it reaches the opponent, the shockwave erupts, knocking his target into the air and stunning them.","max_rank":3,"range_burn":[825],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Nautilus fires a shockwave that chases an enemy champion, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them \\u003cstatus\\u003eUp\\u003c/status\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e them for ? seconds. Other enemies hit by the shockwave are also \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e and \\u003cstatus\\u003eStunned\\u003c/status\\u003e and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NautilusGrandLine.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0111/ability_0111_R1.webm"}]},"112":{"id":112,"key":"Viktor","name":"Viktor","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Viktor.png","enemy_tips":["Be careful about how close you let Viktor get to you. Viktor\'s control of the battlefield increases with his proximity to his opponent.","Be aware of how many augments Viktor has upgraded by looking at the color of the light on his staff (purple, yellow, blue, red)."],"ally_tips":["Death Ray is a powerful poke and a strong area of denial tool. Use it in combination with Gravity Field to control your enemy\'s position.","Make sure you choose the right augment at the right time."],"passive":{"name":"Glorious Evolution","description":"Viktor can augment his basic abilities when he gets kills on enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Viktor_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0112/ability_0112_P1.webm"},"spells":[{"key":"Q","name":"Siphon Power","description":"Viktor blasts an enemy unit dealing magic damage, gaining a shield and empowering his next basic attack.\\u003cbr\\u003e\\u003cbr\\u003eAugment: Siphon Power\'s shield is increased by 60% and Viktor gains bonus Move Speed after casting.","max_rank":5,"range_burn":[600],"cooldown_burn":[9,8,7,6,5],"cost_burn":[45,50,55,60,65],"tooltip":"Viktor blasts an enemy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and granting Viktor \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eViktor\'s next Attack within 3.5 seconds deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eUpgraded:\\u003c/keywordMajor\\u003e Grants \\u003cshield\\u003e? Shield\\u003c/shield\\u003e and Viktor additionally gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViktorPowerTransfer.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0112/ability_0112_Q1.webm"},{"key":"W","name":"Gravity Field","description":"Viktor conjures a heavy gravitational field that slows enemies in its radius. Enemies who stay within the device for too long are stunned.\\u003cbr\\u003e\\u003cbr\\u003eAugment: Viktor\'s non-periodic spells apply a slow to enemies.","max_rank":5,"range_burn":[800],"cooldown_burn":[17,16,15,14,13],"cost_burn":[65],"tooltip":"Viktor deploys a gravitational imprisonment device for ? seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies inside by ?%. Enemies inside for 1.5 seconds are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eUpgraded Passive:\\u003c/keywordMajor\\u003e Viktor\'s non-ultimate Abilities \\u003cstatus\\u003eSlow\\u003c/status\\u003e by ?% for 1 second.\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViktorGravitonField.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0112/ability_0112_W1.webm"},{"key":"E","name":"Death Ray","description":"Viktor uses his robotic arm to fire a chaos beam that cuts across the field in a line, dealing damage to all enemies in its path.\\u003cbr\\u003e\\u003cbr\\u003eAugment: An explosion follows the Death Ray\'s wake, dealing magic damage.","max_rank":5,"range_burn":[525],"cooldown_burn":[12,11,10,9,8],"cost_burn":[70,80,90,100,110],"tooltip":"Viktor fires a death ray in a chosen direction, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies hit.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eUpgraded:\\u003c/keywordMajor\\u003e An aftershock follows the death ray, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViktorDeathRay.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0112/ability_0112_E1.webm"},{"key":"R","name":"Chaos Storm","description":"Viktor conjures a singularity on the field which deals magic damage and interrupts enemy channels. The singularity then periodically does magic damage to all nearby enemies. Viktor can redirect the singularity.\\u003cbr\\u003e\\u003cbr\\u003eAugment: The Chaos Storm moves 25% faster.","max_rank":3,"range_burn":[700],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Viktor conjures a chaos storm in an area for ? seconds, instantly dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e then dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e per second to surrouding enemies. The storm automatically follows champions it has recently damaged.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Viktor manually moves the storm.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eUpgrade:\\u003c/keywordMajor\\u003e The storm moves ?% faster.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViktorChaosStorm.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0112/ability_0112_R1.webm"}]},"113":{"id":113,"key":"Sejuani","name":"Sejuani","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sejuani.png","enemy_tips":["Dodging Arctic Assault and Glacial Prison can give you a huge advantage.","Focus on avoiding the second swing of Winter\'s Wrath which carries the brunt of the damage.","Melee enemies can also stack Frost for Sejuani, be very careful around them."],"ally_tips":["Use Arctic Assault to escape bad situations, interupt channeled spells or chase runners.","Melee allies can stack Frost for your Permafrost, keep an eye on who they are attacking.","Save Glacial Prison for encounters where you have teammates present to take advantage of it."],"passive":{"name":"Fury of the North","description":"After being out of combat, Sejuani gains Frost Armor which grants Armor and Magic Resist and immunity to slows. Frost Armor persists for a short time after Sejuani takes damage.  Sejuani can damage a stunned enemy to shatter it, dealing massive magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Sejuani_passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0113/ability_0113_P1.webm"},"spells":[{"key":"Q","name":"Arctic Assault","description":"Sejuani charges forward, knocking enemies into the air. The charge stops after hitting an enemy champion.","max_rank":5,"range_burn":[650],"cooldown_burn":[18,16,15,13,12],"cost_burn":[70,75,80,85,90],"tooltip":"Sejuani charges, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies and \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them \\u003cstatus\\u003eUp\\u003c/status\\u003e for 0.5 seconds. The charge ends after hitting an enemy champion.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SejuaniQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0113/ability_0113_Q1.webm"},{"key":"W","name":"Winter\'s Wrath","description":"Sejuani swings her mace twice, dealing damage, slowing enemies and applying Frost stacks.","max_rank":5,"range_burn":[600],"cooldown_burn":[9,8,7,6,5],"cost_burn":[65],"tooltip":"Sejuani swings her flail, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e minions and jungle monsters. She then lashes out again, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and briefly \\u003cstatus\\u003eSlowing\\u003c/status\\u003e targets.\\u003cbr /\\u003e\\u003cbr /\\u003eBoth swings apply stacks of \\u003cspellName\\u003ePermafrost\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SejuaniW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0113/ability_0113_W1.webm"},{"key":"E","name":"Permafrost","description":"Sejuani freezes and stuns an enemy champion that has maximum Frost stacks.","max_rank":5,"range_burn":[560],"cooldown_burn":[1],"cost_burn":[20],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Nearby melee allied champions\' Attacks apply a stack to champions and jungle monsters.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive:\\u003c/spellPassive\\u003e Sejuani deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to target enemy with 4 stacks and \\u003cstatus\\u003eStuns\\u003c/status\\u003e them for 1 second(s). ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SejuaniE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0113/ability_0113_E1.webm"},{"key":"R","name":"Glacial Prison","description":"Sejuani throws her bola that freezes and stuns the first champion hit and creates an ice storm that slows other enemies.","max_rank":3,"range_burn":[1300],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Sejuani throws her True Ice bola, \\u003cstatus\\u003eStunning\\u003c/status\\u003e and revealing the first enemy champion hit for 1 second and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the bola travels at least 25% of its range, it \\u003cstatus\\u003eStuns\\u003c/status\\u003e and reveals for 1.5 seconds instead. It then also creates an ice storm that \\u003cstatus\\u003eSlows\\u003c/status\\u003e surrounding enemies by 80% for 2 seconds. All affected enemies take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SejuaniR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0113/ability_0113_R1.webm"}]},"114":{"id":114,"key":"Fiora","name":"Fiora","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Fiora.png","enemy_tips":["Duelist\'s Dance shows you where Fiora will try to attack from, so be ready to punish her when she tries.","Be careful when casting immobilizing disables on Fiora. If her Riposte is available, she can turn their power against you."],"ally_tips":["Thanks to Duelist\'s Dance, Fiora excels at quick trades. Use the Move Speed boost from striking a Vital to escape unscathed or set up for the next one.","Grand Challenge allows Fiora to take down even the most durable opponents and then recover if successful, so do not hesitate to attack the enemy\'s front line."],"passive":{"name":"Duelist\'s Dance","description":"Fiora challenges nearby enemy Champions to dodge her. She calls out a direction from which she will try to strike. If she can complete her own challenge, she receives a small bonus and calls out a new direction.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Fiora_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0114/ability_0114_P1.webm"},"spells":[{"key":"Q","name":"Lunge","description":"Fiora lunges in a direction and stabs a nearby enemy, dealing physical damage and applying on-hit effects.","max_rank":5,"range_burn":[400],"cooldown_burn":[13,11,9,7,6],"cost_burn":[20,25,30,35,40],"tooltip":"Fiora lunges in a direction and stabs the closest enemy, ward, or structure, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. The strike will prioritize \\u003ckeywordMajor\\u003eVitals\\u003c/keywordMajor\\u003e and enemies it will kill.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Fiora strikes an enemy, this Ability\'s Cooldown is reduced by 50%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FioraQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0114/ability_0114_Q1.webm"},{"key":"W","name":"Riposte","description":"Fiora parries all incoming damage and disables for a short time, then stabs in a direction. This stab slows the first enemy champion hit, or stuns them if Fiora blocked an immobilizing effect with this ability.","max_rank":5,"range_burn":[750],"cooldown_burn":[24,22,20,18,16],"cost_burn":[50],"tooltip":"Fiora parries all incoming damage, disables, and negative effects for 0.75 seconds, then stabs. The stab deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first champion hit and \\u003cstatus\\u003eSlows\\u003c/status\\u003e both Move Speed and Attack Speed by 50% for 2 seconds. If Fiora parries an \\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e effect, the stabbed enemy is \\u003cstatus\\u003eStunned\\u003c/status\\u003e rather than \\u003cstatus\\u003eSlowed\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FioraW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0114/ability_0114_W1.webm"},{"key":"E","name":"Bladework","description":"Fiora has increased attack speed for the next two attacks. The first attack slows the target, and the second attack will critically strike.","max_rank":5,"range_burn":[425],"cooldown_burn":[11,10,9,8,7],"cost_burn":[40],"tooltip":"Fiora gains \\u003cattackSpeed\\u003e50/60/70/80/90% Attack Speed\\u003c/attackSpeed\\u003e for her next two Attacks. The first Attack \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 30% for 1 second. The second Attack always critically strikes for \\u003cphysicalDamage\\u003e?% damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FioraE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0114/ability_0114_E1.webm"},{"key":"R","name":"Grand Challenge","description":"Fiora reveals all four Vitals on an enemy champion and gains Move Speed while near them. If Fiora hits all 4 Vitals or if the target dies after she has hit at least one, Fiora and her allies in the area are healed over the next few seconds.","max_rank":3,"range_burn":[500],"cooldown_burn":[110,90,70],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e \\u003cspellName\\u003eDuelist\'s Dance\\u003c/spellName\\u003e \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e bonus is increased to ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Fiora reveals all 4 \\u003ckeywordMajor\\u003eVitals\\u003c/keywordMajor\\u003e on a champion for a max of \\u003ctrueDamage\\u003e? max Health true damage\\u003c/trueDamage\\u003e and gains \\u003cspellName\\u003eDuelist\'s Dance\\u003c/spellName\\u003e\'s Move Speed bonus while near the target.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Fiora strikes all 4 \\u003ckeywordMajor\\u003eVitals\\u003c/keywordMajor\\u003e within ? seconds or if the target dies after she has hit at least one, Fiora restores \\u003chealing\\u003e? Health per second\\u003c/healing\\u003e to surrounding allied champions for between ? to ? seconds, scaling with the number of \\u003ckeywordMajor\\u003eVitals\\u003c/keywordMajor\\u003e hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/FioraR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0114/ability_0114_R1.webm"}]},"115":{"id":115,"key":"Ziggs","name":"Ziggs","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ziggs.png","enemy_tips":["Don\'t step on Ziggs\' mines! They\'ll slow you and make it much easier for him to hit you with his other abiltiies.","Many of Ziggs\' abilities have long cooldowns. Try catching him just after he\'s used his abilities.","Ziggs\' ultimate, Mega Inferno Bomb, deals more damage in the center of the explosion."],"ally_tips":["Even if you\'re far from a fight you can still help from afar with Mega Inferno Bomb.","Slowing your enemies with Hexplosive Minefield makes it easier to land other abilities.","Knocking yourself over walls with Satchel Charge can be great when chasing after or escaping from enemies."],"passive":{"name":"Short Fuse","description":"Periodically, Ziggs\' next basic attack deals bonus magic damage. This cooldown is reduced whenever Ziggs uses an ability.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ZiggsPassiveReady.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0115/ability_0115_P1.webm"},"spells":[{"key":"Q","name":"Bouncing Bomb","description":"Ziggs throws a bouncing bomb that deals magic damage.","max_rank":5,"range_burn":[850],"cooldown_burn":[6,5,5,4,4],"cost_burn":[50,55,60,65,70],"tooltip":"Ziggs throws a bouncing bomb that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZiggsQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0115/ability_0115_Q1.webm"},{"key":"W","name":"Satchel Charge","description":"Ziggs flings an explosive charge that detonates after 4 seconds, or when this ability is activated again. The explosion deals magic damage to enemies, knocking them away. Ziggs is also knocked away, but takes no damage. Ziggs can use the Satchel to hexplode vulnerable enemy turrets.","max_rank":5,"range_burn":[1000],"cooldown_burn":[20,18,16,14,12],"cost_burn":[65],"tooltip":"Ziggs flings an explosive charge that detonates after 4 seconds, or when this ability is \\u003crecast\\u003eRecast\\u003c/recast\\u003e. It deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies and \\u003cstatus\\u003eKnocks\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e. Ziggs is also knocked away, but takes no damage.\\u003cbr /\\u003e\\u003cbr /\\u003eSatchel Charge will automatically destroy towers below {{ f1*100 }}% of their Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZiggsW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0115/ability_0115_W1.webm"},{"key":"E","name":"Hexplosive Minefield","description":"Ziggs scatters proximity mines that detonate on enemy contact, dealing magic damage and slowing. Successive mine detonations on the same target deal reduced damage.","max_rank":5,"range_burn":[900],"cooldown_burn":[16],"cost_burn":[70,80,90,100,110],"tooltip":"Ziggs scatters proximity mines that detonate on enemy contact, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 10/20/30/40/50% for 1.5 seconds. Mines last 10 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZiggsE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0115/ability_0115_E1.webm"},{"key":"R","name":"Mega Inferno Bomb","description":"Ziggs deploys his ultimate creation, the Mega Inferno Bomb, hurling it an enormous distance. Enemies in the primary blast zone take more damage than those farther away.","max_rank":3,"range_burn":[5000],"cooldown_burn":[120,95,70],"cost_burn":[100],"tooltip":"Ziggs hurls his ultimate creation, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e in the center of the blast radius, or \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e at the edge.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZiggsR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0115/ability_0115_R1.webm"}]},"117":{"id":117,"key":"Lulu","name":"Lulu","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Lulu.png","enemy_tips":["The shots from Lulu\'s faerie can be intercepted - hide behind your minions to avoid the additional Faerie attacks.","Lulu excels when opponents heavily commit. Don\'t give her this chance! Use heavy harass tactics instead to force Lulu and her partner out of lane."],"ally_tips":["Glitterlance can be fired at odd angles depending on where your cursor is - Moving your cursor closer to Pix and Lulu will change your area of effect size considerably.","Consider casting Help, Pix! on ranged attackers for the Pix boost and Wild Growth on Tanks or Fighters for the added initiation power."],"passive":{"name":"Pix, Faerie Companion","description":"Pix fires magical bolts of energy whenever the champion he\'s following attacks another enemy unit. These bolts are homing, but can be intercepted by other units.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Lulu_PixFaerieCompanion.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0117/ability_0117_P1.webm"},"spells":[{"key":"Q","name":"Glitterlance","description":"Pix and Lulu each fire a bolt of magical energy that damages and heavily slows all enemies it hits.","max_rank":5,"range_burn":[925],"cooldown_burn":[7],"cost_burn":[50,55,60,65,70],"tooltip":"Lulu and Pix each fire a piercing bolt dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 80%, decaying over 2 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies take ?% more damage from additional bolts.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuluQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0117/ability_0117_Q1.webm"},{"key":"W","name":"Whimsy","description":"If cast on an ally, grants them Attack Speed and Move Speed for a short time. If cast on an enemy, turns them into an adorable critter that can\'t attack or cast spells.","max_rank":5,"range_burn":[650],"cooldown_burn":[17,16,15,14,13],"cost_burn":[65],"tooltip":"When used on an ally, Lulu grants \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e and \\u003cattackSpeed\\u003e25/27.5/30/32.5/35% Attack Speed\\u003c/attackSpeed\\u003e for 3/3.25/3.5/3.75/4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen used on an enemy, Lulu \\u003cstatus\\u003ePolymorphs\\u003c/status\\u003e them for 1.25/1.5/1.75/2/2.25 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuluW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0117/ability_0117_W1.webm"},{"key":"E","name":"Help, Pix!","description":"If cast on an ally, commands Pix to jump to an ally and shield them. He then follows them and aids their attacks. If cast on an enemy, commands Pix to jump to an enemy and damage them. He then follows them and grants you vision of that enemy.","max_rank":5,"range_burn":[650],"cooldown_burn":[8],"cost_burn":[60,65,70,75,80],"tooltip":"When used on an ally, Pix jumps to them and grants \\u003cspellName\\u003ePix, Faerie Companion\\u003c/spellName\\u003e for 6 seconds. If the ally is a champion, Pix also grants \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 2.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen used on an enemy champion, Pix hampers them, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and granting \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of them for 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuluE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0117/ability_0117_E1.webm"},{"key":"R","name":"Wild Growth","description":"Lulu enlarges an ally, knocking nearby enemies into the air and granting the ally a large amount of bonus health. For the next few seconds, that ally gains an aura that slows nearby enemies.","max_rank":3,"range_burn":[900],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Lulu enlarges an ally, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e surrounding enemies for ? seconds. The enlarged ally gains \\u003chealing\\u003e? max Health\\u003c/healing\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e surrounding enemies by ?% for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LuluR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0117/ability_0117_R1.webm"}]},"119":{"id":119,"key":"Draven","name":"Draven","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Draven.png","enemy_tips":["Launch skillshots toward the landing position of Draven\'s Spinning Axes.","Disrupt Draven with the goal of making him drop his axes. If you do, his power drops dramatically."],"ally_tips":["If Draven doesn\'t move, Spinning Axe will fall near his present location. It will fall directly on him, or just to the right or left.","If Draven does move after attacking, Spinning Axe will lead him in the direction of his movement. Use this to control where the Spinning Axe will go."],"passive":{"name":"League of Draven","description":"Draven gains his fans\' Adoration when he catches a Spinning Axe or kills a minion, monster, or tower. Killing enemy champions grants Draven bonus gold based on how much Adoration he has.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Draven_passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0119/ability_0119_P1.webm"},"spells":[{"key":"Q","name":"Spinning Axe","description":"Draven\'s next attack will deal bonus physical damage. This axe will ricochet off the target high up into the air. If Draven catches it, he automatically readies another Spinning Axe. Draven can have two Spinning Axes at once.","max_rank":5,"range_burn":[300],"cooldown_burn":[12,11,10,9,8],"cost_burn":[45],"tooltip":"Draven readies a \\u003ckeywordMajor\\u003eSpinning Axe\\u003c/keywordMajor\\u003e, causing his next Attack to deal an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and ricochet into the air. If Draven catches it, he readies another \\u003ckeywordMajor\\u003eSpinning Axe\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eDraven can hold two \\u003ckeywordMajor\\u003eSpinning Axes\\u003c/keywordMajor\\u003e at once.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DravenSpinning.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0119/ability_0119_Q1.webm"},{"key":"W","name":"Blood Rush","description":"Draven gains increased Move Speed and Attack Speed. The Move Speed bonus decreases rapidly over its duration. Catching a Spinning Axe will refresh the cooldown of Blood Rush.","max_rank":5,"range_burn":[1000],"cooldown_burn":[12],"cost_burn":[40,35,30,25,20],"tooltip":"Draven becomes Ghosted, gains \\u003cspeed\\u003e50/55/60/65/70% Move Speed\\u003c/speed\\u003e decaying over 1.5 seconds and \\u003cattackSpeed\\u003e20/25/30/35/40% Attack Speed\\u003c/attackSpeed\\u003e for 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen Draven catches a \\u003ckeywordMajor\\u003eSpinning Axe\\u003c/keywordMajor\\u003e, this Ability\'s Cooldown is refreshed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DravenFury.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0119/ability_0119_W1.webm"},{"key":"E","name":"Stand Aside","description":"Draven throws his axes, dealing physical damage to targets hit and knocking them aside. Targets hit are slowed.","max_rank":5,"range_burn":[1050],"cooldown_burn":[18,17,16,15,14],"cost_burn":[70],"tooltip":"Draven chucks a sideways axe that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, \\u003cstatus\\u003eKnocks Back\\u003c/status\\u003e, and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 20/25/30/35/40% for 2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DravenDoubleShot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0119/ability_0119_E1.webm"},{"key":"R","name":"Whirling Death","description":"Draven hurls two massive axes to deal physical damage to each unit struck. Whirling Death slowly reverses direction and returns to Draven after striking an enemy champion. Draven may also activate this ability while the axes are in flight to cause it to return early. Deals less damage for each unit hit and resets when the axes reverse direction. Executes enemies who have less health than Draven\'s number of Adoration stacks.","max_rank":3,"range_burn":[20000],"cooldown_burn":[100,90,80],"cost_burn":[100],"tooltip":"Draven hurls two massive axes that deal \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Upon hitting a champion or \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, they reverse direction and return to Draven. The axes deal ?% less damage for each enemy hit, down to a minimum of ?%.\\u003cbr /\\u003e\\u003cbr /\\u003eIf \\u003ckeywordMajor\\u003eWhirling Death\\u003c/keywordMajor\\u003e would leave an enemy champion with less health than ?% of Draven\'s current \\u003ckeywordMajor\\u003eLeague of Draven\\u003c/keywordMajor\\u003e stacks (?), he will execute them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DravenRCast.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0119/ability_0119_R1.webm"}]},"120":{"id":120,"key":"Hecarim","name":"Hecarim","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Hecarim.png","enemy_tips":["Hecarim gains life from nearby enemies with Spirit of Dread but lacks durability, use burst damage.","Hecarim\'s ultimate causes opponents to flee in terror. Spread out to reduce his power in fights."],"ally_tips":["Spirit of Dread restores Health when nearby enemies take damage, including damage dealt by allies. Cast this during a large fight to maximize Hecarim\'s survivability.","Devastating Charge deals more damage based on the distance traveled. Try using Onslaught of Shadows or Summoner Spells such as Ghost or Flash to maximize this damage."],"passive":{"name":"Warpath","description":"Hecarim gains Attack Damage equal to a percentage of his bonus Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Hecarim_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0120/ability_0120_P1.webm"},"spells":[{"key":"Q","name":"Rampage","description":"Hecarim cleaves nearby enemies dealing physical damage. If Hecarim damages at least one enemy, he increases the damage and lowers the cooldown of subsequent Rampages.","max_rank":5,"range_burn":[350],"cooldown_burn":[4],"cost_burn":[28,31,34,37,40],"tooltip":"Hecarim cleaves nearby enemies for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If this Ability hits, he gains a stack that decreases its Cooldown by ? second and increases its damage by ?% for 6 seconds. Stacks up to ? times.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HecarimRapidSlash.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0120/ability_0120_Q1.webm"},{"key":"W","name":"Spirit of Dread","description":"Hecarim deals magic damage to nearby enemies for a short duration. Hecarim gains Health equal to a percentage of any damage those enemies suffer.","max_rank":5,"range_burn":[525],"cooldown_burn":[14],"cost_burn":[50,60,70,80,90],"tooltip":"Hecarim deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds to nearby enemies, and heals for \\u003chealing\\u003e?% of damage\\u003c/healing\\u003e these enemies take from Hecarim and \\u003chealing\\u003e?% of damage\\u003c/healing\\u003e taken from his allies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HecarimW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0120/ability_0120_W1.webm"},{"key":"E","name":"Devastating Charge","description":"Hecarim gains increasing Move Speed and can move through units for a short duration. His next attack knocks the target back and deals additional physical damage based on the distance he has traveled since activating the ability.","max_rank":5,"range_burn":[300],"cooldown_burn":[20,19,18,17,16],"cost_burn":[60],"tooltip":"Hecarim becomes Ghosted and gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e increasing to \\u003cspeed\\u003e?%\\u003c/speed\\u003e over 4 seconds. His next Attack \\u003cstatus\\u003eKnocks Back\\u003c/status\\u003e and deals between \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. \\u003cstatus\\u003eKnock Back\\u003c/status\\u003e distance and damage scales with distance travelled during this Ability.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HecarimRamp.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0120/ability_0120_E1.webm"},{"key":"R","name":"Onslaught of Shadows","description":"Hecarim summons spectral riders and charges forward, dealing magic damage in a line. Hecarim creates a shockwave when he finishes his charge, causing nearby enemies to flee in terror.","max_rank":3,"range_burn":[50000],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Hecarim summons spectral riders and charges forward, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Hecarim unleashes a shockwave at the end of the charge that \\u003cstatus\\u003eFears\\u003c/status\\u003e for between ? to ? seconds, increased by charge distance.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/HecarimUlt.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0120/ability_0120_R1.webm"}]},"121":{"id":121,"key":"Khazix","name":"Kha\'Zix","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Khazix.png","enemy_tips":["Taste Their Fear deals bonus damage to targets that are isolated. Gain an advantage by fighting near allied minions, champions, or turrets.","Leap and Void Assault have long cooldowns. Kha\'Zix is very vulnerable when these are not available."],"ally_tips":["Enemies are considered isolated if they have no allies within a short distance. The damage of Taste Their Fear is massively increased against these targets.","Unseen Threat activates when Kha\'Zix cannot be seen by the enemy team. Reactivate by using brush or Void Assault. Don\'t forget to apply Unseen Threat by autoattacking enemy champions.","Kha\'Zix has a great deal of freedom to choose where and when to fight. Pick your battles carefully to succeed."],"passive":{"name":"Unseen Threat","description":"Nearby enemies that are \\u003cfont color=\'#FFF673\'\\u003eIsolated\\u003c/font\\u003e from their allies are marked. Kha\'Zix\'s abilities have interactions with \\u003cfont color=\'#FFF673\'\\u003eIsolated\\u003c/font\\u003e targets.\\u003cbr\\u003e\\u003cbr\\u003eWhen Kha\'Zix is not visible to the enemy team, he gains Unseen Threat, causing his next basic attack against an enemy champion to deal bonus magic damage and slow them for a few seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Khazix_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0121/ability_0121_P1.webm"},"spells":[{"key":"Q","name":"Taste Their Fear","description":"Deals physical damage to the target. Damage increased on \\u003cfont color=\'#FFF673\'\\u003eIsolated\\u003c/font\\u003e targets. If he chooses to \\u003cfont color=\'#00DD33\'\\u003eEvolve Reaper Claws\\u003c/font\\u003e, this refunds a percent of it\'s cooldown against \\u003cfont color=\'#FFF673\'\\u003eIsolated\\u003c/font\\u003e targets. Kha\'Zix also gains increased range on his basic attacks and Taste Their Fear.","max_rank":5,"range_burn":[325],"cooldown_burn":[4],"cost_burn":[20],"tooltip":"Kha\'zix slashes a nearby enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. This deals \\u003cphysicalDamage\\u003e? damage\\u003c/physicalDamage\\u003e instead to enemies \\u003ckeywordMajor\\u003eIsolated\\u003c/keywordMajor\\u003e from their allies. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KhazixQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0121/ability_0121_Q1.webm"},{"key":"W","name":"Void Spike","description":"Kha\'Zix fires exploding spikes that deal physical damage to enemies hit. Kha\'Zix is healed if he is also within the explosion radius. If he chooses to \\u003cfont color=\'#00DD33\'\\u003eEvolve Spike Racks\\u003c/font\\u003e, Void Spike now fires three spikes in a cone, slow enemies hit, and reveals enemy champions hit for 2 seconds. \\u003cfont color=\'#FFF673\'\\u003eIsolated\\u003c/font\\u003e targets are slowed for extra.","max_rank":5,"range_burn":[1000],"cooldown_burn":[9],"cost_burn":[55,60,65,70,75],"tooltip":"Kha\'Zix fires a spike dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit in a small area. If Kha\'Zix is inside the area, he restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KhazixW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0121/ability_0121_W1.webm"},{"key":"E","name":"Leap","description":"Kha\'Zix leaps to an area, dealing physical damage upon landing. If he chooses to \\u003cfont color=\'#00DD33\'\\u003eEvolve Wings\\u003c/font\\u003e, Leap\'s range increases by 200 and the cooldown resets on champion kill or assist.","max_rank":5,"range_burn":[700],"cooldown_burn":[20,18,16,14,12],"cost_burn":[50],"tooltip":"Kha\'Zix leaps, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e upon landing.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KhazixE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0121/ability_0121_E1.webm"},{"key":"R","name":"Void Assault","description":"Each rank allows Kha\'Zix to evolve one of his abilities, giving it a unique additional effect. When activated, Kha\'Zix becomes \\u003cfont color=\'#91d7ee\'\\u003eInvisible\\u003c/font\\u003e, triggering Unseen Threat and increasing Move Speed. If he chooses to \\u003cfont color=\'#00DD33\'\\u003eEvolve Adaptive Cloaking\\u003c/font\\u003e, Void Assault gains increased \\u003cfont color=\'#91d7ee\'\\u003eInvisibility\\u003c/font\\u003e duration, and an additional use.","max_rank":3,"range_burn":[25000],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kha\'Zix becomes \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e for ? seconds and gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e. Kha\'zix may \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability once within 10 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Leveling up this Ability allows Kha\'zix to \\u003cevolve\\u003eEvolve\\u003c/evolve\\u003e one of his Abilities, granting it additional effects.\\u003cli\\u003e\\u003cspellName\\u003eTaste Their Fear:\\u003c/spellName\\u003e Gain Ability range, Attack range, and lowers Cooldown by ?% against \\u003ckeywordMajor\\u003eIsolated\\u003c/keywordMajor\\u003e targets.\\u003cli\\u003e\\u003cspellName\\u003eVoid Spike:\\u003c/spellName\\u003e Fires 3 spikes and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?%, increased against \\u003ckeywordMajor\\u003eIsolated\\u003c/keywordMajor\\u003e targets.\\u003cli\\u003e\\u003cspellName\\u003eLeap:\\u003c/spellName\\u003e Increased range and refreshes Cooldown on champion takedown.\\u003cli\\u003e\\u003cspellName\\u003eVoid Assault:\\u003c/spellName\\u003e \\u003ckeywordStealth\\u003eInvisibility\\u003c/keywordStealth\\u003e duration lasts ? seconds and gains second \\u003crecast\\u003eRecast\\u003c/recast\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KhazixR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0121/ability_0121_R1.webm"}]},"122":{"id":122,"key":"Darius","name":"Darius","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Darius.png","enemy_tips":["When Darius\'s axe grab is on cooldown, he is vulnerable to harassment attacks.","Darius\'s ability to escape from fights is limited. If you have an advantage against him, press your lead."],"ally_tips":["Decimate is a powerful harassment ability. Strike an enemy from maximum range for the greatest effect.","Noxian Guillotine does more damage the more attacks you can land prior to it. Use Noxian Might to deal maximum damage.","Darius benefits greatly from enhanced survivability. The longer you can prolong a fight, the more powerful he becomes."],"passive":{"name":"Hemorrhage","description":"Darius\' attacks and damaging abilities cause enemies to bleed for physical damage over 5 seconds, stacking up to 5 times. Darius enrages and gains massive Attack Damage when his target reaches max stacks.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Darius_Icon_Hemorrhage.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0122/ability_0122_P1.webm"},"spells":[{"key":"Q","name":"Decimate","description":"Darius winds up and swings his axe in a wide circle. Enemies struck by the blade take more damage than those struck by the handle. Darius heals based on enemy champions and large monsters hit by the blade.","max_rank":5,"range_burn":[1],"cooldown_burn":[9,8,7,6,5],"cost_burn":[30,35,40,45,50],"tooltip":"Darius hefts his axe then swings it around, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e with the edge and \\u003cphysicalDamage\\u003e? damage\\u003c/physicalDamage\\u003e with the handle. Enemies hit with the handle do not take a \\u003ckeywordMajor\\u003eHemorrhage\\u003c/keywordMajor\\u003e stack.\\u003cbr /\\u003e\\u003cbr /\\u003eDarius restores \\u003chealing\\u003e13% missing Health\\u003c/healing\\u003e per enemy champion and large jungle monster hit with the edge, up to a max of \\u003chealing\\u003e39%\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DariusCleave.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0122/ability_0122_Q1.webm"},{"key":"W","name":"Crippling Strike","description":"Darius\'s next attack strikes an enemy\'s crucial artery. As they bleed out, their Move Speed is slowed.","max_rank":5,"range_burn":[300],"cooldown_burn":[5],"cost_burn":[40],"tooltip":"Darius\' next Attack deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by 90% for 1 second.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability refunds its Mana cost and reduces its Cooldown by 50% if it kills the target.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DariusNoxianTacticsONH.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0122/ability_0122_W1.webm"},{"key":"E","name":"Apprehend","description":"Darius hones his axe, passively causing his physical damage to ignore a percentage of his target\'s Armor. When activated, Darius sweeps up his enemies with his axe\'s hook and pulls them to him.","max_rank":5,"range_burn":[535],"cooldown_burn":[24,21,19,16,14],"cost_burn":[70,60,50,40,30],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Darius gains 15/20/25/30/35% Armor Penetration.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Darius hooks with his axe, \\u003cstatus\\u003ePulling\\u003c/status\\u003e, and \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 40% for 1 second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DariusAxeGrabCone.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0122/ability_0122_E1.webm"},{"key":"R","name":"Noxian Guillotine","description":"Darius leaps to an enemy champion and strikes a lethal blow, dealing true damage. This damage is increased for each stack of Hemorrhage on the target. If Noxian Guillotine is a killing blow, its cooldown is refreshed for a brief duration.","max_rank":3,"range_burn":[460],"cooldown_burn":[120,100,80],"cost_burn":[100,100,0],"tooltip":"Darius leaps to an enemy and strikes a lethal blow, dealing \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e. For each \\u003ckeywordMajor\\u003eHemorrhage\\u003c/keywordMajor\\u003e on the target, this Ability deals an additional ?% damage, up to a max of \\u003ctrueDamage\\u003e? damage\\u003c/trueDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this kills the target, Darius may \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability once within ? seconds. At rank 3, this Ability has no Mana cost and kills refresh the Cooldown completely.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DariusExecute.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0122/ability_0122_R1.webm"}]},"126":{"id":126,"key":"Jayce","name":"Jayce","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Jayce.png","enemy_tips":["Jayce can attack in melee or at range. Pay attention to his stance and weapon color to know how he is going to attack.","If you see Jayce drop his Acceleration Gate, be careful, he is probably about to cast Shock Blast.","Jayce is strong in the early game. If he gains the advantage, play defensively."],"ally_tips":["Be sure to switch stances often. It will enhance your attacks and grant you quick bursts of speed.","If you find yourself taking lots of damage, try using Jayce\'s Hammer Stance, as it grants you additional defenses.","For increased range and damage, try casting Shock Blast through the Acceleration Gate."],"passive":{"name":"Hextech Capacitor","description":"When Jayce swaps weapons he gains Move Speed for a short duration.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Jayce_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0126/ability_0126_P1.webm"},"spells":[{"key":"Q","name":"To the Skies! / Shock Blast","description":"Hammer Stance: Leaps to an enemy dealing physical damage and slowing enemies.\\u003cbr\\u003e\\u003cbr\\u003eCannon Stance: Fires an orb of electricity that detonates upon hitting an enemy (or reaching the end of its path) dealing physical damage to all enemies hit.","max_rank":6,"range_burn":[600],"cooldown_burn":[16,14,12,10,8,6],"cost_burn":[40],"tooltip":"\\u003ckeywordMajor\\u003eMercury Hammer:\\u003c/keywordMajor\\u003e Jayce leaps to an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to surrounding enemies and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JayceToTheSkies.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0126/ability_0126_Q1.webm"},{"key":"W","name":"Lightning Field / Hyper Charge","description":"Hammer Stance: Passive: Restores Mana per strike. Active: Creates a field of lightning damaging nearby enemies for several seconds.\\u003cbr\\u003e\\u003cbr\\u003eCannon Stance: Gains a burst of energy, increasing Attack Speed to maximum for several attacks.","max_rank":6,"range_burn":[285],"cooldown_burn":[10],"cost_burn":[40],"tooltip":"\\u003ckeywordMajor\\u003eMercury Hammer - Passive:\\u003c/keywordMajor\\u003e Jayce\'s \\u003ckeywordMajor\\u003eHammer\\u003c/keywordMajor\\u003e Attacks grant \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMercury Hammer - Active:\\u003c/keywordMajor\\u003e Jayce creates an electric aura dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JayceStaticField.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0126/ability_0126_W1.webm"},{"key":"E","name":"Thundering Blow / Acceleration Gate","description":"Hammer Stance: Deals magic damage to an enemy and knocks them back a short distance.\\u003cbr\\u003e\\u003cbr\\u003eCannon Stance: Deploys an Acceleration Gate increasing the Move Speed of all allied champions who pass through it. If Shock Blast is fired through the gate the missile speed, range, and damage will increase.","max_rank":6,"range_burn":[240],"cooldown_burn":[20,18,16,14,12,10],"cost_burn":[55],"tooltip":"\\u003ckeywordMajor\\u003eHammer Form\\u003c/keywordMajor\\u003e: Jayce swings his hammer, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e his target and dealing \\u003cmagicDamage\\u003e? plus ?% max Health magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JayceThunderingBlow.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0126/ability_0126_E1.webm"},{"key":"R","name":"Mercury Cannon / Mercury Hammer","description":"Hammer Stance: Transforms the Mercury Hammer into the Mercury Cannon gaining new abilities and increased range. The first attack in this form reduces the target\'s Armor and Magic Resist.\\u003cbr\\u003e\\u003cbr\\u003eCannon Stance: Transforms the Mercury Cannon into the Mercury Hammer gaining new abilities and increasing Armor and Magic Resist. The first attack in this form deals additional magic damage.","max_rank":1,"range_burn":[600],"cooldown_burn":[6],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMercury Hammer\\u003c/keywordMajor\\u003e: Jayce transforms his weapon into the \\u003ckeywordMajor\\u003eMercury Cannon\\u003c/keywordMajor\\u003e, gaining Attack Range and new Abilities. Jayce\'s next Attack removes \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JayceStanceHtG.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0126/ability_0126_R1.webm"}]},"127":{"id":127,"key":"Lissandra","name":"Lissandra","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Lissandra.png","enemy_tips":["The best way to stop Lissandra from moving using her Glacial Path is to immobilize her before she reactivates it.","Lissandra\'s Ring of Frost has a long cooldown at early ranks; engage her while it\'s on cooldown.","Lissandra\'s Ice Shard only slows the first unit it hits. Approach Lissandra from behind your team\'s minions to avoid being slowed."],"ally_tips":["You can instantly use your ultimate on yourself by pressing the self cast key and the ultimate key at once (alt+R by default).","Casting Glacial Path and then running in the opposite direction will leave your enemies uncertain which way you will actually go.","Lissandra\'s abilities are shorter range than those of many mages. As a result, buying items that offer both ability power and defense, like Zhonya\'s Hourglass and Banshee\'s Veil, can be a great choice to help her both survive and deal damage."],"passive":{"name":"Iceborn Subjugation","description":"When an enemy champion dies near Lissandra they become a Frozen Thrall. Frozen Thralls slow nearby enemies and then, after a delay, shatter from the intense cold, dealing magic damage to nearby targets.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Lissandra_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0127/ability_0127_P1.webm"},"spells":[{"key":"Q","name":"Ice Shard","description":"Throws a spear of ice that shatters when it hits an enemy, dealing magic damage and slowing Move Speed. Shards pass through the target, dealing the same damage to other enemies hit.","max_rank":5,"range_burn":[725],"cooldown_burn":[8,7,6,5,4],"cost_burn":[55,60,65,70,75],"tooltip":"Lissandra throws a spear of ice that shatters on the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 16/19/22/25/28% for 1.5 seconds, and also dealing the damage to enemies behind them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LissandraQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0127/ability_0127_Q1.webm"},{"key":"W","name":"Ring of Frost","description":"Freezes nearby enemies in ice, dealing magic damage and rooting them.","max_rank":5,"range_burn":[450],"cooldown_burn":[14,13,12,11,10],"cost_burn":[40],"tooltip":"Lissandra creates an ice field, \\u003cstatus\\u003eRooting\\u003c/status\\u003e nearby enemies for 1.1/1.2/1.3/1.4/1.5 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LissandraW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0127/ability_0127_W1.webm"},{"key":"E","name":"Glacial Path","description":"Lissandra creates an ice claw that deals magic damage. Reactivating this ability transports Lissandra to the claw\'s current location.","max_rank":5,"range_burn":[1050],"cooldown_burn":[24,21,18,15,12],"cost_burn":[80,85,90,95,100],"tooltip":"Lissandra casts forth an ice claw that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Lissandra can \\u003crecast\\u003eRecast\\u003c/recast\\u003e while the claw travels to teleport to its location.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LissandraE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0127/ability_0127_E1.webm"},{"key":"R","name":"Frozen Tomb","description":"If cast on an enemy champion, the target is frozen solid, stunning it. If cast on Lissandra, she encases herself in dark ice, healing herself while becoming untargetable and invulnerable. Dark ice then emanates from the target dealing magic damage to enemies and slowing Move Speed.","max_rank":3,"range_burn":[550],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Lissandra encases herself or an enemy champion in ice. Enemies are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds. When self cast, Lissandra enters Stasis for ? seconds and restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e, increased by ?% for each ?% missing Health.\\u003cbr /\\u003e\\u003cbr /\\u003eIn either case, dark ice eminates from the target, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The ice persists for ? seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies by ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LissandraR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0127/ability_0127_R1.webm"}]},"131":{"id":131,"key":"Diana","name":"Diana","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Diana.png","enemy_tips":["Dodge Crescent Strike, or move to safety if you are affected by Moonlight.","Pale Cascade orbs only last a few seconds. Avoid Diana and engage her after the shield dissipates.","Diana can play very aggressively if she uses Lunar Rush without Moonlight, but you can punish her by slowing or stunning her when she has no way to get back into position."],"ally_tips":["Landing Crescent Strike is critically important, but don\'t be afraid to miss. The cooldown is short and the mana cost is low.","Consider when to cast Lunar Rush without Moonlight and when to wait for another Crescent Strike.","Use Moonfall and Lunar Rush to stay on targets and activate Moonsilver Blade for extra damage."],"passive":{"name":"Moonsilver Blade","description":"Every third strike cleaves nearby enemies for an additional magic damage. After casting a spell, Diana gains Attack Speed for her next 3 attacks.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Diana_Passive_LunarBlade.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0131/ability_0131_P1.webm"},"spells":[{"key":"Q","name":"Crescent Strike","description":"Unleashes a bolt of lunar energy in an arc dealing magic damage.\\u003cbr\\u003e\\u003cbr\\u003eAfflicts enemies struck with Moonlight, revealing them if they are not stealthed for 3 seconds.","max_rank":5,"range_burn":[900],"cooldown_burn":[8,7,7,6,6],"cost_burn":[50],"tooltip":"Diana unleashes an arc of lunar energy, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and marking with \\u003ckeywordMajor\\u003eMoonlight\\u003c/keywordMajor\\u003e for ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMoonlight\\u003c/keywordMajor\\u003e reveals enemies that are not \\u003ckeywordStealth\\u003estealthed\\u003c/keywordStealth\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DianaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0131/ability_0131_Q1.webm"},{"key":"W","name":"Pale Cascade","description":"Diana creates three orbiting spheres that detonate on contact with enemies to deal damage in an area. She also gains a temporary shield that absorbs damage. If her third sphere detonates, the shield gains additional strength.","max_rank":5,"range_burn":[800],"cooldown_burn":[15,13,12,10,9],"cost_burn":[40,45,50,55,60],"tooltip":"Diana creates three orbiting spheres for ? seconds that explode on contact, each dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, up to a max of \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eDiana also gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for the same duration. When the last sphere detonates, she gains an additional \\u003cshield\\u003e? Shield\\u003c/shield\\u003e and refreshes the duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DianaOrbs.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0131/ability_0131_W1.webm"},{"key":"E","name":"Lunar Rush","description":"Becomes the living embodiment of the vengeful moon, dashing to an enemy and dealing magic damage.\\u003cbr\\u003e\\u003cbr\\u003eLunar Rush has no cooldown when used to dash to an enemy afflicted with Moonlight. All other enemies will have the Moonlight debuff removed regardless of whether they were the target of Lunar Rush.","max_rank":5,"range_burn":[825],"cooldown_burn":[22,20,18,16,14],"cost_burn":[40,45,50,55,60],"tooltip":"Diana becomes as the vengeful moon, dashing to an enemy and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. If the target is afflicted with \\u003ckeywordMajor\\u003eMoonlight\\u003c/keywordMajor\\u003e, this Ability\'s Cooldown is refreshed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DianaTeleport.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0131/ability_0131_E1.webm"},{"key":"R","name":"Moonfall","description":"Diana reveals and draws in all nearby enemies and slows them.\\u003cbr\\u003e\\u003cbr\\u003eIf Diana pulls in one or more enemy champions, the moonlight crashes down onto her after a short delay, dealing magic damage in an area around her, increased for each target beyond the first pulled.","max_rank":3,"range_burn":[475],"cooldown_burn":[100,90,80],"cost_burn":[100],"tooltip":"Diana \\u003cstatus\\u003ePulls In\\u003c/status\\u003e, \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?%, and reveals nearby enemies for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Diana hits at least one enemy champion, she calls to the moon, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e for each champion pulled beyond the first, up to a max of an additional \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/DianaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0131/ability_0131_R1.webm"}]},"133":{"id":133,"key":"Quinn","name":"Quinn","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Quinn.png","enemy_tips":["After being marked, move away from Quinn so she can\'t take advantage of it.","Keep tabs on Quinn\'s position. Behind Enemy Lines can enable Valor to cross the map very quickly and attack you by surprise.","When Quinn is using Behind Enemy Lines, damaging her removes her Move Speed bonus temporarily."],"ally_tips":["Attacking a ","Vulnerable"," target marked by Valor will put Harrier on cooldown. Quickly consuming Harrier marks will allow you to generate them faster.","Vault is powerful but must be used with caution, as enemies can attack Quinn when she strikes them. Vault can sometimes be used to cross terrain if your back is to a wall.","Use Behind Enemy Lines for traveling very long distances quickly, for farming minions around the map, or for chasing wounded targets."],"passive":{"name":"Harrier","description":"Valor, Quinn\'s Demacian eagle, periodically marks enemies as \\u003cfont color=\'#FFF673\'\\u003eVulnerable\\u003c/font\\u003e. Quinn\'s first basic attack against \\u003cfont color=\'#FFF673\'\\u003eVulnerable\\u003c/font\\u003e targets will deal bonus physical damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Quinn_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0133/ability_0133_P1.webm"},"spells":[{"key":"Q","name":"Blinding Assault","description":"Quinn calls Valor to mark an enemy and hinder its vision before damaging all enemies in the immediate area.","max_rank":5,"range_burn":[1025],"cooldown_burn":[11,10,10,9,9],"cost_burn":[50,55,60,65,70],"tooltip":"Quinn orders Valor to dive, making the first enemy hit \\u003ckeywordMajor\\u003eVulnerable\\u003c/keywordMajor\\u003e, reducing their vision radius for 1.75 seconds and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to all surrounding enemies.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the first enemy struck is not a champion, it is \\u003cstatus\\u003eDisarmed\\u003c/status\\u003e for 1.75 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QuinnQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0133/ability_0133_Q1.webm"},{"key":"W","name":"Heightened Senses","description":"Passively grants Quinn Attack Speed and Move Speed after she attacks a \\u003cfont color=\'#FFF673\'\\u003eVulnerable\\u003c/font\\u003e target. Activate to have Valor reveal a large area nearby.","max_rank":5,"range_burn":[2100],"cooldown_burn":[50,45,40,35,30],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Attacking a \\u003ckeywordMajor\\u003eVulnerable\\u003c/keywordMajor\\u003e target grants Quinn \\u003cattackSpeed\\u003e28/36/44/52/60% Attack Speed\\u003c/attackSpeed\\u003e and \\u003cspeed\\u003e20/25/30/35/40% Move Speed\\u003c/speed\\u003e for 2 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Valor reveals a large area nearby for 2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QuinnW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0133/ability_0133_W1.webm"},{"key":"E","name":"Vault","description":"Quinn dashes to an enemy, dealing physical damage and slowing the target\'s Move Speed. Upon reaching the target, she leaps off the target, briefly interrupting it, and lands near her maximum Attack Range away from the target.","max_rank":5,"range_burn":[675],"cooldown_burn":[12,11,10,9,8],"cost_burn":[50],"tooltip":"Quinn dashes to an enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and marking them \\u003ckeywordMajor\\u003eVulnerable\\u003c/keywordMajor\\u003e. Quinn then leaps backwards from the target, slightly \\u003cstatus\\u003eKnocking\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 50%, decaying over 1.5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QuinnE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0133/ability_0133_E1.webm"},{"key":"R","name":"Behind Enemy Lines","description":"Quinn and Valor team up to fly around at great speed.  Ending the ability casts Skystrike, which deals damage to nearby enemies and marks champions as Vulnerable.","max_rank":3,"range_burn":[700],"cooldown_burn":[3],"cost_burn":[100,50,0],"tooltip":"Quinn calls to Valor, pairing up after channeling for 2 seconds gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e and allowing her to \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability. Attacking or using \\u003cspellName\\u003eBlinding Assault\\u003c/spellName\\u003e or \\u003cspellName\\u003eVault\\u003c/spellName\\u003e automatically \\u003crecast\\u003eRecasts\\u003c/recast\\u003e this Ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Quinn and Valor perform an aerial maneuver, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, marking champions as \\u003ckeywordMajor\\u003eVulnerable\\u003c/keywordMajor\\u003e, and ending this Ability.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QuinnR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0133/ability_0133_R1.webm"}]},"134":{"id":134,"key":"Syndra","name":"Syndra","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Syndra.png","enemy_tips":["Get boots early when playing against Syndra, they\'ll help you avoid many of her spells.","Attack Syndra after she\'s used Scatter the Weak, it has a long cooldown so she\'ll be vulnerable.","At max rank Syndra\'s spells gain bonus effects and change in appearance."],"ally_tips":["To maximize your ultimate\'s damage use it when there are many spheres on the battlefield.","After you hit an enemy champion with Force of Will follow up with Dark Sphere, they\'ll be slowed and have a hard time avoiding it.","Get one of your spells to rank 5 as quickly as possible, they gain powerful bonus effects at max rank."],"passive":{"name":"Transcendent","description":"Syndra\'s spells gain extra effects at max rank.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eDark Sphere\\u003c/font\\u003e: Bonus damage against champions.\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eForce of Will\\u003c/font\\u003e: Bonus true damage.\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eScatter the Weak\\u003c/font\\u003e: Increased width.\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eUnleashed Power\\u003c/font\\u003e: Increased range.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/SyndraPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0134/ability_0134_P1.webm"},"spells":[{"key":"Q","name":"Dark Sphere","description":"Syndra conjures a Dark Sphere dealing magic damage. The sphere remains and can be manipulated by her other powers.","max_rank":5,"range_burn":[800],"cooldown_burn":[4],"cost_burn":[40,50,60,70,80],"tooltip":"Syndra conjures a \\u003ckeywordMajor\\u003eDark Sphere\\u003c/keywordMajor\\u003e, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The \\u003ckeywordMajor\\u003eSphere\\u003c/keywordMajor\\u003e remains for 6 seconds and can be manipulated by Syndra\'s other Abilities.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SyndraQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0134/ability_0134_Q1.webm"},{"key":"W","name":"Force of Will","description":"Syndra picks up and throws a Dark Sphere or enemy minion dealing magic damage and slowing the Move Speed of enemies.","max_rank":5,"range_burn":[925],"cooldown_burn":[12,11,10,9,8],"cost_burn":[60,70,80,90,100],"tooltip":"Syndra grabs a \\u003ckeywordMajor\\u003eDark Sphere\\u003c/keywordMajor\\u003e, enemy minion, or non-epic jungle monster. She drags it with her and can \\u003crecast\\u003eRecast\\u003c/recast\\u003e for up to 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Syndra hurls the grabbed unit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 25/30/35/40/45% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SyndraW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0134/ability_0134_W1.webm"},{"key":"E","name":"Scatter the Weak","description":"Syndra knocks enemies and Dark Spheres back dealing magic damage. Enemies hit by Dark Spheres become stunned.","max_rank":5,"range_burn":[650],"cooldown_burn":[18,17,16,15,14],"cost_burn":[50],"tooltip":"Syndra projects a wave of force, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e enemies and \\u003ckeywordMajor\\u003eDark Spheres\\u003c/keywordMajor\\u003e and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDark Spheres\\u003c/keywordMajor\\u003e that are pushed \\u003cstatus\\u003eStun\\u003c/status\\u003e enemies for 1.5 seconds and deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SyndraE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0134/ability_0134_E1.webm"},{"key":"R","name":"Unleashed Power","description":"Syndra bombards an enemy Champion with all of her Dark Spheres.","max_rank":3,"range_burn":[675],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Syndra draws on her full cataclysmic power, launching the 3 \\u003ckeywordMajor\\u003eDark Spheres\\u003c/keywordMajor\\u003e orbiting her plus up to 4 more previously created at an enemy champion. Each \\u003ckeywordMajor\\u003eDark Sphere\\u003c/keywordMajor\\u003e deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e (max \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SyndraR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0134/ability_0134_R1.webm"}]},"136":{"id":136,"key":"AurelionSol","name":"Aurelion Sol","image_url":"https://opgg-static.akamaized.net/images/lol/champion/AurelionSol.png","enemy_tips":["Try to get inside his orbit, since his stars can\'t hurt you up close.","His stars disappear while stunned or silenced, giving you an easy opportunity to fight him.","He gains speed while chasing in a straight line, but taking damage makes him lose that momentum.","His Starsurge ability can grow to cover a huge area - don\'t stay in the same place too long!"],"ally_tips":["You can use Comet of Legend\'s flight to grow Starsurge to massive proportions.","Save Voice of Light to use as a defense against melee opponents if you need to - otherwise, use its slow to start a fight at long range.","Comet of Legend allows you to move quickly around the map; use it to put pressure on other lanes."],"passive":{"name":"Center of the Universe","description":"Stars orbit Aurelion Sol, dealing magic damage when they hit an enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/AurelionSol_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0136/ability_0136_P1.webm"},"spells":[{"key":"Q","name":"Starsurge","description":"Aurelion Sol creates an expanding disk, which explodes to stun and damage enemies when it moves too far away from him.","max_rank":5,"range_burn":[1075],"cooldown_burn":[12,11,10,9,8],"cost_burn":[60,70,80,90,100],"tooltip":"Aurelion Sol creates a small star that grows and grants him \\u003cspeed\\u003e20% Move Speed\\u003c/speed\\u003e. Upon exiting Aurelion Sol\'s \\u003ckeywordMajor\\u003eOuter Limit\\u003c/keywordMajor\\u003e or after \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, the star explodes, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStunning\\u003c/status\\u003e for between ? and 2.2/2.4/2.6/2.8/3 seconds, based on travel time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AurelionSolQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0136/ability_0136_Q1.webm"},{"key":"W","name":"Celestial Expansion","description":"Aurelion Sol pushes his stars farther out, increasing their damage and speed.","max_rank":5,"range_burn":[600],"cooldown_burn":[8,6,5,3,2],"cost_burn":[70,80,90,100,110],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Increases \\u003cspellName\\u003eCenter of the Universe\'s\\u003c/spellName\\u003e damage by ?.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Aurelion Sol\'s stars expand to his \\u003ckeywordMajor\\u003eOuter Limit\\u003c/keywordMajor\\u003e, increase in speed, and deal ?% damage. After 3 seconds, \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, or using \\u003cspellName\\u003eComet of Legend\\u003c/spellName\\u003e they retract and Aurelion Sol gains \\u003cspeed\\u003e40% Move Speed\\u003c/speed\\u003e, decaying over 1.5 seconds.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AurelionSolW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0136/ability_0136_W1.webm"},{"key":"E","name":"Comet of Legend","description":"Aurelion Sol takes off flying for a long distance.","max_rank":5,"range_burn":[5500,6000,6500,7000,7500],"cooldown_burn":[80,75,70,65,60],"cost_burn":[60],"tooltip":"Aurelion Sol starts flying along a path at \\u003cspeed\\u003e600/650/700/750/800 Move Speed\\u003c/speed\\u003e. Taking damage from champions or structures ends the flight. While flying he can see and be seen over walls.\\u003cbr /\\u003e\\u003cbr /\\u003eThis ability can only be used outside of combat.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AurelionSolE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0136/ability_0136_E1.webm"},{"key":"R","name":"Voice of Light","description":"Aurelion Sol projects a blast of pure starfire, damaging and slowing all enemies caught in it and knocking nearby enemies back to a safer distance.","max_rank":3,"range_burn":[1500],"cooldown_burn":[110,90,70],"cost_burn":[100],"tooltip":"Aurelion Sol breathes out a blast of starfire, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 40/50/60% for 2 seconds, and \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e enemies to his \\u003ckeywordMajor\\u003eOuter Limit\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AurelionSolR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0136/ability_0136_R1.webm"}]},"141":{"id":141,"key":"Kayn","name":"Kayn","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kayn.png","enemy_tips":["Umbral Trespass requires Kayn to damage a target first. Try to dodge Blade\'s Reach to deny him a long range cast of Umbral Trespass.","When Kayn is in terrain near you, you will get a visual warning on the edge of the terrain he\'s in.","Damage Kayn while he\'s in Shadow Step to shorten its duration, or apply hard crowd control (stun, charm, knockup, etc) to end Shadow Step immediately."],"ally_tips":["Look at the line-up of both your team and the enemy\'s team when picking your form.","Remember that nearby enemies can see which wall you\'re in."],"passive":{"name":"The Darkin Scythe","description":"Kayn wields an ancient weapon and fights Rhaast, the darkin within it, for control. Either the \\u003cfont color=\'#fe5c50\'\\u003eDarkin\\u003c/font\\u003e will triumph, or Kayn will master Rhaast and become the \\u003cfont color=\'#8484fb\'\\u003eShadow Assassin\\u003c/font\\u003e.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#fe5c50\'\\u003eDarkin:\\u003c/font\\u003e Heal for a percentage of spell damage dealt to champions.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#8484fb\'\\u003eShadow Assassin:\\u003c/font\\u003e For the first few seconds in combat with enemy champions, deal bonus damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kayn_Passive_Primary.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0141/ability_0141_P1.webm"},"spells":[{"key":"Q","name":"Reaping Slash","description":"Kayn dashes, then slashes. Both deal damage.","max_rank":5,"range_burn":[350],"cooldown_burn":[7,6,6,5,5],"cost_burn":[50],"tooltip":"Kayn dashes then spins his scythe, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies he passes through, then deals the damage again to nearby enemies.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDarkin Slayer:\\u003c/keywordMajor\\u003e Instead deal \\u003cphysicalDamage\\u003e? plus ? max Health physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaynQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0141/ability_0141_Q1.webm"},{"key":"W","name":"Blade\'s Reach","description":"Kayn damages and slows targets in a line.","max_rank":5,"range_burn":[700],"cooldown_burn":[13,12,11,10,9],"cost_burn":[60,65,70,75,80],"tooltip":"Kayn swipes his scythe upward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies hit by 90%, decaying over 1.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eShadow Assassin:\\u003c/keywordMajor\\u003e Kayn can move while using this Ability and increases its range.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDarkin Slayer:\\u003c/keywordMajor\\u003e Additionally \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e enemies hit for 1 second(s).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaynW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0141/ability_0141_W1.webm"},{"key":"E","name":"Shadow Step","description":"Kayn can walk through terrain.","max_rank":5,"range_burn":[400],"cooldown_burn":[21,19,17,15,13],"cost_burn":[90],"tooltip":"Kayn gains \\u003cspeed\\u003e40% Move Speed\\u003c/speed\\u003e, becomes Ghosted, and can move through Terrain for 7/7.5/8/8.5/9 seconds. When he first enters terrain, he restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eBeing \\u003cstatus\\u003eImmobilized\\u003c/status\\u003e and spending more than 1.5 consecutive seconds outside of Terrain ends this Ability early.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eShadow Assassin:\\u003c/keywordMajor\\u003e Gain \\u003cspeed\\u003e80% Move Speed\\u003c/speed\\u003e, \\u003cstatus\\u003eSlow\\u003c/status\\u003e immunity, and reduce the Cooldown to ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaynE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0141/ability_0141_E1.webm"},{"key":"R","name":"Umbral Trespass","description":"Kayn hides in an enemy\'s body, dealing massive damage when he bursts out.","max_rank":3,"range_burn":[550],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Champions damaged by Kayn are marked for 3.15 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eKayn infests a marked enemy, becoming Untargetable. After ? seconds or after \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, Kayn bursts out, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the enemy.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eShadow Assassin:\\u003c/keywordMajor\\u003e Increases this Ability\'s range, the distance Kayn exits, and refreshes \\u003cspellName\\u003eThe Darkin Scythe\'s\\u003c/spellName\\u003e Cooldown on exit.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eDarkin Slayer:\\u003c/keywordMajor\\u003e Instead deals \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e and restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e (?% damage amount).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaynR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0141/ability_0141_R1.webm"}]},"142":{"id":142,"key":"Zoe","name":"Zoe","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zoe.png","enemy_tips":["Zoe\'s Paddle Star deals more damage the further it has flown.","Zoe must return to her starting point after casting Portal Jump, making her vulnerable to a counterattack.","Sleepy Trouble Bubble travels further over walls. Stop Zoe from hiding in fog of war to prevent her from setting the spell up."],"ally_tips":["Paddle Star deals more damage the further it has flown. Casting it behind yourself before redirecting can deal tons of damage.","Break Sleep with your biggest damage source, since enemies who are asleep take double damage.","Sleepy Trouble Bubble travels further over walls. Find a hiding spot to set up for a long distance kill."],"passive":{"name":"More Sparkles!","description":"Zoe\'s next basic attack after casting a spell deals bonus magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Zoe_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0142/ability_0142_P1.webm"},"spells":[{"key":"Q","name":"Paddle Star!","description":"Zoe fires a missile that she can redirect in flight. Deals more damage the longer it flies in a straight line.","max_rank":5,"range_burn":[800],"cooldown_burn":[8,8,7,7,6],"cost_burn":[40,45,50,55,60],"tooltip":"Zoe fires a star that deals increasing damage the further it travels to the first enemy hit -- between \\u003cmagicDamage\\u003e? to ? magic damage\\u003c/magicDamage\\u003e. Enemies surrounding the target take 80% damage.\\u003cbr /\\u003e\\u003cbr /\\u003eZoe can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability to redirect the missile to a new position near Zoe.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZoeQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0142/ability_0142_Q1.webm"},{"key":"W","name":"Spell Thief","description":"Zoe can pick up the remnants of enemy summoner spell and active item casts and cast them once herself. Whenever she casts a summoner spell, she gains 3 missiles that fire at the nearest target.","max_rank":5,"range_burn":[3000,4500,6000,3000,3000],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Enemies drop spell shards when casting a Summoner Spell or using an Active Item. Specific minions also drop a spell shard when Zoe kills them. Zoe can pick up this shard to cast that ability once.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e When Zoe casts this Ability or any Summoner Spell, she gains \\u003cspeed\\u003e30/40/50/60/70% Move Speed\\u003c/speed\\u003e for ? seconds and tosses 3 missiles at the target she Attacked most recently. These missiles deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e each.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Cast the Ability from a spell shard Zoe has picked up.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZoeW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0142/ability_0142_W1.webm"},{"key":"E","name":"Sleepy Trouble Bubble","description":"Causes the target to become drowsy, then fall asleep. The first source of damage that breaks the sleep is doubled, up to a cap.","max_rank":5,"range_burn":[800],"cooldown_burn":[16,15,14,13,12],"cost_burn":[80],"tooltip":"Zoe dropkicks a bubble that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, lingering as a trap if it hits nothing. The bubble\'s range is extended when flying over terrain.\\u003cbr /\\u003e\\u003cbr /\\u003eAfter a delay, the victim falls \\u003cstatus\\u003eAsleep\\u003c/status\\u003e for 2 seconds. Attacks and Ability hits wake them up but deal double damage, up to \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZoeE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0142/ability_0142_E1.webm"},{"key":"R","name":"Portal Jump","description":"Blink to a nearby position for 1 second. Then blink back.","max_rank":3,"range_burn":[575],"cooldown_burn":[11,8,5],"cost_burn":[40],"tooltip":"Zoe teleports to a nearby position for 1 second. Afterwards, she teleports back. Zoe can use Abilities and Attack, but can\'t move during this time.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZoeR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0142/ability_0142_R1.webm"}]},"143":{"id":143,"key":"Zyra","name":"Zyra","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zyra.png","enemy_tips":["Zyra\'s seeds can be destroyed by stepping on them. If she tries to grow them as you do, dodge back at the last moment. ","Moving closer to Zyra can be a smart move if she places plants too far away from herself.","Plants take fixed damage from attacks and effects, similar to wards. They also expire quickly on their own.","Moving the fight to a different area will deprive Zyra of accumulated seeds.","Seeds placed by Zyra\'s W are larger, a different color, and grant a small amount of vision to her team."],"ally_tips":["Placing a seed in your spell\'s path after you have cast it gives you the best chance of having a seed in the proper spot.","Seeds grant vision to your team.","Zyra is a great ambusher - look for opportunities to set a trap of seeds in brush, then lure enemies in."],"passive":{"name":"Garden of Thorns","description":"Seeds spawn around Zyra periodically, becoming faster with level. Zyra can cast Deadly Spines or Grasping Roots near seeds to grow plants, who fight for Zyra.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ZyraP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0143/ability_0143_P1.webm"},"spells":[{"key":"Q","name":"Deadly Spines","description":"Thick vines spread through the ground and explode into spines, dealing magic damage to enemies within the area. If cast near a seed, Deadly Spines grows a Thorn Spitter plant, which fires at enemies from afar.","max_rank":5,"range_burn":[800],"cooldown_burn":[7,6,6,5,5],"cost_burn":[70],"tooltip":"Zyra causes thick vines to spread and explode into spines, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability is cast near a \\u003ckeywordMajor\\u003eSeed\\u003c/keywordMajor\\u003e, the \\u003ckeywordMajor\\u003eSeed\\u003c/keywordMajor\\u003e grows into a Thorn Spitter that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and lasts ? seconds. Thorn Spitters have 575 range.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZyraQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0143/ability_0143_Q1.webm"},{"key":"W","name":"Rampant Growth","description":"Zyra plants a seed, lasting up to 60 seconds. Deadly Spines and Grasping Roots cast near seeds will turn them into plants who fight for Zyra. Zyra can store multiple seeds at once, and killing enemies reduces Rampant Growth\'s recharge time.","max_rank":5,"range_burn":[850],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Zyra plants a \\u003ckeywordMajor\\u003eSeed\\u003c/keywordMajor\\u003e that lasts 60 seconds. These \\u003ckeywordMajor\\u003eSeeds\\u003c/keywordMajor\\u003e grant \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of enemy champions that step on them for 2 seconds, but are still destroyed.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 2 charges with a ? second recharge time. Killing an enemy reduces the recharge time by 20%. Champion takedowns, large jungle monster kills, and large minion kills reduce the recharge time by 100% instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZyraW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0143/ability_0143_W1.webm"},{"key":"E","name":"Grasping Roots","description":"Zyra sends forth vines through the ground to ensnare her target, dealing damage and rooting enemies they come across. If cast near a seed, Grasping Roots grows a Vine Lasher, whose short range attacks reduce enemy Move Speed.","max_rank":5,"range_burn":[1100],"cooldown_burn":[12],"cost_burn":[70,75,80,85,90],"tooltip":"Zyra sends vines forward, \\u003cstatus\\u003eRooting\\u003c/status\\u003e for 1/1.25/1.5/1.75/2 second(s) and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. \\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability passes near a \\u003ckeywordMajor\\u003eSeed\\u003c/keywordMajor\\u003e, the \\u003ckeywordMajor\\u003eSeed\\u003c/keywordMajor\\u003e grows into a Vine Lasher that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and lasts ? seconds. Vine Lashers have 400 range, and their Attacks \\u003cstatus\\u003eSlow\\u003c/status\\u003e by 30% for 2 seconds. The \\u003cstatus\\u003eSlow\\u003c/status\\u003e from multiple Vine Lashers stacks up to ? times.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZyraE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0143/ability_0143_E1.webm"},{"key":"R","name":"Stranglethorns","description":"Zyra summons a twisted thicket at her target location, dealing damage to enemies as it expands and knocking them airborne as it contracts. Plants within the thicket are enraged.","max_rank":3,"range_burn":[700],"cooldown_burn":[110,100,90],"cost_burn":[100],"tooltip":"Zyra summons the fury of nature, growing a twisted thicket that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. After 2 seconds, the vines snap upwards, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for 1 second.\\u003cbr /\\u003e\\u003cbr /\\u003eZyra\'s plants within the thicket become enraged, resetting their duration, gaining \\u003chealing\\u003e50% Health\\u003c/healing\\u003e and Attacking for ?% bonus damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZyraR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0143/ability_0143_R1.webm"}]},"145":{"id":145,"key":"Kaisa","name":"Kai\'Sa","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kaisa.png","enemy_tips":["Kai\'Sa is very good at picking off isolated enemies. Stick together against her.","Kai\'Sa is very vulnerable to getting outranged by mages and long range carries.","Make sure to place wards in your blind spots so you can see Kai\'Sa coming."],"ally_tips":["Try to catch enemy carries alone to burst them with Icathian Rain.","Work with your teammates to set up your Ultimate and optimize damage with your passive.","Make sure to buy items that will evolve at least 1 or 2 of your spells."],"passive":{"name":"Second Skin","description":"Kai\'Sa\'s basic attacks stack Plasma, dealing increasing bonus magic damage. Allies\' immobilizing effects help stack Plasma. Additionally, Kai\'Sa\'s item purchases upgrade her basic spells to have more powerful properties.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kaisa_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0145/ability_0145_P1.webm"},"spells":[{"key":"Q","name":"Icathian Rain","description":"Kai\'Sa shoots a swarm of missiles that seek out nearby targets.\\u003cbr\\u003e\\u003cbr\\u003eLiving Weapon: Icathian Rain is upgraded to shoot more missiles.","max_rank":5,"range_burn":[600],"cooldown_burn":[10,9,8,7,6],"cost_burn":[55],"tooltip":"Kai\'Sa launches 6 missiles that split among nearby enemies, each dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Additional hits on champions or jungle monsters deal 25% damage.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eEvolved\\u003c/keywordMajor\\u003e: Kai\'Sa instead fires 12 missiles.\\u003cbr /\\u003eCurrent: \\u003cphysicalDamage\\u003e?/100 Bonus Attack Damage\\u003c/physicalDamage\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaisaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0145/ability_0145_Q1.webm"},{"key":"W","name":"Void Seeker","description":"Kai\'Sa shoots a long range missile, marking enemies with her passive.\\u003cbr\\u003e\\u003cbr\\u003eLiving Weapon: Void Seeker is upgraded to apply more passive marks and reduce cooldown on champion hit.","max_rank":5,"range_burn":[3000],"cooldown_burn":[22,20,18,16,14],"cost_burn":[55,60,65,70,75],"tooltip":"Kai\'Sa fires a void blast that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, applies 2 stacks of \\u003ckeywordMajor\\u003ePlasma\\u003c/keywordMajor\\u003e, and grants \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e of the first enemy hit for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eEvolved\\u003c/keywordMajor\\u003e: Kai\'Sa instead applies 3 stacks of \\u003ckeywordMajor\\u003ePlasma\\u003c/keywordMajor\\u003e and hitting a champion reduces the Cooldown by 77%.\\u003cbr /\\u003eCurrent: \\u003cmagicDamage\\u003e?/100 Ability Power\\u003c/magicDamage\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaisaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0145/ability_0145_W1.webm"},{"key":"E","name":"Supercharge","description":"Kai\'Sa briefly increases her Move Speed, then increases her Attack Speed.\\u003cbr\\u003e\\u003cbr\\u003eLiving Weapon: Supercharge is upgraded to briefly grant Invisibility.","max_rank":5,"range_burn":[1],"cooldown_burn":[16,14,13,11,10],"cost_burn":[30],"tooltip":"Kai\'Sa supercharges her void energy, gaining \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e and becoming Ghosted while charging, then gaining \\u003cattackSpeed\\u003e40/50/60/70/80% Attack Speed\\u003c/attackSpeed\\u003e for 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAttacks reduce this Ability\'s Cooldown by 0.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eEvolved\\u003c/keywordMajor\\u003e: Kai\'Sa also becomes \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e for 0.5 seconds.\\u003cbr /\\u003eCurrent: \\u003cattackSpeed\\u003e?/100% Bonus Attack Speed\\u003c/attackSpeed\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaisaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0145/ability_0145_E1.webm"},{"key":"R","name":"Killer Instinct","description":"Kai\'Sa dashes near an enemy champion.","max_rank":3,"range_burn":[1500,2250,3000],"cooldown_burn":[130,100,70],"cost_burn":[100],"tooltip":"Kai\'Sa warps near an enemy champion affected by \\u003ckeywordMajor\\u003ePlasma\\u003c/keywordMajor\\u003e and gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KaisaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0145/ability_0145_R1.webm"}]},"147":{"id":147,"key":"Seraphine","name":"Seraphine","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Seraphine.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Stage Presence","description":"Every third basic spell will cast twice from Seraphine. Additionally, casting spells near allies grants her bonus magic damage and range on her next basic attack.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Seraphine_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0147/ability_0147_P1.webm"},"spells":[{"key":"Q","name":"High Note","description":"Seraphine deals damage in an area.","max_rank":5,"range_burn":[900],"cooldown_burn":[10,8,7,6,5],"cost_burn":[65,70,75,80,85],"tooltip":"Seraphine projects a pure note, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, increased by the target\'s missing Health percentage up to \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e below ?% Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SeraphineQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0147/ability_0147_Q1.webm"},{"key":"W","name":"Surround Sound","description":"Seraphine Shields and Hastes nearby allies. If she is already Shielded she will Heal nearby allies as well.","max_rank":5,"range_burn":[800],"cooldown_burn":[28,26,24,22,20],"cost_burn":[50,60,70,80,90],"tooltip":"Seraphine spurs her nearby allied champions in song, granting herself \\u003cspeed\\u003e? decaying Move Speed\\u003c/speed\\u003e and \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds (allies granted \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e and \\u003cshield\\u003e? Shield\\u003c/shield\\u003e instead).\\u003cbr /\\u003e\\u003cbr /\\u003eIf Seraphine is already \\u003cshield\\u003eShielded\\u003c/shield\\u003e, she calls out to her allies to join her, restoring \\u003chealing\\u003e?% missing Health\\u003c/healing\\u003e to them per nearby ally champion after a ? second delay.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SeraphineW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0147/ability_0147_W1.webm"},{"key":"E","name":"Beat Drop","description":"Seraphine deals damage and impairs the movement of enemies in a line.","max_rank":5,"range_burn":[1300],"cooldown_burn":[10],"cost_burn":[60,70,80,90,100],"tooltip":"Seraphine unleashes a heavy soundwave, dealing \\u003cmagicDamage\\u003e? Magic Damage\\u003c/magicDamage\\u003e to enemies in a line and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies that are already \\u003cstatus\\u003eSlowed\\u003c/status\\u003e are \\u003cstatus\\u003eRooted\\u003c/status\\u003e instead, and \\u003cstatus\\u003eImmobilized\\u003c/status\\u003e enemies are \\u003cstatus\\u003eStunned\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SeraphineE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0147/ability_0147_E1.webm"},{"key":"R","name":"Encore","description":"Seraphine deals damage and charms enemies hit, refreshing the range with every allied or enemy champion hit.","max_rank":3,"range_burn":[25000],"cooldown_burn":[160,130,100],"cost_burn":[100],"tooltip":"Seraphine takes the stage, projecting a captivating force that \\u003cstatus\\u003eCharms\\u003c/status\\u003e for ? seconds and deals \\u003cmagicDamage\\u003e{{ r1totaldamage }} magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eAny champions struck (including allies) become part of the performance, extending the range of this Ability. Allied champions gain maximum \\u003ckeywordMajor\\u003eNotes\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SeraphineR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0147/ability_0147_R1.webm"}]},"150":{"id":150,"key":"Gnar","name":"Gnar","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Gnar.png","enemy_tips":["Gnar can\'t gain Rage for 15 seconds after he turns from big to little. Use this chance to engage on his team.","Gnar\'s animations and resource bar change as he gets closer to transforming.  ","Gnar\'s ultimate stuns if he hits you into a wall. Be careful when fighting him near one."],"ally_tips":["Managing your Rage is very important. Try to time out your transformations so you can get maximum benefit from both forms.","Position yourself next to walls to bait your enemies into getting stunned by your ultimate.","Know your strengths! Mini Gnar is fast, squishy, and has high sustained damage. Mega Gnar is slow, tough, and has high burst."],"passive":{"name":"Rage Gene","description":"While in combat Gnar generates Rage. At maximum Rage his next ability will transform him into Mega Gnar, granting increased survivability and access to new spells.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Gnar_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0150/ability_0150_P1.webm"},"spells":[{"key":"Q","name":"Boomerang Throw / Boulder Toss","description":"Gnar throws a boomerang that damages and slows enemies it hits before returning to him. If he catches the boomerang its cooldown is reduced.\\u003cbr\\u003e\\u003cbr\\u003eMega Gnar instead throws a boulder that stops on the first unit hit, damaging and slowing everything nearby. It can then be picked up to reduce the cooldown.","max_rank":5,"range_burn":[1100],"cooldown_burn":[20,17,15,12,10],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMini Gnar:\\u003c/keywordMajor\\u003e Gnar throws a boomerang that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds. The boomerang returns after hitting an enemy, dealing reduced damage to subsequent targets. Each enemy can only be hit once. Catching the boomerang reduces its Cooldown by ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GnarQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0150/ability_0150_Q1.webm"},{"key":"W","name":"Hyper / Wallop","description":"Gnar\'s attacks and spells hype him up, dealing bonus damage and granting him Move Speed.\\u003cbr\\u003e\\u003cbr\\u003eMega Gnar is too enraged to be hyper and instead can rear up on his hind legs and smash down on the area in front of him, stunning enemies in an area.","max_rank":5,"range_burn":[0],"cooldown_burn":[7],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMini Gnar Passive:\\u003c/keywordMajor\\u003e Every third Attack or Ability on the same enemy deals an additional \\u003cmagicDamage\\u003e? plus ?% max Health magic damage\\u003c/magicDamage\\u003e and grants \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GnarW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0150/ability_0150_W1.webm"},{"key":"E","name":"Hop / Crunch","description":"Gnar leaps to a location and bounces off the head of any unit he lands on, traveling further.\\u003cbr\\u003e\\u003cbr\\u003eMega Gnar is too large to bounce and instead lands with earth-shattering force, dealing damage in an area around him.","max_rank":5,"range_burn":[475],"cooldown_burn":[22,19,17,14,12],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMini Gnar:\\u003c/keywordMajor\\u003e Gnar leaps, gaining \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds. If Gnar lands on a unit he will bounce off it, traveling further. Bouncing off an enemy deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and briefly \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GnarE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0150/ability_0150_E1.webm"},{"key":"R","name":"GNAR!","description":"Mega Gnar throws everything around him in a chosen direction, dealing damage and slowing them.  Any enemy that hits a wall is stunned and takes bonus damage.","max_rank":3,"range_burn":[590],"cooldown_burn":[90,60,30],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMini Gnar Passive:\\u003c/keywordMajor\\u003e Increase \\u003cspellName\\u003eHyper\'s\\u003c/spellName\\u003e \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003ckeywordMajor\\u003eMega Gnar:\\u003c/keywordMajor\\u003e Gnar tosses nearby enemies, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. Enemies that hit a wall instead take \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and are \\u003cstatus\\u003eStunned\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GnarR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0150/ability_0150_R1.webm"}]},"154":{"id":154,"key":"Zac","name":"Zac","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zac.png","enemy_tips":["Zac heals from the goo that separates from him. You can crush the goo pieces by stepping on them.","Kill all of Zac\'s bloblets when he splits apart to stop him from reforming.","Silences, stuns, roots and knockups will all interrupt Zac when he is charging Elastic Slingshot."],"ally_tips":["Picking up goo chunks is very important to staying alive.","When Cell Division is ready, try to die in a position that makes it difficult for the enemy team to kill your bloblets.","Charging Elastic Slingshot from the fog of war will give opponents less time to react."],"passive":{"name":"Cell Division","description":"Each time Zac hits an enemy with an ability, he sheds a chunk of himself that can be reabsorbed to restore Health. Upon taking fatal damage, Zac splits into 4 bloblets that attempt to recombine. If any bloblets remain, he will revive with an amount of Health depending on the Health of the surviving bloblets. Each bloblet has a percentage of Zac\'s maximum Health, Armor and Magic Resistance. This ability has a 5 minute cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ZacPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0154/ability_0154_P1.webm"},"spells":[{"key":"Q","name":"Stretching Strikes","description":"Zac stretches an arm, grabbing an enemy. Attacking a different enemy will cause him to throw both targets towards each other.","max_rank":5,"range_burn":[800],"cooldown_burn":[15,13,12,10,9],"cost_burn":[0],"tooltip":"Zac stretches his arm out, attaching it to the first enemy hit to deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and briefly \\u003cstatus\\u003eSlow\\u003c/status\\u003e them. Zac\'s next Attack gains increased range and applies the same damage and \\u003cstatus\\u003eSlow\\u003c/status\\u003e. \\u003cbr /\\u003e\\u003cbr /\\u003eIf Zac hits a \\u003ci\\u003edifferent\\u003c/i\\u003e enemy with this Attack, he \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e both towards each other. If they collide, they and surrounding enemies take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and are briefly \\u003cstatus\\u003eSlowed\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZacQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0154/ability_0154_Q1.webm"},{"key":"W","name":"Unstable Matter","description":"Zac explodes outward towards nearby enemies, dealing a percentage of their maximum health as magic damage.","max_rank":5,"range_burn":[350],"cooldown_burn":[5],"cost_burn":[0],"tooltip":"Zac\'s body erupts, dealing \\u003cmagicDamage\\u003e? + ? max Health magic damage\\u003c/magicDamage\\u003e to nearby enemies.\\u003cbr /\\u003e\\u003cbr /\\u003eAbsorbing \\u003ckeywordMajor\\u003eGoo\\u003c/keywordMajor\\u003e reduces this Ability\'s Cooldown by 1 second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZacW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0154/ability_0154_W1.webm"},{"key":"E","name":"Elastic Slingshot","description":"Zac attaches his arms to the ground and stretches back, launching himself forward.","max_rank":5,"range_burn":[300],"cooldown_burn":[24,21,18,15,12],"cost_burn":[0],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Zac pulls himself taut, charging up a dash over 0.9/1/1.1/1.2/1.3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Zac launches himself and \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e enemies where he lands for up to ? second (based on charge time), dealing them \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Zac spawns an extra chunk of \\u003ckeywordMajor\\u003eGoo\\u003c/keywordMajor\\u003e for each enemy champion hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZacE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0154/ability_0154_E1.webm"},{"key":"R","name":"Let\'s Bounce!","description":"Zac bounces four times, knocking up enemies hit and slowing them.","max_rank":3,"range_burn":[300],"cooldown_burn":[130,115,100],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e \\u003cspellName\\u003eCell Division\\u003c/spellName\\u003e healing is increased to \\u003chealing\\u003e? Health\\u003c/healing\\u003e per \\u003ckeywordMajor\\u003eGoo\\u003c/keywordMajor\\u003e chunk.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Zac bounces ? times. The first bounce to hit each enemy \\u003cstatus\\u003eKnocks\\u003c/status\\u003e them back and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Subsequent bounces deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlow\\u003c/status\\u003e by ?% for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eZac gains up to \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e over time and can cast \\u003cspellName\\u003eUnstable Matter\\u003c/spellName\\u003e while bouncing.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZacR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0154/ability_0154_R1.webm"}]},"157":{"id":157,"key":"Yasuo","name":"Yasuo","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Yasuo.png","enemy_tips":["Steel Tempest is very narrow. Dodge laterally if possible. ","When Yasuo lands two Steel Tempests in a row, his next will fire a tornado. Watch and listen for the associated sound to prepare to dodge.","Yasuo is at his weakest just after he has launched a whirlwind. Engage at that point.","Yasuo\'s shield from Resolve lasts only 2 seconds. Dealing damage to him will trigger it. Wait it out, then engage."],"ally_tips":["Dash through a minion to have Sweeping Blade available to chase your opponent should they flee; Dash directly to your opponent to preserve a minion as your escape route.","At level 18, Yasuo\'s Steel Tempest reaches its Attack Speed cap with 55% Attack Speed from items.","Last Breath can be cast on any target that is knocked Airborne, even by one of your allies."],"passive":{"name":"Way of the Wanderer","description":"Yasuo\'s Critical Strike Chance is increased. Additionally, Yasuo builds toward a shield whenever he is moving. The shield triggers when he takes damage from a champion or monster.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Yasuo_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0157/ability_0157_P1.webm"},"spells":[{"key":"Q","name":"Steel Tempest","description":"Thrusts forward, damaging all enemies in a line.\\u003cbr\\u003e\\u003cbr\\u003eOn hit, grants a stack of Gathering Storm for a few seconds. At 2 stacks, Steel Tempest fires a whirlwind that knocks \\u003cfont color=\'#6655CC\'\\u003eAirborne\\u003c/font\\u003e.\\u003cbr\\u003e\\u003cbr\\u003eSteel Tempest is treated as a basic attack and scales with all the same things.","max_rank":5,"range_burn":[475],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"Yasuo thrusts, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If he hits, he gains a stack for ? seconds. While he has 2 stacks, his next use of this Ability fires a whirlwind from range, dealing the same damage and \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eIf used while dashing, this Ability strikes in a circle rather than a stab.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YasuoQ1Wrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0157/ability_0157_Q1.webm"},{"key":"W","name":"Wind Wall","description":"Creates a moving wall that blocks all enemy projectiles for 4 seconds.","max_rank":5,"range_burn":[400],"cooldown_burn":[30,27,24,21,18],"cost_burn":[0],"tooltip":"Yasuo creates a drifting wall of wind that blocks all enemy projectiles for 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YasuoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0157/ability_0157_W1.webm"},{"key":"E","name":"Sweeping Blade","description":"Dashes through target enemy, dealing magic damage. Each cast increases your next dash\'s base Damage, up to a max amount.\\u003cbr\\u003e\\u003cbr\\u003eCannot be re-cast on the same enemy for a few seconds.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#99FF99\'\\u003eIf Steel Tempest is cast while dashing, it will strike as a circle.\\u003c/font\\u003e","max_rank":5,"range_burn":[475],"cooldown_burn":[0,0,0,0,0],"cost_burn":[0],"tooltip":"Yasuo dashes through a target, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Each use of this Ability grants 25% bonus damage to the next use for 5 seconds, stacking up to 50%.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has a 10/9/8/7/6 second per-target Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YasuoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0157/ability_0157_E1.webm"},{"key":"R","name":"Last Breath","description":"Blinks to an \\u003cfactionIonia1\\u003eAirborne\\u003c/factionIonia1\\u003e enemy champion, dealing physical damage and holding all \\u003cfactionIonia1\\u003eAirborne\\u003c/factionIonia1\\u003e enemies in the area in the air. Grants maximum Flow but resets all stacks of Gathering Storm.\\u003cbr\\u003e\\u003cbr\\u003eFor a moderate time afterwards, Yasuo\'s critical strikes gain significant Bonus Armor Penetration.","max_rank":3,"range_burn":[1400],"cooldown_burn":[70,50,30],"cost_burn":[0],"tooltip":"Yasuo teleports to an \\u003cstatus\\u003eAirborne\\u003c/status\\u003e enemy champion, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and holding all nearby \\u003cstatus\\u003eAirborne\\u003c/status\\u003e enemies up for an additional ? second. Yasuo also gains maximum \\u003ckeywordMajor\\u003eFlow\\u003c/keywordMajor\\u003e, but loses all \\u003cspellName\\u003eSteel Tempest\\u003c/spellName\\u003e stacks.\\u003cbr /\\u003e\\u003cbr /\\u003eAfterwards, Yasuo\'s critical strikes ignore \\u003cscaleArmor\\u003e?% bonus Armor\\u003c/scaleArmor\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YasuoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0157/ability_0157_R1.webm"}]},"161":{"id":161,"key":"Velkoz","name":"Vel\'Koz","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Velkoz.png","enemy_tips":["Vel\'Koz is very dangerous if left alone in a fight. Try to focus him down early.","Vel\'Koz has fairly low mobility and is vulnerable to ganks.","Life Form Disintegration Ray can be interrupted by stuns, silences and knockups."],"ally_tips":["When laning, use Void Rift to kill minions while building stacks of Organic Deconstruction on your opponent. You can then follow up with your other abilities.","Shooting Plasma Fission diagonally and splitting at maximum range allows you to hit opponents that are out of the range of the initial missile, but is more challenging to pull off.","Be very careful about when to use Life Form Disintegration Ray. Many champions have abilities that can interrupt the spell."],"passive":{"name":"Organic Deconstruction","description":"Vel\'Koz\'s abilities apply \\u003ckeywordName\\u003eOrganic Deconstruction\\u003c/keywordName\\u003e to enemies on hit. If 3 stacks are accumulated, the enemy will take a burst of true damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/VelKoz_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0161/ability_0161_P1.webm"},"spells":[{"key":"Q","name":"Plasma Fission","description":"Vel\'Koz shoots a bolt of plasma that splits in two on reactivation or upon hitting an enemy. The bolt slows and damages on hit.","max_rank":5,"range_burn":[1050],"cooldown_burn":[7],"cost_burn":[40,45,50,55,60],"tooltip":"Vel\'Koz shoots a plasma bolt that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% decaying over ? second(s). At the end of it\'s range, on hitting a target, or on \\u003crecast\\u003eRecasting\\u003c/recast\\u003e, the bolt splits and fires two new bolts at a 90 degree angle.\\u003cbr /\\u003e\\u003cbr /\\u003eKilling a unit with this restores \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VelkozQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0161/ability_0161_Q1.webm"},{"key":"W","name":"Void Rift","description":"Vel\'Koz opens a rift to the void that deals an initial burst of damage, then explodes for a second burst of damage after a delay.","max_rank":5,"range_burn":[1050],"cooldown_burn":[1],"cost_burn":[50,55,60,65,70],"tooltip":"Vel\'Koz opens a rift to the void, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The rift then erupts, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 2 charges (? second refresh).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VelkozW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0161/ability_0161_W1.webm"},{"key":"E","name":"Tectonic Disruption","description":"Vel\'Koz causes an area to explode, knocking up enemies, and knocking close enemies slightly away.","max_rank":5,"range_burn":[810],"cooldown_burn":[16,15,14,13,12],"cost_burn":[50,55,60,65,70],"tooltip":"Vel\'Koz disrupts a nearby area, causing it to explode, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for 0.75 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Enemies close to Vel\'koz will be \\u003cstatus\\u003eKnocked Back\\u003c/status\\u003e instead of \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VelkozE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0161/ability_0161_E1.webm"},{"key":"R","name":"Life Form Disintegration Ray","description":"Vel\'Koz unleashes a channelled beam that follows the cursor for 2.5 seconds that deals magic damage. Organic Deconstruction Researches enemy champions causing them to take true damage instead.","max_rank":3,"range_burn":[1575],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Vel\'Koz channels a ray of energy that follows the cursor, dealing a total of \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over 2.5 seconds and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 20%. Deals \\u003ctrueDamage\\u003etrue damage\\u003c/trueDamage\\u003e instead to enemies recently damaged by \\u003cspellName\\u003eOrganic Deconstruction\\u003c/spellName\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies gain stacks of \\u003ckeywordMajor\\u003eDeconstruction\\u003c/keywordMajor\\u003e periodically while in the beam.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VelkozR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0161/ability_0161_R1.webm"}]},"163":{"id":163,"key":"Taliyah","name":"Taliyah","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Taliyah.png","enemy_tips":["When Taliyah casts Unraveled Earth in the lane, be on the lookout for Seismic Shove. If she throws you into her minefield, the throws and stones will break your bones.","Taliyah\'s Threaded Volley is locked into a direction. If she\'s throwing rocks at you, dodge to the side!"],"ally_tips":["Try to throw enemies into Unraveled Earth using Seismic Shove.","Remember, you don\'t always have to ride Weaver\'s Wall.","Once you have Rylai\'s Crystal Scepter, casting Threaded Volley at enemies chasing you is a great way of making them regret everything."],"passive":{"name":"Rock Surfing","description":"Taliyah gains Move Speed near walls.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Taliyah_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0163/ability_0163_P1.webm"},"spells":[{"key":"Q","name":"Threaded Volley","description":"Taliyah throws a volley of rocks in a target direction, moving freely as she casts. This creates Worked Ground below her. If Taliyah casts Threaded Volley on Worked Ground, she consumes the ground to throw a stronger boulder that slows enemies.","max_rank":5,"range_burn":[1000],"cooldown_burn":[7,6,5,4,3],"cost_burn":[60,65,70,75,80],"tooltip":"Taliyah hurls 5 rocks, each dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e in an area around the first enemy hit while creating Worked Ground at that area. Subsequent hits against the same enemy deal ?% less damage.\\u003cbr /\\u003e\\u003cbr /\\u003eCasts on worked ground cost 20 Mana and have ?% less Cooldown, consume the Worked Ground, and hurl a boulder that \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies it hits by ?% for ? seconds, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the primary target.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaliyahQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0163/ability_0163_Q1.webm"},{"key":"W","name":"Seismic Shove","description":"Taliyah causes an area of ground to erupt and throws enemies within it in a direction of her choosing.","max_rank":5,"range_burn":[900],"cooldown_burn":[14,12,11,9,8],"cost_burn":[40,30,20,10,0],"tooltip":"Taliyah quakes the earth, \\u003cstatus\\u003eKnocking\\u003c/status\\u003e enemies in an area in the chosen direction.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaliyahWVC.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0163/ability_0163_W1.webm"},{"key":"E","name":"Unraveled Earth","description":"Taliyah creates a slowing minefield. If enemies dash through it or are knocked through it, the mines explode and stun them.","max_rank":5,"range_burn":[950],"cooldown_burn":[16,15,14,13,12],"cost_burn":[90,95,100,105,110],"tooltip":"Taliyah scatters loose stones in an area, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies hit by ?% and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The stones detonate when enemies dash or are \\u003cstatus\\u003eknocked\\u003c/status\\u003e through them, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for the remaining movement duration + ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaliyahE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0163/ability_0163_E1.webm"},{"key":"R","name":"Weaver\'s Wall","description":"Taliyah creates a very long wall and then surfs it.","max_rank":3,"range_burn":[2500,4500,6500],"cooldown_burn":[180,150,120],"cost_burn":[100],"tooltip":"Taliyah creates a massive earthen wall for 5 seconds. If she immediately \\u003crecast\\u003eRecasts\\u003c/recast\\u003e, she will ride along the wall as it unravels. Moving or being immobilized will end the ride.\\u003cbr /\\u003e\\u003cbr /\\u003eThis ability cannot be cast if Taliyah has taken damage from Champions or structures or dealt damage within the last ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TaliyahR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0163/ability_0163_R1.webm"}]},"164":{"id":164,"key":"Camille","name":"Camille","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Camille.png","enemy_tips":["Camille\'s shield only works against one damage type, so hit her when she\'s vulnerable to your damage.","The Hextech Ultimatum has a very short range to cast, so try to flash away from her before she gets close."],"ally_tips":["Try waiting until the other team is distracted with fighting your team, and use Hookshot to pick off vulnerable targets.","Use the CC from your abilities to land both of your Precision Protocol attacks on enemies."],"passive":{"name":"Adaptive Defenses","description":"Basic attacks on champions grant a shield equal to a percentage of Camille\'s maximum health against their damage type (Physical or Magic) for a brief duration.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Camille_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0164/ability_0164_P1.webm"},"spells":[{"key":"Q","name":"Precision Protocol","description":"Camille\'s next attack deals bonus damage and grants bonus Move Speed. This spell can be recast for a short period of time, doing significantly increased bonus damage if Camille delays a period of time between the two attacks.","max_rank":5,"range_burn":[325],"cooldown_burn":[9,8,7,6,6],"cost_burn":[25],"tooltip":"Camille\'s next Attack deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and grants her \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? second. This ability can be \\u003crecast\\u003eRecast\\u003c/recast\\u003e in the next ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the \\u003crecast\\u003eRecast\\u003c/recast\\u003e Attack hits at least ? seconds after the first, the bonus damage is increased to \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e and ? of the Attack\'s damage is converted into \\u003ctrueDamage\\u003etrue damage\\u003c/trueDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThis Ability triggers spell effects upon dealing damage.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CamilleQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0164/ability_0164_Q1.webm"},{"key":"W","name":"Tactical Sweep","description":"Camille blasts in a cone after a delay, dealing damage. Enemies in the outer half are slowed and take extra damage, while also healing Camille.","max_rank":5,"range_burn":[610],"cooldown_burn":[17,15,14,12,11],"cost_burn":[50,55,60,65,70],"tooltip":"Camille winds up and slices, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies hit by the outer half are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% decaying over ? seconds, and they take an additional \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e. Camille restores \\u003chealing\\u003e?% of the bonus damage dealt to champions as Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CamilleW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0164/ability_0164_W1.webm"},{"key":"E","name":"Hookshot","description":"Camille pulls herself to a wall, leaping off and knocking up enemy champions upon landing.","max_rank":5,"range_burn":[800],"cooldown_burn":[16,15,14,13,12],"cost_burn":[70],"tooltip":"Camille fires a hookshot that attaches to terrain, pulling her to it for 1 second and allowing this Ability to be \\u003crecast\\u003eRecast\\u003c/recast\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Camille dashes from the wall, colliding with the first enemy champion hit. Upon landing, she deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to nearby enemies and \\u003cstatus\\u003eStuns\\u003c/status\\u003e enemy champions for ? seconds. Dashes towards enemy champions travel twice as far and grant \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds on impact.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CamilleE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0164/ability_0164_E1.webm"},{"key":"R","name":"The Hextech Ultimatum","description":"Camille dashes to target champion, anchoring them to the area. She also deals bonus magic damage to the target with her basic attacks.","max_rank":3,"range_burn":[475],"cooldown_burn":[140,115,90],"cost_burn":[100],"tooltip":"Camille briefly becomes Untargetable and leaps onto an enemy champion, interrupting channels and locking them into an area they cannot escape by any means for ? seconds. Other nearby enemies are \\u003cstatus\\u003eKnocked Away\\u003c/status\\u003e. Her Attacks against the trapped enemy deal an additional \\u003cmagicDamage\\u003e? plus ?% current Health magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/CamilleR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0164/ability_0164_R1.webm"}]},"166":{"id":166,"key":"Akshan","name":"Akshan","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Akshan.png","enemy_tips":[],"ally_tips":["Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they least expect him. With a keen sense of justice and a legendary death-reversing weapon, he rights the wrongs of Runeterra\'s many scoundrels while living by his own moral code: “Don\'t be an ass.”"],"passive":{"name":"Dirty Fighting","description":"Every three hits from Akshan\'s Attacks and Abilities deals bonus damage and grants him a Shield if the target was a champion.\\u003cbr\\u003e\\u003cbr\\u003eWhen Akshan Attacks, he fires an additional Attack for reduced damage. If he cancels the additional Attack, he instead gains Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/akshan_p.Akshan.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0166/ability_0166_P1.webm"},"spells":[{"key":"Q","name":"Avengerang","description":"Akshan throws a boomerang that deals damage going out and coming back, extending its range each time it hits an enemy.","max_rank":5,"range_burn":[850],"cooldown_burn":[8,7,6,5,5],"cost_burn":[60,65,70,75,80],"tooltip":"Akshan throws a boomerang that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, extending the range each time an enemy is hit.\\u003cbr /\\u003e\\u003cbr /\\u003eChampion hits grant Akshan \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkshanQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0166/ability_0166_Q1.webm"},{"key":"W","name":"Going Rogue","description":"Akshan passively marks enemy champions as Scoundrels when they kill his ally champions. If Akshan kills a Scoundrel, he resurrects the allies they killed, gains bonus gold, and clears all marks.\\u003cbr\\u003e\\u003cbr\\u003eWhen activated, Akshan enters camouflage and gains Move Speed and Mana Regen while moving towards Scoundrels. Akshan loses the camouflage quickly while he is not in brush or near terrain.","max_rank":5,"range_burn":[5500],"cooldown_burn":[18,14,10,6,2],"cost_burn":[40,30,20,10,0],"tooltip":"\\u003cspellPassive\\u003ePassive\\u003c/spellPassive\\u003e: Enemy champions that kill Akshan\'s allies become \\u003ckeywordMajor\\u003eScoundrels\\u003c/keywordMajor\\u003e for ? seconds. Takedowns on a \\u003ckeywordMajor\\u003eScoundrel\\u003c/keywordMajor\\u003e within ? seconds of being damaged by Akshan grant him ? Gold, resurrects the slain allies, and removes all other \\u003ckeywordMajor\\u003eScoundrels\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive\\u003c/spellActive\\u003e: Akshan becomes \\u003ckeywordStealth\\u003eCamouflaged\\u003c/keywordStealth\\u003e for ? seconds or indefinitely while he is near a wall or in brush. While \\u003ckeywordStealth\\u003eCamouflaged\\u003c/keywordStealth\\u003e in this way, Akshan also gains \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e and \\u003cscaleMana\\u003e?% missing Mana regen\\u003c/scaleMana\\u003e while moving towards \\u003ckeywordMajor\\u003eScoundrels\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkshanW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0166/ability_0166_W1.webm"},{"key":"E","name":"Heroic Swing","description":"Akshan fires a grappling hook into terrain then swings around it, repeatedly firing at the nearest enemy while swinging. He can jump off early or gets knocked off when colliding with champions or terrain.","max_rank":5,"range_burn":[800],"cooldown_burn":[18,16,15,13,12],"cost_burn":[70],"tooltip":"\\u003cspellActive\\u003eFirst Cast:\\u003c/spellActive\\u003e Akshan fires a grappling hook, attaching to the first terrain hit.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eSecond Cast:\\u003c/spellActive\\u003e Akshan swings around the terrain, repeatedly firing at the nearest enemy for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e per shot.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eThird Cast:\\u003c/spellActive\\u003e Akshan dives off the rope, firing a final shot.\\u003cbr /\\u003e\\u003cbr /\\u003eColliding with an enemy Champion or terrain ends the swing early.\\u003cbr /\\u003e\\u003cbr /\\u003eChampion takedowns refresh this Ability\'s Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkshanE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0166/ability_0166_E1.webm"},{"key":"R","name":"Comeuppance","description":"Akshan locks onto an enemy champion and starts storing bullets. When released, he fires all stored bullets, dealing damage based on missing health to the first champion, minion, or structure hit.","max_rank":3,"range_burn":[2500],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Akshan locks onto a champion and begins overcharging his gun for up to ? seconds, storing up to ? bullets.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Akshan unleashes the stored bullets, each dealing at least \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy or structure hit, increased up to \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e based on missing Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AkshanR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0166/ability_0166_R1.webm"}]},"200":{"id":200,"key":"Belveth","name":"Bel\'Veth","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Belveth.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Death in Lavender ","description":"Bel\'Veth gains permanent attack speed stacks after taking down large minions and monsters and champions. She also gains temporary bonus attack speed after using an ability.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Belveth_Passive.Belveth.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0200/ability_0200_P1.webm"},"spells":[{"key":"Q","name":"Void Surge","description":"Bel\'Veth dashes in a chosen direction and damages all enemies she passes through.","max_rank":5,"range_burn":[450],"cooldown_burn":[1],"cost_burn":[0],"tooltip":"Bel\'Veth dashes, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies she passes through.\\u003cbr /\\u003e\\u003cbr /\\u003eEach direction has an unique Cooldown of ? seconds that scales down based on her \\u003cattackSpeed\\u003eAttack Speed\\u003c/attackSpeed\\u003e.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BelvethQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0200/ability_0200_Q1.webm"},{"key":"W","name":"Above and Below","description":"Bel\'Veth slams her tail to the ground, damaging, knocking up, and slowing her enemies.","max_rank":5,"range_burn":[715],"cooldown_burn":[12,11,10,9,8],"cost_burn":[0],"tooltip":"Bel\'Veth slams her tail, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e foes for ? seconds, and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. If a champion is hit, this refreshes the Cooldown of \\u003cspellName\\u003eVoid Surge\\u003c/spellName\\u003e in that direction.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BelvethW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0200/ability_0200_W1.webm"},{"key":"E","name":"Royal Maelstrom","description":"Bel\'Veth roots herself in place, channeling a storm of slashes around her that targets the lowest-health enemy and grants her lifesteal and damage reduction.","max_rank":5,"range_burn":[500],"cooldown_burn":[22,20,18,16,14],"cost_burn":[0],"tooltip":"Bel\'Veth channels and slashes around herself, gaining ?% Damage Reduction, ? Life Steal, and Attacking {{ f2.0 }} times over ? seconds with the number of Attacks increasing based on her \\u003cattackSpeed\\u003eAttack Speed\\u003c/attackSpeed\\u003e. Each Attack strikes the lowest-health enemy, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e to \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e based on the target\'s missing Health.\\u003cbr /\\u003e\\u003cbr /\\u003eUsing another Ability or \\u003crecast\\u003eRecasting\\u003c/recast\\u003e ends this Ability early.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BelvethE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0200/ability_0200_E1.webm"},{"key":"R","name":"Endless Banquet","description":"Bel\'Veth consumes Void coral remnants, transforming into her true form and increasing her max health, attack range, attack speed, and out-of-combat move speed. Consuming the Void coral remnants of a Void epic monster will grant her a longer ultimate duration, as well as the power to summon Void remora.","max_rank":3,"range_burn":[275],"cooldown_burn":[1],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every second Attack against the same target deals an additional \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e, stacking infinitely. Takedowns against champions and epic monsters leave behind a piece of Void Coral.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Consuming Void Coral grants \\u003ckeywordMajor\\u003e? Lavender\\u003c/keywordMajor\\u003e stack and activates Bel\'Veth\'s true form for ? seconds. Void Coral from Void epic monsters increases the duration to ? seconds and causes minions that die nearby to become Void Remora. While casting, Bel\'Veth \\u003cstatus\\u003eSlows\\u003c/status\\u003e nearby enemies before exploding, dealing \\u003ctrueDamage\\u003e? + ?% missing-Health true damage\\u003c/trueDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIn her true form, Bel\'Veth gains \\u003chealing\\u003e? max Health\\u003c/healing\\u003e, \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e out of combat, ? Attack range, \\u003cattackSpeed\\u003e?% Total Attack Speed\\u003c/attackSpeed\\u003e, and \\u003cspellName\\u003eVoid Surge\\u003c/spellName\\u003e can pass through walls.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BelvethR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0200/ability_0200_R1.webm"}]},"201":{"id":201,"key":"Braum","name":"Braum","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Braum.png","enemy_tips":["Braum must land Winter\'s Bite or a basic attack to start Concussive Blows. If you get marked, exit combat range before getting hit 3 more times to avoid the stun.","Braum\'s ultimate has a long cast time, use that extra time to dodge. Walking over the frozen ground left behind will slow you, position so that you don\'t need to cross it.","Unbreakable gives Braum extremely strong directional defense, either wait until it is down or outposition the ability."],"ally_tips":["Work with your allies to stack Concussive Blows, encourage them to basic attack marked targets.","Leap in front of squishy friends and shield them from projectiles with Unbreakable.","Glacial Fissure leaves a powerful slow zone, position it well to split teamfights and slow the enemy approach."],"passive":{"name":"Concussive Blows","description":"Braum\'s basic attacks apply Concussive Blows. Once the first stack is applied, \\u003cfont color=\'#FFF673\'\\u003eally\\u003c/font\\u003e basic attacks also stack Concussive Blows. \\u003cbr\\u003e\\u003cbr\\u003eUpon reaching 4 stacks, the target is stunned and takes magic damage. For the next few seconds they cannot receive new stacks, but take bonus magic damage from Braum\'s attacks.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Braum_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0201/ability_0201_P1.webm"},"spells":[{"key":"Q","name":"Winter\'s Bite","description":"Braum propels freezing ice from his shield, slowing and dealing magic damage.\\u003cbr\\u003e\\u003cbr\\u003eApplies a stack of \\u003cfont color=\'#FFF673\'\\u003eConcussive Blows\\u003c/font\\u003e.","max_rank":5,"range_burn":[1000],"cooldown_burn":[10,9,8,7,6],"cost_burn":[45,50,55,60,65],"tooltip":"Braum propels freezing ice from his shield, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 70% decaying over 2 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eApplies a stack of \\u003ckeywordMajor\\u003eConcussive Blows\\u003c/keywordMajor\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BraumQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0201/ability_0201_Q1.webm"},{"key":"W","name":"Stand Behind Me","description":"Braum leaps to a target allied champion or minion. On arrival, Braum and the ally gain Armor and Magic Resist for a few seconds.","max_rank":5,"range_burn":[650],"cooldown_burn":[12,11,10,9,8],"cost_burn":[40],"tooltip":"Braum leaps to an allied champion or minion. On arrival, Braum grants the target \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e for 3 seconds. Braum grants himself \\u003cscaleArmor\\u003e?\\u003c/scaleArmor\\u003e Armor and  \\u003cscaleMR\\u003e?\\u003c/scaleMR\\u003e Magic Resist for the same duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BraumW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0201/ability_0201_W1.webm"},{"key":"E","name":"Unbreakable","description":"Braum raises his shield in a direction for several seconds, intercepting all projectiles causing them to hit him and be destroyed. He negates the damage of the first attack completely and reduces the damage of all subsequent attacks from this direction.","max_rank":5,"range_burn":[25000],"cooldown_burn":[16,14,12,10,8],"cost_burn":[30,35,40,45,50],"tooltip":"Braum raises his shield for 3/3.25/3.5/3.75/4 seconds, intercepting enemy missiles from the chosen direction, causing them to hit Braum and then be destroyed. The first missile Braum blocks deals no damage, and subsequent projectiles deal 35/40/45/50/55% reduced damage.\\u003cbr /\\u003e\\u003cbr /\\u003eBraum gains \\u003cspeed\\u003e10% Move Speed\\u003c/speed\\u003e while his shield is raised.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BraumE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0201/ability_0201_E1.webm"},{"key":"R","name":"Glacial Fissure","description":"Braum slams the ground, knocking up enemies nearby and in a line in front of him. A fissure is left along the line that slows enemies.","max_rank":3,"range_burn":[1250],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Braum slams the ground sending forth a fissure that \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e enemies in its path and nearby Braum, and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The first target hit is \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e for between ? and ? seconds, increasing with distance from Braum. All others hit are \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThe fissure also creates a zone for ? seconds, that \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?%.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BraumRWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0201/ability_0201_R1.webm"}]},"202":{"id":202,"key":"Jhin","name":"Jhin","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Jhin.png","enemy_tips":["Deadly Flourish only roots those hit by one of Jhin\'s basic attacks, traps, or allies within the last 4 seconds.","Jhin places invisible traps around the map. Watch where you step!","Jhin\'s attacks are quite potent, but he runs out of ammo after the 4th shot. Use this window to jump him and burst him down."],"ally_tips":["Deadly Flourish has incredible range. When approaching a fight be sure to look ahead for enemies that could be rooted.","Your ultimate deals significantly less damage to enemies with full health. Look to pick off weakened targets as they run away.","You can still cast your spells while reloading. Use them to fill the down time."],"passive":{"name":"Whisper","description":"Jhin\'s hand cannon, Whisper, is a precise instrument designed to deal superior damage. It fires at a fixed rate and carries only four shots. Jhin imbues the final bullet with dark magics to critically strike and deal bonus execute damage. Whenever Whisper crits, it inspires Jhin with a burst of Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Jhin_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0202/ability_0202_P1.webm"},"spells":[{"key":"Q","name":"Dancing Grenade","description":"Jhin launches a magical cartridge at an enemy. It can hit up to four targets and gains damage each time it kills.","max_rank":5,"range_burn":[550],"cooldown_burn":[7,6,6,5,5],"cost_burn":[40,45,50,55,60],"tooltip":"Jhin launches a cartridge that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e before bouncing to a nearby enemy that has not been hit yet.\\u003cbr /\\u003e\\u003cbr /\\u003eThe cartridge can hit a maximum of ? times. Enemies that die shortly after being hit increase the damage of subsequent hits by ?%.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JhinQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0202/ability_0202_Q1.webm"},{"key":"W","name":"Deadly Flourish","description":"Jhin brandishes his cane, firing a single shot with incredible range. It pierces through minions and monsters, but stops on the first champion hit. If the target was recently struck by Jhin\'s allies, lotus traps, or damaged by Jhin, they are rooted.","max_rank":5,"range_burn":[3000],"cooldown_burn":[12],"cost_burn":[50,60,70,80,90],"tooltip":"Jhin fires a long range shot dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first champion hit and other enemies along the way.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this skill strikes a champion that has been damaged by an allied champion within the last ? seconds, it will \\u003cstatus\\u003eRoot\\u003c/status\\u003e them for ? second(s) and grant Jhin \\u003cspellName\\u003eWhisper\\u003c/spellName\\u003e\'s Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JhinW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0202/ability_0202_W1.webm"},{"key":"E","name":"Captive Audience","description":"Jhin places an invisible lotus trap that blooms when walked over. It slows nearby enemies before dealing damage with an explosion of serrated petals. \\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FFFFFF\'\\u003eBeauty in Death -\\u003c/font\\u003e When Jhin kills an enemy champion, a lotus trap will bloom near their corpse.","max_rank":5,"range_burn":[750],"cooldown_burn":[2],"cost_burn":[30,35,40,45,50],"tooltip":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e Champions Jhin kills will create and detonate a Lotus Trap at their location.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Jhin places an invisible Lotus Trap for ? minutes that creates a zone that \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% when stepped on by an enemy. After ? seconds, the trap detonates, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eThis ability has 2 charges (? second refresh).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JhinE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0202/ability_0202_E1.webm"},{"key":"R","name":"Curtain Call","description":"Jhin channels, transforming Whisper into a shoulder-mounted mega-cannon. It is able to fire 4 super shots at extreme range that pierce through minions and monsters, but stop on the first champion impacted. Whisper cripples enemies hit, which slows them and deals execute damage. The 4th shot is perfectly crafted, epically powerful, and guaranteed to critically strike.","max_rank":3,"range_burn":[25000],"cooldown_burn":[120,105,90],"cost_burn":[100],"tooltip":"Jhin sets up and channels, enabling him to fire 4 super shots, each dealing between \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first champion hit based on their percentage missing health and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. The fourth shot critically strikes for ?% damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JhinR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0202/ability_0202_R1.webm"}]},"203":{"id":203,"key":"Kindred","name":"Kindred","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kindred.png","enemy_tips":["Kindred is fragile - turn the pressure up on her, and she will be forced to play cautiously.","Clear the Hunts Wolf activates on jungle camps to slow down Kindred\'s damage output.","When Kindred uses Lamb\'s Respite get inside, it stops all champions from dying."],"ally_tips":["Moving around between attacks while jungling will help you avoid damage and also generate more heals from Wolf\'s Frenzy.","Pick which Hunts you want to pursue carefully; getting many of them is the key to success as the game goes on.","Don\'t go in first to a large team fight. Wait for your teammates to initiate."],"passive":{"name":"Mark of the Kindred","description":"Kindred can mark targets to Hunt. Successfully completing a Hunt permanently empowers Kindred\'s basic abilities. Every 4 hunts completed also increases Kindred\'s basic attack range.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kindred_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0203/ability_0203_P1.webm"},"spells":[{"key":"Q","name":"Dance of Arrows","description":"Kindred tumbles and shoots up to three arrows at nearby targets.","max_rank":5,"range_burn":[340],"cooldown_burn":[8],"cost_burn":[35],"tooltip":"Kindred vaults, firing an arrow at up to 3 enemies, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and gaining \\u003cattackSpeed\\u003e? Attack Speed\\u003c/attackSpeed\\u003e for 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile inside of \\u003cspellName\\u003eWolf\'s Frenzy\\u003c/spellName\\u003e, this Ability\'s Cooldown is reduced to 4/3.5/3/2.5/2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KindredQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0203/ability_0203_Q1.webm"},{"key":"W","name":"Wolf\'s Frenzy","description":"Wolf enrages and attacks enemies around him.  Lamb passively gains stacks by moving and attacking. When fully charged, Lamb\'s next attack restores health.","max_rank":5,"range_burn":[560],"cooldown_burn":[18,17,16,15,14],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Kindred gains stacks as they move and attack. At 100 stacks, Kindred\'s next Attack restores up to \\u003chealing\\u003e? Health\\u003c/healing\\u003e based on their missing Health.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kindred claims a territory, ordering Wolf to bite at the last enemy Lamb Attacked. Wolf\'s bites deal \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e plus \\u003cmagicDamage\\u003e? current Health magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KindredW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0203/ability_0203_W1.webm"},{"key":"E","name":"Mounting Dread","description":"Lamb fires a carefully placed shot, slowing the target. If Lamb attacks the target two more times, her third attack instead directs Wolf to pounce on the enemy, savaging them for massive damage.","max_rank":5,"range_burn":[500],"cooldown_burn":[14,13,12,11,10],"cost_burn":[0],"tooltip":"Kindred weakens an enemy, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eKindred\'s third Attack against the target within ? seconds of each other directs Wolf to pounce on the enemy, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e? missing Health physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eWolf\'s pounce critically strikes for \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e? missing Health physical damage\\u003c/physicalDamage\\u003e instead if they are below ? Health.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KindredEWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0203/ability_0203_E1.webm"},{"key":"R","name":"Lamb\'s Respite","description":"Lamb grants all living things inside a zone a respite from death. Until the effect ends, nothing can die. At the end, units are healed.","max_rank":3,"range_burn":[500],"cooldown_burn":[180,150,120],"cost_burn":[100],"tooltip":"Kindred blesses the ground for 4 seconds, allowing no unit, ally, enemy, or neutral to die while inside. Upon reaching 10% Health, units can\'t be damaged or healed while still inside the zone.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen the blessing ends, all units inside heal for \\u003chealing\\u003e225/300/375 Health\\u003c/healing\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KindredR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0203/ability_0203_R1.webm"}]},"221":{"id":221,"key":"Zeri","name":"Zeri","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zeri.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Living Battery","description":"Zeri gains Move Speed whenever she receives a shield. When she damages an enemy shield she absorbs its energy, shielding herself.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ZeriP.Zeri.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0221/ability_0221_P1.webm"},"spells":[{"key":"Q","name":"Burst Fire","description":"Zeri\'s Attacks are treated as Abilities and Burst Fire is treated as an Attack. Moving and casting Burst Fire stores up energy in Zeri\'s Sparkpack. When fully charged her next Attack will slow and deal bonus damage. Burst Fire shoots a burst of 7 rounds that deal attack damage to the first enemy hit.","max_rank":5,"range_burn":[800],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Zeri\'s Attacks are treated as Abilities and can be charged up by moving and casting this ability. Uncharged Attacks deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, increased to \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e vs. enemies below ?% health, and consume some charge. A fully charged Attack deals \\u003cmagicDamage\\u003e? + ? max Health magic damage\\u003c/magicDamage\\u003e and consumes all charge.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e This Ability is treated as an Attack. Zeri fires a burst of ? rounds that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZeriQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0221/ability_0221_Q1.webm"},{"key":"W","name":"Ultrashock Laser","description":"Zeri fires an electric pulse that slows and damages the first enemy hit. If the pulse hits a wall it expands into a long range laser.","max_rank":5,"range_burn":[1150],"cooldown_burn":[12,11,10,9,8],"cost_burn":[50,60,70,80,90],"tooltip":"Zeri fires an electric pulse that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e the first enemy hit by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the pulse hits terrain, it expands into a laser that applies the effects in an area and Critically Strikes champions and monsters.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZeriW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0221/ability_0221_W1.webm"},{"key":"E","name":"Spark Surge","description":"Zeri dashes a short distance and energizes her next 3 shots of Burst Fire, causing them to pierce through enemies. She will vault and grind over any terrain she touches.","max_rank":5,"range_burn":[25000],"cooldown_burn":[24,22,21,19,18],"cost_burn":[80],"tooltip":"Zeri dashes a short distance and vaults over any terrain she touches, greatly extending the dash range. Her next 3 shots of \\u003cspellName\\u003eBurst Fire\\u003c/spellName\\u003e pierce, dealing ?% damage to enemies after the first.\\u003cbr /\\u003e\\u003cbr /\\u003eHitting an enemy champion with an Attack or Ability reduces this Ability\'s cooldown by ? seconds. Critical strikes reduce the cooldown 2 additional times.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZeriE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0221/ability_0221_E1.webm"},{"key":"R","name":"Lightning Crash","description":"Zeri discharges a nova of electricity and overcharges herself, gaining increased damage and stacking Move Speed that refreshes and gets stronger every time she hits an enemy champion. While overcharged, Burst fire becomes a faster triple shot that chains lightning between enemies.","max_rank":3,"range_burn":[800],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Zeri discharges a nova of electricity, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies and gaining ? stacks of Overcharge for each champion hit for ? seconds. Each stack grants \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e. Hitting an enemy champion with an Attack or Ability adds a stack of Overcharge and refreshes its duration by ? seconds. Critical strikes add 2 additional stacks.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile Overcharged Zeri also gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e and \\u003cspellName\\u003eBurst Fire\\u003c/spellName\\u003e becomes a faster triple shot that deals an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and chains \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e + \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to nearby enemies. \\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZeriR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0221/ability_0221_R1.webm"}]},"222":{"id":222,"key":"Jinx","name":"Jinx","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Jinx.png","enemy_tips":["Jinx\'s minigun takes time to ramp up. If you see her poking with rockets try to jump on her and burst her down.","Jinx\'s ultimate does less damage the closer you are to her.","Jinx\'s snare grenades have a long cooldown and are her primary means of protecting herself. If she misses with them she will have a hard time escaping if engaged upon. "],"ally_tips":["Rockets aren\'t always the best choice! Jinx\'s minigun is incredibly powerful when fully ramped up. Switch to it whenever an enemy champion gets too close.","Jinx\'s rockets deal full damage to all enemies in the explosion. Use them on minions in lane to hit nearby enemy champions without drawing minion aggro.","When a fight starts try to stay on the edge of fray by poking with rockets and Zap!. Do not run in and unload with the minigun until you feel it is safe."],"passive":{"name":"Get Excited!","description":"Jinx receives massively increased Move Speed and Attack Speed whenever she helps kill or destroy an enemy champions epic jungle monster, or structure.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Jinx_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0222/ability_0222_P1.webm"},"spells":[{"key":"Q","name":"Switcheroo!","description":"Jinx modifies her basic attacks by swapping between Pow-Pow, her minigun and Fishbones, her rocket launcher. Attacks with Pow-Pow grant Attack Speed, while attacks with Fishbones deal area of effect damage, gain increased range, but drain Mana and attack slower.","max_rank":5,"range_burn":[600],"cooldown_burn":[0],"cost_burn":[20],"tooltip":"Jinx swaps weapons between Fishbones the rocket launcher and Pow-Pow the minigun.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile using the rocket launcher, Jinx\'s Attacks deal \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the target and nearby enemies, gain ? range, cost Mana, and scale ?% less with bonus Attack Speed.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile using the minigun, Jinx\' Attacks grant \\u003cattackSpeed\\u003eAttack Speed\\u003c/attackSpeed\\u003e for ? seconds, stacking up to ? times (\\u003cattackSpeed\\u003e+?% %i:scaleAS% max\\u003c/attackSpeed\\u003e).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JinxQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0222/ability_0222_Q1.webm"},{"key":"W","name":"Zap!","description":"Jinx uses Zapper, her shock pistol, to fire a blast that deals damage to the first enemy hit, slowing and revealing it.","max_rank":5,"range_burn":[1450],"cooldown_burn":[8,7,6,5,4],"cost_burn":[50,60,70,80,90],"tooltip":"Jinx fires a shock blast that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit, \\u003cstatus\\u003eSlows\\u003c/status\\u003e them by ?%, and reveals them for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JinxW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0222/ability_0222_W1.webm"},{"key":"E","name":"Flame Chompers!","description":"Jinx throws out a line of snare grenades that explode after 5 seconds, lighting enemies on fire. Flame Chompers will bite enemy champions who walk over them, rooting them in place.","max_rank":5,"range_burn":[925],"cooldown_burn":[24,20,17,13,10],"cost_burn":[90],"tooltip":"Jinx tosses out 3 chompers that last for ? seconds. They explode on contact with enemy champions, \\u003cstatus\\u003eRooting\\u003c/status\\u003e them for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JinxE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0222/ability_0222_E1.webm"},{"key":"R","name":"Super Mega Death Rocket!","description":"Jinx fires a super rocket across the map that gains damage as it travels. The rocket will explode upon colliding with an enemy champion, dealing damage to it and surrounding enemies based on their missing Health.","max_rank":3,"range_burn":[25000],"cooldown_burn":[75,65,55],"cost_burn":[100],"tooltip":"Jinx fires a rocket that explodes on the first enemy champion hit, dealing \\u003cphysicalDamage\\u003e? to ? + ?% missing Health physical damage\\u003c/physicalDamage\\u003e, gaining damage over the first second of travel time. Nearby enemies take ?% Damage.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eMissing Health damage cannot exceed ? against Monsters.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/JinxR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0222/ability_0222_R1.webm"}]},"223":{"id":223,"key":"TahmKench","name":"Tahm Kench","image_url":"https://opgg-static.akamaized.net/images/lol/champion/TahmKench.png","enemy_tips":["When you see Tahm Kench use the shield from Thick Skin, remember that he just opted out of a good deal of healing. He will also not accumulate new gray health until Thick Skin comes off cooldown. Use this to your advantage!","Watch out for Kench\'s Abyssal Dive - you can cancel it\'s channel with immobilizing crowd control effects."],"ally_tips":["Your most important function as a support is to keep fragile allies safe. Keep Devour\'s range and cooldown in mind and position accordingly!","Consider carefully when to use Thick Skin\'s active. Sometimes shielding early to avoid further damage is good, but sometimes the healing is more beneficial."],"passive":{"name":"An Acquired Taste","description":"Tahm Kench puts the heft of his immense body behind his attacks, gaining extra damage based on his total health. Damaging enemy champions builds stacks of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e. At three stacks, he can use \\u003cspellName\\u003eDevour\\u003c/spellName\\u003e on an enemy champion.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/TahmKenchP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0223/ability_0223_P1.webm"},"spells":[{"key":"Q","name":"Tongue Lash","description":"Tahm Kench lashes out with his tongue, damaging and slowing the first unit hit and healing himself if he strikes an enemy champion.\\u003cbr\\u003e\\u003cbr\\u003eApplies a stack of  \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e to enemy champions. If the champion already has 3 stacks of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e, they are stunned and the stacks are consumed.","max_rank":5,"range_burn":[900],"cooldown_burn":[7,6,6,5,5],"cost_burn":[50,46,42,38,34],"tooltip":"Deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit and slows them by ?% for ? seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eOn Champion hit, heals Tahm for \\u003chealing\\u003e? +?% of his missing health\\u003c/healing\\u003e and applies a stack of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e dealing \\u003cmagicDamage\\u003e? extra magic damage\\u003c/magicDamage\\u003e. If that Champion already had 3 stacks of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e, they will also be stunned for ? seconds, consuming the stacks.\\u003cbr /\\u003e\\u003cbr /\\u003eActivate \\u003cspan class=\\"color0bf7de\\"\\u003eDevour\\u003c/span\\u003e while your tongue is in midair to devour enemy champions who already have 3 stacks of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e from a distance when you hit them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TahmKenchQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0223/ability_0223_Q1.webm"},{"key":"W","name":"Abyssal Dive","description":"Dive down and then re-appear at target location, damaging and knocking up all enemies in an area.","max_rank":5,"range_burn":[1000,1050,1100,1150,1200],"cooldown_burn":[21,20,19,18,17],"cost_burn":[60,75,90,105,120],"tooltip":"Dive down and then re-appear at target location, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and knock up all enemies in an area for ? second. Hitting at least one enemy champion refunds ?% of the cooldown and mana cost.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspan class=\\"color0bf7de\\"\\u003eDevoured\\u003c/span\\u003e allies can be taken along for the ride (but can always hop out early).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TahmKenchW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0223/ability_0223_W1.webm"},{"key":"E","name":"Thick Skin","description":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e Tahm Kench stores a percent of the damage he takes and heals based on it while out of combat.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Convert all stored damage into a temporary shield.","max_rank":5,"range_burn":[2400],"cooldown_burn":[3],"cost_burn":[0],"tooltip":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e ?% of damage Tahm Kench takes is stored by his \\u003cspellName\\u003eThick Skin\\u003c/spellName\\u003e, increased to ?% if there are at least ? nearby enemy champions. If Kench has not taken damage within ? seconds, \\u003cspellName\\u003eThick Skin\\u003c/spellName\\u003e will rapidly be consumed to heal Tahm for ? of its value.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Convert all your stored \\u003cspellName\\u003eThick Skin\\u003c/spellName\\u003e into a \\u003cshield\\u003eShield\\u003c/shield\\u003e, lasting ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TahmKenchE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0223/ability_0223_E1.webm"},{"key":"R","name":"Devour","description":"Tahm Kench devours a champion for a few seconds, dealing magic damage if they are an enemy, or shielding them if they are an ally.","max_rank":3,"range_burn":[25000],"cooldown_burn":[0],"cost_burn":[100],"tooltip":"Tahm Kench devours a champion for a few seconds. He can re-cast to spit them out.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspecialRules\\u003eEnemy Champions:\\u003c/specialRules\\u003e Require 3 stacks of \\u003cspellName\\u003eAn Acquired Taste\\u003c/spellName\\u003e. Are devoured for up to ? seconds and take \\u003cmagicDamage\\u003e? (+? of their Max Health) magic damage\\u003c/magicDamage\\u003e. Tahm Kench is slowed by ?% and \\u003ckeywordName\\u003eGrounded\\u003c/keywordName\\u003e during this effect.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspecialRules\\u003eAlly Champions:\\u003c/specialRules\\u003e Are devoured for up to ? seconds and are granted \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for up to ? seconds after being spit out. Allies can also choose to exit early. Tahm Kench is \\u003ckeywordName\\u003eGrounded\\u003c/keywordName\\u003e during this effect, but can cast \\u003ckeywordName\\u003eAbyssal Dive\\u003c/keywordName\\u003e and gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/TahmKenchRWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0223/ability_0223_R1.webm"}]},"234":{"id":234,"key":"Viego","name":"Viego","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Viego.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Sovereign\'s Domination","description":"Enemies who fall before Viego become wraiths. By attacking a wraith, Viego temporarily seizes control of the dead enemy\'s body, healing for a percentage of his target\'s max health and gaining access to their basic abilities and items. He replaces their Ultimate with a free cast of his own.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Viego_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0234/ability_0234_P1.webm"},"spells":[{"key":"Q","name":"Blade of the Ruined King","description":"Viego\'s spectral blade passively deals bonus percent current Health damage \\u003cOnHit\\u003eOn-Hit\\u003c/OnHit\\u003e and strikes twice vs. enemies he recently hit with an Ability, stealing Health.\\u003cbr\\u003e\\u003cbr\\u003eViego can activate this Ability to thrust his zweihander forward, impaling enemies in front of him.","max_rank":5,"range_burn":[600],"cooldown_burn":[5,4,4,3,3],"cost_burn":[0],"tooltip":" \\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Viego\'s Attacks deal an additional \\u003cphysicalDamage\\u003e? current Health physical damage\\u003c/physicalDamage\\u003e. His first Attack against an enemy he has recently damaged with an Ability hits a second time, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and restoring \\u003chealing\\u003e?% of damage dealt as Health\\u003c/healing\\u003e. These bonuses are kept during \\u003ckeywordMajor\\u003ePossession\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive: \\u003c/spellActive\\u003eViego stabs forward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViegoQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0234/ability_0234_Q1.webm"},{"key":"W","name":"Spectral Maw","description":"Viego charges up before dashing forward, releasing a ball of concentrated Black Mist that stuns the first enemy hit.","max_rank":5,"range_burn":[400],"cooldown_burn":[8],"cost_burn":[0],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Viego begins gathering Mist, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e himself by ?%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Viego dashes forward and hurls the gathered Mist. Deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eStuns\\u003c/status\\u003e the first enemy hit for ? to ? seconds based on charge time.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViegoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0234/ability_0234_W1.webm"},{"key":"E","name":"Harrowed Path","description":"Viego commands the Black Mist to haunt and surround a piece of terrain. Viego can hide in the Mist as a wraith, gaining camouflage, Move Speed, and Attack Speed.","max_rank":5,"range_burn":[750],"cooldown_burn":[14,12,10,8,6],"cost_burn":[0],"tooltip":"Viego sends forth a spectre to haunt the first terrain hit, surrounding it with Mist for ? seconds. Viego gains \\u003ckeywordStealth\\u003eCamouflage\\u003c/keywordStealth\\u003e, \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, and \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e while inside the Mist.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViegoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0234/ability_0234_E1.webm"},{"key":"R","name":"Heartbreaker","description":"Viego teleports to a nearby location and executes an enemy champion on arrival, piercing their heart and causing a destructive shockwave around them that knocks away their allies.","max_rank":3,"range_burn":[500],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Viego discards any souls he is currently \\u003ckeywordMajor\\u003ePossessing\\u003c/keywordMajor\\u003e and teleports. On arrival he Attacks the champion with the lowest percent Health, briefly \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% and dealing \\u003cphysicalDamage\\u003e? + ?% missing Health physical damage\\u003c/physicalDamage\\u003e. Other nearby enemies are \\u003cstatus\\u003eKnocked Back\\u003c/status\\u003e and take \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViegoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0234/ability_0234_R1.webm"}]},"235":{"id":235,"key":"Senna","name":"Senna","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Senna.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Absolution","description":"When units die near Senna, their souls are periodically trapped by the Black Mist. Senna can attack these souls to free them, absorbing the Mist that held them in death. Mist fuels her Relic Cannon\'s power with increased Attack Damage, Attack Range, and Critical Strike Chance. \\u003cbr\\u003e\\u003cbr\\u003eAttacks from Senna\'s Relic Cannon take longer to fire, deal bonus damage, and briefly grant her a portion of her target\'s Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Senna_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0235/ability_0235_P1.webm"},"spells":[{"key":"Q","name":"Piercing Darkness","description":"From the twin barrels of her Relic Cannon, Senna fires a unified beam of light and shadow through a target, healing allies and damaging enemies.","max_rank":5,"range_burn":[600],"cooldown_burn":[15],"cost_burn":[70,80,90,100,110],"tooltip":"Senna shoots a bolt of piercing shadow through an ally or enemy, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ? for ? second. Restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to allied champions. \\u003cbr /\\u003e\\u003cbr /\\u003eAttacks reduce this Ability\'s Cooldown by ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SennaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0235/ability_0235_Q1.webm"},{"key":"W","name":"Last Embrace","description":"Senna sends forth a wave of Black Mist. If it hits an enemy it latches onto them hungrily, rooting them and everything nearby after a brief delay.","max_rank":5,"range_burn":[1250],"cooldown_burn":[11],"cost_burn":[50,55,60,65,70],"tooltip":"Senna sends forth the Black Mist, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit. After a ? second delay the target and other nearby enemies are \\u003cstatus\\u003eRooted\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SennaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0235/ability_0235_W1.webm"},{"key":"E","name":"Curse of the Black Mist","description":"Senna draws the Mist she has stored in her weapon into a storm around her, embracing darkness and becoming a wraith within. Allies who enter the area are camouflaged and also appear as wraiths as the Mist shrouds them. Wraiths gain increased Move Speed, are unselectable, and hide their identities.","max_rank":5,"range_burn":[400],"cooldown_burn":[26,24,23,21,20],"cost_burn":[70],"tooltip":"Senna dissolves into a cloud of Black Mist for ? seconds, becoming a Wraith. Allied champions who enter the Mist are \\u003ckeywordStealth\\u003eCamouflaged\\u003c/keywordStealth\\u003e and become Wraiths when they leave. Wraiths gain \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, are Unselectable, and hide their identities as long as no enemy champions are nearby.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SennaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0235/ability_0235_E1.webm"},{"key":"R","name":"Dawning Shadow","description":"Senna calls upon the relic stones of fallen Sentinels, splitting her relic cannon into a holy array of shadow and light. She then fires a global beam that shields allies from harm, while damaging enemies caught in the center.","max_rank":3,"range_burn":[25000],"cooldown_burn":[160,140,120],"cost_burn":[100],"tooltip":"Senna fires a beam of light that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to all enemy champions hit. Allied champions hit in a wider area receive \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SennaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0235/ability_0235_R1.webm"}]},"236":{"id":236,"key":"Lucian","name":"Lucian","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Lucian.png","enemy_tips":["Lucian has strong burst, but little sustained damage.","Lucian cannot change the aim of The Culling. Take advantage of this by avoiding the angle of the bullets.","Piercing Light does not give Lucian extra Attack Range. He still needs to find a target in range to line up his shot. Avoid Piercing Light by anticipating the angle Lucian will choose."],"ally_tips":["For optimal burst, try to combine Relentless Pursuit into Piercing Light.","Ardent Blaze actually explodes in a star pattern. Try to line it up so the spokes hit enemy champions.","Once you have chosen an angle for The Culling, you cannot change it. Pick your moment well!","Because of Lightslinger, Lucian benefits more from Attack Damage than he does from Attack Speed."],"passive":{"name":"Lightslinger","description":"Whenever Lucian uses an ability, his next attack becomes a double-shot. When Lucian is empowered by another Ally, his next 2 basic attacks will deal bonus magic damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Lucian_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0236/ability_0236_P1.webm"},"spells":[{"key":"Q","name":"Piercing Light","description":"Lucian shoots a bolt of piercing light through a target.","max_rank":5,"range_burn":[500],"cooldown_burn":[9,8,7,6,5],"cost_burn":[48,56,64,72,80],"tooltip":"Lucian shoots a bolt of piercing light, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LucianQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0236/ability_0236_Q1.webm"},{"key":"W","name":"Ardent Blaze","description":"Lucian shoots a missile that explodes in a star shape, marking and briefly revealing enemies. Lucian gains Move Speed for attacking marked enemies.","max_rank":5,"range_burn":[900],"cooldown_burn":[14,13,12,11,10],"cost_burn":[60],"tooltip":"Lucian fires a shot that explodes at the end of its range or on the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, briefly revealing enemies and marking them for 6 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen Lucian or an ally damages a marked enemy, Lucian gains \\u003cspeed\\u003e60/65/70/75/80 Move Speed\\u003c/speed\\u003e for 1 second. Allies triggering this effect will also grant Lucian \\u003cattention\\u003eVigilance\\u003c/attention\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LucianW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0236/ability_0236_W1.webm"},{"key":"E","name":"Relentless Pursuit","description":"Lucian quickly dashes a short distance. Lightslinger attacks reduce Relentless Pursuit\'s cooldown.","max_rank":5,"range_burn":[445],"cooldown_burn":[22,20,18,16,14],"cost_burn":[40,30,20,10,0],"tooltip":"Lucian dashes.\\u003cbr /\\u003e\\u003cbr /\\u003eCooldown is reduced by 1 second whenever Lucian hits an enemy with \\u003cspellName\\u003eLightslinger\\u003c/spellName\\u003e (2 seconds for champions). ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LucianE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0236/ability_0236_E1.webm"},{"key":"R","name":"The Culling","description":"Lucian unleashes a torrent of shots from his weapons.","max_rank":3,"range_burn":[1400],"cooldown_burn":[110,100,90],"cost_burn":[100],"tooltip":"Lucian rapidly fires \\u003ckeywordMajor\\u003e?\\u003c/keywordMajor\\u003e shots in a direction for ? seconds or until he \\u003crecast\\u003eRecasts\\u003c/recast\\u003e. Each shot deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile firing, Lucian may use \\u003cspellName\\u003eRelentless Pursuit\\u003c/spellName\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eTotal Damage: \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LucianR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0236/ability_0236_R1.webm"}]},"238":{"id":238,"key":"Zed","name":"Zed","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Zed.png","enemy_tips":["Zed receives bonus effect from Attack Damage items he purchases, so Armor is super effective against him.","After Zed uses his Living Shadow, he is at his most vulnerable as his damage, slow, and mobility are both dependent upon it.","Zed\'s Shadow Slash can only slow you if his shadow hits you with it. "],"ally_tips":["Saving energy and spell cooldowns until you use your ultimate will maximize Death Mark\'s damage.","Quickly double tapping Living Shadow will teleport Zed to his shadow immediately for rapid escapes.","Placing a Living Shadow before using Death Mark can give Zed a safe escape from combat."],"passive":{"name":"Contempt for the Weak","description":"Zed\'s basic attacks against low health targets deals bonus Magic Damage. This effect can only occur once every few seconds against the same enemy champion.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/shadowninja_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0238/ability_0238_P1.webm"},"spells":[{"key":"Q","name":"Razor Shuriken","description":"Zed and his shadows throw their shurikens.\\u003cbr\\u003e\\u003cbr\\u003eEach shuriken deals damage to every enemy hit.","max_rank":5,"range_burn":[900],"cooldown_burn":[6],"cost_burn":[75,70,65,60,55],"tooltip":"Zed and his \\u003ckeywordMajor\\u003eShadows\\u003c/keywordMajor\\u003e throw their shurikens, each dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy they pass through, and \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to each additional enemy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZedQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0238/ability_0238_Q1.webm"},{"key":"W","name":"Living Shadow","description":"\\u003cfont color=\'#FF9900\'\\u003ePassive:\\u003c/font\\u003e Zed gains energy whenever he and his shadows strike an enemy with the same ability. Energy can only be gained once per cast ability.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eActive:\\u003c/font\\u003e Zed\'s shadow dashes forward, remaining in place for a few seconds. Reactivating Living Shadow will cause Zed to switch positions with this shadow.","max_rank":5,"range_burn":[650],"cooldown_burn":[20,18,17,15,14],"cost_burn":[40,35,30,25,20],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Zed gains \\u003ckeywordMajor\\u003e30/35/40/45/50 Energy\\u003c/keywordMajor\\u003e whenever he and his \\u003ckeywordMajor\\u003eShadows\\u003c/keywordMajor\\u003e strike an enemy with the same Ability.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Zed\'s \\u003ckeywordMajor\\u003eShadow\\u003c/keywordMajor\\u003e dashes forward, remaining in place for 5 seconds. \\u003crecast\\u003eRecasting\\u003c/recast\\u003e this Ability will cause Zed to switch positions with this \\u003ckeywordMajor\\u003eShadow\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZedW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0238/ability_0238_W1.webm"},{"key":"E","name":"Shadow Slash","description":"Zed and his shadows slash, dealing damage to nearby enemies.","max_rank":5,"range_burn":[290],"cooldown_burn":[5,4,4,3,3],"cost_burn":[50],"tooltip":"Zed and his \\u003ckeywordMajor\\u003eShadows\\u003c/keywordMajor\\u003e slash, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to nearby enemies.\\u003cbr /\\u003e\\u003cbr /\\u003eEach enemy champion hit by Zed\'s slash reduces \\u003cspellName\\u003eLiving Shadow\\u003c/spellName\\u003e\'s Cooldown by ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eEnemies hit by a \\u003ckeywordMajor\\u003eShadow\\u003c/keywordMajor\\u003e\'s slash are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for ? seconds. Enemies hit by multiple slashes take no additional damage but are \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZedE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0238/ability_0238_E1.webm"},{"key":"R","name":"Death Mark","description":"Zed becomes untargetable and dashes to an enemy champion, marking them. After 3 seconds the mark triggers, repeating a portion of all the damage Zed dealt to the target while they were marked.","max_rank":3,"range_burn":[625],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Zed becomes Untargetable and dashes to an enemy champion, marking them. After ? seconds, the mark triggers, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and repeating ?% of all damage dealt to the target by Zed while the mark was active.\\u003cbr /\\u003e\\u003cbr /\\u003eThe dash leaves a \\u003ckeywordMajor\\u003eShadow\\u003c/keywordMajor\\u003e behind for ? seconds. Zed can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability to switch positions with this \\u003ckeywordMajor\\u003eShadow\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ZedR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0238/ability_0238_R1.webm"}]},"240":{"id":240,"key":"Kled","name":"Kled","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kled.png","enemy_tips":["Kled generates courage by damaging enemies with his Pocket Pistol and basic attacks, killing minions, and attacking structures or epic monsters.","Watch Kled\'s courage bar when he\'s off his mount - when it reaches 100%, he will remount and regain a significant amount of health.","Kled is much more threatening when he has Violent Tendencies ready."],"ally_tips":["Kled generates some courage by killing minions, but gets much more from fighting Champions.","The last hit of Violent Tendencies deals more damage than the first three - make sure you hit it!","Chaaaaaaaarge!!! can be cast at a great range. Try and predict where the enemy team will be by the time you reach them."],"passive":{"name":"Skaarl, the Cowardly Lizard","description":"Kled rides his trusty steed, Skaarl, who takes damage for him. When Skaarl\'s health depletes, Kled dismounts.\\u003cbr\\u003e\\u003cbr\\u003eWhile dismounted, Kled\'s abilities change and he deals less damage to champions. Kled can restore Skaarl\'s courage by fighting enemies. At maximum courage, Kled remounts with a portion of Skaarl\'s health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kled_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0240/ability_0240_P1.webm"},"spells":[{"key":"Q","name":"Bear Trap on a Rope","description":"Kled throws a bear trap that damages and hooks an enemy champion. If shackled for a short duration, the target takes additional physical damage and is yanked toward Kled.\\u003cbr\\u003e\\u003cbr\\u003eWhen dismounted, this ability is replaced by Pocket Pistol, a ranged gun blast that knocks back Kled and restores courage.","max_rank":5,"range_burn":[800],"cooldown_burn":[11,10,9,8,7],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eMounted:\\u003c/keywordMajor\\u003e Kled throws a bear trap that deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and hooks onto the first enemy champion or large jungle monster hit.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Kled stays near a hooked enemy for 1.75 seconds, he yanks out the trap, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e, \\u003cstatus\\u003ePulling\\u003c/status\\u003e them, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ?% for ? seconds, and applying ?% Grievous Wounds for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KledQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0240/ability_0240_Q1.webm"},{"key":"W","name":"Violent Tendencies","description":"Kled gains massive attack speed for four attacks. The fourth attack deals more damage.","max_rank":5,"range_burn":[0],"cooldown_burn":[12,10,9,7,6],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every 4 seconds, Kled\'s next Attack grants \\u003cattackSpeed\\u003e150% Attack Speed\\u003c/attackSpeed\\u003e for four Attacks or 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThe fourth hit deals an additional \\u003cphysicalDamage\\u003e20/30/40/50/60 plus ? max Health physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KledW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0240/ability_0240_W1.webm"},{"key":"E","name":"Jousting","description":"Kled dashes, dealing physical damage and gaining a short burst of speed. Kled can cast this ability again to dash back through his initial target, dealing the same damage.","max_rank":5,"range_burn":[550],"cooldown_burn":[13,12,11,10,9],"cost_burn":[0],"tooltip":"Kled dashes, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies he passes through.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability hits an enemy champion or large jungle monster, Kled gains \\u003cspeed\\u003e50% Move Speed\\u003c/speed\\u003e for 1 second and can \\u003crecast\\u003eRecast\\u003c/recast\\u003e within 3 seconds to dash back through the same target.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KledE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0240/ability_0240_E1.webm"},{"key":"R","name":"Chaaaaaaaarge!!!","description":"Kled and Skaarl charge to a location, leaving a speed-granting trail behind them and gaining a shield. Skaarl locks onto and rams the first enemy champion encountered.","max_rank":3,"range_burn":[3500,4000,4500],"cooldown_burn":[140,125,110],"cost_burn":[0],"tooltip":"Kled charges toward an area, leaving a trail that grants allies increasing \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e. While charging and for 2 seconds after Kled gains up to \\u003cshield\\u003e? Shield\\u003c/shield\\u003e. Skaarl rams the first enemy champion encountered, dealing up to \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e (based on distance travelled) and briefly \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KledR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0240/ability_0240_R1.webm"}]},"245":{"id":245,"key":"Ekko","name":"Ekko","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ekko.png","enemy_tips":["Ekko is significantly weaker when his ultimate is down. Watch for the trail he leaves behind to determine if Chronobreak is available.","Ekko\'s stun zone takes 3 seconds to arm. Watch for the image he creates on cast and try to guess where the zone was placed.","The second hit of Timewinder does more damage than the first; try to avoid it."],"ally_tips":["Chronobreak is a potent escape tool, but it can also be quite powerful when used offensively. Don\'t underestimate its damage potential.","If you can proc Z-Drive Resonance on an enemy champion, it\'s worth taking risks to do so. The bonus Move Speed makes it easy to escape.","Phase Dive\'s dash is a great tool for setting up Ekko\'s other abilities. Use it to get double hits with Timewinder or get into position to detonate Parallel Convergence."],"passive":{"name":"Z-Drive Resonance","description":"Every third attack or damaging spell on the same target deals bonus magic damage, and grants Ekko a burst of speed if the target is a champion.\\u003cbr\\u003e\\u003cbr\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Ekko_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0245/ability_0245_P1.webm"},"spells":[{"key":"Q","name":"Timewinder","description":"Ekko throws a temporal grenade that expands into a time-distortion field upon hitting an enemy champion, slowing and damaging anyone caught inside. After a delay, the grenade rewinds back to Ekko, dealing damage on its return.","max_rank":5,"range_burn":[1075],"cooldown_burn":[9,8,8,7,7],"cost_burn":[50,60,70,80,90],"tooltip":"Ekko throws a device dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. On hitting a champion or reaching the end of its range, it expands into a field that \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies inside by 32/39/46/53/60%. After it expands, Ekko recalls it, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EkkoQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0245/ability_0245_Q1.webm"},{"key":"W","name":"Parallel Convergence","description":"Ekko\'s basic attacks deal bonus magic damage to low health enemies. He can cast Parallel Convergence to split the timeline, creating an anomaly after a few seconds that slows enemies caught inside. If Ekko enters the anomaly, he gains shielding and stuns enemies by suspending them in time.","max_rank":5,"range_burn":[1600],"cooldown_burn":[22,20,18,16,14],"cost_burn":[30,35,40,45,50],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Ekko\'s Attacks against enemies below 30% Health deal \\u003cmagicDamage\\u003e? missing Health magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Ekko launches a chronosphere lasting 1.5 seconds after a delay that \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies inside by ?%. If Ekko enters the sphere, he detonates it, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for 2.25 seconds and gaining \\u003cshield\\u003e? Shield\\u003c/shield\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EkkoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0245/ability_0245_W1.webm"},{"key":"E","name":"Phase Dive","description":"Ekko rolls evasively while charging up his Z-Drive. His next attack deals bonus damage and warps reality, teleporting him to his target.","max_rank":5,"range_burn":[325],"cooldown_burn":[9,8,8,7,7],"cost_burn":[40,45,50,55,60],"tooltip":"Ekko dashes and empowers his next Attack to have bonus range, teleport him to his target, and deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EkkoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0245/ability_0245_E1.webm"},{"key":"R","name":"Chronobreak","description":"Ekko shatters his timeline, becoming untargetable and rewinding to a more favorable point in time. He returns to whenever he was a few seconds ago, and heals for a percentage of the damage received in that duration. Enemies near his arrival zone take massive damage.","max_rank":3,"range_burn":[850],"cooldown_burn":[110,80,50],"cost_burn":[100],"tooltip":"Ekko turns back time, entering Stasis while teleporting to where he was 4 seconds ago and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to nearby enemies. In addition, Ekko restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e, increased by ?% for each 1% Health he lost in last 4 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/EkkoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0245/ability_0245_R1.webm"}]},"246":{"id":246,"key":"Qiyana","name":"Qiyana","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Qiyana.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Royal Privilege","description":"Qiyana\'s first basic attack or ability against each enemy deals bonus damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Qiyana_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0246/ability_0246_P1.webm"},"spells":[{"key":"Q","name":"Elemental Wrath / Edge of Ixtal","description":"Qiyana swings her weapon, dealing damage with a bonus effect based on her element.","max_rank":5,"range_burn":[525],"cooldown_burn":[7],"cost_burn":[35],"tooltip":"If Qiyana does not have an \\u003ckeywordMajor\\u003eEnchantment\\u003c/keywordMajor\\u003e, she slashes, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to enemies in a small area. If she does, this Ability gains extra range and an additional effect based on the type of \\u003ckeywordMajor\\u003eEnchantment\\u003c/keywordMajor\\u003e:\\u003cli\\u003e\\u003ckeywordMajor\\u003eIce Enchantment\\u003c/keywordMajor\\u003e: Briefly \\u003cstatus\\u003eRoots\\u003c/status\\u003e, then \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? second.\\u003cli\\u003e\\u003ckeywordMajor\\u003eRock Enchantment\\u003c/keywordMajor\\u003e: Deals an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to units below ?% Health.\\u003cli\\u003e\\u003ckeywordMajor\\u003eWild Enchantment\\u003c/keywordMajor\\u003e: Leaves a trail that turns Qiyana \\u003ckeywordStealth\\u003eInvisible\\u003c/keywordStealth\\u003e and grants \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QiyanaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0246/ability_0246_Q1.webm"},{"key":"W","name":"Terrashape","description":"Qiyana dashes to a location and enchants her weapon with an element. Her attacks and abilities deal bonus damage while her weapon is enchanted. ","max_rank":5,"range_burn":[1100],"cooldown_burn":[7],"cost_burn":[25,30,35,40,45],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While Qiyana\'s weapon is \\u003ckeywordMajor\\u003eEnchanted\\u003c/keywordMajor\\u003e, she gains \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e and her Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. She also gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e while out of combat near the corresponding terrain type.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Qiyana dashes towards a nearby brush, terrain, or river and \\u003ckeywordMajor\\u003eEnchants\\u003c/keywordMajor\\u003e her weapon with that particular terrain type. This refreshes \\u003cspellName\\u003eElemental Wrath / Edge of Ixtal\\u003c/spellName\\u003e\'s Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QiyanaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0246/ability_0246_W1.webm"},{"key":"E","name":"Audacity","description":"Qiyana dashes to an enemy, damaging them.","max_rank":5,"range_burn":[650],"cooldown_burn":[12,11,10,9,8],"cost_burn":[40,45,50,55,60],"tooltip":"Qiyana dashes through an enemy and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to them.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QiyanaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0246/ability_0246_E1.webm"},{"key":"R","name":"Supreme Display of Talent","description":"Qiyana sends out a shockwave that detonates whatever elements she hits with it, stunning and damaging nearby enemies.","max_rank":3,"range_burn":[950],"cooldown_burn":[120],"cost_burn":[100],"tooltip":"Qiyana launches a shockwave that \\u003cstatus\\u003eKnocks Back\\u003c/status\\u003e enemies and detonates when it hits terrain. The explosion follows the entire edge of the terrain, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for between 0.5 and ? seconds and dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e. \\u003cstatus\\u003eStun\\u003c/status\\u003e duration scales down with distance the shockwave has travelled.\\u003cbr /\\u003e\\u003cbr /\\u003eAny river or brush the shockwave passes through also explode after a delay for the same damage and \\u003cstatus\\u003eStun\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/QiyanaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0246/ability_0246_R1.webm"}]},"254":{"id":254,"key":"Vi","name":"Vi","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Vi.png","enemy_tips":["A fully charged Vault breaker deals double damage. If you see Vi start to charge you should back off or try to dodge it.","Vi will shred your Armor and gain Attack Speed if she manages to hit you three times in a row. Try not to engage in extended brawls with her.","Vi cannot be stopped while using her ult. Remember to save your displacement effects until after she\'s done charging."],"ally_tips":["A fully charged Vault Breaker will deal double damage. It\'s great for catching and finishing off fleeing enemies.","Relentless Force does full damage to anyone caught in the shockwave. Use it on minions in lane to hit enemies hiding behind them.","Cease and Desist is a powerful initiation tool, just remember not to get too far ahead of the rest of your team."],"passive":{"name":"Blast Shield","description":"Vi charges a shield over time. The shield can be activated by hitting an enemy with an ability.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ViPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0254/ability_0254_P1.webm"},"spells":[{"key":"Q","name":"Vault Breaker","description":"Vi charges her gauntlets and unleashes a vault shattering punch, carrying her forward. Enemies she hits are knocked back and receive a stack of Denting Blows.","max_rank":5,"range_burn":[250],"cooldown_burn":[12,10,9,7,6],"cost_burn":[50,60,70,80,90],"tooltip":"\\u003ccharge\\u003eBegin Charging:\\u003c/charge\\u003e Vi begins charging a powerful punch, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e herself by 15%.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crelease\\u003eRelease:\\u003c/release\\u003e Vi dashes forward dealing between \\u003cphysicalDamage\\u003e? and ? physical damage\\u003c/physicalDamage\\u003e based on charge time and applying \\u003cspellName\\u003eDenting Blows\\u003c/spellName\\u003e to all enemies hit. Vi stops upon colliding with an enemy champion, and \\u003cstatus\\u003eKnocks\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0254/ability_0254_Q1.webm"},{"key":"W","name":"Denting Blows","description":"Vi\'s punches break her opponent\'s Armor, dealing bonus damage and granting her Attack Speed.","max_rank":5,"range_burn":[750],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Every 3rd Attack on the same target deals an additional \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e, removes \\u003cscaleArmor\\u003e20% Armor\\u003c/scaleArmor\\u003e and grants Vi \\u003cattackSpeed\\u003e30/37.5/45/52.5/60% Attack Speed\\u003c/attackSpeed\\u003e for 4 seconds. It also reduces the remaining Cooldown of \\u003cspellName\\u003eBlast Shield\\u003c/spellName\\u003e by 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0254/ability_0254_W1.webm"},{"key":"E","name":"Relentless Force","description":"Vi\'s next attack blasts through her target, dealing damage to enemies behind it.","max_rank":5,"range_burn":[400],"cooldown_burn":[1],"cost_burn":[26,32,38,44,50],"tooltip":"Vi\'s next Attack deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the target and enemies behind them.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has 2 charges (? second refresh).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0254/ability_0254_E1.webm"},{"key":"R","name":"Cease and Desist","description":"Vi runs down an enemy, knocking aside anyone in the way. When she reaches her target she knocks it into the air, jumps after it, and slams it back into the ground.","max_rank":3,"range_burn":[800],"cooldown_burn":[120,100,80],"cost_burn":[100,125,150],"tooltip":"Vi singles out an enemy champion, revealing them and dashing unstoppably towards them. Upon reaching them, Vi \\u003cstatus\\u003eKnocks\\u003c/status\\u003e them \\u003cstatus\\u003eUp\\u003c/status\\u003e for ? seconds and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eAny other enemies Vi collides with are dealt damage, knocked aside, and \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ViR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0254/ability_0254_R1.webm"}]},"266":{"id":266,"key":"Aatrox","name":"Aatrox","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Aatrox.png","enemy_tips":["Aatrox\'s attacks are very telegraphed, so use the time to dodge the hit zones.","Aatrox\'s Infernal Chains are easier to exit when running towards the sides or at Aatrox.","Keep your distance when Aatrox uses his Ultimate to prevent him from reviving."],"ally_tips":["Use Umbral Dash while casting The Darkin Blade to increase your chances of hitting the enemy.","Crowd Control abilities like Infernal Chains or your allies\' immobilizing effects will help you set up The Darkin Blade.","Cast World Ender when you are sure you can force a fight."],"passive":{"name":"Deathbringer Stance","description":"Periodically, Aatrox\'s next basic attack deals bonus \\u003cphysicalDamage\\u003ephysical damage\\u003c/physicalDamage\\u003e and heals him, based on the target\'s max health. ","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Aatrox_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0266/ability_0266_P1.webm"},"spells":[{"key":"Q","name":"The Darkin Blade","description":"Aatrox slams his greatsword down, dealing physical damage. He can swing three times, each with a different area of effect.","max_rank":5,"range_burn":[25000],"cooldown_burn":[14,12,10,8,6],"cost_burn":[0],"tooltip":"Aatrox slams his greatsword, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If they are hit on the edge, they are briefly \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e and they take \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e instead. This Ability can be \\u003crecast\\u003eRecast\\u003c/recast\\u003e twice, each one changing shape and dealing 25% more damage than the previous one.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AatroxQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0266/ability_0266_Q1.webm"},{"key":"W","name":"Infernal Chains","description":"Aatrox smashes the ground, dealing damage to the first enemy hit. Champions and large monsters have to leave the impact area quickly or they will be dragged to the center and take the damage again.","max_rank":5,"range_burn":[825],"cooldown_burn":[20,18,17,15,14],"cost_burn":[0],"tooltip":"Aatrox fires a chain, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e the first enemy hit by ?% for ? seconds and dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. Champions and large jungle monsters have ? seconds to leave the impact area or be \\u003cstatus\\u003ePulled\\u003c/status\\u003e back to the center and damaged again for the same amount.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AatroxW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0266/ability_0266_W1.webm"},{"key":"E","name":"Umbral Dash","description":"Passively, Aatrox heals when damaging enemy champions. On activation, he dashes in a direction.","max_rank":5,"range_burn":[25000],"cooldown_burn":[9,8,7,6,5],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Aatrox gains \\u003clifeSteal\\u003e?% Omnivamp\\u003c/lifeSteal\\u003e against champions, increased to \\u003clifeSteal\\u003e?% Omnivamp\\u003c/lifeSteal\\u003e during \\u003ckeywordMajor\\u003eWorld Ender\\u003c/keywordMajor\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Aatrox dashes. He can use this Ability while winding up his other Abilities.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AatroxE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0266/ability_0266_E1.webm"},{"key":"R","name":"World Ender","description":"Aatrox unleashes his demonic form, fearing nearby enemy minions and gaining attack damage, increased healing, and Move Speed. If he gets a takedown, this effect is extended.","max_rank":3,"range_burn":[25000],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Aatrox reveals his true demonic form, \\u003cstatus\\u003eFearing\\u003c/status\\u003e nearby minions for ? seconds and gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over ? seconds. He also gains \\u003cscaleAD\\u003e?% Attack Damage\\u003c/scaleAD\\u003e and increases \\u003chealing\\u003eself-healing by ?%\\u003c/healing\\u003e for the duration.\\u003cbr /\\u003e\\u003cbr /\\u003eChampion takedowns extend the duration of this effect by ? seconds and refresh the \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e effect.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AatroxR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0266/ability_0266_R1.webm"}]},"267":{"id":267,"key":"Nami","name":"Nami","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Nami.png","enemy_tips":["Aqua Prison is a very powerful ability with a long cooldown, take advantage of the situation if Nami misses this ability.","Tidal Wave has a very long range but travels slowly, be aware of when it is coming your way as you can move out of its path.","Try to avoid fighting an opponent affected by Tidecaller\'s Blessing, it lasts a short duration so waiting it out can help you greatly."],"ally_tips":["Aqua Prison has a long cooldown, make sure to use it at the right moment.","Using Ebb and Flow during an engagement with enemy champions will help sway the battle in your favor.","Nami\'s ultimate can come in very handy for initiating on enemies who are far away."],"passive":{"name":"Surging Tides","description":"When Nami\'s Abilities hit allied champions they gain Move Speed for a short duration.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/NamiPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0267/ability_0267_P1.webm"},"spells":[{"key":"Q","name":"Aqua Prison","description":"Sends a bubble to a target area, dealing damage and stunning all enemies on impact.","max_rank":5,"range_burn":[875],"cooldown_burn":[12,11,10,9,8],"cost_burn":[60],"tooltip":"Nami hurls a bubble, \\u003cstatus\\u003eStunning\\u003c/status\\u003e for 1.5 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NamiQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0267/ability_0267_Q1.webm"},{"key":"W","name":"Ebb and Flow","description":"Unleashes a stream of water that bounces back and forth between allied and enemy champions, healing allies and damaging enemies.","max_rank":5,"range_burn":[725],"cooldown_burn":[10],"cost_burn":[70,80,90,100,110],"tooltip":"Nami unleashes a stream of water that bounces between allied and enemy champions. Each champion can only be hit once, and it hits up to 3 targets.\\u003cli\\u003eRestores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to allies and will bounce to a nearby enemy champion. \\u003cli\\u003eDeals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies and will bounce to a nearby allied champion.\\u003cbr /\\u003eThe damage and healing value is modified by ? each bounce. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NamiW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0267/ability_0267_W1.webm"},{"key":"E","name":"Tidecaller\'s Blessing","description":"Empowers an allied champion for a short duration. The ally\'s basic attacks and spells deal bonus magic damage and slow the target.","max_rank":5,"range_burn":[800],"cooldown_burn":[11],"cost_burn":[55,60,65,70,75],"tooltip":"Nami empowers an allied champion\'s next 3 Attacks and Abilities for 6 seconds, causing them to \\u003cstatus\\u003eSlow\\u003c/status\\u003e their targets by ? for 1 second and deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NamiE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0267/ability_0267_E1.webm"},{"key":"R","name":"Tidal Wave","description":"Summons a massive Tidal Wave that knocks up, slows, and damages enemies. Allies hit gain double the effect of Surging Tides.","max_rank":3,"range_burn":[2550],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Nami summons a tidal wave, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for 0.5 seconds, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 50/60/70%, and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The duration of the \\u003cstatus\\u003eSlow\\u003c/status\\u003e increases based on distance the wave traveled, up to 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAllies hit by the wave gain double the effect of \\u003cspellName\\u003eSurging Tides\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NamiR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0267/ability_0267_R1.webm"}]},"268":{"id":268,"key":"Azir","name":"Azir","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Azir.png","enemy_tips":["Azir relies on his soldiers to deal damage and can only move them so often. Try to capitalize on windows of time when his soldiers are stationary.","Azir has immense damage over a prolonged amount of time but lacks the upfront burst of other mages. Try to burst him out before he can turn a confrontation around.","Try to think of Sand Soldiers as fire. Don\'t stand in the fire."],"ally_tips":["Be careful about putting down both of the soldiers stored by Arise! Unless you\'re going all-in, always have a soldier in your back pocket if you need to escape over a wall or if you misposition your other soldier and need damage now.","In the lane, try to position your soldiers between the enemy\'s minions and the enemy champion. This way you can use them both to last hit and to project threat onto your lane opponent.","Think of Emperor\'s Divide as a defensive ability first and foremost. Use it when the enemy engages on you or your allies. Remember that your team can walk through the soldiers summoned by Emperor\'s Divide and use this to your advantage when enemy melee champions engage on you.","Be a bird!"],"passive":{"name":"Shurima\'s Legacy","description":"Azir can summon the Disc of the Sun from the ruins of allied or enemy turrets.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Azir_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0268/ability_0268_P1.webm"},"spells":[{"key":"Q","name":"Conquering Sands","description":"Azir sends all Sand Soldiers towards a location. Sand Soldiers deal magic damage to enemies they pass through and apply a slow for 1 second.","max_rank":5,"range_burn":[740],"cooldown_burn":[14,12,10,8,6],"cost_burn":[55],"tooltip":"Azir orders all \\u003ckeywordMajor\\u003eSand Soldiers\\u003c/keywordMajor\\u003e to an area, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies they pass through and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by 25% for 1 second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AzirQWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0268/ability_0268_Q1.webm"},{"key":"W","name":"Arise!","description":"Azir summons a Sand Soldier to attack nearby targets for him, replacing his basic attack against targets within the soldier\'s range. Their attacks deal magic damage to enemies in a line. Arise! also passively grants attack speed to Azir and his Sand Soldiers.","max_rank":5,"range_burn":[500],"cooldown_burn":[1],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Azir gains \\u003cattackSpeed\\u003e15/25/35/45/55% Attack Speed\\u003c/attackSpeed\\u003e. Upon having 3 or more \\u003ckeywordMajor\\u003eSand Soldiers\\u003c/keywordMajor\\u003e, he gains an additional \\u003cattackSpeed\\u003e15/25/35/45/55% Attack Speed\\u003c/attackSpeed\\u003e for 5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Azir summons a \\u003ckeywordMajor\\u003eSand Soldier\\u003c/keywordMajor\\u003e for 10 seconds. When Azir Attacks an enemy near a \\u003ckeywordMajor\\u003eSand Soldier\\u003c/keywordMajor\\u003e, he instead orders the soldiers to stab, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e in their direction.\\u003cbr /\\u003e\\u003cbr /\\u003eThis Ability has ? charges.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AzirW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0268/ability_0268_W1.webm"},{"key":"E","name":"Shifting Sands","description":"Azir shields himself briefly and dashes to one of his Sand Soldiers, damaging enemies. If he hits an enemy champion, he instantly readies a new Sand Soldier for deployment and halts his dash.","max_rank":5,"range_burn":[1100],"cooldown_burn":[19,18,17,16,15],"cost_burn":[60],"tooltip":"Azir grants himself \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 1.5 seconds and dashes to one of his \\u003ckeywordMajor\\u003eSand Soldiers\\u003c/keywordMajor\\u003e, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies he passes through.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Azir hits an enemy champion, he stops and gains a \\u003ckeywordMajor\\u003eSand Soldier\\u003c/keywordMajor\\u003e charge.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AzirEWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0268/ability_0268_E1.webm"},{"key":"R","name":"Emperor\'s Divide","description":"Azir summons a wall of soldiers which charge forward, knocking back and damaging enemies.","max_rank":3,"range_burn":[250],"cooldown_burn":[120,105,90],"cost_burn":[100],"tooltip":"Azir summons a wall of armored soldiers that charges forward, \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e enemies and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The soldiers remain, blocking enemy paths for 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/AzirR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0268/ability_0268_R1.webm"}]},"350":{"id":350,"key":"Yuumi","name":"Yuumi","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Yuumi.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Bop \'n\' Block","description":"Periodically, when Yuumi attacks a champion, she restores mana and gains a shield that follows her, protecting her and the ally she\'s attached to.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/YuumiP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0350/ability_0350_P1.webm"},"spells":[{"key":"Q","name":"Prowling Projectile","description":"Yuumi fires a missile, dealing damage to the first target hit. It deals bonus damage and slows if it takes at least 1 second to get to its target.\\u003cbr\\u003e\\u003cbr\\u003eWhile Attached, the missile can be controlled with your cursor.","max_rank":6,"range_burn":[1150],"cooldown_burn":[13,12,10,9,7,6],"cost_burn":[90],"tooltip":"Yuumi summons an errant missile that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit. If the missile travels for ? second before impacting, it deals \\u003cmagicDamage\\u003e? plus ?% current Health magic damage\\u003c/magicDamage\\u003e instead and \\u003cstatus\\u003eSlows\\u003c/status\\u003e champions by ?% for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003eIf cast while \\u003ckeywordMajor\\u003eAttached\\u003c/keywordMajor\\u003e, Yuumi can control the missile using her mouse.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YuumiQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0350/ability_0350_Q1.webm"},{"key":"W","name":"You and Me!","description":"Passively, Yuumi increases her ally\'s Adaptive Force and her own. Actively, Yuumi dashes to a target ally, becoming untargetable from everything except turrets.","max_rank":5,"range_burn":[25000],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Yuumi increases her \\u003ckeywordMajor\\u003eAttached\\u003c/keywordMajor\\u003e ally\'s Adaptive Force by ? + ?%, and grants herself the same amount.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Yuumi dashes to an ally champion and \\u003ckeywordMajor\\u003eAttaches\\u003c/keywordMajor\\u003e to them. While Yuumi is \\u003ckeywordMajor\\u003eAttached\\u003c/keywordMajor\\u003e, she follows her partner\'s movement and is Untargetable except from towers.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e effects on Yuumi place this Ability on a ? second Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YuumiW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0350/ability_0350_W1.webm"},{"key":"E","name":"Zoomies","description":"Heals Yuumi and boosts Move Speed and Attack Speed. If she\'s attached, she passes it to her ally instead.\\u003cbr\\u003e","max_rank":5,"range_burn":[25000],"cooldown_burn":[12,11,10,9,8],"cost_burn":[0],"tooltip":"Yuumi restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to herself and gains \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e and \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for ? seconds. If Yuumi is \\u003ckeywordMajor\\u003eAttached\\u003c/keywordMajor\\u003e, this Ability affects her ally instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YuumiE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0350/ability_0350_E1.webm"},{"key":"R","name":"Final Chapter","description":"Yuumi channels seven waves of damage, rooting anyone hit by three or more. Yuumi can move, attach, and cast Zoomies! while channeling.","max_rank":3,"range_burn":[1100],"cooldown_burn":[130,110,90],"cost_burn":[100],"tooltip":"Yuumi channels for ? seconds, launching ? waves dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Champions hit by ? waves are \\u003cstatus\\u003eRooted\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eYuumi can move and cast \\u003cspellName\\u003eYou and Me!\\u003c/spellName\\u003e and \\u003cspellName\\u003eZoomies\\u003c/spellName\\u003e while channeling.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YuumiR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0350/ability_0350_R1.webm"}]},"360":{"id":360,"key":"Samira","name":"Samira","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Samira.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Daredevil Impulse","description":"Samira builds a combo by hitting attacks or abilities unique from the previous hit. Samira\'s attacks in melee range deal additional magic damage. Samira\'s attacks against enemies affected by \\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e effects will dash her to her attack range. If the enemy is \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e, she also keeps them \\u003cstatus\\u003eKnocked Up\\u003c/status\\u003e briefly.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/SamiraP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0360/ability_0360_P1.webm"},"spells":[{"key":"Q","name":"Flair","description":"Samira fires a shot or swings her sword, dealing damage. If cast during Wild Rush, strike all enemies in her path upon completion.","max_rank":5,"range_burn":[950],"cooldown_burn":[6,5,4,3,2],"cost_burn":[30],"tooltip":"Samira fires a shot, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability is cast towards an enemy in melee range, Samira will instead slash with her sword, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SamiraQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0360/ability_0360_Q1.webm"},{"key":"W","name":"Blade Whirl","description":"Samira slashes around her, damaging enemies and destroying enemy missiles.","max_rank":5,"range_burn":[325],"cooldown_burn":[30,28,26,24,22],"cost_burn":[60],"tooltip":"Samira slashes around her for ? seconds, damaging enemies twice for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e each and destroying any enemy missiles that enter the area.\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SamiraW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0360/ability_0360_W1.webm"},{"key":"E","name":"Wild Rush","description":"Samira dashes through an enemy (including structures), slashing enemies she passes through and gaining Attack Speed. Killing an enemy champion refreshes this ability\'s cooldown.","max_rank":5,"range_burn":[600],"cooldown_burn":[20,18,16,14,12],"cost_burn":[40],"tooltip":"Samira dashes through an enemy (including structures), slashing enemies she passes through dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and gaining \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e for 3 seconds. \\u003cbr /\\u003e\\u003cbr /\\u003eIf an enemy champion is killed within 3 seconds of Samira damaging them, Wild Rush\'s cooldown is reset.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SamiraE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0360/ability_0360_E1.webm"},{"key":"R","name":"Inferno Trigger","description":"Samira unleashes a torrent of shots from her weapons, wildly shooting all enemies surrounding her.","max_rank":3,"range_burn":[600],"cooldown_burn":[5],"cost_burn":[0],"tooltip":"Samira can only use this Ability if her current \\u003ckeywordMajor\\u003eStyle\\u003c/keywordMajor\\u003e rating is S.\\u003cbr /\\u003e\\u003cbr /\\u003eSamira unleashes a torrent of shots from her weapons, wildly shooting all enemies surrounding her 10 times over 2 seconds, each shot dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and applying lifesteal at ?% effectiveness. Each shot can also critically strike.\\u003cbr /\\u003e\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SamiraR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0360/ability_0360_R1.webm"}]},"412":{"id":412,"key":"Thresh","name":"Thresh","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Thresh.png","enemy_tips":["Thresh\'s Death Sentence has a long cast time. Watch for the cast to begin to take evasive actions.","Intentionally breaking a wall of The Box can allow a vulnerable ally to escape unscathed.","Thresh relies on collecting souls for a portion of his defense and damage. Try punishing him when he moves to collect them."],"ally_tips":["Communication is key when making use of Thresh\'s lantern. Let your teammates know how you like to use it.","Death Sentence and Flay can be combined in either cast order for powerful combinations.","Thresh can collect souls without needing to kill units himself. Planning your map position to be near the most deaths will help to maximize soul collection."],"passive":{"name":"Damnation","description":"Thresh can harvest the souls of enemies that die near him, permanently granting him Armor and Ability Power.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Thresh_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0412/ability_0412_P1.webm"},"spells":[{"key":"Q","name":"Death Sentence","description":"Thresh binds an enemy in chains and pulls them toward him. Activating this ability a second time pulls Thresh to the enemy.","max_rank":5,"range_burn":[1075],"cooldown_burn":[20,18,16,14,12],"cost_burn":[70],"tooltip":"Thresh throws out his scythe, \\u003cstatus\\u003eStunning\\u003c/status\\u003e the first unit hit and \\u003cstatus\\u003ePulling\\u003c/status\\u003e them towards Thresh for 1.5 seconds. The scythe does \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and also grants \\u003ckeywordStealth\\u003eTrue Sight\\u003c/keywordStealth\\u003e for the duration.\\u003cbr /\\u003e\\u003cbr /\\u003eThresh can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability to pull himself to the enemy.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability hits, its Cooldown is reduced by 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ThreshQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0412/ability_0412_Q1.webm"},{"key":"W","name":"Dark Passage","description":"Thresh throws out a lantern that shields nearby allied Champions from damage. Allies can click the lantern to dash to Thresh.","max_rank":5,"range_burn":[950],"cooldown_burn":[22,20,19,17,16],"cost_burn":[50,55,60,65,70],"tooltip":"Thresh throws his lantern, allowing an ally to click on it to dash to Thresh.\\u003cbr /\\u003e\\u003cbr /\\u003eThe lantern also grants \\u003cshield\\u003e? Shield\\u003c/shield\\u003e to Thresh and up to one ally champion if they come in contact with it. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ThreshW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0412/ability_0412_W1.webm"},{"key":"E","name":"Flay","description":"Thresh\'s attacks wind up, dealing more damage the longer he waits between attacks. When activated, Thresh sweeps his chain, knocking all enemies hit in the direction of the blow.","max_rank":5,"range_burn":[500],"cooldown_burn":[13,12,11,10,10],"cost_burn":[60,65,70,75,80],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Thresh\'s Attacks deal additional damage based on how long since he last Attacked. They deal between \\u003cmagicDamage\\u003e?\\u003c/magicDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Thresh whips his chains, \\u003cstatus\\u003ePulling\\u003c/status\\u003e or \\u003cstatus\\u003ePushing\\u003c/status\\u003e enemies in the direction of the swing. Enemies hit are also \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 20/25/30/35/40% for 1 second and take \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ThreshE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0412/ability_0412_E1.webm"},{"key":"R","name":"The Box","description":"A prison of walls that slow and deal damage if broken.","max_rank":3,"range_burn":[450],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Thresh creates a prison of spectral walls, \\u003cstatus\\u003eSlowing\\u003c/status\\u003e champions by 99% for 2 seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Walls break after one collision, and after one is broken, the rest deal no damage and \\u003cstatus\\u003eSlow\\u003c/status\\u003e for half duration.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ThreshRPenta.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0412/ability_0412_R1.webm"}]},"420":{"id":420,"key":"Illaoi","name":"Illaoi","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Illaoi.png","enemy_tips":["Killing Tentacles whenever possible will make it much easier to win a fight against Illaoi.","When your spirit gets pulled out, fight back if you can. Dealing damage to Illaoi reduces the spirit\'s duration.","Avoid grouping up for Leap of Faith to reduce the number of Tentacles available to Illaoi."],"ally_tips":["Tentacles are an immense source of power. Don\'t fight without them.","Spirits inherit their target\'s current health. If making a ","Vessel"," is your goal, try whittling your opponent\'s health down a bit first to make killing the spirit easier.","Leap of Faith is best used to follow-up a strong engage or when being engaged upon. Be careful about being the first one into a fight."],"passive":{"name":"Prophet of an Elder God","description":"Illaoi and the \\u003cfont color=\'#669900\'\\u003eVessels\\u003c/font\\u003e she creates spawn Tentacles on nearby impassible terrain. Tentacles swing at spirits, \\u003cfont color=\'#669900\'\\u003eVessels\\u003c/font\\u003e, and victims of Illaoi\'s Harsh lesson. Tentacles deal physical damage to enemies hit, and will heal Illaoi if they damage a champion.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Illaoi_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0420/ability_0420_P1.webm"},"spells":[{"key":"Q","name":"Tentacle Smash","description":"Increases the damage dealt by Tentacles. When activated, Illaoi smashes down a Tentacle that deals physical damage.","max_rank":5,"range_burn":[850],"cooldown_burn":[10,9,8,7,6],"cost_burn":[40,45,50,55,60],"tooltip":"\\u003cpassive\\u003ePassive:\\u003c/passive\\u003e \\u003ckeywordMajor\\u003eSlam\\u003c/keywordMajor\\u003e damage is increased by \\u003cphysicalDamage\\u003e?%\\u003c/physicalDamage\\u003e (currently \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cactive\\u003eActive:\\u003c/active\\u003e Illaoi swings her idol, causing a Tentacle to \\u003ckeywordMajor\\u003eSlam\\u003c/keywordMajor\\u003e forward.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IllaoiQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0420/ability_0420_Q1.webm"},{"key":"W","name":"Harsh Lesson","description":"Illaoi leaps to her target, dealing physical damage and causing nearby Tentacles to also swing at the target.","max_rank":5,"range_burn":[400],"cooldown_burn":[4],"cost_burn":[30],"tooltip":"Illaoi\'s next Attack causes her to leap at the target, dealing an additional \\u003cphysicalDamage\\u003e? max Health physical damage\\u003c/physicalDamage\\u003e. When she strikes, nearby Tentacles will \\u003ckeywordMajor\\u003eSlam\\u003c/keywordMajor\\u003e at the target.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IllaoiW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0420/ability_0420_W1.webm"},{"key":"E","name":"Test of Spirit","description":"Illaoi rips the spirit from a foe\'s body, forcing it to stand before her. Spirits echo a percentage of the damage they take to the original target. If killed, or if the target gets too far from the spirit, the target will become a \\u003cfont color=\'#669900\'\\u003eVessel\\u003c/font\\u003e and begin spawning Tentacles.","max_rank":5,"range_burn":[900],"cooldown_burn":[16,15,14,13,12],"cost_burn":[35,40,45,50,55],"tooltip":"Illaoi pulls the spirit from an enemy champion for ? seconds. The spirit can be damaged like a champion, with ? of that damage echoing to its owner.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the spirit dies or the target leaves its range, the target becomes marked for ? seconds and is \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for ? seconds. Marked enemies spawn Tentacles every \\u003cscaleLevel\\u003e?\\u003c/scaleLevel\\u003e seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eTentacles will automatically \\u003ckeywordMajor\\u003eSlam\\u003c/keywordMajor\\u003e at spirits and marked enemies once every ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IllaoiE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0420/ability_0420_E1.webm"},{"key":"R","name":"Leap of Faith","description":"Illaoi smashes her idol into the ground, dealing physical damage to nearby enemies. A Tentacle spawns for each enemy champion hit.","max_rank":3,"range_burn":[450],"cooldown_burn":[120,95,70],"cost_burn":[100],"tooltip":"Illaoi smashes her idol into the ground, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to nearby enemies and spawning a Tentacle for each enemy champion hit.\\u003cbr /\\u003e\\u003cbr /\\u003eFor the next ? seconds, Tentacles are untargetable and \\u003ckeywordMajor\\u003eSlam\\u003c/keywordMajor\\u003e 50% faster, and \\u003cspellName\\u003eHarsh Lesson\\u003c/spellName\\u003e has a 2 second cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IllaoiR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0420/ability_0420_R1.webm"}]},"421":{"id":421,"key":"RekSai","name":"Rek\'Sai","image_url":"https://opgg-static.akamaized.net/images/lol/champion/RekSai.png","enemy_tips":["If you see one of Rek\'Sai\'s tunnels, briefly stand on one of the entrances to destroy it.","Rek\'Sai\'s Furious Bite gains damage as she builds Fury. Be very careful around her when her Fury is full.","When Rek\'Sai is near, she can see the position of you and your allies, but only if you\'re moving."],"ally_tips":["Keeping tunnels spread out across the map will ensure you have choices when you want to cast Void Rush.","Cast Burrow before travelling around the map to take advantage of the increased Move Speed and the safety provided by Tremor Sense.","Tremor Sense can warn you of enemies closing in, and is particularly useful when entering enemy territory."],"passive":{"name":"Fury of the Xer\'Sai","description":"Rek\'sai generates Fury by Attack and hitting with basic abilities. She consumes this Fury while Burrowed to restore health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/RekSai_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0421/ability_0421_P1.webm"},"spells":[{"key":"Q","name":"Queen\'s Wrath / Prey Seeker","description":"Rek\'Sai\'s next 3 basic attacks deal bonus Physical Damage to nearby enemies.\\u003cbr\\u003e\\u003cbr\\u003eWhile Burrowed, Rek\'Sai launches a burst of void-charged earth that deals Physical Damage and reveals enemies hit.","max_rank":5,"range_burn":[325],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eUn-Burrowed\\u003c/keywordMajor\\u003e: Rek\'Sai\'s next 3 Attacks within 5 seconds deal an additional \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to nearby enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RekSaiQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0421/ability_0421_Q1.webm"},{"key":"W","name":"Burrow / Un-burrow","description":"Rek\'Sai burrows into the ground, gaining new abilities and increased Move Speed. Her vision range is reduced and she cannot use basic attacks.\\u003cbr\\u003e\\u003cbr\\u003eWhile Burrowed, Rek\'Sai may cast Un-burrow to knock up and damage nearby enemies.","max_rank":5,"range_burn":[1650],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"\\u003ckeywordMajor\\u003eUn-Burrowed:\\u003c/keywordMajor\\u003e Rek\'sai burrows into the ground, gaining access to new Abilities, and \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, but cannot Attack. She has reduced vision range, but nearby enemies that move and are otherwise unseen will have their positions revealed to Rek\'sai and her allies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RekSaiW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0421/ability_0421_W1.webm"},{"key":"E","name":"Furious Bite / Tunnel","description":"Rek\'Sai bites her target, dealing double and True Damage if she has max Fury.\\u003cbr\\u003e\\u003cbr\\u003eWhile Burrowed, Rek\'Sai creates a re-usable, long lasting tunnel. Enemies can destroy it by standing on top of either entrance.","max_rank":5,"range_burn":[250],"cooldown_burn":[12],"cost_burn":[0],"tooltip":"\\u003cscaleAD\\u003eUn-Burrowed:\\u003c/scaleAD\\u003e Rek\'Sai bites a target, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. At max \\u003ckeywordMajor\\u003eFury\\u003c/keywordMajor\\u003e, the bite deals \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RekSaiE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0421/ability_0421_E1.webm"},{"key":"R","name":"Void Rush","description":"Rek\'sai passively marks targets by damaging them. She can activate this ability to become briefly untargetable and lunge at a marked target for heavy damage based on their missing health.","max_rank":3,"range_burn":[1500],"cooldown_burn":[100,90,80],"cost_burn":[0],"tooltip":"Rek\'Sai targets an enemy damaged by her in the last ? seconds and then dives underground, becoming untargetable. Moments later, she leaps unstoppably at her target, dealing \\u003cphysicalDamage\\u003e? plus ?% missing Health physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RekSaiRWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0421/ability_0421_R1.webm"}]},"427":{"id":427,"key":"Ivern","name":"Ivern","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ivern.png","enemy_tips":["Ivern can be deceptively slippery. Be careful chasing him too far.","Ivern\'s brush has a long duration. Watch out for ambushes!","Be careful when fighting Ivern alone if he has Daisy ready to help!"],"ally_tips":["Try to help allies follow up a good Rootcaller hit with Triggerseed!","Use Brushmaker to set up future ambush spots!","Daisy can block skillshots and slow down enemies. Use her to peel for your teammates!"],"passive":{"name":"Friend of the Forest","description":"Ivern cannot attack or be attacked by non-epic monsters. Ivern can create magical groves on jungle camps which grow over time. When the grove is fully grown, Ivern may free the monsters to receive gold and experience. After level 5 Ivern can share jungle buffs with allies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/IvernP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0427/ability_0427_P1.webm"},"spells":[{"key":"Q","name":"Rootcaller","description":"Ivern conjures a vine, dealing damage and rooting enemy targets hit. Ivern\'s allies can dash to the rooted target.","max_rank":5,"range_burn":[1075],"cooldown_burn":[14,13,12,11,10],"cost_burn":[60],"tooltip":"Ivern conjures a vine dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eRooting\\u003c/status\\u003e the first enemy hit for 1.2/1.4/1.6/1.8/2 seconds. Allies that Attack a \\u003cstatus\\u003eRooted\\u003c/status\\u003e enemy dash into attack range.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IvernQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0427/ability_0427_Q1.webm"},{"key":"W","name":"Brushmaker","description":"In brush, Ivern\'s attacks deal bonus magic damage. Ivern can activate this ability to create a patch of brush.","max_rank":5,"range_burn":[1150],"cooldown_burn":[0],"cost_burn":[30],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e While in brush and for 3 seconds after leaving it Ivern\'s Attacks deal an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Ivern grows a patch of Brush for 30 seconds and reveals it for 3 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IvernW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0427/ability_0427_W1.webm"},{"key":"E","name":"Triggerseed","description":"Ivern places a shield on an ally which explodes after a short duration slowing and damaging enemies.","max_rank":5,"range_burn":[750],"cooldown_burn":[11,10,9,8,7],"cost_burn":[70],"tooltip":"Ivern grants \\u003cshield\\u003e? Shield\\u003c/shield\\u003e to an ally champion. After 2 seconds, it bursts, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e enemies by 50/55/60/65/70% for 2 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IvernE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0427/ability_0427_E1.webm"},{"key":"R","name":"Daisy!","description":"Ivern summons his Sentinel friend Daisy to fight with him. Daisy will send out a shockwave if she attacks the same champion three times in a row.","max_rank":3,"range_burn":[600],"cooldown_burn":[140,130,120],"cost_burn":[100],"tooltip":"Ivern summons his sentinel friend Daisy for ? seconds. If Daisy Attacks the same champion three consecutive times she creates a shockwave, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e enemies for 1 second (3s Cooldown).\\u003cbr /\\u003e\\u003cbr /\\u003eDaisy has:\\u003cbr /\\u003e\\u003chealing\\u003e? Health\\u003c/healing\\u003e\\u003cbr /\\u003e\\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e\\u003cbr /\\u003e\\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e\\u003cbr /\\u003e\\u003cscaleAD\\u003e? Attack Damage\\u003c/scaleAD\\u003e\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Manually issue orders to Daisy.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/IvernR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0427/ability_0427_R1.webm"}]},"429":{"id":429,"key":"Kalista","name":"Kalista","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Kalista.png","enemy_tips":["Kalista\'s mobility is dependent upon attacking. This means it is low when she is outside of her attack range and that Attack Speed slows reduce the amount of distance she can cover in an engagement.","Kalista cannot cancel her basic attack wind up. While she is very mobile, this offers a window to land spells on her if you anticipate when she will begin attacking.","If you can break line of sight from Kalista, including through brush, her basic attacks will miss you, falling harmlessly to the ground."],"ally_tips":["Rend is a valuable last hitting aid, since its cooldown resets if it kills a target. ","Entering a move order once to trigger Martial Poise will not clear Kalista\'s basic attack target.","Due to her passive, Kalista\'s Move Speed is effectively increased by Attack Speed."],"passive":{"name":"Martial Poise","description":"Enter a movement command while winding up Kalista\'s basic attack or Pierce to lunge a short distance when she launches her attack.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Kalista_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0429/ability_0429_P1.webm"},"spells":[{"key":"Q","name":"Pierce","description":"Throw a fast moving spear that passes through enemies it kills.","max_rank":5,"range_burn":[1150],"cooldown_burn":[8],"cost_burn":[50,55,60,65,70],"tooltip":"Kalista hurls a spear, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first target hit. If this kills the target, the spear continues onward, carrying any \\u003cspellName\\u003eRend\\u003c/spellName\\u003e stacks to the next target hit.\\u003cbr /\\u003e\\u003cbr /\\u003eKalista can dash after using this Ability using \\u003cspellName\\u003eMartial Poise\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KalistaMysticShot.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0429/ability_0429_Q1.webm"},{"key":"W","name":"Sentinel","description":"Gain bonus damage when Kalista and her Oathsworn strike the same target. \\u003cbr\\u003e\\u003cbr\\u003eActivate to send a soul to scout out the path, revealing the area in front of it.","max_rank":5,"range_burn":[5000],"cooldown_burn":[30],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e When Kalista and her \\u003ckeywordMajor\\u003eOathsworn\\u003c/keywordMajor\\u003e both Attack the same target, she deals \\u003cmagicDamage\\u003e14/15/16/17/18% max Health magic damage\\u003c/magicDamage\\u003e. This effect has a 10 second Cooldown per target.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellPassive\\u003eActive: \\u003c/spellPassive\\u003eKalista sends a ghost to patrol an area for three laps. Champions spotted are revealed for 4 seconds. This ability has 2 charges (90/80/70/60/50 second refresh).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KalistaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0429/ability_0429_W1.webm"},{"key":"E","name":"Rend","description":"Attacks impale their targets with spears. Activate to rip the spears out, slowing and dealing escalating damage.","max_rank":5,"range_burn":[1000],"cooldown_burn":[0],"cost_burn":[30],"tooltip":"\\u003cspellPassive\\u003ePassive: \\u003c/spellPassive\\u003eKalista\'s spears linger in their target for 4 seconds, stacking any number of times.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Kalista rips the spears from nearby enemies, dealing \\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e plus \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e per spear beyond the first. \\u003cstatus\\u003eSlows\\u003c/status\\u003e enemies hit by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf this Ability kills at least one target, its Cooldown is refreshed and it refunds \\u003cscaleMana\\u003e? Mana\\u003c/scaleMana\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KalistaExpungeWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0429/ability_0429_E1.webm"},{"key":"R","name":"Fate\'s Call","description":"Kalista teleports the Oathsworn ally to herself. They gain the ability to dash toward a position, knocking enemy champions back.","max_rank":3,"range_burn":[1000],"cooldown_burn":[150,120,90],"cost_burn":[100],"tooltip":"Kalista puts her \\u003ckeywordMajor\\u003eOathsworn\\u003c/keywordMajor\\u003e into Stasis and draws them to herself for up to 4 seconds. The \\u003ckeywordMajor\\u003eOathsworn\\u003c/keywordMajor\\u003e can click to launch themselves, stopping at the first champion hit and \\u003cstatus\\u003eKnocking Back\\u003c/status\\u003e all nearby enemies. If the \\u003ckeywordMajor\\u003eOathsworn\\u003c/keywordMajor\\u003e hits a champion, they are placed at their maximum attack range from it.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/KalistaRx.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0429/ability_0429_R1.webm"}]},"432":{"id":432,"key":"Bard","name":"Bard","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Bard.png","enemy_tips":["Bard\'s opponents can also travel through his Magical Journey doorways. You can follow him, if you think it\'s safe.","You can crush Bard\'s healing shrines just by walking over them. Don\'t let his allies take them without a fight.","Bard\'s ultimate, Tempered Fate, affects allies, enemies, monsters, and turrets alike. Sometimes it can be to your advantage to jump into it!"],"ally_tips":["It\'s important to collect chimes to improve your meep\'s attacks, but don\'t neglect your lane partner! Try to make a big entrance by bringing an ally into the lane with you with Magical Journey.","Let your Caretaker\'s Shrines charge up - they heal for a lot more when at full power.","Don\'t forget that enemies can also use your Magical Journey doorways, and that your ultimate can also hit your allies!"],"passive":{"name":"Traveler\'s Call","description":"\\u003cfont color=\'#FF9900\'\\u003eMeeps:\\u003c/font\\u003e Bard attracts lesser spirits that assist with his basic attacks to deal extra magic damage. When Bard has collected enough  \\u003cfont color=\'#cccc00\'\\u003eChimes\\u003c/font\\u003e, his meeps will also deal damage in an area and slow enemies hit.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cfont color=\'#FF9900\'\\u003eChimes:\\u003c/font\\u003e Ancient \\u003cfont color=\'#cccc00\'\\u003echimes\\u003c/font\\u003e randomly appear for Bard to collect. These grant experience, restore mana, and provide out of combat Move Speed.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Bard_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0432/ability_0432_P1.webm"},"spells":[{"key":"Q","name":"Cosmic Binding","description":"Bard fires a missile which will slow the first enemy struck, and continue onward. If it strikes a wall, it will stun the initial target; if it strikes another enemy, it will stun them both.","max_rank":5,"range_burn":[25000],"cooldown_burn":[11,10,9,8,7],"cost_burn":[60],"tooltip":"Bard fires an energy bolt, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first two enemies hit. The first target hit is \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by 60% for 1/1.2/1.4/1.6/1.8 second(s).\\u003cbr /\\u003e\\u003cbr /\\u003eIf the bolt hits a second enemy or a wall, any enemies hit are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for 1/1.2/1.4/1.6/1.8 second(s).\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BardQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0432/ability_0432_Q1.webm"},{"key":"W","name":"Caretaker\'s Shrine","description":"Reveals a healing shrine which powers up over a short time, disappearing after healing and speeding up the first ally that touches it.","max_rank":5,"range_burn":[800],"cooldown_burn":[14],"cost_burn":[70],"tooltip":"Bard creates a health shrine that grants \\u003cspeed\\u003e30% Move Speed\\u003c/speed\\u003e decaying over 1.5 seconds and restores at least \\u003chealing\\u003e? Health\\u003c/healing\\u003e to the first ally to enter. The shrine grows to restore \\u003chealing\\u003e? Health\\u003c/healing\\u003e after existing for 10 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eBard can have up to 3 shrines at once. If an enemy champion enters a shrine, it is destroyed.\\u003cbr /\\u003e\\u003cbr /\\u003eCurrent Active Shrines: ? / ?","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BardW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0432/ability_0432_W1.webm"},{"key":"E","name":"Magical Journey","description":"Bard opens a portal in nearby terrain. Allies and enemies alike can take a one-way trip through that terrain by moving into the portal.","max_rank":5,"range_burn":[900],"cooldown_burn":[22,20,19,17,16],"cost_burn":[30],"tooltip":"Bard opens a one-way portal through Terrain for 10 seconds. Any champion can enter the portal by moving onto it while near the entrance.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BardE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0432/ability_0432_E1.webm"},{"key":"R","name":"Tempered Fate","description":"Bard sends spirit energy arcing to a location, putting all champions, minions, monsters, and turrets hit into stasis for a brief time.","max_rank":3,"range_burn":[3400],"cooldown_burn":[110,95,80],"cost_burn":[100],"tooltip":"Bard hurls magical protective energy to an area, placing all units and structures hit into Stasis for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/BardR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0432/ability_0432_R1.webm"}]},"497":{"id":497,"key":"Rakan","name":"Rakan","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Rakan.png","enemy_tips":["Rakan\'s movement abilities forecast their destination. Try to use this to your advantage.","Champions with crowd control that can be applied quickly excel against Rakan.","Catching Rakan with no allies around severely inhibits his mobility. Try to find him alone."],"ally_tips":["Rakan requires allies near him to make the most out of his tools.","Rakan\'s dash speeds increase with his Move Speed. Use the extra speed to surprise your enemies!","Danger is as fun as you let it be."],"passive":{"name":"Fey Feathers","description":"Rakan periodically gains a shield.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Rakan_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0497/ability_0497_P1.webm"},"spells":[{"key":"Q","name":"Gleaming Quill","description":"Flings a magical feather that deals magic damage. Striking a champion or epic monster enables Rakan to heal his allies.","max_rank":5,"range_burn":[850],"cooldown_burn":[0],"cost_burn":[60],"tooltip":"Rakan flings a magical feather that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to the first enemy hit.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the feather hits a champion or epic jungle monster, Rakan restores \\u003chealing\\u003e? Health\\u003c/healing\\u003e to himself and nearby allies after 3 seconds or when he touches an allied champion.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RakanQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0497/ability_0497_Q1.webm"},{"key":"W","name":"Grand Entrance","description":"Dashes to a location, knocking up nearby enemies on arrival.","max_rank":5,"range_burn":[600],"cooldown_burn":[16,14,13,11,10],"cost_burn":[50,60,70,80,90],"tooltip":"Rakan dashes, then spirals into the air, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for ? second and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RakanW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0497/ability_0497_W1.webm"},{"key":"E","name":"Battle Dance","description":"Flies to an allied champion granting them a shield. Can be re-cast for free for a short duration.","max_rank":5,"range_burn":[650],"cooldown_burn":[0],"cost_burn":[40,45,50,55,60],"tooltip":"Rakan dashes to an allied champion, granting them \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eRakan can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability once within 5 seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RakanE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0497/ability_0497_E1.webm"},{"key":"R","name":"The Quickness","description":"Gains Move Speed, charming and dealing magic damage to enemies touched.","max_rank":3,"range_burn":[150],"cooldown_burn":[130,110,90],"cost_burn":[100],"tooltip":"Rakan gains \\u003cspeed\\u003e75% Move Speed\\u003c/speed\\u003e for 4 seconds. Rakan deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eCharms\\u003c/status\\u003e enemies for 1/1.25/1.5 second(s) the first time he touches them. The first champion touched grants Rakan \\u003cspeed\\u003e150% decaying Move Speed\\u003c/speed\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RakanR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0497/ability_0497_R1.webm"}]},"498":{"id":498,"key":"Xayah","name":"Xayah","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Xayah.png","enemy_tips":["Xayah\'s Bladecaller will only root targets hit by 3 or more returning Feathers.","Long fights in the same area with Xayah will allow her to drop a lot of Feathers. Try to stay on the move!","Make sure you are ready when you go for the kill. Untargetability from Featherstorm can quickly turn an ambush in Xayah\'s favor."],"ally_tips":["Xayah\'s attacks and abilities leave Feathers on the ground that she can later recall for massive area damage and control.","Xayah can use Featherstorm to dodge almost any ability while also creating a ton of Feathers. Try to utilize the offensive and defensive aspects of this ability."],"passive":{"name":"Clean Cuts","description":"After using an ability, Xayah\'s next basic attacks will hit all targets along their path and leave a \\u003cfont color=\'#C200E1\'\\u003eFeather\\u003c/font\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/XayahPassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0498/ability_0498_P1.webm"},"spells":[{"key":"Q","name":"Double Daggers","description":"Xayah throws two damaging daggers that also drop Feathers she can recall.","max_rank":5,"range_burn":[400],"cooldown_burn":[10,9,9,8,8],"cost_burn":[50],"tooltip":"Xayah throws two daggers, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e each and leaving two \\u003ckeywordMajor\\u003eFeathers\\u003c/keywordMajor\\u003e. Targets hit after the first take \\u003cphysicalDamage\\u003e? damage\\u003c/physicalDamage\\u003e from each dagger.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XayahQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0498/ability_0498_Q1.webm"},{"key":"W","name":"Deadly Plumage","description":"Xayah creates a storm of blades that increase her Attack Speed and damage while also granting her Move Speed if she attacks a champion.","max_rank":5,"range_burn":[1000],"cooldown_burn":[20,19,18,17,16],"cost_burn":[60,55,50,45,40],"tooltip":"Xayah creates a storm of blades for 4 seconds that grants her \\u003cattackSpeed\\u003e35/40/45/50/55% Attack Speed\\u003c/attackSpeed\\u003e and cause her Attacks to fire a secondary blade that deals 20% damage.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen the secondary blade hits a champion, she grants herself \\u003cspeed\\u003e30% Move Speed\\u003c/speed\\u003e for 1.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Rakan is nearby he will also gain the effects of this Ability, except he gains \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e when \\u003ci\\u003eXayah\\u003c/i\\u003e strikes a target.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XayahW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0498/ability_0498_W1.webm"},{"key":"E","name":"Bladecaller","description":"Xayah calls back all her dropped Feathers dealing damage and rooting enemies.","max_rank":5,"range_burn":[2000],"cooldown_burn":[10,9,9,8,8],"cost_burn":[30],"tooltip":"Xayah calls all \\u003ckeywordMajor\\u003eFeathers\\u003c/keywordMajor\\u003e back to her, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e each. If ? or more \\u003ckeywordMajor\\u003eFeathers\\u003c/keywordMajor\\u003e hit an enemy, they are \\u003cstatus\\u003eRooted\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XayahE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0498/ability_0498_E1.webm"},{"key":"R","name":"Featherstorm","description":"Xayah leaps into the air becoming untargetable and throwing out a fan of daggers, dropping Feathers she can recall.","max_rank":3,"range_burn":[450],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Xayah leaps into the air becoming Untargetable and Ghosted for 1.5 seconds before raining down daggers that deal \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and leave behind a line of \\u003ckeywordMajor\\u003eFeathers\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/XayahR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0498/ability_0498_R1.webm"}]},"516":{"id":516,"key":"Ornn","name":"Ornn","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Ornn.png","enemy_tips":["Try to stay away from walls. Ornn is much less strong if he cannot stun you.","Attack Ornn to keep him from creating items in lane."],"ally_tips":["Learning build paths of items can help quickly select upgrades in lane.","Volcanic Rupture can be used to set up zoning areas to threaten enemies.","The order of your abilties matters! Try to optimize Brittle usage."],"passive":{"name":"Living Forge","description":"Ornn gains an additional bonus Armor and Magic Resistance from all sources.\\u003cbr\\u003e\\u003cbr\\u003eOrnn can spend gold to forge non-consumable items anywhere.\\u003cbr\\u003e\\u003cbr\\u003eAdditionally, he can create masterwork items for himself and for his allies.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/OrnnP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0516/ability_0516_P1.webm"},"spells":[{"key":"Q","name":"Volcanic Rupture","description":"Ornn slams the ground, sending out a fissure dealing damage and slowing enemies hit. After a small delay, a magma pillar forms at the end location.","max_rank":5,"range_burn":[800],"cooldown_burn":[9,8,8,7,7],"cost_burn":[45],"tooltip":"Ornn slams the ground, creating a fissure dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by 40% for 2 seconds. A pillar of rock forms at the fissure\'s end for 4 seconds. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrnnQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0516/ability_0516_Q1.webm"},{"key":"W","name":"Bellows Breath","description":"Ornn advances, breathing fire. Enemies hit by the final gout of flame become Brittle.","max_rank":5,"range_burn":[25000],"cooldown_burn":[12,11,11,10,10],"cost_burn":[45,50,55,60,65],"tooltip":"Ornn stomps forward Unstoppably while breathing fire, dealing \\u003cmagicDamage\\u003e?% max Health magic damage\\u003c/magicDamage\\u003e over ? seconds. Enemies hit by the final bout of flame become \\u003ckeywordMajor\\u003eBrittle\\u003c/keywordMajor\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cstatus\\u003eImmobilizing\\u003c/status\\u003e effects on \\u003ckeywordMajor\\u003eBrittle\\u003c/keywordMajor\\u003e targets have their duration increased by 30% and deal an additional \\u003cmagicDamage\\u003e? max Health magic damage\\u003c/magicDamage\\u003e. Ornn\'s Attacks against \\u003ckeywordMajor\\u003eBrittle\\u003c/keywordMajor\\u003e targets \\u003cstatus\\u003eKnock\\u003c/status\\u003e them \\u003cstatus\\u003eBack\\u003c/status\\u003e, dealing the additional damage.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrnnW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0516/ability_0516_W1.webm"},{"key":"E","name":"Searing Charge","description":"Ornn charges, dealing damage to enemies he passes through. If Ornn collides with terrain while charging, the impact creates a shockwave around him which deals damage and knocks up enemies.","max_rank":5,"range_burn":[450],"cooldown_burn":[16,15,14,13,12],"cost_burn":[35,40,45,50,55],"tooltip":"Ornn charges, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. If Ornn rams into terrain, he creates a shockwave that \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e enemies for ? seconds and applies the same damage to those not hit by the charge.\\u003cbr /\\u003e\\u003cbr /\\u003eOrnn\'s charge destroys magma pillars and terrain created by enemies.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrnnE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0516/ability_0516_E1.webm"},{"key":"R","name":"Call of the Forge God","description":"Ornn summons a massive elemental at a location which travels toward him with increasing speed. Enemies run over by the elemental take damage, are slowed and are made Brittle. Ornn can recast the ability to charge into the elemental, redirecting it in the direction he hits it, causing the elemental to affect any enemies it runs over to be knocked up, dealing the same damage and re-applying Brittle.","max_rank":3,"range_burn":[2500],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Ornn summons a massive lava elemental, which stampedes towards him, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and applying \\u003ckeywordMajor\\u003eBrittle\\u003c/keywordMajor\\u003e for ? seconds. The elemental also \\u003cstatus\\u003eSlows\\u003c/status\\u003e by up to ?% based on distance traveled.\\u003cbr /\\u003e\\u003cbr /\\u003eOrnn can \\u003crecast\\u003eRecast\\u003c/recast\\u003e to dash with a headbutt. If he dashes into the elemental, he redirects and empowers it, causing it to \\u003cstatus\\u003eKnock Up\\u003c/status\\u003e the first champion for ? second and subsequent champions for ? seconds. The elemental also deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and reapplies \\u003ckeywordMajor\\u003eBrittle\\u003c/keywordMajor\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/OrnnR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0516/ability_0516_R1.webm"}]},"517":{"id":517,"key":"Sylas","name":"Sylas","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sylas.png","enemy_tips":["Sylas\'s healthbar can be deceptive, watch out for his Kingslayer!","Try to fight Sylas when he isn\'t able to take your ultimate."],"ally_tips":["Wait for you or your enemy to reach low health before using Kingslayer for maximum effect.","Space out your ability usage to get maximum effect from Petricite Burst.","Clever use of enemy ultimates can open up new possibilities to approach teamfights."],"passive":{"name":"Petricite Burst","description":"After casting a spell, Sylas stores a charge of Petricite Burst.  Sylas\'s basic attacks will expend a charge and whirl his energized chains around him dealing bonus magic damage to enemies hit. While Sylas has a charge of Petricite Burst, he gains attack speed. ","image_url":"https://opgg-static.akamaized.net/images/lol/passive/SylasP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0517/ability_0517_P1.webm"},"spells":[{"key":"Q","name":"Chain Lash","description":"Sylas lashes his chains out, intersecting at his targeted location dealing damage to and slowing enemies. \\u003cbr\\u003e\\u003cbr\\u003eAfter a delay, magical energy explodes from the intersection point dealing damage.","max_rank":5,"range_burn":[775],"cooldown_burn":[10,9,8,7,6],"cost_burn":[55],"tooltip":"Sylas lashes his chains out, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e by ? for ? seconds. The place where the chains intersect explodes, dealing a further \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SylasQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0517/ability_0517_Q1.webm"},{"key":"W","name":"Kingslayer","description":"Sylas lunges at an enemy with magical force dealing damage and healing himself against enemy champions.","max_rank":5,"range_burn":[400],"cooldown_burn":[12,10,9,7,6],"cost_burn":[50,60,70,80,90],"tooltip":"Sylas lunges at an enemy with magical force dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Against champions, Sylas restores between \\u003chealing\\u003e?\\u003c/healing\\u003e and \\u003chealing\\u003e? Health\\u003c/healing\\u003e based on his missing Health (max healing at or below ?% Health).","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SylasW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0517/ability_0517_W1.webm"},{"key":"E","name":"Abscond / Abduct","description":"Sylas dashes to a location. Sylas can recast the ability to throw his chains out, pulling himself to an enemy he hits.","max_rank":5,"range_burn":[400],"cooldown_burn":[13,12,11,10,9],"cost_burn":[65],"tooltip":"Sylas quickly dashes, and prepares a \\u003crecast\\u003eRecast\\u003c/recast\\u003e for 3.5 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Sylas throws his chains, pulling himself to the first enemy hit, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, and \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SylasE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0517/ability_0517_E1.webm"},{"key":"R","name":"Hijack","description":"Sylas steals the enemy\'s ultimate ability and can cast it freely.","max_rank":3,"range_burn":[950],"cooldown_burn":[80,55,30],"cost_burn":[75],"tooltip":"Sylas hijacks an enemy champion, allowing him to cast a copy of their ultimate Ability, based on his Ultimate level and using his stats.\\u003cbr /\\u003e\\u003cbr /\\u003eHijacking an enemy places a Cooldown on them for ?% (modified by Sylas\' Ability Haste) of the enemy\'s ultimate\'s Cooldown, with a minimum of ? seconds, during which time Sylas cannot hijack them again.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SylasR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0517/ability_0517_R1.webm"}]},"518":{"id":518,"key":"Neeko","name":"Neeko","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Neeko.png","enemy_tips":["Standing behind minions against Neeko is very dangerous as Tangle-Barbs become stronger.","Pop Blossom\'s warning visuals are invisible if Neeko is disguised."],"ally_tips":["You can set her passive to use hotkeys in the options menu. The default is Shift+F1~F5","Try to use Inherent Glamour sparingly, ineffective uses will put enemies on the alert."],"passive":{"name":"Inherent Glamour","description":"Neeko can look like an ally champion. Taking damage from enemy Champions or casting damaging spells breaks the disguise.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Neeko_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0518/ability_0518_P1.webm"},"spells":[{"key":"Q","name":"Blooming Burst","description":"Neeko throws a seed dealing magic damage. The seed blooms again on hitting champions or killing units.","max_rank":5,"range_burn":[800],"cooldown_burn":[7],"cost_burn":[50,60,70,80,90],"tooltip":"Neeko throws a seed that blooms to deal ? magic damage. If it kills a unit or hits a champion or large monster, it will bloom again, dealing ? magic damage. Max 2 extra blooms.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NeekoQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0518/ability_0518_Q1.webm"},{"key":"W","name":"Shapesplitter","description":"Neeko passively deals bonus magic damage every third attack. Neeko can activate to send a clone in a direction.","max_rank":5,"range_burn":[900],"cooldown_burn":[16,15,14,13,12],"cost_burn":[0],"tooltip":"\\u003cspan class=\\"colorFF9900\\"\\u003ePassive:\\u003c/span\\u003e Every 3rd attack deals ? bonus magic damage and increases Neeko\'s Move Speed by ?% for ? second.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspan class=\\"colorFF9900\\"\\u003eActive:\\u003c/span\\u003e Neeko becomes invisible for ? seconds and projects a clone that lasts ? seconds. Neeko and the clone gain ?% Move Speed for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NeekoW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0518/ability_0518_W1.webm"},{"key":"E","name":"Tangle-Barbs","description":"Neeko slings a tangle that damage and root everything it passes through. If the tangle kills an enemy or passes through a champion, it becomes larger, faster, and roots for longer.","max_rank":5,"range_burn":[1000],"cooldown_burn":[12,11,11,10,10],"cost_burn":[60,65,70,75,80],"tooltip":"Neeko slings a tangle that deals ? magic damage and roots for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThe tangle becomes empowered after hitting an enemy, growing larger, moving faster, and rooting for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NeekoE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0518/ability_0518_E1.webm"},{"key":"R","name":"Pop Blossom","description":"After a short preparation, Neeko leaps into the air and gains a shield. Upon landing, nearby enemies are damaged and stunned. The preparation is hidden if Neeko is disguised.","max_rank":3,"range_burn":[600],"cooldown_burn":[90],"cost_burn":[100],"tooltip":"After ? seconds Neeko leaps into the air. She gains a shield that absorbs ? damage (+? for each nearby enemy champion).\\u003cbr /\\u003e\\u003cbr /\\u003eWhen Neeko lands she deals ? magic damage and stuns nearby enemies for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eThis ability can be prepared in secret if Neeko is disguised.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/NeekoR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0518/ability_0518_R1.webm"}]},"523":{"id":523,"key":"Aphelios","name":"Aphelios","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Aphelios.png","enemy_tips":["Each of Aphelios\' weapons have different weaknesses, try to exploit the ones that work best for your champion. Watch out for the purple Gravity gun, it can root you."],"ally_tips":["Each of Aphelios\' weapons have different strengths, so try to find the right situation for your current weapons. "],"passive":{"name":"The Hitman and the Seer","description":"Aphelios wields 5 Lunari Weapons made by his sister Alune. He has access to two at a time: one main-hand and one off-hand. Each weapon has a unique Basic Attack and Ability. Attacks and abilities consume a weapon\'s ammo. When out of ammo, Aphelios discards the weapon and Alune summons the next of the 5. ","image_url":"https://opgg-static.akamaized.net/images/lol/passive/ApheliosP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0523/ability_0523_P1.webm"},"spells":[{"key":"Q","name":"Weapon Abilites","description":"Aphelios has 5 different activated abilities, based on his main-hand weapon:\\u003cbr\\u003e\\u003cbr\\u003eCalibrum (Rifle): Long range shot that marks its target for a long-range follow-up attack.\\u003cbr\\u003eSeverum (Scythe Pistol): Run fast while attacking nearby enemies with both weapons.\\u003cbr\\u003eGravitum (Cannon): Root all enemies slowed by this weapon.\\u003cbr\\u003eInfernum (Flamethrower): Blast enemies in a cone and attack them with your off-hand weapon.\\u003cbr\\u003eCrescendum (Chakram): Deploy a sentry that shoots your off-hand weapon.\\u003cbr\\u003e","max_rank":6,"range_burn":[1450],"cooldown_burn":[9],"cost_burn":[60],"tooltip":"","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ApheliosQ_ClientTooltipWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0523/ability_0523_Q1.webm"},{"key":"W","name":"Phase","description":"Aphelios swaps his main-hand gun with his off-hand gun, replacing his basic attack and activated ability.","max_rank":6,"range_burn":[250],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"Swap main-hand and off-hand weapons, equipping \\u003cb\\u003e\\u003ci\\u003e\\u003cspan class=\\"colora64dff\\"\\u003eGravitum\\u003c/span\\u003e\\u003c/i\\u003e\\u003c/b\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ApheliosW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0523/ability_0523_W1.webm"},{"key":"E","name":"Weapon Queue System","description":"Aphelios has no third ability. This slot shows the next weapon Alune will give him. Weapon order begins fixed but may change over game time -- when a weapon is out of ammo it goes to the end of the order.","max_rank":6,"range_burn":[1000],"cooldown_burn":[0],"cost_burn":[0],"tooltip":"","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ApheliosE_ClientTooltipWrapper.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0523/ability_0523_E1.webm"},{"key":"R","name":"Moonlight Vigil","description":"Fire a concentrated blast of moonlight that explodes on enemy champions. Applies the unique effect of Aphelios\' main-hand gun.","max_rank":3,"range_burn":[1300],"cooldown_burn":[120,110,100],"cost_burn":[100],"tooltip":"Aphelios fires a concentrated blast of moonlight that explodes when it hits a champion, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to surrounding enemies.\\u003cbr /\\u003e\\u003cbr /\\u003eThen, Aphelios attacks all champions hit with his main-hand weapon. {{ Spell_ApheliosR_WeaponMod_? }}","image_url":"https://opgg-static.akamaized.net/images/lol/spell/ApheliosR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0523/ability_0523_R1.webm"}]},"526":{"id":526,"key":"Rell","name":"Rell","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Rell.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Break the Mold","description":"Rell attacks slowly but steals her target\'s \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e on hit, dealing bonus damage based on the amount stolen.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/RellP.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0526/ability_0526_P1.webm"},"spells":[{"key":"Q","name":"Shattering Strike","description":"Rell thrusts her lance to deal \\u003cmagicDamage\\u003emagic damage\\u003c/magicDamage\\u003e to units in a line, breaking their Shields.  The first unit hit additionally suffers \\u003cspellName\\u003eBreak the Mold\\u003c/spellName\\u003e\'s defense steal. \\u003cbr\\u003e\\u003cbr\\u003eIf Rell is bound to an ally with \\u003cspellName\\u003eAttract and Repel\\u003c/spellName\\u003e, they both recover health for each enemy champion hit by this spell.","max_rank":5,"range_burn":[700],"cooldown_burn":[9,8,7,6,5],"cost_burn":[50],"tooltip":"Rell thrusts her lance, destroying all Shield and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. The first unit hit takes \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e instead and suffers \\u003cspellName\\u003eBreak the Mold\\u003c/spellName\\u003e\'s defense steal. \\u003cbr /\\u003e\\u003cbr /\\u003eIf Rell is bound to an ally with \\u003cspellName\\u003eAttract and Repel\\u003c/spellName\\u003e, they both recover \\u003chealing\\u003e? plus ?% missing Health\\u003c/healing\\u003e for each enemy champion hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RellQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0526/ability_0526_Q1.webm"},{"key":"W","name":"Ferromancy: Crash Down","description":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Rell gains additional Move Speed while mounted and additional \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e while armored.\\u003cbr\\u003e\\u003cbr\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Rell changes forms, casting a different spell based on form.\\u003cli\\u003e Mounted: Rell crashes down in her armor, knocking enemies up and gaining a large shield.\\u003c/li\\u003e\\u003cli\\u003e Armored: Rell forms her mount, gaining a burst of speed and flipping the next enemy she attacks.\\u003c/li\\u003e","max_rank":5,"range_burn":[550],"cooldown_burn":[11],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive - Mounted:\\u003c/spellPassive\\u003e Rell gains \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e, reduced when taking damage. \\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive - Ferromancy: Crash Down:\\u003c/spellActive\\u003e Rell leaps off her mount, \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e enemies for ? second and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Rell then enters Armored form, gaining \\u003cshield\\u003e? Shield\\u003c/shield\\u003e, reducing her \\u003cspeed\\u003eMove Speed\\u003c/speed\\u003e, and allowing her to use \\u003cspellName\\u003eFerromancy: Mount Up\\u003c/spellName\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RellW_Dismount.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0526/ability_0526_W1.webm"},{"key":"E","name":"Attract and Repel","description":"Rell binds a piece of her Armor to another allied champion to grant them \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e while near.\\u003cbr\\u003e\\u003cbr\\u003eWhile she has an ally bound in this way, Rell can cast this ability without targeting an allied champion to snap the binding and \\u003cstatus\\u003eStun\\u003c/status\\u003e enemies caught in it.","max_rank":5,"range_burn":[1500],"cooldown_burn":[18,16,14,12,11],"cost_burn":[40],"tooltip":"Rell binds a piece of her Armor to another allied champion, granting them \\u003cscaleArmor\\u003e? Armor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003e? Magic Resist\\u003c/scaleMR\\u003e while near you. Doing this has no cost and puts this Ability on Cooldown for 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Rell uses this Ability without targeting an allied champion, she snaps the binding, \\u003cstatus\\u003eStunning\\u003c/status\\u003e enemies around and between herself and her bound ally for ? seconds and dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RellE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0526/ability_0526_E1.webm"},{"key":"R","name":"Magnet Storm","description":"Rell explodes in a magnetic fury, violently \\u003cstatus\\u003ePulling\\u003c/status\\u003e nearby enemies towards herself. Then Rell constantly \\u003cstatus\\u003eDrags\\u003c/status\\u003e nearby enemies towards herself for a short while, dealing \\u003cmagicDamage\\u003emagic damage\\u003c/magicDamage\\u003e over time.","max_rank":3,"range_burn":[200],"cooldown_burn":[120,100,80],"cost_burn":[100],"tooltip":"Rell explodes in a magnetic fury, violently \\u003cstatus\\u003ePulling\\u003c/status\\u003e nearby enemies towards herself. Then Rell constantly \\u003cstatus\\u003eDrags\\u003c/status\\u003e nearby enemies towards herself and deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e over the next ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RellR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0526/ability_0526_R1.webm"}]},"555":{"id":555,"key":"Pyke","name":"Pyke","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Pyke.png","enemy_tips":["Pyke regenerates a significant amount of damage he has taken from enemy champions, but only when you can\'t see him!","When Pyke is hidden nearby in his Ghostwater Dive, sharks will circle underneath your feet.","Try not to stand near low health allies. If Pyke executes them using Death From Below, you might be next on the list."],"ally_tips":["Pyke is very fragile so don\'t be afraid to temporarily run from a fight. You can regenerate a significant amount of health from Gift of the Drowned Ones when enemies can\'t see you.","Hitting an enemy with the Hold version of Bone Skewer will always pull them the same distance. Use it in melee range to throw targets behind you.","The Tap version of Bone Skewer is much faster and deals additional damage.","A lot of your agressive spells are also your escapes. Make sure you always have a plan to get out of the fight."],"passive":{"name":"Gift of the Drowned Ones","description":"When Pyke is hidden from enemies, he regenerates damage that he has recently taken from champions. Pyke also cannot gain extra Maximum Health from any source, and instead gains Bonus AD.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/PykePassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0555/ability_0555_P1.webm"},"spells":[{"key":"Q","name":"Bone Skewer","description":"Pyke either stabs an enemy in front of him or pulls an enemy towards him.","max_rank":5,"range_burn":[400],"cooldown_burn":[10,9,9,8,8],"cost_burn":[74,78,82,86,90],"tooltip":"\\u003ctap\\u003eTap:\\u003c/tap\\u003e Pyke stabs, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit, preferring champions. They are then \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for ? second(s).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003chold\\u003eHold: \\u003c/hold\\u003ePyke throws his harpoon, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to the first enemy hit and \\u003cstatus\\u003ePulling\\u003c/status\\u003e them towards him. They are then \\u003cstatus\\u003eSlowed\\u003c/status\\u003e by ?% for ? second(s).\\u003cbr /\\u003e\\u003cbr /\\u003eIf Pyke successfuly hits an enemy champion or the channel does not complete successfully, ?% of the Mana cost is refunded.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PykeQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0555/ability_0555_Q1.webm"},{"key":"W","name":"Ghostwater Dive","description":"Pyke enters Camouflage and gains significant Move Speed that decays over time.","max_rank":5,"range_burn":[600],"cooldown_burn":[12,11,11,10,10],"cost_burn":[50],"tooltip":"Pyke gains \\u003ckeywordStealth\\u003eCamouflage\\u003c/keywordStealth\\u003e and \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e decaying over ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PykeW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0555/ability_0555_W1.webm"},{"key":"E","name":"Phantom Undertow","description":"Pyke dashes and leaves behind a phantom that will return to him, stunning enemy champions along its path.","max_rank":5,"range_burn":[550],"cooldown_burn":[15,14,13,12,11],"cost_burn":[40],"tooltip":"Pyke dashes, leaving a drowned phantom behind him that returns to him shortly. The phantom \\u003cstatus\\u003eStuns\\u003c/status\\u003e for ? seconds and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e to champions.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PykeE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0555/ability_0555_E1.webm"},{"key":"R","name":"Death From Below","description":"Pyke blinks to and executes low health enemies, allowing him to cast this spell again and granting additional gold to an ally who assists.","max_rank":3,"range_burn":[750],"cooldown_burn":[100,85,70],"cost_burn":[100],"tooltip":"Pyke strikes all enemy champions in an X, teleporting to and \\u003cdanger\\u003eexecuting\\u003c/danger\\u003e targets below \\u003cscaleAD\\u003e?\\u003c/scaleAD\\u003e Health. Champions above the threshold and non-champions instead take physical damage equal to ?% of that amount (\\u003cphysicalDamage\\u003e?\\u003c/physicalDamage\\u003e). \\u003cbr /\\u003e\\u003cbr /\\u003eWhen an enemy champions dies inside the X, Pyke can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability for free within ? seconds. If he executed that champion, the last assisting ally will also get kill gold. If he did not, he will still get kill gold as if he did.\\u003cbr /\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/PykeR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0555/ability_0555_R1.webm"}]},"711":{"id":711,"key":"Vex","name":"Vex","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Vex.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Doom \'n Gloom","description":"Vex periodically becomes empowered, causing her next basic Ability to fear enemies and interrupt dashes. Whenever a nearby enemy dashes, Vex applies a mark that can be consumed for bonus damage that also reduces the cooldown of her empowered state.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Icons_Vex_Passive.S_Yordle.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0711/ability_0711_P1.webm"},"spells":[{"key":"Q","name":"Mistral Bolt","description":"Launch a damaging missile that accelerates mid-flight.","max_rank":5,"range_burn":[1200],"cooldown_burn":[9,8,7,6,5],"cost_burn":[45,50,55,60,65],"tooltip":"Vex launches a wave of mist that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. After a delay, the wave becomes smaller and faster.\\u003cbr /\\u003e\\u003cbr /\\u003eConsumes \\u003ckeywordMajor\\u003eGloom\\u003c/keywordMajor\\u003e on enemies hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VexQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0711/ability_0711_Q1.webm"},{"key":"W","name":"Personal Space","description":"Gain a shield and damage nearby enemies.","max_rank":5,"range_burn":[475],"cooldown_burn":[20,18,16,14,12],"cost_burn":[75],"tooltip":"Vex gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds and emits a shockwave that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eConsumes \\u003ckeywordMajor\\u003eGloom\\u003c/keywordMajor\\u003e on enemies hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VexW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0711/ability_0711_W1.webm"},{"key":"E","name":"Looming Darkness","description":"Summon a damaging and slowing zone that applies Gloom to enemies.","max_rank":5,"range_burn":[800],"cooldown_burn":[13],"cost_burn":[70,80,90,100,110],"tooltip":"Vex commands Shadow to fly to a location, increasing in size as it travels. Upon arriving, it deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eApplies \\u003ckeywordMajor\\u003eGloom\\u003c/keywordMajor\\u003e to enemies hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VexE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0711/ability_0711_E1.webm"},{"key":"R","name":"Shadow Surge","description":"Fire a missile that marks an enemy champion.  Recast to dash to them and deal damage.","max_rank":3,"range_burn":[2000,2500,3000],"cooldown_burn":[140,120,100],"cost_burn":[100],"tooltip":"Shadow excitedly surges forward, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and marking the first enemy champion hit for 4 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast\\u003c/recast\\u003e: Dash to the marked champion, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e on arrival.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the marked champion dies within ? seconds of taking damage from this Ability, its Cooldown is temporarily reset.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/VexR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0711/ability_0711_R1.webm"}]},"777":{"id":777,"key":"Yone","name":"Yone","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Yone.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Way of the Hunter","description":"Yone deals magic damage with every second Attack. In addition, his critical strike chance is increased.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/YonePassive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0777/ability_0777_P1.webm"},"spells":[{"key":"Q","name":"Mortal Steel","description":"Thrusts forward, damaging all enemies in a line.\\u003cbr\\u003e\\u003cbr\\u003eOn hit, grants a stack of Gathering Storm for a few seconds. At 2 stacks, Mortal Steel dashes Yone forward with a gust of wind knocking enemies \\u003cstatus\\u003eAirborne\\u003c/status\\u003e.\\u003cbr\\u003e\\u003cbr\\u003eMortal Steel is treated as a basic attack and scales with all the same things.","max_rank":5,"range_burn":[450],"cooldown_burn":[4],"cost_burn":[0],"tooltip":"Yone thrusts forward, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eOn hit, grants a stack for ? seconds. At 2 stacks, this skill causes Yone to dash forward with a wave of wind that \\u003cstatus\\u003eKnocks Up\\u003c/status\\u003e for {{ q3knockupduration }} seconds and deals \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YoneQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0777/ability_0777_Q1.webm"},{"key":"W","name":"Spirit Cleave","description":"Cleaves forward, damaging all enemies in a cone. Grants a shield to Yone, the value is increased by the number of champions hit by the swipe.\\u003cbr\\u003e\\u003cbr\\u003eSpirit Cleave\'s cooldown and cast time scale with attack speed.","max_rank":5,"range_burn":[700],"cooldown_burn":[16],"cost_burn":[0],"tooltip":"Yone cleaves forward, dealing \\u003cphysicalDamage\\u003e? + ?% max Health physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? + ?% max Health magic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eIf Yone hits, he gains \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds. The amount of \\u003cshield\\u003eShield\\u003c/shield\\u003e increases for each champion struck. ","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YoneW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0777/ability_0777_W1.webm"},{"key":"E","name":"Soul Unbound","description":"Yone\'s spirit leaves his body behind, gaining Move Speed. When this skill ends, Yone\'s spirit is forced back to his body and he repeats a portion of the damage he dealt as a spirit.","max_rank":5,"range_burn":[25000],"cooldown_burn":[22,19,16,13,10],"cost_burn":[0],"tooltip":"Yone enters a spirit form for ? seconds, leaving his body behind for the duration and gaining \\u003cspeed\\u003e?% ramping Move Speed\\u003c/speed\\u003e. \\u003cbr /\\u003e\\u003cbr /\\u003eWhen the spirit form ends, Yone snaps back to his body and repeats ?% of all damage he dealt to champions during this time. You may \\u003crecast\\u003eRecast\\u003c/recast\\u003e this skill during spirit form.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast: \\u003c/recast\\u003eEnd spirit form early.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YoneE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0777/ability_0777_E1.webm"},{"key":"R","name":"Fate Sealed","description":"Yone blinks behind the last champion in a line with a slash so powerful it pulls all enemies hit towards him.","max_rank":3,"range_burn":[1000],"cooldown_burn":[120,90,60],"cost_burn":[0],"tooltip":"Yone strikes all enemies along a path for \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, teleporting behind the last champion hit and \\u003cstatus\\u003eKnocking Up\\u003c/status\\u003e victims towards Yone.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/YoneR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0777/ability_0777_R1.webm"}]},"875":{"id":875,"key":"Sett","name":"Sett","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Sett.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Pit Grit","description":"Sett\'s basic attacks alternate between left and right punch. Right punch is slightly stronger and faster. Sett also hates losing, gaining additional health regeneration based off of his missing health.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Sett_P.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0875/ability_0875_P1.webm"},"spells":[{"key":"Q","name":"Knuckle Down","description":"Sett\'s next two attacks deal additional damage based off of the target\'s max health. Sett also gains Move Speed while moving towards enemy champions.","max_rank":5,"range_burn":[0],"cooldown_burn":[9,8,7,6,5],"cost_burn":[0],"tooltip":"Sett itches for a fight, gaining \\u003cspeed\\u003e?% Move Speed\\u003c/speed\\u003e towards enemy champions for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eAdditionally Sett\'s next two Attacks deal an additional \\u003cphysicalDamage\\u003e? plus ? max Health physical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SettQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0875/ability_0875_Q1.webm"},{"key":"W","name":"Haymaker","description":"Sett passively stores damage he takes as Grit. On cast, Sett expends all stored Grit to gain a shield and punch an area, dealing true damage in the center and physical damage on the sides.","max_rank":5,"range_burn":[25000],"cooldown_burn":[18,16,15,13,12],"cost_burn":[0],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Sett stores ?% of damage taken as \\u003ckeywordMajor\\u003eGrit\\u003c/keywordMajor\\u003e, up to \\u003ckeywordMajor\\u003e?\\u003c/keywordMajor\\u003e. \\u003ckeywordMajor\\u003eGrit\\u003c/keywordMajor\\u003e decays quickly ? seconds after the damage was taken.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Sett consumes all \\u003ckeywordMajor\\u003eGrit\\u003c/keywordMajor\\u003e, gaining a \\u003cshield\\u003e?% Grit consumed Shield\\u003c/shield\\u003e decaying over ? seconds. Sett then delivers a massive punch, dealing \\u003ctrueDamage\\u003e? plus ? Grit consumed true damage\\u003c/trueDamage\\u003e to enemies in the center (max \\u003ctrueDamage\\u003e? damage\\u003c/trueDamage\\u003e). Enemies not in the center instead take \\u003cphysicalDamage\\u003ephysical damage\\u003c/physicalDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SettW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0875/ability_0875_W1.webm"},{"key":"E","name":"Facebreaker","description":"Sett pulls in all enemies on opposite sides of him, dealing damage and stunning them. If enemies were only on one side, they are slowed instead of stunned.","max_rank":5,"range_burn":[490],"cooldown_burn":[16,14,13,11,10],"cost_burn":[0],"tooltip":"Sett smashes enemies on either side of him into each other, dealing \\u003cphysicalDamage\\u003e? physical damage\\u003c/physicalDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. If Sett grabbed at least one enemy on each side, all enemies are \\u003cstatus\\u003eStunned\\u003c/status\\u003e for ? second.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SettE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0875/ability_0875_E1.webm"},{"key":"R","name":"The Show Stopper","description":"Sett carries an enemy champion through the air and slams them into the ground, dealing damage and slowing all enemies near where they land.","max_rank":3,"range_burn":[400],"cooldown_burn":[120,100,80],"cost_burn":[0],"tooltip":"Sett grabs an enemy champion and \\u003cstatus\\u003eSuppresses\\u003c/status\\u003e them as he carries them forward, then slams them into the ground, dealing \\u003cphysicalDamage\\u003e? plus ?% of the grabbed enemy\'s bonus Health physical damage\\u003c/physicalDamage\\u003e to surrounding enemies and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? second. Enemies take less damage the further they are from where Sett lands.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/SettR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0875/ability_0875_R1.webm"}]},"876":{"id":876,"key":"Lillia","name":"Lillia","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Lillia.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Dream-Laden Bough","description":"Hitting a champion or monster with a skill will deal additional max Health damage over time.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Lillia_Icon_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0876/ability_0876_P1.webm"},"spells":[{"key":"Q","name":"Blooming Blows","description":"Passively, Lillia gains stacking Move Speed when hitting enemies with spells. She can activate this to deal magic damage to nearby enemies, dealing extra true damage on the edge.","max_rank":5,"range_burn":[450],"cooldown_burn":[6,5,5,4,4],"cost_burn":[65],"tooltip":"\\u003cspellPassive\\u003ePassive:\\u003c/spellPassive\\u003e Lillia\'s Ability hits grant \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e for ? seconds, stacking up to ? times.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive:\\u003c/spellActive\\u003e Lillia whirls her censer, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, plus an additional \\u003ctrueDamage\\u003e? true damage\\u003c/trueDamage\\u003e at the outer edge.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LilliaQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0876/ability_0876_Q1.webm"},{"key":"W","name":"Watch Out! Eep!","description":"Lillia deals damage in a nearby area, dealing heavy damage in the center.","max_rank":5,"range_burn":[500],"cooldown_burn":[14,13,12,11,10],"cost_burn":[50],"tooltip":"Lillia winds up a huge strike, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. Enemies in the center take \\u003cmagicDamage\\u003e? damage\\u003c/magicDamage\\u003e instead.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LilliaW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0876/ability_0876_W1.webm"},{"key":"E","name":"Swirlseed","description":"Lillia hurls a seed that damages and slows those it lands on. If it doesn\'t hit anything, it will continue rolling until it hits a wall or target.","max_rank":5,"range_burn":[700],"cooldown_burn":[16],"cost_burn":[70],"tooltip":"Lillia lobs a swirlseed overhead, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e where it lands and revealing and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e them by ?% for ? seconds. If no enemies are hit, the seed rolls until it hits an enemy or collides with terrain.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LilliaE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0876/ability_0876_E1.webm"},{"key":"R","name":"Lilting Lullaby","description":"Lillia causes all enemies with Dream Dust on them to become Drowsy before falling asleep. Those enemies will take extra damage on being forcibly woken up.","max_rank":3,"range_burn":[1600],"cooldown_burn":[150,130,110],"cost_burn":[50],"tooltip":"Lillia causes all enemy champions with \\u003ckeywordMajor\\u003eDream Dust\\u003c/keywordMajor\\u003e to become \\u003cstatus\\u003eDrowsy\\u003c/status\\u003e for ? seconds. Afterward, they fall \\u003cstatus\\u003eAsleep\\u003c/status\\u003e for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eWhen awakened by damage, they take an additional \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/LilliaR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0876/ability_0876_R1.webm"}]},"887":{"id":887,"key":"Gwen","name":"Gwen","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Gwen.png","enemy_tips":["Gwen\'s Hallowed Mist shroud will only follow her once, after that it will dissipate when she leaves.","Gwen must hit something to recast her Ultimate, try to evade her between casts.","Gwen needs to attack a few times to set up her damage, so try to get the jump on her."],"ally_tips":["Always be Attacking - In addition to dealing bonus damage, Gwen\'s Attacks empower or reset many of her Abilities.","Gwen can still damage enemies outside her Hallowed Mists, especially with her Ultimate\'s range.","Some of Gwen\'s Abilities can apply her passive to multiple enemies, so aim them at groups to get maximum damage and healing."],"passive":{"name":"A Thousand Cuts","description":"Gwen\'s attacks deal bonus magic damage based on the targets health. She heals for a portion of the damage dealt to champions by this effect. ","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Gwen_Passive.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0887/ability_0887_P1.webm"},"spells":[{"key":"Q","name":"Snip Snip!","description":"Gwen snips her scissors in a cone up to 6 times dealing magic damage. Gwen deals true damage to units in the center and applies her passive to them on each snip.","max_rank":5,"range_burn":[450],"cooldown_burn":[6,5,5,4,3],"cost_burn":[40],"tooltip":"\\u003cspellPassive\\u003ePassive\\u003c/spellPassive\\u003e: Gwen gains 1 stack when she hits an enemy with an attack (max 4, lasts ? seconds).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003cspellActive\\u003eActive\\u003c/spellActive\\u003e: Consumes stacks. Gwen snips once for \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, snips again for each ammo consumed, and then snips a final time for \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e. \\u003cbr /\\u003e\\u003cbr /\\u003eThe center of each strikes deals \\u003ctrueDamage\\u003etrue damage\\u003c/trueDamage\\u003e instead and applies \\u003cspellName\\u003eA Thousand Cuts\\u003c/spellName\\u003e to enemies hit.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GwenQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0887/ability_0887_Q1.webm"},{"key":"W","name":"Hallowed Mist","description":"Gwen summons mist that protects her from enemies outside of it. She can only be targeted by enemies who enter the mist.","max_rank":5,"range_burn":[0],"cooldown_burn":[22,21,20,19,18],"cost_burn":[60],"tooltip":"Gwen summons the Hallowed Mist, making her Untargetable to all enemies (except towers) outside the zone for ? seconds or until she leaves it. While in the Mist, Gwen gains ? \\u003cscaleArmor\\u003eArmor\\u003c/scaleArmor\\u003e and \\u003cscaleMR\\u003eMagic Resist\\u003c/scaleMR\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003eGwen can \\u003crecast\\u003eRecast\\u003c/recast\\u003e this Ability once to call the Mist to her. This will automatically \\u003crecast\\u003eRecast\\u003c/recast\\u003e the first time Gwen attempts to leave the zone.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GwenW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0887/ability_0887_W1.webm"},{"key":"E","name":"Skip \'n Slash","description":"Gwen dashes a short distance then gains Attack Speed, attack range, and magic damage \\u003cOnHit\\u003eOn-Hit\\u003c/OnHit\\u003e for a few seconds. If she hits an enemy during that time, this Ability\'s cooldown is partially refunded. ","max_rank":5,"range_burn":[400],"cooldown_burn":[13,12,11,10,9],"cost_burn":[35],"tooltip":"Gwen dashes and empowers her Attacks for ? seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eEmpowered Attacks gain \\u003cattackSpeed\\u003e? Attack Speed\\u003c/attackSpeed\\u003e, \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e %i:OnHit% \\u003cOnHit\\u003eOn-Hit\\u003c/OnHit\\u003e, ? range, and the first one to hit an enemy refunds ?% of this Ability\'s Cooldown.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GwenE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0887/ability_0887_E1.webm"},{"key":"R","name":"Needlework","description":"Gwen hurls a needle that slows enemies hit, deals magic damage, and applies A Thousand Cuts to champions hit. \\u003cbr\\u003e\\u003cbr\\u003eThis ability can be cast up to two more times, with each cast throwing additional needles and dealing more damage. Gwen must hit an enemy between each cast to unlock the next one. ","max_rank":3,"range_burn":[1200],"cooldown_burn":[100,90,80],"cost_burn":[100],"tooltip":"\\u003cspellActive\\u003eFirst Cast:\\u003c/spellActive\\u003e Hurl a needle that deals \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e, \\u003cstatus\\u003eSlows\\u003c/status\\u003e by ?% for ? seconds, and applies \\u003cspellName\\u003eA Thousand Cuts\\u003c/spellName\\u003e to all enemies hit. If Gwen hits an enemy with an Attack or Ability within 6 second of casting this, she can \\u003crecast\\u003eRecast\\u003c/recast\\u003e it (up to 2 additional times).\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eSecond Cast:\\u003c/recast\\u003e Fire three needles to deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eThird Cast:\\u003c/recast\\u003e Fire five needles to deal \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/GwenR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0887/ability_0887_R1.webm"}]},"888":{"id":888,"key":"Renata","name":"Renata Glasc","image_url":"https://opgg-static.akamaized.net/images/lol/champion/Renata.png","enemy_tips":[],"ally_tips":[],"passive":{"name":"Leverage","description":"Renata\'s Attacks deal bonus damage and mark enemies. Renata\'s allies can damage marked enemies to deal bonus damage.","image_url":"https://opgg-static.akamaized.net/images/lol/passive/Renata_P.Renata.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0888/ability_0888_P1.webm"},"spells":[{"key":"Q","name":"Handshake","description":"Renata sends out a missile rooting the first enemy hit, and can recast the ability to throw the unit in a direction.","max_rank":5,"range_burn":[900],"cooldown_burn":[16],"cost_burn":[80],"tooltip":"Renata sends out a missile from her arm, \\u003cstatus\\u003eRooting\\u003c/status\\u003e the first enemy hit for ? second and dealing \\u003cscaleAP\\u003e?\\u003c/scaleAP\\u003e \\u003cmagicDamage\\u003emagic damage\\u003c/magicDamage\\u003e.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crecast\\u003eRecast:\\u003c/recast\\u003e Renata \\u003cstatus\\u003ePulls\\u003c/status\\u003e the enemy in a direction, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e to enemies they are thrown into and \\u003cstatus\\u003eStunning\\u003c/status\\u003e for ? seconds if the thrown enemy is a champion.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenataQ.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0888/ability_0888_Q1.webm"},{"key":"W","name":"Bailout","description":"Renata buffs an allied champion to fight harder, delaying their death and potentially saving them if they get a takedown.","max_rank":5,"range_burn":[800],"cooldown_burn":[28,27,26,25,24],"cost_burn":[80],"tooltip":"Renata infuses an ally champion, granting \\u003cattackSpeed\\u003e? Attack Speed\\u003c/attackSpeed\\u003e and \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e towards enemies, increasing to \\u003cattackSpeed\\u003e? Attack Speed\\u003c/attackSpeed\\u003e and \\u003cspeed\\u003e? Move Speed\\u003c/speed\\u003e over ? seconds. Takedowns refresh the duration of the buff.\\u003cbr /\\u003e\\u003cbr /\\u003eIf the ally would die, they instead return to full Health, which then decays over 3 seconds.\\u003cbr /\\u003e\\u003cbr /\\u003eIf they get a Takedown while decaying, they will be set to \\u003chealing\\u003e?% max Health\\u003c/healing\\u003e and stop decaying.\\u003cbr /\\u003e\\u003cbr /\\u003e\\u003crules\\u003eThe Champion\'s death can be delayed by healing or similar effects while in the decaying state, but cannot be prevented unless the Champion gets a Takedown. Champions can only delay their death once.\\u003c/rules\\u003e","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenataW.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0888/ability_0888_W1.webm"},{"key":"E","name":"Loyalty Program","description":"Renata sends out a pair of chemtech missiles, shielding allies and damaging and slowing enemies hit.","max_rank":5,"range_burn":[800],"cooldown_burn":[14,13,12,11,10],"cost_burn":[70,80,90,100,110],"tooltip":"Renata sends out a pair of chemtech missiles, dealing \\u003cmagicDamage\\u003e? magic damage\\u003c/magicDamage\\u003e and \\u003cstatus\\u003eSlowing\\u003c/status\\u003e surrounding enemies and enemies hit by 30% for ? seconds. Allies hit gain \\u003cshield\\u003e? Shield\\u003c/shield\\u003e for ? seconds.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenataE.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0888/ability_0888_E1.webm"},{"key":"R","name":"Hostile Takeover","description":"Renata sends out a wave of chemicals, causing any enemies hit to go Berserk.","max_rank":3,"range_burn":[2000],"cooldown_burn":[150,130,110],"cost_burn":[100],"tooltip":"Renata sends out a wave of chemicals, \\u003cstatus\\u003eBerserking\\u003c/status\\u003e enemies for ? seconds, causing them to Attack the nearest unit, prioritizing their allies.\\u003cbr /\\u003e\\u003cbr /\\u003eWhile \\u003cstatus\\u003eBerserk\\u003c/status\\u003e, enemies gain \\u003cattackSpeed\\u003e?% Attack Speed\\u003c/attackSpeed\\u003e.","image_url":"https://opgg-static.akamaized.net/images/lol/spell/RenataR.png","video_url":"https://d28xe8vt774jo5.cloudfront.net/champion-abilities/0888/ability_0888_R1.webm"}]}}'

# %%
json.find('id')
# Out:
# 7

# %%
# 챔피언별 통계:  css-1q0pqql exo2f213
html2 = BeautifulSoup(resp.text, 'html.parser')
html2
# Out:
# {"data":[{"champion_id":81,"play":2354715,"win":1177195,"lose":1177520,"kill":14818470,"death":12308672,"assist":16380854,"cs":409506794,"neutral_cs":26801468,"gold":27597924113,"pick_rate":0.3629,"ban_rate":0.11182255069276738,"ward":3131562},{"champion_id":145,"play":1471276,"win":729144,"lose":742132,"kill":11978605,"death":8216417,"assist":8708327,"cs":270891511,"neutral_cs":22610406,"gold":18958651944,"pick_rate":0.2268,"ban_rate":0.02406387358816002,"ward":2012166},{"champion_id":236,"play":1390190,"win":706335,"lose":683855,"kill":11327400,"death":7970229,"assist":8030624,"cs":254889577,"neutral_cs":20032173,"gold":17300089997,"pick_rate":0.2143,"ban_rate":0.40491030482319357,"ward":2314111},{"champion_id":104,"play":1104690,"win":543973,"lose":560717,"kill":7337448,"death":6052151,"assist":7035585,"cs":83124665,"neutral_cs":127667926,"gold":13661827765,"pick_rate":0.1703,"ban_rate":0.27897578901439263,"ward":3127747},{"champion_id":64,"play":1090727,"win":499817,"lose":590910
# ...

# %%
html2 = str(html2)
data2 = json.loads(html2)
# data2 = data2['data2']
# data2
# Out:
# []

# %%
data2 = pd.DataFrame(data2)
data2
# Out:
#      champion_id     play      win     lose      kill     death    assist  \
# 0             81  2354715  1177195  1177520  14818470  12308672  16380854
# 1            145  1471276   729144   742132  11978605   8216417   8708327
# 2            236  1390190   706335   683855  11327400   7970229   8030624
# 3            104  1104690   543973   560717   7337448   6052151   7035585
# 4             64  1090727   499817   590910   7350763   6215595   8835403
# ..           ...      ...      ...      ...       ...       ...       ...
# 155           77    64638    31594    33044    361113    336146    450001
# 156          526    57686    28542    29144     92678    375049    778379
# 157          427    35467    16711    18756     86421    161434    403734
# 158          136    32252    16247    16005    162488    179365    280760
# 159           72    31139    16005    15134    122230    143666    281705
#
#             cs  neutral_cs         gold  pick_rate  ban_rate     ward
# ...

# %%
data == data2
# Out:
#      champion_id  play   win  lose  kill  death  assist    cs  neutral_cs  \
# 0           True  True  True  True  True   True    True  True        True
# 1           True  True  True  True  True   True    True  True        True
# 2           True  True  True  True  True   True    True  True        True
# 3           True  True  True  True  True   True    True  True        True
# 4           True  True  True  True  True   True    True  True        True
# ..           ...   ...   ...   ...   ...    ...     ...   ...         ...
# 155         True  True  True  True  True   True    True  True        True
# 156         True  True  True  True  True   True    True  True        True
# 157         True  True  True  True  True   True    True  True        True
# 158         True  True  True  True  True   True    True  True        True
# 159         True  True  True  True  True   True    True  True        True
#
#      gold  pick_rate  ban_rate  ward
# 0    True       True      True  True
# ...
